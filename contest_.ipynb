# %% [markdown]
# #### 상세 페이지 스크래핑

# %%
import requests
from bs4 import BeautifulSoup
import os
import re
from urllib.parse import urljoin


sub_url='https://www.wevity.com'
main_url='https://www.wevity.com/?c=find&s=1&mode=soon&gub=1&cidx=21&gbn=viewok&gp=1&ix=43762'

res=requests.get(main_url)
html=res.text
res.status_code
soup = BeautifulSoup(html, 'html.parser')


view=soup.select_one("div.contest-detail div.tit-area span").text

view=re.sub('<.*?>','',view)
regex=re.compile(r'[조회수, \n\r\t:]')
view=regex.sub('', view)
# print(view)



img_url= soup.select_one("div.img div.thumb img")
#img_urls.append(img_url['src'])
img_link=urljoin(sub_url, img_url["src"])
contest_name=img_url["alt"]

# print(contest_name)
# print(img_link)

#-------------------------------------------------------------------
contest_dict={}
contest_dict['공모이름']=contest_name
contest_dict['이미지']=img_link
contest_dict['조회수']=view

for li_tag in soup.select('ul.cd-info-list li'):
#     print(li_tag)
    
    
    contest_field=li_tag.select_one('span.tit').text
    
    contest_val=re.sub('<span.*?>.*?</span>','',str(li_tag))
    contest_val=re.sub('<.*?>','',contest_val)
    regex=re.compile(r'[\n\r\t]')
    contest_val=regex.sub('', contest_val)
#     print(contest_field)
    if not contest_val.startswith('$(function()'):        
#         print(contest_val)
        contest_dict[contest_field]=contest_val
    
contest_dict
# Out:
# {'공모이름': '2020 경북콘텐츠코리아랩 콘텐츠 창작살롱 공모전',
#  '이미지': 'https://www.wevity.com/upload/contest/20200805035806_99605599.jpg',
#  '조회수': '3442',
#  '분야': '기획/아이디어, 광고/마케팅, 디자인/캐릭터/웹툰, 웹/모바일/플래시, 게임/소프트웨어, 문학/글/시나리오, 예체능/미술/음악',
#  '응모대상': '제한없음, 기타',
#  '주최/주관': '경상북도콘텐츠진흥원',
#  '후원/협찬': '',
#  '접수기간': '2020-08-05 ~ 2020-08-18',
#  '총 상금': '3천만원~1천만원',
#  '1등 상금': '250만원',
#  '홈페이지': 'https://www.gbckl.kr:2017/home2020/sub5/sub1.asp?mode=view&amp;aseq=1574',
#  '첨부파일': '파일없음'}

# %%
def detail_pg(main_url):
    import requests
    from bs4 import BeautifulSoup
    import os
    import re
    from urllib.parse import urljoin


    sub_url='https://www.wevity.com'
    res=requests.get(main_url)
    html=res.text
    res.status_code
    soup = BeautifulSoup(html, 'html.parser')
    
    
    view=soup.select_one("div.contest-detail div.tit-area span").text
    view=re.sub('<.*?>','',view)
    regex=re.compile(r'[조회수, \n\r\t:]')
    view=regex.sub('', view)
    # print(view)



    img_url= soup.select_one("div.img div.thumb img")
    img_link=urljoin(sub_url, img_url["src"])
    contest_name=img_url["alt"]


    contest_dict={}
    contest_dict['공모이름']=contest_name
    contest_dict['이미지']=img_link
    contest_dict['조회수']=view

    for li_tag in soup.select('ul.cd-info-list li'):

        contest_field=li_tag.select_one('span.tit').text

        contest_val=re.sub('<span.*?>.*?</span>','',str(li_tag))
        contest_val=re.sub('<.*?>','',contest_val)
        regex=re.compile(r'[\n\r\t]')
        contest_val=regex.sub('', contest_val)
        if not contest_val.startswith('$(function()'):        
            contest_dict[contest_field]=contest_val
    return contest_dict

# %%
# def make_json(content_list, fname):
#     import json
    
#     with open('data/{}.json'.format(fname),'w',encoding='utf8') as file:
#         json.dump(contest_list, file)

#     print('json file write 종료')

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
# https://www.wevity.com/?c=find&s=1&gub=1&cidx=21&sp=&sw=&gbn=list&mode=
# 게임
# https://www.wevity.com/?c=find&s=1&gub=1&cidx=22&sp=&sw=&gbn=list&mode=
# 과학공학
# https://www.wevity.com/?c=find&s=1&gub=1&cidx=88&sp=&sw=&gbn=list&mode=
# 취업창업



contest_game=[]
#게임
get_dict={}
for val in ['soon','ing']:
    main_url='https://www.wevity.com/?c=find&s=1&gub=1&cidx=21&sp=&sw=&gbn=list&mode={}'.format(val)
    print(main_url)
    res=requests.get(main_url)
    html=res.text
    print(res.status_code)
    soup = BeautifulSoup(html, 'html.parser')
    for a_tag in soup.select('ul.list div.tit a'):
        link=urljoin(main_url, a_tag['href'])
    #     print(link)
        get_dict=detail_pg(link)
        contest_game.append(get_dict)
print('게임')
print(contest_game)
print('-'*40)



# 과학공학
contest_science=[]
get_dict={}
for val in ['soon','ing']:
    main_url='https://www.wevity.com/?c=find&s=1&gub=1&cidx=22&sp=&sw=&gbn=list&mode={}'.format(val)
    print(main_url)
    res=requests.get(main_url)
    html=res.text
    print(res.status_code)
    soup = BeautifulSoup(html, 'html.parser')
    for a_tag in soup.select('ul.list div.tit a'):
        link=urljoin(main_url, a_tag['href'])
    #     print(link)
        get_dict=detail_pg(link)
        contest_science.append(get_dict)
print('과학공학')
print(contest_science)
print('-'*40)



# 취업창업
contest_job=[]
get_dict={}
for val in ['soon','ing']:
    main_url='https://www.wevity.com/?c=find&s=1&gub=1&cidx=88&sp=&sw=&gbn=list&mode={}'.format(val)
    print(main_url)
    res=requests.get(main_url)
    html=res.text
    print(res.status_code)
    soup = BeautifulSoup(html, 'html.parser')
    for a_tag in soup.select('ul.list div.tit a'):
        link=urljoin(main_url, a_tag['href'])
    #     print(link)
        get_dict=detail_pg(link)
        contest_job.append(get_dict)
print('취업창업')
print(contest_job)
print('-'*40)
# Out:
# https://www.wevity.com/?c=find&s=1&gub=1&cidx=21&sp=&sw=&gbn=list&mode=soon
# 200
# https://www.wevity.com/?c=find&s=1&gub=1&cidx=21&sp=&sw=&gbn=list&mode=ing
# 200
# 게임
# ...

# %%
print('게임')
print(contest_game)
print('-'*40)

print('과학공학')
print(contest_science)
print('-'*40)

print('취업창업')
print(contest_job)
print('-'*40)
# Out:
# 게임
# ...

# %%
import pymysql
import sqlalchemy
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("mysql+mysqldb://minji:"+"minji"+"@192.168.0.25:3306/poor_db", encoding="utf-8")
conn = engine.connect()

#contest_dict
contest_dict = {"contest_game": contest_game, "contest_science": contest_science, "contest_job": contest_job}

for table_name, contest in contest_dict.items():
    print("\n", table_name, "\n")
    contest_df = pd.DataFrame(columns=['공모이름', '이미지', '조회수', '분야', '응모대상', '주최/주관', '후원/협찬', '접수기간', '총 상금', '1등 상금', '홈페이지', '첨부파일'])
    
    for post in contest:
        obj = pd.Series(post)
        contest_df = contest_df.append(obj, ignore_index=True)
        print(post)
    
    contest_df.to_sql(name=table_name, con=engine, if_exists='replace', index=True, index_label='id')
# Out:
#  contest_game
#
# {'공모이름': '2020 경북콘텐츠코리아랩 콘텐츠 창작살롱 공모전', '이미지': 'https://www.wevity.com/upload/contest/20200805035806_99605599.jpg', '조회수': '3443', '분야': '기획/아이디어, 광고/마케팅, 디자인/캐릭터/웹툰, 웹/모바일/플래시, 게임/소프트웨어, 문학/글/시나리오, 예체능/미술/음악', '응모대상': '제한없음, 기타', '주최/주관': '경상북도콘텐츠진흥원', '후원/협찬': '', '접수기간': '2020-08-05 ~ 2020-08-18', '총 상금': '3천만원~1천만원', '1등 상금': '250만원', '홈페이지': 'https://www.gbckl.kr:2017/home2020/sub5/sub1.asp?mode=view&amp;aseq=1574', '첨부파일': '파일없음'}
# {'공모이름': 'Fintech AI 온라인 해커톤', '이미지': 'https://www.wevity.com/upload/contest/20200729023128_a66ee920.jpg', '조회수': '1201', '분야': '기획/아이디어, 웹/모바일/플래시, 게임/소프트웨어, 과학/공학, 취업/창업', '응모대상': '제한없음', '주최/주관': '앵커밸류 / 앵커밸류', '후원/협찬': 'ANW Foundation, SBCN, FABOT', '접수기간': '2020-07-27 ~ 2020-08-16', '총 상금': '1천만원이하', '1등 상금': '$3,000', '홈페이지': 'https://www.an-va.com/', '첨부파일': '파일없음'}
# ...
