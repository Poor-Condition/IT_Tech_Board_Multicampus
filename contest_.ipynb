# %% [markdown]
# #### 상세 페이지 스크래핑

# %%
import requests
from bs4 import BeautifulSoup
import os
import re
from urllib.parse import urljoin


sub_url='https://www.wevity.com'
main_url='https://www.wevity.com/?c=find&s=1&mode=soon&gub=1&cidx=21&gbn=viewok&gp=1&ix=43762'

res=requests.get(main_url)
html=res.text
res.status_code
soup = BeautifulSoup(html, 'html.parser')


view=soup.select_one("div.contest-detail div.tit-area span").text

view=re.sub('<.*?>','',view)
regex=re.compile(r'[조회수, \n\r\t:]')
view=regex.sub('', view)
# print(view)



img_url= soup.select_one("div.img div.thumb img")
#img_urls.append(img_url['src'])
img_link=urljoin(sub_url, img_url["src"])
contest_name=img_url["alt"]

# print(contest_name)
# print(img_link)

#-------------------------------------------------------------------
contest_dict={}
contest_dict['공모이름']=contest_name
contest_dict['이미지']=img_link
contest_dict['조회수']=view

for li_tag in soup.select('ul.cd-info-list li'):
#     print(li_tag)
    
    
    contest_field=li_tag.select_one('span.tit').text
    
    contest_val=re.sub('<span.*?>.*?</span>','',str(li_tag))
    contest_val=re.sub('<.*?>','',contest_val)
    regex=re.compile(r'[\n\r\t]')
    contest_val=regex.sub('', contest_val)
#     print(contest_field)
    if not contest_val.startswith('$(function()'):        
#         print(contest_val)
        contest_dict[contest_field]=contest_val
    
contest_dict
# Out:
# {'공모이름': '2020 경북콘텐츠코리아랩 콘텐츠 창작살롱 공모전',
#  '이미지': 'https://www.wevity.com/upload/contest/20200805035806_99605599.jpg',
#  '조회수': '4879',
#  '분야': '기획/아이디어, 광고/마케팅, 디자인/캐릭터/웹툰, 웹/모바일/플래시, 게임/소프트웨어, 문학/글/시나리오, 예체능/미술/음악',
#  '응모대상': '제한없음, 기타',
#  '주최/주관': '경상북도콘텐츠진흥원',
#  '후원/협찬': '',
#  '접수기간': '2020-08-05 ~ 2020-08-18',
#  '총 상금': '3천만원~1천만원',
#  '1등 상금': '250만원',
#  '홈페이지': 'https://www.gbckl.kr:2017/home2020/sub5/sub1.asp?mode=view&amp;aseq=1574',
#  '첨부파일': '파일없음'}

# %%
def detail_pg(main_url):
    import requests
    from bs4 import BeautifulSoup
    import os
    import re
    from urllib.parse import urljoin


    sub_url='https://www.wevity.com'
    res=requests.get(main_url)
    html=res.text
    res.status_code
    soup = BeautifulSoup(html, 'html.parser')
    
    
    view=soup.select_one("div.contest-detail div.tit-area span").text
    view=re.sub('<.*?>','',view)
    regex=re.compile(r'[조회수, \n\r\t:]')
    view=regex.sub('', view)
    # print(view)



    img_url= soup.select_one("div.img div.thumb img")
    img_link=urljoin(sub_url, img_url["src"])
    contest_name=img_url["alt"]


    contest_dict={}
    contest_dict['공모이름']=contest_name
    contest_dict['이미지']=img_link
    contest_dict['조회수']=view

    for li_tag in soup.select('ul.cd-info-list li'):

        contest_field=li_tag.select_one('span.tit').text

        contest_val=re.sub('<span.*?>.*?</span>','',str(li_tag))
        contest_val=re.sub('<.*?>','',contest_val)
        regex=re.compile(r'[\n\r\t]')
        contest_val=regex.sub('', contest_val)
        if not contest_val.startswith('$(function()'):        
            contest_dict[contest_field]=contest_val
    return contest_dict

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
# https://www.wevity.com/?c=find&s=1&gub=1&cidx=21&sp=&sw=&gbn=list&mode=
# 게임
# https://www.wevity.com/?c=find&s=1&gub=1&cidx=22&sp=&sw=&gbn=list&mode=
# 과학공학
# https://www.wevity.com/?c=find&s=1&gub=1&cidx=88&sp=&sw=&gbn=list&mode=
# 취업창업


#게임
contest_game=[]
game_dict={}
for val in ['soon','ing']:
    main_url='https://www.wevity.com/?c=find&s=1&gub=1&cidx=21&sp=&sw=&gbn=list&mode={}'.format(val)
    print(main_url)
    res=requests.get(main_url)
    html=res.text
    print(res.status_code)
    soup = BeautifulSoup(html, 'html.parser')
    for a_tag in soup.select('ul.list div.tit a'):
        link=urljoin(main_url, a_tag['href'])
    #     print(link)
        game_dict=detail_pg(link)
        game_dict['분류']='게임/소프트웨어'
        contest_game.append(game_dict)
print('게임')
print(contest_game)
print('-'*40)



# 과학공학
contest_sci=[]
sci_dict={}
for val in ['soon','ing']:
    main_url='https://www.wevity.com/?c=find&s=1&gub=1&cidx=22&sp=&sw=&gbn=list&mode={}'.format(val)
    print(main_url)
    res=requests.get(main_url)
    html=res.text
    print(res.status_code)
    soup = BeautifulSoup(html, 'html.parser')
    for a_tag in soup.select('ul.list div.tit a'):
        link=urljoin(main_url, a_tag['href'])
    #     print(link)
        sci_dict=detail_pg(link)
        sci_dict['분류']='과학/공학'
        contest_sci.append(sci_dict)
print('과학공학')
print(contest_sci)
print('-'*40)



# 취업창업
contest_job=[]
job_dict={}
for val in ['soon','ing']:
    main_url='https://www.wevity.com/?c=find&s=1&gub=1&cidx=88&sp=&sw=&gbn=list&mode={}'.format(val)
    print(main_url)
    res=requests.get(main_url)
    html=res.text
    print(res.status_code)
    soup = BeautifulSoup(html, 'html.parser')
    for a_tag in soup.select('ul.list div.tit a'):
        link=urljoin(main_url, a_tag['href'])
    #     print(link)
        job_dict=detail_pg(link)
        job_dict['분류']='취업/창업'
        contest_job.append(job_dict)
print('취업창업')
print(contest_job)
print('-'*40)
# Out:
# https://www.wevity.com/?c=find&s=1&gub=1&cidx=21&sp=&sw=&gbn=list&mode=soon
# 200
# https://www.wevity.com/?c=find&s=1&gub=1&cidx=21&sp=&sw=&gbn=list&mode=ing
# 200
# 게임
# [{'공모이름': '코딩대회 코드네임B_', '이미지': 'https://www.wevity.com/upload/contest/20200812013528_abe70dc8.jpg', '조회수': '1032', '분야': '게임/소프트웨어', '응모대상': '제한없음', '주최/주관': '브랜디', '후원/협찬': '', '접수기간': '2020-08-07 ~ 2020-08-26', '총 상금': '3천만원~1천만원', '1등 상금': '1,000만원', '홈페이지': 'https://goor.me/brandi', '첨부파일': '파일없음', '분류': '게임/소프트웨어'}, {'공모이름': '2020 식품안전나라 데이터 활용 아이디어·사례 공모전', '이미지': 'https://www.wevity.com/upload/contest/20200801030245_aefd0da6.jpg', '조회수': '9597', '분야': '기획/아이디어, 광고/마케팅, 논문/리포트, 웹/모바일/플래시, 게임/소프트웨어, 문학/글/시나리오', '응모대상': '제한없음', '주최/주관': '식품의약품안전처, 식품안전정보원', '후원/협찬': '', '접수기간': '2020-07-29 ~ 2020-10-25', '총 상금': '1천만원이하', '1등 상금': '300만원', '홈페이지': 'https://bit.ly/3jRiZeo', '첨부파일': '파일없음', '분류': '게임/소프트웨어'}, {'공모이름': '2020 은평구 청소년 e스포츠 대회', '이미지': 'https://www.wevity.com/upload/contest/20200822230050_255503ac.jpg', '
공모전', '이미지': 'https://www.wevity.com/upload/contest/20200616195949_942d02d0.jpg', '조회수': '1019', '분야': '취업/창업', '응모대상': '제한없음', '주최/주관': '라이나전성기재단', '후원/협찬': '', '접수기간': '2020-07-01 ~ 2020-09-25', '총 상금': '5천만원이상', '1등 상금': '1억원', '홈페이지': 'https://www.junsungki.com/lounge/notice-detail.do?id=86', '첨부파일': '제4회 라이나50+어워즈_공고문.pdf', '분류': '취업/창업'}, {'공모이름': '제8회 범정부 공공데이터 활용 창업경진대회', '이미지': 'https://www.wevity.com/upload/contest/20200523002707_40a074fa.jpg', '조회수': '1322', '분야': '취업/창업', '응모대상': '제한없음, 기타', '주최/주관': '행정안전부', '후원/협찬': '', '접수기간': '2020-02-01 ~ 2020-10-31', '총 상금': '5천만원이상', '1등 상금': '2,000만원', '홈페이지': 'http://www.startupidea.kr/', '첨부파일': '파일없음', '분류': '취업/창업'}]
# ----------------------------------------

# %%
import pymysql
import sqlalchemy
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("mysql+mysqldb://root:"+"root"+"@localhost:3307/poor_db", encoding="utf-8")
conn = engine.connect()

#contest_dict
contest_dict = {"contest":contest}

for table_name, contest in contest_dict.items():
    print("\n", table_name, "\n")
    contest_df = pd.DataFrame(columns=['공모이름','분류', '이미지', '조회수', '분야', '응모대상', '주최/주관', '후원/협찬', '접수기간', '총 상금', '1등 상금', '홈페이지', '첨부파일'])
    
    for post in contest:
        obj = pd.Series(post)
        contest_df = contest_df.append(obj, ignore_index=True)
        print(post)
    
    contest_df.to_sql(name=table_name, con=engine, if_exists='replace', index=True, index_label='id')
# Out:
#  contest
#
# {'공모이름': 'Estilo Town 초기창업팀 I.S.S.A.C. 모집', '이미지': 'https://www.wevity.com/upload/contest/20200824230417_8bf9630f.jpg', '조회수': '38', '분야': '취업/창업', '응모대상': '일반인, 대학생', '주최/주관': '이화여대 Estilo Town(캠퍼스타운) 사업단 / 이화여대, 서대문구', '후원/협찬': '서울특별시', '접수기간': '2020-08-03 ~ 2020-08-31', '총 상금': '1천만원이하', '1등 상금': '300만원', '홈페이지': 'https://campustown.seoul.go.kr/site/main/university/university_news/572?depId=dep10019', '첨부파일': 'Estilo Town(캠퍼스타운) I.S.S.A.C. 모집 요강 및 신청서 양식.zip'}
# {'공모이름': '한국항공우주연구원 2020년 항공우주기술1기반 예비창업자 지원 사업, STAR Exploration', '이미지': 'https://www.wevity.com/upload/contest/20200806001017_45a80d0b.jpg', '조회수': '687', '분야': '취업/창업', '응모대상': '일반인, 대학생', '주최/주관': '한국항공우주연구원 / 한국항공우주연구원', '후원/협찬': '', '접수기간': '2020-07-27 ~ 2020-08-26', '총 상금': '3천만원~1천만원', '1등 상금': '', '홈페이지': 'http://star-exploration.com', '첨부파일': '항공우주기술기반예비창업자지원사업.zip'}
# {'공모이름': '2020 마이데이터 사업모델 해커톤', '이미지': 'https://www.wevity.com/upload/contest/20200723032307_012e3840.jpg', '조회수': '840', '분야': '취업/창업', '응모대상': '제한없음', '주최/주관': 'SCG(Social Consulting Group)', '후원/협찬': '', '접수기간': '2020-07-01 ~ 2020-09-01', '총 상금': '1천만원이하', '1등 상금': '100만원', '홈페이지': 'http://scgjob.com/scgmydata', '첨부파일': '2020 마이데이터 사업모델 해커톤 제출서류_양식.hwp'}
