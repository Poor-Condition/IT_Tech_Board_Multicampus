# %%
#library import 하기

import requests
from bs4 import BeautifulSoup
import re
from urllib.parse import urljoin

# %%
# 클라우드 직업 스크래핑

job_list_cloud = []
page_num = 1
main_url = 'http://www.saramin.co.kr'

while True:
    url = f'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page={page_num}&cat_key=41704%2C40220&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=1'
    req_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    }
    html = requests.get(url, req_header).text
    soup = BeautifulSoup(html, 'html.parser')
    
    # 만약 더이상 페이지 리스트에 공고가 없을 경우 break
    if soup.select('div.list_body div.list_item') == []:
        break
    for tag in soup.select('div.list_body div.list_item'):
        company_dict = {}
        company_dict["기업명"] = tag.select('div.company_nm a span')[0].text
        company_dict["직무"] = tag.select('div.notification_info a span')[0].text
        company_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
        company_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
        # 근무형태가 빈칸인 직무들도 있음
        try:
            company_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
        except:
            company_dict["근무형태"] = ""
        try:    
            company_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
        except:
            company_dict["근무지"] = ""
        category_list = []
        # 분류는 여러가지가 있기 때문에 리스트 형태로 저장
        for item in tag.select('div.notification_info div.job_meta span span'):
            category_list.append(item.text)
        company_dict["분류"] = str(category_list)
        company_dict["분류필터"] = "cloud"
        
        detail_url = tag.select_one('div.notification_info a').attrs['href']
        full_detail_url = urljoin(main_url, detail_url)
        company_dict["상세링크"] = full_detail_url
        job_list_cloud.append(company_dict)
    page_num += 1
job_list_cloud
# Out:
# [{'기업명': 'appknot',
#   '직무': '앱-웹 기획/디자인/웹개발/iOS앱개발/마케팅',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['홍보·PR·사보', '마케팅·광고·분석']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38645181&adsCategoryItem=effect_bold&'},
#  {'기업명': '피플메이드',
#   '직무': '[교육플랫폼 피플메이드] 클래스 기획 MD 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['상품기획·MD', '마케팅·광고·분석']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38641511&adsCategoryItem=effect_bold&'},
#  {'기업명': '한국PMI컨설팅그룹',
#   '직무': 'java 기반 풀스택 개발자- 정규직 채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38616356'},
#  {'기업명': '(주)크리젠솔루션',
#   '직무': '[신입]크리젠솔루션 JAVA 개발자 모집',
#   '경력사항': '신입',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38639519'},
#  {'기업명': '(주)매드업',
#   '직무': '[매드업] 퍼포먼스마케터/개발자 외 대규모 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['인사·교육·노무', '마케팅·광고·분석']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596083&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)전우행복꿈사람사랑디허브',
#   '직무': '주니어/시니어웹 개발자 분을 (NodeJS 필수 React 권장) 모십니',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 종로구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38456117'},
#  {'기업명': '(주)경일게임아카데미',
#   '직무': '정부무료 게임회사 취업연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38644455&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)화이트스캔',
#   '직무': 'R&D 신입/경력 연구원 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서대문구',
#   '분류': "['총무·법무·사무', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38647365&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)아임웹',
#   '직무': '부문별 인재 채용(개발/마케팅/디자인)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서대문구',
#   '분류': "['사무보조·문서작성', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38645780&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)대우능력개발교육원',
#   '직무': '2020년 100% 국비무료 9~10월 개강 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '서울 중랑구',
#   '분류': "['총무·법무·사무', '사무보조·문서작성']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631354&adsCategoryItem=effect_bold&'},
#  {'기업명': '(학)창신대학교산학협력단',
#   '직무': '[국비무료] 사물인터넷[IoT]과 로봇운영자 과정 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '경남전체',
#   '분류': "['전기·전자·제어', '반도체·디스플레이·LCD']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38603781&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)테크데이타',
#   '직무': '[신입] 테크데이타 IT 기술 엔지니어 채용',
#   '경력사항': '신입',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['IT·솔루션영업', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599126'},
#  {'기업명': '유이수(주)',
#   '직무': '유이수와 함께하실 Frontend junior [개발연구소] 경력자 모집',
#   '경력사항': '2 ~ 5년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38656287'},
#  {'기업명': '휴먼교육센터학원',
#   '직무': '[전액무료]자바/파이썬 IT교육받고 취업하자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38510654&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)레뷰코퍼레이션',
#   '직무': '플랫폼그룹 부문별 신입/경력직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['캐릭터·만화·애니', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38541335&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)에이블정보',
#   '직무': '어플리케이션 개발자/웹개발자 정규직 경력 채용',
#   '경력사항': '5 ~ 15년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '게임·Game']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38615277&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)상록아이엔씨',
#   '직무': '[경험자 우대] Python/Linux AI 시스템 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 부천시',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601843&adsCategoryItem=effect_bold&'},
#  {'기업명': '(재)대구테크노파크',
#   '직무': '(재)대구테크노파크 각 부문 직원 채용 공고',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직',
#   '근무지': '대구 달서구',
#   '분류': "['기획·전략·경영', '의료기사']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38647327'},
#  {'기업명': '(주)푸드테크',
#   '직무': 'AWS/인프라 부문 경력사원 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631228&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)휴먼코아',
#   '직무': '[SK l 정규직ㅣ경력3년이상] 클라우드 부문 채용(솔루션/Cert)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38654096'},
#  {'기업명': 'JW홀딩스(주)',
#   '직무': 'JW그룹 4차 신입/경력 수시채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['해외영업·무역영업', '기획·전략·경영']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38650838'},
#  {'기업명': '창원문성대학교산학협력단',
#   '직무': '빅데이터 전문기술 교육과정 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '교육생',
#   '근무지': '경남 창원시 의창구',
#   '분류': "['회계·재무·세무·IR', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38611128'},
#  {'기업명': '패스트캠퍼스(주)',
#   '직무': '[패스트캠퍼스] 대규모 인재 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '마케팅·광고·분석']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38230007&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)슈프리마',
#   '직무': '[슈프리마] 풀스택 개발자 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38304984&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)디타임',
#   '직무': '디타임 프론트엔드 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38613023'},
#  {'기업명': '(주)유비케어',
#   '직무': 'GC녹십자헬스케어 가족사 각 직무별 신입/ 경력사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['기획·전략·경영', '회계·재무·세무·IR']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38616985'},
#  {'기업명': '교보라이프플래닛생명보험(주)',
#   '직무': '각 부문 경력 채용(영상, 데이터 분석/모델링, ITA, 리스크관리)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['기획·전략·경영', '금융·보험영업']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38628751&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)시지온',
#   '직무': '라이브리 서비스 광고 플랫폼 개발자 모집',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648078'},
#  {'기업명': '인큐솔루션(주)',
#   '직무': '[신입/경력]HW/SW 엔지니어 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['기술영업', '반도체·디스플레이·LCD']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38628664&adsCategoryItem=effect_bold&'},
#  {'기업명': '(유)딜리버리히어로 코리아',
#   '직무': '전 개발직군 대규모 채용중',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38476546'},
#  {'기업명': '(주)지이씨엘코리아',
#   '직무': 'GECL KOREA 신입/경력직 (MD, PHP, JAVA, 웹디자인, SA/SE, SEO)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 금천구',
#   '분류': "['해외영업·무역영업', '상품기획·MD']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596692'},
#  {'기업명': '포디리플레이코리아(주)',
#   '직무': '[4DReplay] 클라우드 서비스 및 Platform Back End 개발자 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38634954'},
#  {'기업명': '(주)이글루시큐리티',
#   '직무': '클라우드 엔지니어 (정규직)',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['ERP·시스템분석·설계', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38646025'},
#  {'기업명': '주식회사 하우투약',
#   '직무': '[알약물약] 프론트엔드 및 백엔드 서버(PHP) 개발자 모십니다',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38655564'},
#  {'기업명': '에스비아이코스머니(주)',
#   '직무': '2020년 하반기 각 부문별 직원채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38640756'},
#  {'기업명': '비비엠씨(주)',
#   '직무': '각 부문 신입 및 경력 모집 (시스템네트워크운영/콜센터/웹개발/영업)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['일반영업', '기술영업']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38638977'},
#  {'기업명': '(주)토패즈',
#   '직무': 'IoT/AI 부문 개발자 모집 (.NET/WEB/Firmware)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 화성시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631027'},
#  {'기업명': '(주)후이즈',
#   '직무': '㈜후이즈 쇼핑몰 각 부문별 신입/경력 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563638'},
#  {'기업명': '(주)코믹스브이',
#   '직무': '웹(PHP) 개발 및 플랫폼 개발팀원 관리 및 교육 시니어개발자',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574767'},
#  {'기업명': '(주)페칭',
#   '직무': 'Node.js 백엔드 개발자를 모십니다',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 관악구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38655386'},
#  {'기업명': '한국직업전문학교',
#   '직무': '[국비무료/수당지급] 빅데이터/응용 S/W 개발자 과정 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '서울 구로구',
#   '분류': "['그래픽디자인·CG', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38393122'},
#  {'기업명': '(주)지에스아이엘',
#   '직무': '(주)지에스아아엘 - 시스템개발팀 경력직 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567524'},
#  {'기업명': '(주)큐픽스',
#   '직무': '[신입/경력/전문연구요원] AWS/Ruby 백엔드엔지니어 (인프라)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586042'},
#  {'기업명': '원투씨엠(주)',
#   '직무': '소프트웨어 개발/서비스기획 경력 채용',
#   '경력사항': '5 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533730'},
#  {'기업명': '주식회사 해줌',
#   '직무': '발전량 예측 API 백엔드 개발자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526293'},
#  {'기업명': '(주)디타임',
#   '직무': '(주)디타임 백엔드개발자 경력직 채용',
#   '경력사항': '6 ~ 20년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565481'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 개발 경력자 대규모 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 송파구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561876'},
#  {'기업명': '(주) 하트게임즈',
#   '직무': '야근無) 웹/게임 서버 개발 경력자 채용 ( node.js node)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '게임·Game']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574743'},
#  {'기업명': '㈜트인시스템즈',
#   '직무': '서울 인프라 프로젝트 PM 경력 지원 모집',
#   '경력사항': '9 ~ 20년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38652559'},
#  {'기업명': '팀윙크(주)',
#   '직무': '[팀윙크] 핀테크 네이티브 개발자 (시니어) 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38651685'},
#  {'기업명': '(주)이젠아카데미인재개발원',
#   '직무': '[취업연수 국비교육]자바/파이썬/빅데이터/웹/영상/건축',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['캐릭터·만화·애니', '광고·시각디자인']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=36825236'},
#  {'기업명': '주식회사 코드베르그',
#   '직무': '코드베르그 Back-end 개발부문 모집 (PHP or Node.js)',
#   '경력사항': '3 ~ 6년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38434985'},
#  {'기업명': '(주)티시스',
#   '직무': '태광그룹 ㈜티시스 경력사원 공개채용 (IT, 부동산, 건설, 레저)',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['AS·서비스·수리', '레저·스포츠']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649618'},
#  {'기업명': '켈리서비스 유한회사',
#   '직무': '[한국화웨이/영어or중국어] IT Engineer (서버유지보수, ICT)',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 중구',
#   '분류': "['기술영업', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38584624'},
#  {'기업명': '주식회사 단비',
#   '직무': 'JAVA / ERP / AI / 머신러닝 / Go / Python / MES',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 해운대구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38377404'},
#  {'기업명': '제이피스 주식회사',
#   '직무': '[행정/공공기관] 한국정보통신진흥협회 유통망기반팀 사원 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 강남구',
#   '분류': "['총무·법무·사무', '사무보조·문서작성']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649622'},
#  {'기업명': '제이피스 주식회사',
#   '직무': '[AI/공공기관] 한국정보통신진흥협회 데이터전략팀 사원 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 강남구',
#   '분류': "['총무·법무·사무', '사무보조·문서작성']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649589'},
#  {'기업명': '(주)중고나라',
#   '직무': '[중고나라] 개발 부문 전문가 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38617768'},
#  {'기업명': '(주)판도라티비',
#   '직무': '[ 코박(COBAK) ]  Back-end 개발자 채용(Python / django)',
#   '경력사항': '1 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38636485'},
#  {'기업명': '(주)판도라티비',
#   '직무': '[ 코박(COBAK) ]  Back-end 개발자 채용(Java / Spring)',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649299'},
#  {'기업명': '캐시워크',
#   '직무': '캐시워크와 함께 걸어갈 Node.js 서버 개발자님을 찾습니다',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649262'},
#  {'기업명': '(주)넷코아테크',
#   '직무': '각 부문 신입/경력 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['총무·법무·사무', '인사·교육·노무']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38640774'},
#  {'기업명': '(주)보고플레이',
#   '직무': '[Live 커머스 플랫폼] PD,MD,마케팅,CS,JAVA,iOS/Android앱개발',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['상품기획·MD', '홍보·PR·사보']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569631'},
#  {'기업명': '(주)푸드테크',
#   '직무': 'IT부문 신입 및 경력사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 강남구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526283'},
#  {'기업명': '(주)텐일레븐',
#   '직무': '[텐일레븐] 2020 경력 개발자 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38545582'},
#  {'기업명': '코코네(주)',
#   '직무': '(COCONE) 인프라 엔지니어 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648353'},
#  {'기업명': '주식회사 미로',
#   '직무': '(주)미로 IoT & 스마트홈 개발자채용 (신입/경력/전문연구요원)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '인천 연수구',
#   '분류': "['전기·전자·제어', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38559164'},
#  {'기업명': 'KOG',
#   '직무': '[INFRA팀] 게임 서비스 및 사내 업무 인프라 구축(개발) / 운영',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대구 중구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38641643'},
#  {'기업명': '(주)웰데이타시스템',
#   '직무': 'H자동차그룹 Car Cloud(오픈스택+쿠버네티스) 서비스 운영',
#   '경력사항': '3 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579660'},
#  {'기업명': '컴즈(주)',
#   '직무': 'S/W Test & QA Engineer 채용의 件',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 구로구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38646245'},
#  {'기업명': '주식회사 오픈소스컨설팅',
#   '직무': '[오픈소스컨설팅] 각 부문 엔지니어 채용(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '하드웨어·소프트웨어']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38605104'},
#  {'기업명': '(주)위메프',
#   '직무': '[보안]클라우드 보안운영 담당자(정규직)',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37608770'},
#  {'기업명': '(주)위메프',
#   '직무': '[개발]위메프오 DevOps Engineer(정규직)',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38644560'},
#  {'기업명': '(주)위메프',
#   '직무': '[개발]위메프 시스템엔지니어(정규직)',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38643798'},
#  {'기업명': '(주)센드버드코리아',
#   '직무': '[실리콘밸리 기업] 클라우드 데이터 아키텍트 (DA / NoSQL)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38642318'},
#  {'기업명': '라인파이낸셜플러스(주)',
#   '직무': '[LINE BIZ PLUS/LINE FINANCIAL] Developer Recruitment',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38630968'},
#  {'기업명': '(주)팡게임',
#   '직무': '시스템관리자(SE) 경력직 모집',
#   '경력사항': '2 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38641759'},
#  {'기업명': '(주)시지온',
#   '직무': '어트랙트 서비스 자바 백엔드 개발자 모집',
#   '경력사항': '5 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38641178'},
#  {'기업명': '네오위즈',
#   '직무': '[네오위즈] 각 부문 신입 / 경력자모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['회계·재무·세무·IR', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38447372'},
#  {'기업명': '(주)피플리',
#   '직무': '워라밸이 실현되는 곳에서 즐겁게 일할 iOS 경력 개발지',
#   '경력사항': '3 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38639559'},
#  {'기업명': '㈜해커스교육그룹',
#   '직무': '2020년 해커스 교육그룹 [신입/경력] 각 부문별 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38369849'},
#  {'기업명': '한국직업능력교육원 안산',
#   '직무': '경기/시흥・안산/군포 국비무료 취업연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '경기 안산시 단원구',
#   '분류': "['회계·재무·세무·IR', '생산관리·품질관리']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38527236&adsCategoryItem=effect_bold&'},
#  {'기업명': '한국산업단지공단',
#   '직무': '20년 하반기 신입직원/고졸채용형인턴/체험형청년인턴 모집 공고',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '대구 달서구',
#   '분류': "['총무·법무·사무', '회계·재무·세무·IR']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596493'},
#  {'기업명': '(주)인터웹',
#   '직무': '4차산업혁명 기반의 신사업 참여 개발자 모집',
#   '경력사항': '경력 6년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38634157'},
#  {'기업명': '나무기술(주)',
#   '직무': 'Cloud 엔지니어 / 프리세일즈&컨설팅 / 웹 애플리케이션 개발',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38633878'},
#  {'기업명': '(주)코오롱',
#   '직무': '2020년 코오롱그룹 8월 정기공채',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 과천시',
#   '분류': "['보안·경호·안전', '회계·재무·세무·IR']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38615757'},
#  {'기업명': '(주)락플레이스',
#   '직무': 'Azure 엔지니어 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631776'},
#  {'기업명': '컴즈(주)',
#   '직무': 'S/W QA & Test Engineer 채용의 件',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 구로구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631502'},
#  {'기업명': '주식회사 메디칼파크',
#   '직무': '응용소프트웨어 프로그래머 연구원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 용인시 수지구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38353503'},
#  {'기업명': '(주)민병철교육그룹',
#   '직무': '[민병철유폰] AWS 시스템 엔지니어 (총 경력 5년 이상)',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38629966'},
#  {'기업명': '굿어스데이터(주)',
#   '직무': 'Cloud 엔지니어 (경력 3년 이상)',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38629602'},
#  {'기업명': '피이지코리아',
#   '직무': '2020 하반기 백엔드 개발자, UX/UI디자이너 채용 (신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 화성시',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38522882'},
#  {'기업명': '(주)립페이',
#   '직무': '[정규직] 서비스 플랫폼(백엔드) 개발자 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '통신·모바일']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560508'},
#  {'기업명': '호스트웨이아이디씨(주)',
#   '직무': '[정규직] 시스템 엔지니어 모집(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582146'},
#  {'기업명': '(주)지에스아이티엠',
#   '직무': '2020년 하반기 GS ITM 경력사원 공개채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587357'},
#  {'기업명': '한국전자통신연구원',
#   '직무': '2020년 3차 박사후연수연구원 및 위촉연구원 공개채용',
#   '경력사항': '경력무관',
#   '학력': '석사↑',
#   '근무형태': '계약직',
#   '근무지': '대전 유성구',
#   '분류': "['화학·에너지', '반도체·디스플레이·LCD']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590666'},
#  {'기업명': '펍지(주)',
#   '직무': '펍지㈜ 각 부문별 수시 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['총무·법무·사무', '인사·교육·노무']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38542347'},
#  {'기업명': '(주)안랩',
#   '직무': '2020 하반기 안랩 연구소 신입사원 공개채용',
#   '경력사항': '신입',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578654'},
#  {'기업명': '(주)이노그리드',
#   '직무': '2020 하반기 클라우드 전문기업 이노그리드 신입·경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['상품기획·MD', '홍보·PR·사보']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38415519'},
#  {'기업명': '㈜게임스프링',
#   '직무': 'Node.js 게임서버 프로그래머 (병역특례 가능 - 보충역, 전직)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38604925'},
#  {'기업명': '(주)코레이즈',
#   '직무': '[코레이즈] IT네트워크/납품·영업/클라우드/인프라 부문별 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 성동구',
#   '분류': "['IT·솔루션영업', '하드웨어·소프트웨어']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38620413'},
#  {'기업명': '(주)넥스클라우드',
#   '직무': 'Cloud Platform Consulting Manager',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터', '경영분석·컨설턴트']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38619252'},
#  {'기업명': '(주)더블다운인터액티브',
#   '직무': '웹/게임서버 개발자(경력), 클라이언트 개발자(신입/경력) 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '게임·Game']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580038'},
#  {'기업명': '㈜아이티언',
#   '직무': '보안 솔루션 및 서비스 운영 엔지니어(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38414809'},
#  {'기업명': '에스지에이(주)',
#   '직무': 'SGA임베디드-Cloud팀] 클라우드(Azure, M365) 기술지원 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38611017'},
#  {'기업명': '(주)두댓',
#   '직무': '서버 프로그래머 경력직 채용',
#   '경력사항': '경력 10년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38532714'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 2020년 개발 경력자 대규모 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37872627'},
#  {'기업명': '(주)월드스폰',
#   '직무': '웹 서비스 유지보수 및 기획자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552512'},
#  {'기업명': '(주)해시스냅',
#   '직무': '백엔드(Back-end) 개발자 채용',
#   '경력사항': '3 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38606564'},
#  {'기업명': '(주)에이프릴세븐',
#   '직무': '[스타트업] 서버개발자 채용 공고',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38585353'},
#  {'기업명': '(주)샤픈고트',
#   '직무': '[샤픈고트] 프론트 앤드 개발자 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 해운대구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38611187'},
#  {'기업명': '조이시티',
#   '직무': '[JOYCITY] 플랫폼 서버 개발자 모집 (경력3년)',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38519268'},
#  {'기업명': '㈜안랩',
#   '직무': '[안랩] Cloud System Architect 경력직 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38609745'},
#  {'기업명': '아토리서치(주)',
#   '직무': '[아토리서치]전문연구요원(병역특례) 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38545903'},
#  {'기업명': '에스피테크놀러지(주)',
#   '직무': '에스피테크놀러지(주) Java 개발자 경력직 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 관악구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38605396'},
#  {'기업명': '디딤365 주식회사',
#   '직무': 'AWS 클라우드 기술영업 신입사원 모집',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['IT·솔루션영업', '기술영업']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38523449'},
#  {'기업명': '디딤365 주식회사',
#   '직무': '클라우드 및 시스템 엔지니어 신입/경력(청년내일채움공제 가능)',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575060'},
#  {'기업명': '디딤365 주식회사',
#   '직무': '멀티 클라우드 포털 개발 신입/경력사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575121'},
#  {'기업명': '스마일샤크',
#   '직무': '[신입] AWS 솔루션 아키텍트(SA)를 스마일샤크팀으로 모십니다.',
#   '경력사항': '신입',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586155'},
#  {'기업명': '(주)온빛',
#   '직무': '병원 플랫폼 개발자 모집 (안드로이드/iOS/백엔드) (연봉 3000~)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대구 북구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38534946'},
#  {'기업명': '(주)케어랩스',
#   '직무': '병원갈땐 굿닥) 백엔드서버 개발자 대규모 채용',
#   '경력사항': '5 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575280'},
#  {'기업명': '(주)웅진씽크빅',
#   '직무': "(주)웅진씽크빅 '빅데이터 개발/엔지니어' 모집",
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38606876'},
#  {'기업명': '(주)이지다이아텍',
#   '직무': '[기업부설연구소] 응용소프트웨어 개발자 경력직원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552827'},
#  {'기업명': '(주)여우전자',
#   '직무': '여우전자 하반기 신규채용 모집 공고',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['마케팅·광고·분석', '일반영업']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574212'},
#  {'기업명': '(주)핀크럭스',
#   '직무': '[부산] 서비스를 함께 만들어 가실 웹개발자를 찾습니다.',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 부산진구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562265'},
#  {'기업명': '(주)테크데이타',
#   '직무': '[경력] 테크데이타 - AWS 클라우드 엔지니어(SA) 모집',
#   '경력사항': '2 ~ 9년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 용산구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598106'},
#  {'기업명': '리디안솔루션(주)',
#   '직무': 'SAP (Cloud Platform/ CPI / ABAP) 관련 신입, 경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598068'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 네트워크 운영 및 정보보호 담당 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38333581'},
#  {'기업명': '(주)아미크',
#   '직무': '[벤처/강소기업] Cloud Product(AWS) 기획 및 개발 채용',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38593601'},
#  {'기업명': '(주)직스엔닥스',
#   '직무': '[개발팀](웹/앱)우수한 React 프론트엔드 개발자 채용 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592735'},
#  {'기업명': '베스핀글로벌(주)',
#   '직무': 'Software QA 채용(경력 3년이상)',
#   '경력사항': '3 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592386'},
#  {'기업명': '주식회사 위주',
#   '직무': '[주식회사위주]놀러와요시장 어플 서버개발 경력직채용(7년이상)',
#   '경력사항': '경력 7년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38466824'},
#  {'기업명': '(주)크로센트',
#   '직무': '클라우드 엔지니어 및 아키텍트 (신입/경력) 정규직 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591760'},
#  {'기업명': '(주)닥플',
#   '직무': '[주식회사 닥플] B2C 서비스 개발 PL 채용',
#   '경력사항': '경력 7년↑',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589692'},
#  {'기업명': '굿어스㈜',
#   '직무': 'Cisco SD-WAN 엔지니어 (경력 2년 이상)',
#   '경력사항': '2 ~ 7년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587238'},
#  {'기업명': '(주)아모레퍼시픽',
#   '직무': "[경력] '20년 AMOREPACIFIC 경력채용_플랫폼 Back-end 개발",
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569683'},
#  {'기업명': '(주)아모레퍼시픽',
#   '직무': "[경력] '20년 AMOREPACIFIC 경력채용_플랫폼 기술 PM",
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570239'},
#  {'기업명': '(주)아톤',
#   '직무': '[ATON] 신규 서비스 개발팀장 / 서버개발 경력 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38553981'},
#  {'기업명': '주식회사 포티투마루',
#   '직무': '[포티투마루] 인공지능 프론트엔드 개발 채용(경력)',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 관악구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580784'},
#  {'기업명': '카이스컴퍼니',
#   '직무': 'React js, AWS, IoT外 1개 부문 개발자 채용 - 정규직&계약직',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '충북 청주시 서원구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580459'},
#  {'기업명': '주식회사 오파테크',
#   '직무': '서버개발 정규직 모집 공고(경력)',
#   '경력사항': '3 ~ 6년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38483345'},
#  {'기업명': '(주)웰데이타시스템',
#   '직무': '[엔클라우드24] [클라우드&IDC 기술영업/컨설팅/ 공공영업] 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['IT·솔루션영업', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579626'},
#  {'기업명': '(주)웰데이타시스템',
#   '직무': '프런트앤드 앱/웹 자바(JAVA) PHP, 클라우드 서비스 개발자 모집',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579619'},
#  {'기업명': '(주)피처링',
#   '직무': '(정규직) 서버 및 웹 Backend 웹개발자를 채용합니다.',
#   '경력사항': '2 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 연수구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563022'},
#  {'기업명': '(주)그로브소프트',
#   '직무': '㈜그로브소프트 2020 하반기 경력직 추가 채용(기획, 개발, 퍼블리셔)',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38566074'},
#  {'기업명': '라인게임즈 주식회사',
#   '직무': '[라인게임즈] 기술PM 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574275'},
#  {'기업명': '주식회사오션라이트에이아이',
#   '직무': '서버·네트워크·보안(서버관리&AWS外 3개 부문) 채용합니다',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '대구 북구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38571517'},
#  {'기업명': '스마일샤크',
#   '직무': '[경력] AWS 솔루션 아키텍트(SA)를 스마일샤크팀으로 모십니다.',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38550815'},
#  {'기업명': '(주)웨어포인트',
#   '직무': '(잠실/운영)시스템 엔지니어(SE/TA) 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직 · 프리랜서',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570404'},
#  {'기업명': '(주)엔픽셀',
#   '직무': '[인프라팀] 클라우드 엔지니어 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38413525'},
#  {'기업명': '(주)에스오월드테크놀리지',
#   '직무': '서버관리자(AWS) 채용',
#   '경력사항': '2 ~ 5년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '인턴직',
#   '근무지': '서울 영등포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38568005'},
#  {'기업명': '삼양데이타시스템㈜',
#   '직무': '그룹 Infra 분야 운영 인력 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38550753'},
#  {'기업명': '오픈플랜(주)',
#   '직무': '[오픈플랜] back-end Developer 우수 인재를 모십니다.',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38505378'},
#  {'기업명': '베스핀글로벌(주)',
#   '직무': 'BigData 전문인력 채용(경력 5년 이상)',
#   '경력사항': '5 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38566513'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 구글클라우드 부문 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['일반영업', 'IT·솔루션영업']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38409477'},
#  {'기업명': '(주)앨리스헬스케어',
#   '직무': '백엔드(Back-end) 개발자(경력)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565409'},
#  {'기업명': '(주)이카운트',
#   '직무': '㈜이카운트 시스템관리자(SA팀) 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565193'},
#  {'기업명': '쿠팡 주식회사',
#   '직무': '[쿠팡페이] System Engineer',
#   '경력사항': '경력 8년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38398255'},
#  {'기업명': '㈜지에스아이티엠',
#   '직무': 'SE/NE/DBA 경력사원 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38519641'},
#  {'기업명': '(주)크리에이트코리아',
#   '직무': '백엔드 개발자/ 웹 & 모바일 개발자 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중랑구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563318'},
#  {'기업명': '대한상공회의소 광주인력개발원',
#   '직무': '2020년도 국비 기술교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '광주 광산구',
#   '분류': "['기계·기계설비', '전기·전자·제어']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38404367'},
#  {'기업명': '대한상공회의소 충남인력개발원',
#   '직무': '4차산업/전기전자/기계설계/자동화 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '충남전체',
#   '분류': "['전기·전자·제어', '설계·CAD·CAM']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38445379'},
#  {'기업명': '오케스트로(주)',
#   '직무': '클라우드연구소 PaaS 엔지니어',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552496'},
#  {'기업명': '매드업',
#   '직무': '[테크사업부] 백엔드 개발자 채용',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38553452'},
#  {'기업명': '(주) 딥노이드',
#   '직무': '인공지능, 의료영상 연구원 모집[경력, 병역특례 지원가능]',
#   '경력사항': '신입 · 경력',
#   '학력': '석사↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 구로구',
#   '분류': "['인공지능(AI)·빅데이터', '연구소·R&D']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38362204'},
#  {'기업명': '(주)씨알에스큐브',
#   '직무': 'AWS(DevOps) 엔지니어 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
# ...
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38614729'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '그룹 HR 공유 Infra HRIS 시스템 구축 SaaS 솔루션 클라우드',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38613919'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '렌탈 시스템 구축 프로젝트 PL업무 수행 Spring framework',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38613908'},
#  {'기업명': '스펙트럼파트너스',
#   '직무': '클라우드 기획자 경력사원 채용 - 정규직',
#   '경력사항': '8 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38613907'},
#  {'기업명': '(주)에이치앤티어세스',
#   '직무': '화장품 회사 인프라 엔지니어',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '컨텐츠·사이트운영']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38611092'},
#  {'기업명': '제이피스 주식회사',
#   '직무': 'LG전자 본사 AI/Dig Data 관련 사무보조 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 강서구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38609512'},
#  {'기업명': '(주)잡뉴스솔로몬서치',
#   '직무': '통합보안관리솔루션 클라우드 엔지니어 (대리-차장), 송파구',
#   '경력사항': '4 ~ 14년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['하드웨어·소프트웨어', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601487'},
#  {'기업명': '제이에이씨리크루트먼트코리아(주)',
#   '직무': '[일본계] IT 회사 엔지니어 담당(주임~대리)',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601390'},
#  {'기업명': '(주)인터비즈시스템',
#   '직무': '[네오플라이] 블록체인 시스템 엔지니어 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38585362'},
#  {'기업명': '(주)HR컨설팅그룹',
#   '직무': '[대기업계열 it회사] AWS CLOUD운영',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38588581'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '헤딩150만원 [국내대기업 IT계열사] Cloud Data Engineer',
#   '경력사항': '6 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594371'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '헤딩150만원[국내대기업 IT계열사] Cloud Application Architect',
#   '경력사항': '6 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594361'},
#  {'기업명': '(주)브이비젼',
#   '직무': '[글로벌벤처그룹] React-Native 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594227'},
#  {'기업명': '(주)브이비젼',
#   '직무': '[글로벌벤처그룹] Back-end 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591980'},
#  {'기업명': '에이치알코어스',
#   '직무': '클라우드 기획(계약직/ 상암동 근무)',
#   '경력사항': '경력 7년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591628'},
#  {'기업명': '커리어커넥트(주)',
#   '직무': '대형금융그룹 IT운영팀원 (WAS / Cloud 금융권 경력자) 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38588560'},
#  {'기업명': '(주)에이치알맨파워그룹',
#   '직무': '블록체인 개발/운영 CTO 또는 Technical Leader 경력직 모집',
#   '경력사항': '경력 12년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586629'},
#  {'기업명': '(주)씨앤에이코리아',
#   '직무': '[코스닥상장 중견그룹사] IT인프라(AWS) 담당 과장급 채용',
#   '경력사항': '7 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38585802'},
#  {'기업명': '브리스캔영어쏘시에이츠(주)',
#   '직무': 'TOP 금융사 대기업 - ICT(신기술) 컨설팅',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583835'},
#  {'기업명': '맨쉬 컨설팅 주식회사',
#   '직무': '종합 헬스케어 플랫폼사 (CTO or Technical Leader)',
#   '경력사항': '경력 10년↑',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582813'},
#  {'기업명': '로버트월터스코리아(주)',
#   '직무': '[글로벌/IT/엔지니어] DevOps/System Engineer',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579081'},
#  {'기업명': 'search square',
#   '직무': 'SW개발 (IoT기업 Backend 개발)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578539'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '(가전 및 생활용품 기업) 데이터 엔지니어',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38620398'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '(가전 및 생활용품 기업) 모바일 앱(안드로이드) 개발자',
#   '경력사항': '경력 7년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38620803'},
#  {'기업명': '피플워크(주)',
#   '직무': '인공지능 딥러닝기반 영상인식 처리 알고리즘 개발',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '통신·모바일']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38626706'},
#  {'기업명': '피플워크(주)',
#   '직무': 'AI(인공지능) 딥러닝기반 영상인식 처리 알고리즘 개발',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '통신·모바일']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38584287'},
#  {'기업명': '(주)스카우트',
#   '직무': '글로벌기업 카테고리매니저 대리과장급',
#   '경력사항': '7 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653342'},
#  {'기업명': '(주)헬로서치',
#   '직무': '(대기업) 인프라보안 담당자 채용',
#   '경력사항': '8 ~ 14년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653288'},
#  {'기업명': '(주)헬로서치',
#   '직무': '[대기업 IT사] 빅데이터 엔지니어 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653269'},
#  {'기업명': '(주)탑앤스카우트',
#   '직무': '[AI, IoT] 공공프로젝트 PM 충원',
#   '경력사항': '경력 8년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601402'},
#  {'기업명': '(주)키스템프',
#   '직무': '[양천구/월212만/신입가능]유명 외국계 승강기 기업 품질데이터',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '파견직',
#   '근무지': '서울 양천구',
#   '분류': "['전기·전자·제어', '생산관리·품질관리']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38616124'},
#  {'기업명': '피플워크(주)',
#   '직무': 'MSA클라우드 기반 사내시스템 웹개발[대기업]',
#   '경력사항': '4 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38620149'},
#  {'기업명': '피플워크(주)',
#   '직무': 'AI(인공지능) 딥러닝기반 영상인식 처리 알고리즘 개발(4년-12년',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '통신·모바일']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38614076'},
#  {'기업명': '(주)유앤파트너즈',
#   '직무': '[대기업계열] 데이터 전략 컨설턴트 / AI사업부  팀장外',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38639110'},
#  {'기업명': '(주)드림잡스쿨',
#   '직무': 'AI코딩스쿨 방과후 학교 프로그램 개발 관리자 모집',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '광주 광산구',
#   '분류': "['퍼블리싱·UI개발', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38633598'},
#  {'기업명': '굿커리어',
#   '직무': '중견기업 머신비젼장비 SW개발 팀원,팀장급 구함(굿커리어)',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576789'},
#  {'기업명': '구루넷',
#   '직무': '웹 개발자 모집',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38622026'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592716'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Digital Healthcare 빅데이터 플랫폼 전문가',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592696'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Battery 생산지원시스템(QMS/SCM/EMS) 구축 및 Global 확산/운영',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 동구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592694'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자 SAP',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592662'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 java',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592671'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자 시스템통합 IT 아웃소싱',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38620372'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Digital Healthcare 빅데이터 플랫폼 전문가 유전체 분석',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38620354'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38613915'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 Java, Oracle',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38613912'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Digital Healthcare 플랫폼 서비스 기획원 신약개발 상장사',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38613897'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Digital Healthcare 플랫폼 서비스 기획원',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38607444'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Battery 생산지원시스템(QMS/SCM/EMS) 구축',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 동구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38607442'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '[삼성물산/연봉상위] 모바일 앱 및 웹 운영 경력 개발자 채용',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591901'},
#  {'기업명': '(주)브이비젼',
#   '직무': '[글로벌벤처그룹] front-end 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38588743'},
#  {'기업명': '(주)피플케어코리아',
#   '직무': 'Partner Sales Enablement Manager (SW/Solution)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['IT·솔루션영업', '영업기획·관리·지원']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583253'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '[삼성물산/잠실역] 모바일 앱 및 웹 운영 경력 개발자 채용',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570689'},
#  {'기업명': '에이피써치',
#   '직무': '세일즈포스(Salesforce) 개발자 (대리-과장급) / 패션 상장기업',
#   '경력사항': '3 ~ 8년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578164'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '[삼성물산/잠실] 모바일 앱 및 웹 운영 경력 개발자 채용',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38508132'}]

# %%
# 파이썬 직업 스크래핑

job_list_python = []
page_num = 1
main_url = 'http://www.saramin.co.kr'

while True:
    url = f'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page={page_num}&cat_key=41711%2C40721%2C40426&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=1#searchTitle'
    req_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    }
    html = requests.get(url, req_header).text
    soup = BeautifulSoup(html, 'html.parser')
    if soup.select('div.list_body div.list_item') == []:
        break
    for tag in soup.select('div.list_body div.list_item'):
        company_dict = {}
        company_dict["기업명"] = tag.select('div.company_nm a span')[0].text
        company_dict["직무"] = tag.select('div.notification_info a span')[0].text
        company_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
        company_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
        try:
            company_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
        except:
            company_dict["근무형태"] = ""
        try:    
            company_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
        except:
            company_dict["근무지"] = ""
        category_list = []
        for item in tag.select('div.notification_info div.job_meta span span'):
            category_list.append(item.text)
        company_dict["분류"] = str(category_list)
        company_dict["분류필터"] = "python"
        
        detail_url = tag.select_one('div.notification_info a').attrs['href']
        full_detail_url = urljoin(main_url, detail_url)
        company_dict["상세링크"] = full_detail_url
        job_list_python.append(company_dict)
    page_num += 1
job_list_python
# Out:
# [{'기업명': '이타스코리아(주)',
#   '직무': '[ETAS] CycurHSM/ LIB FAE 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38650221&adsCategoryItem=effect_bold&'},
#  {'기업명': '국제컴퓨터아카데미',
#   '직무': '[100%무료 취업준비생모집]웹디/건축/게임/프로그래밍/3D프린터',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울 관악구',
#   '분류': "['그래픽디자인·CG', '제품·산업디자인']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=34393991&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)엔씨아이티에스',
#   '직무': '[NCSOFT자회사] 엔씨아이티에스 각 분야 모집공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586493&adsCategoryItem=effect_bold&'},
#  {'기업명': '스윙로드',
#   '직무': '스윙로드 (백엔드 부문) 정규직 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38423092&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)디케이비엠시',
#   '직무': 'CRM, BI, SI 컨설팅솔루션 관리/개발자 채용 공고',
#   '경력사항': '2 ~ 17년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['그래픽디자인·CG', '웹기획·PM']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528106&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)데이터스트림즈',
#   '직무': '2020년 IT빅데이터 솔루션 기업 전사 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38642677&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)필옵틱스',
#   '직무': '[비전검사실] Vision SW 설계/개발 엔지니어 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시 권선구',
#   '분류': "['반도체·디스플레이·LCD', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38615872&adsCategoryItem=effect_bold&'},
#  {'기업명': '신한양직업전문학교',
#   '직무': '[국비지원] 하반기 취업대비 4차 산업 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '부산 부산진구',
#   '분류': "['물류·유통·운송', '기계·기계설비']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38541577&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)에스엠투네트웍스',
#   '직무': '마케팅조사 인턴사원 채용',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '인턴직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['사무보조·문서작성', '마케팅·광고·분석']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38633025&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)리파인',
#   '직무': '개발자 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38639596&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)인텔리안시스템즈',
#   '직무': '각 부문별 신입 및 경력채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['사무보조·문서작성', '웹기획·PM']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38637555&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)에스텍플러스',
#   '직무': '(단기/월500이상) 백엔드 개발자 (python) 경력 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '컨텐츠·사이트운영']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38629152'},
#  {'기업명': '(주)매드업',
#   '직무': '[매드업] 퍼포먼스마케터/개발자 외 대규모 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['인사·교육·노무', '마케팅·광고·분석']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596083&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)중헌제약',
#   '직무': '중헌제약 각 부문 신입/경력 채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['경리·출납·결산', '회계·재무·세무·IR']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38654402&adsCategoryItem=effect_bold&'},
#  {'기업명': '케이에이앤',
#   '직무': '스마트 팩토리 S/W 개발/테스트원 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '울산 북구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38605981'},
#  {'기업명': '한국기술교육직업전문학교',
#   '직무': '[전액국비] 4차산업 IT전문인력 취업연계교육',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '부산 동래구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539306&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)대우능력개발교육원',
#   '직무': '2020년 100% 국비무료 9~10월 개강 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '서울 중랑구',
#   '분류': "['총무·법무·사무', '사무보조·문서작성']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631354&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)르호봇마이닝',
#   '직무': '본사 리눅스 경력사원 모집 공고',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['반도체·디스플레이·LCD', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653747'},
#  {'기업명': '(주)헥사콘',
#   '직무': 'WEB 개발자 채용',
#   '경력사항': '2 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38643465&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)씨유박스',
#   '직무': '각 부문 신입 및 경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '고졸↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 금천구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591207&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)매쓰모카',
#   '직무': '[벤처기업] 백엔드 Backend 개발자[PHP,Mysql(mariaDB),Python]',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '부산 해운대구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38635162&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)노보믹스',
#   '직무': '㈜노보믹스 바이오인포매틱스 BI 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['바이오·제약·식품', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38604577&adsCategoryItem=effect_bold&'},
#  {'기업명': '(학)창신대학교산학협력단',
#   '직무': '[국비무료] 사물인터넷[IoT]과 로봇운영자 과정 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '경남전체',
#   '분류': "['전기·전자·제어', '반도체·디스플레이·LCD']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38603781&adsCategoryItem=effect_bold&'},
#  {'기업명': '교보정보통신(주)',
#   '직무': '주니어 아키텍트(AA), HW영업 경력직원 모집',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 종로구',
#   '분류': "['일반영업', 'IT·솔루션영업']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38636554&adsCategoryItem=effect_bold&'},
#  {'기업명': '휴먼교육센터학원',
#   '직무': '[전액무료]자바/파이썬 IT교육받고 취업하자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38510654&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)쎄미시스코',
#   '직무': '㈜쎄미시스코 소프트웨어 개발자 경력직 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시',
#   '분류': "['반도체·디스플레이·LCD', '서버·네트워크·보안']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38597487&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)스틸리언',
#   '직무': '모바일 보안 솔루션 개발 [병특 가능]',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 용산구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653071&adsCategoryItem=effect_bold&'},
#  {'기업명': '뮤자인',
#   '직무': '각 부문별 신입 및 경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강동구',
#   '분류': "['마케팅·광고·분석', '그래픽디자인·CG']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38636033&adsCategoryItem=effect_bold&'},
#  {'기업명': '리눅스웨어 주식회사',
#   '직무': '[메일플러그]  웹 / 시스템 개발자 정규직 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38645113&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)애드락애드버테인먼트',
#   '직무': '애드락애드버테인먼트 개발자 채용 공고',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38609147&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)성원아이북랜드',
#   '직무': '[강남본사] 각 부문 신입/경력직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['상품기획·MD', '기획·전략·경영']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38619151&adsCategoryItem=effect_bold&'},
#  {'기업명': '디아이티(주)',
#   '직무': '2020 DIT 하반기 공개 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시 영통구',
#   '분류': "['기계·기계설비', '전기·전자·제어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38577337&adsCategoryItem=effect_bold&'},
#  {'기업명': '이노뎁(주)',
#   '직무': '2020 기술연구그룹 공채',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['사무보조·문서작성', '그래픽디자인·CG']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38637717&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)상록아이엔씨',
#   '직무': '[경험자 우대] Python/Linux AI 시스템 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 부천시',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601843&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)NE능률',
#   '직무': '2020년 ㈜NE능률 신입 공채 및 경력 수시 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['일반영업', '영업기획·관리·지원']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579763&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)마크로젠',
#   '직무': '㈜마크로젠 각 부문 신입/경력 직원채용',
#   '경력사항': '신입 · 경력',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['회계·재무·세무·IR', '일반영업']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38647890'},
#  {'기업명': '(주)텐마인즈',
#   '직무': '2020년 하반기 텐마인즈 부문별 신입/경력사원 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 용산구',
#   '분류': "['상품기획·MD', '기획·전략·경영']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653034'},
#  {'기업명': '주식회사 엠케이',
#   '직무': '2020 하반기 인공지능(AI)·빅데이터 외 신입&경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '인턴직',
#   '근무지': '대전 유성구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574766'},
#  {'기업명': '(주)푸드테크',
#   '직무': 'AWS/인프라 부문 경력사원 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631228&adsCategoryItem=effect_bold&'},
#  {'기업명': '(사)스마트미디어인재개발원',
#   '직무': '빅데이터·인공지능·IoT 무료 취업교육 모집!',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '광주 남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38024536&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)프렌츠',
#   '직무': '웹 프로그래머(서버개발) 및 웹/모바일기획 채용',
#   '경력사항': '1 ~ 4년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590376'},
#  {'기업명': '(주)슈프리마',
#   '직무': '[슈프리마] 소프트웨어(SW) 개발',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38437988&adsCategoryItem=effect_bold&'},
#  {'기업명': '패스트캠퍼스(주)',
#   '직무': '[패스트캠퍼스] 대규모 인재 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '마케팅·광고·분석']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38230007&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)유비케어',
#   '직무': 'GC녹십자헬스케어 가족사 각 직무별 신입/ 경력사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['기획·전략·경영', '회계·재무·세무·IR']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38616985'},
#  {'기업명': '교보라이프플래닛생명보험(주)',
#   '직무': '각 부문 경력 채용(영상, 데이터 분석/모델링, ITA, 리스크관리)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['기획·전략·경영', '금융·보험영업']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38628751&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)시지온',
#   '직무': '라이브리 서비스 광고 플랫폼 개발자 모집',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648078'},
#  {'기업명': '인큐솔루션(주)',
#   '직무': '[신입/경력]HW/SW 엔지니어 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['기술영업', '반도체·디스플레이·LCD']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38628664&adsCategoryItem=effect_bold&'},
#  {'기업명': '(유)딜리버리히어로 코리아',
#   '직무': '전 개발직군 대규모 채용중',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38476546'},
#  {'기업명': '(주)이노그루',
#   '직무': 'JAVA 개발 경력 정규직 채용',
#   '경력사항': '3 ~ 6년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38633996&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)페니로이스',
#   '직무': '전략 기획 & IT 컨설팅 채용 공고',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631322&adsCategoryItem=effect_bold&'},
#  {'기업명': '주식회사 큐버',
#   '직무': 'Back-end 개발 경력자',
#   '경력사항': '5 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589402'},
#  {'기업명': '(주)더블다운인터액티브',
#   '직무': '[더블유게임즈 자회사] 웹/게임서버 개발자 경력 모집 (1년이상)',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '게임·Game']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38615802'},
#  {'기업명': '포디리플레이코리아(주)',
#   '직무': '[4DReplay] 클라우드 서비스 및 Platform Back End 개발자 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38634954'},
#  {'기업명': '싸이엔스(주)',
#   '직무': 'AI 인공지능 S/W 개발자 (Tensorflow, Pytorch, Keras)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38619372'},
#  {'기업명': '글로벌인',
#   '직무': '[국비연수] 국내/일본 현지 호텔 프론트, IT 개발자 정규직 취업 국비 연수',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '교육생',
#   '근무지': '아시아·중동 일본',
#   '분류': "['호텔·카지노·콘도', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38654219'},
#  {'기업명': '㈜프론티스',
#   '직무': '[프론티스] IoT, AI 플랫폼 (C#/.NET/JAVA) 개발 (수원) 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시 영통구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38643441'},
#  {'기업명': '(주)유비온',
#   '직무': '[유비온] 에듀테크센터 각 부문 하반기 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['일반영업', 'IT·솔루션영업']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38647311'},
#  {'기업명': '한국IT교육원',
#   '직무': '[기업선발 후 맞춤취업교육]5G기반 스마트웰니스 의료기기 인공',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '대구 동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595914'},
#  {'기업명': '비비엠씨(주)',
#   '직무': '각 부문 신입 및 경력 모집 (시스템네트워크운영/콜센터/웹개발/영업)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['일반영업', '기술영업']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38638977'},
#  {'기업명': '(재)부산정보산업진흥원',
#   '직무': '[AI 기본과정] Python 라이브러리를 활용한 인공지능 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '부산 해운대구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38603946'},
#  {'기업명': '(주)아이스크림에듀',
#   '직무': '㈜아이스크림에듀 데이터/브랜드 마케팅팀 팀장 채용',
#   '경력사항': '경력 8년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['마케팅·광고·분석', '웹기획·PM']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570291'},
#  {'기업명': '(주)후이즈',
#   '직무': '㈜후이즈 쇼핑몰 각 부문별 신입/경력 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563638'},
#  {'기업명': '(주)캐럿글로벌',
#   '직무': '[솔루션개발팀] 웹기획자/웹디자이너/웹개발자 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38618158'},
#  {'기업명': '(주)엔지테크',
#   '직무': '[(주)엔지테크] 병원 프로그램 교육 신입 및 경력 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['인사·교육·노무', '웹마스터·QA·테스터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38612119'},
#  {'기업명': '(주)스트라티오코리아',
#   '직무': '(주)스트라티오코리아 2020 하반기 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '고졸↑',
#   '근무형태': '계약직',
#   '근무지': '서울 서초구',
#   '분류': "['경리·출납·결산', '회계·재무·세무·IR']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38634125'},
#  {'기업명': '(주)코믹스브이',
#   '직무': '웹(PHP) 개발 및 플랫폼 개발팀원 관리 및 교육 시니어개발자',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574767'},
#  {'기업명': '(주)두잉랩',
#   '직무': '[Tech Startup 두잉랩] 딥러닝 및 Web 개발 엔지니어 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601542'},
#  {'기업명': '한국직업전문학교',
#   '직무': '[국비무료/수당지급] 빅데이터/응용 S/W 개발자 과정 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '서울 구로구',
#   '분류': "['그래픽디자인·CG', '서버·네트워크·보안']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38393122'},
#  {'기업명': '(주)한국바코드정보기술',
#   '직무': '프로그램 개발 경력 및 신입',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '부산 중구',
#   '분류': "['응용프로그램개발', 'ERP·시스템분석·설계']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38654817'},
#  {'기업명': 'LINE+',
#   '직무': '[LINE PLUS] Cloud Service 개발 및 운영',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38634512'},
#  {'기업명': '워크픽(주)',
#   '직무': '(구로디지털단지/최고복지)웹개발(Python&백엔드&Java) 채용',
#   '경력사항': '3 ~ 8년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38654519'},
#  {'기업명': '에스이테크놀로지(주)',
#   '직무': '(신입, 정규직) 웹프로그래머 모집-엔지니어링 분야',
#   '경력사항': '신입',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38654372'},
#  {'기업명': '에스이테크놀로지(주)',
#   '직무': '(경력, 정규직) 웹프로그래머 모집-엔지니어링 분야',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38654281'},
#  {'기업명': '콴텍(주)',
#   '직무': '[콴텍, 금융] 함께 성장할 금융 데이터 분석 전문가 모십니다.',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['금융·보험영업', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38482773'},
#  {'기업명': '(주)비아이매트릭스',
#   '직무': '데이터분석 솔루션 개발자(python, Pandas) 채용',
#   '경력사항': '경력 7년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38654203'},
#  {'기업명': '(주)와이비시스템',
#   '직무': '개발자 담당 경력 정규직 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579699'},
#  {'기업명': '(주)큐픽스',
#   '직무': '[신입/경력/전문연구요원] AWS/Ruby 백엔드엔지니어 (인프라)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586042'},
#  {'기업명': '(주)큐픽스',
#   '직무': '[신입/경력/전문연구요원] 컴퓨터비전/딥러닝/SLAM 알고리즘',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586016'},
#  {'기업명': '(주)더포스',
#   '직무': '주식회사더포스 개발자 경력직 채용 전자공학과우대',
#   '경력사항': '5 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 화성시',
#   '분류': "['웹마스터·QA·테스터', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38654082'},
#  {'기업명': '원투씨엠(주)',
#   '직무': '소프트웨어 개발/서비스기획 경력 채용',
#   '경력사항': '5 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533730'},
#  {'기업명': '쿠팡(주)',
#   '직무': '경영지원 대규모 채용(Finance,HR,Legal,Business Data Analyst)',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 송파구',
#   '분류': "['총무·법무·사무', '인사·교육·노무']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589504'},
#  {'기업명': '주식회사 해줌',
#   '직무': '발전량 예측 API 백엔드 개발자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526293'},
#  {'기업명': '(주)쓰리웨이소프트',
#   '직무': '전력설비 DeepLearning 및 응용 개발자모심',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596507'},
#  {'기업명': '(주)아이스크림에듀',
#   '직무': '㈜아이스크림에듀 콘텐츠,개발,마케팅,영업,관리 직군 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['상품기획·MD', '마케팅·광고·분석']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569553'},
#  {'기업명': '행복쇼핑 주식회사',
#   '직무': 'PHP/REACT/PYTHON/퍼블리셔 경력자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653615'},
#  {'기업명': '(주)미디움',
#   '직무': '(주) 미디움 우수인재 모집(영상처리,AI,APP서버 개발)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '웹기획·PM']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38493102'},
#  {'기업명': '(주)에이텍에이피',
#   '직무': '[R&D] 서버 개발자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653062'},
#  {'기업명': '더화이트커뮤니케이션(주)',
#   '직무': '분야별 경력직 모집 (전략,기획,R&D,디자인,CS)',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598693'},
#  {'기업명': '써모아이(주)',
#   '직무': '소프트웨어 개발 정규직 신입/경력 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 노원구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38652395'},
#  {'기업명': '주식회사 노벨알엔디',
#   '직무': '[삼성전자 화성] JAVA 개발자(신입/경력) 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 프리랜서',
#   '근무지': '경기 화성시',
#   '분류': "['그래픽디자인·CG', '서버·네트워크·보안']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38612652'},
#  {'기업명': '주식회사 빌리오',
#   '직무': '빌리오(Billyo) 프론트엔드 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38625287'},
#  {'기업명': '주식회사 빌리오',
#   '직무': '빌리오(Billyo) 백엔드 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38641768'},
#  {'기업명': '주식회사 빌리오',
#   '직무': '빌리오(Billyo) 퍼포먼스 마케터 경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38625336'},
#  {'기업명': '(주)밀버스',
#   '직무': '[MILVUS]빅데이터분석 마케팅(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['마케팅·광고·분석', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38651165'},
#  {'기업명': '(주)티월드글로벌',
#   '직무': '웹(WEB) 개발자 채용(경력직)',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38647748'},
#  {'기업명': '(주)이젠아카데미인재개발원',
#   '직무': '[취업연수 국비교육]자바/파이썬/빅데이터/웹/영상/건축',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['캐릭터·만화·애니', '광고·시각디자인']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=36825236'},
#  {'기업명': '켈리서비스 유한회사',
#   '직무': '[글로벌 포털 G사 ] Technical Solutions Consultant',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 강남구',
#   '분류': "['AS·서비스·수리', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569889'},
#  {'기업명': '한국정보기술단',
#   '직무': '[한국정보기술단] 빅데이터 분석 기술인력 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 과천시',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38508480'},
#  {'기업명': '주식회사 더맘마',
#   '직무': '2020년 기술연구소 경력직 채용 (연구부분)',
#   '경력사항': '경력 5년↑',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['응용프로그램개발', '연구소·R&D']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38650255'},
#  {'기업명': '(주)알리아스',
#   '직무': '[ VR / AR ] 콘텐츠 코딩 엔지니어 신입/경력사원 모집(정규직)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경남 김해시',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38359878'},
#  {'기업명': '(주)페이타랩',
#   '직무': '현대인의 필수인 패스오더 개발자를 모십니다.[5개 직군]',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 부산진구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38365421'},
#  {'기업명': '테크빌교육(주)',
#   '직무': '[테크빌교육] 개발PM·프로그래머·기획·데이터분석 등 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38363291'},
#  {'기업명': '(주)퀀텀솔루션',
#   '직무': '2020 신입 및 경력직 모집 - 지능형 플랫폼 개발 분야',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '제주 제주시',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38430998'},
#  {'기업명': '(주)글로비트',
#   '직무': '연구개발 펌웨어 R&D분야 직원 채용 공고',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 군포시',
#   '분류': "['전기·전자·제어', '설계·CAD·CAM']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38610115'},
#  {'기업명': '데브시스터즈(주)',
#   '직무': 'Data Scientist (경력)',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['ERP·시스템분석·설계', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649690'},
#  {'기업명': '로크웰오토메이션코리아(주)',
#   '직무': 'Software Lead Engineer 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기계·기계설비', '전기·전자·제어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567097'},
#  {'기업명': '(주)판도라티비',
#   '직무': '[ 코박(COBAK) ]  Back-end 개발자 채용(Python / django)',
#   '경력사항': '1 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38636485'},
#  {'기업명': '㈜로드와이즈',
#   '직무': '[인공지능/바이오]분야 연구/개발자 채용공고(팀장/팀원)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38487444'},
#  {'기업명': '엔에이치엔(주)',
#   '직무': '[NHN] 기술 부문 수시채용 (신입/경력)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649014'},
#  {'기업명': '하나금융투자(주)',
#   '직무': '하나금융투자 전문직(경력) 인재 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['해외영업·무역영업', '기획·전략·경영']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38633389'},
#  {'기업명': '트리컴퍼니',
#   '직무': '반응형 웹 개발/기획 실무자 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38603185'},
#  {'기업명': '(주)푸드테크',
#   '직무': 'IT부문 신입 및 경력사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 강남구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526283'},
#  {'기업명': '(주)쿠돈',
#   '직무': '시니어 백엔드 개발자 (Python, django) 채용',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648263'},
#  {'기업명': '(주)팬토믹스',
#   '직무': '의료영상 소프트웨어 개발자 경력자 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38641786'},
#  {'기업명': '(주)엠투아이티',
#   '직무': '[신입] 서비스사업부 신입사원 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38647645'},
#  {'기업명': '(주)큐비콘',
#   '직무': '3D 프린터 하드웨어 · 소프트웨어 2개 부문 담당자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 중원구',
#   '분류': "['전기·전자·제어', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38647621'},
#  {'기업명': '공공장소',
#   '직무': '공공장소 [IT개발팀] 웹 백엔드 개발자 채용',
#   '경력사항': '1 ~ 5년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38647502'},
#  {'기업명': '(주)코난테크놀로지',
#   '직무': '2020년 ㈜코난테크놀로지 하반기 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38612027'},
#  {'기업명': '(주)유비온',
#   '직무': '[유비온] 미래교육사업부(웹 어플리케이션 개발자 채용)',
#   '경력사항': '3 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576322'},
#  {'기업명': '지속가능발전소(주)',
#   '직무': '지속가능발전소 기업부설연구소 전문연구요원(병역특례) 모집',
#   '경력사항': '경력무관',
#   '학력': '석사↑',
#   '근무형태': '병역특례',
#   '근무지': '서울 영등포구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38628495'},
#  {'기업명': '(주)유노믹',
#   '직무': '[부산] 신입/경력 채용 (기술영업/마케팅, 데이터분석/SW개발)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '부산 동구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579931'},
#  {'기업명': '지속가능발전소(주)',
#   '직무': '지속가능발전소 Data Scientist(데이터분석) 경력직 채용',
#   '경력사항': '3 ~ 5년',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38646935'},
#  {'기업명': 'KOG',
#   '직무': '[INFRA팀] 게임 서비스 및 사내 업무 인프라 구축(개발) / 운영',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대구 중구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38641643'},
#  {'기업명': '(주)로지올',
#   '직무': '[생각대로] 전국1위 배달 플랫폼 백엔드/모바일/웹 개발자',
#   '경력사항': '1 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹개발', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38609242'},
#  {'기업명': '주식회사 오픈소스컨설팅',
#   '직무': '[오픈소스컨설팅] 각 부문 엔지니어 채용(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38605104'},
#  {'기업명': '(주)뷰노',
#   '직무': '[뷰노] 의료영상, 생체신호, 음성인식 ML/DL 연구원을 찾습니다',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['인공지능(AI)·빅데이터', '연구소·R&D']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38532086'},
#  {'기업명': '(주)뷰노',
#   '직무': '[뷰노] SW Engineer 및 서비스개발 담당자를 찾습니다',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['기술영업', '웹마스터·QA·테스터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38532091'},
#  {'기업명': '(주)트랜스코스모스코리아',
#   '직무': '당사 CX개발사업본부 개발 및 운영 담당자(신입/경력)Mj5E',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38512364'},
#  {'기업명': '주식회사 와이즈인컴퍼니',
#   '직무': '빅데이터분석 및 개발자 모집(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590627'},
#  {'기업명': '아우토크립트(주)',
#   '직무': '아우토크립트 웹개발 경력 모집',
#   '경력사항': '경력 7년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38642152'},
#  {'기업명': '(주)유노믹',
#   '직무': '[서울] 신입/경력 채용 (기술영업/마케팅, 데이터분석/SW개발)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['기획·전략·경영', '홍보·PR·사보']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567864'},
#  {'기업명': '더조은컴퓨터아트학원',
#   '직무': '[100%무료 취업준비생모집]웹디/건축/게임/프로그래밍/3D프린터',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['그래픽디자인·CG', '제품·산업디자인']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=34529977'},
#  {'기업명': '(주)코리아센터',
#   '직무': 'PHP 및 Python 웹 개발자 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38602736'},
#  {'기업명': '(주)스마트콘',
#   '직무': '개발연구소 개발자',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38644565'},
#  {'기업명': '(주)비트나인',
#   '직무': '[비트나인] DB엔지니어 경력직 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38644465'},
#  {'기업명': '(주)리버스랩',
#   '직무': 'Back-End / Web Front-end 개발자 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38644368'},
#  {'기업명': '(주)컴트루테크놀로지',
#   '직무': '[병역특례(보충역)] Web개발, iOS개발, AI개발, 응용개발 모집',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38635221'},
#  {'기업명': '(주)컴트루테크놀로지',
#   '직무': '[인공지능 보안솔루션] 딥러닝아키텍쳐 / AI 개발자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '서울 마포구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38635222'},
#  {'기업명': '주식회사 엔디소프트',
#   '직무': '(주)NDSOFT 2020년 개발자 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 해운대구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38572298'},
#  {'기업명': '(주)스프링클라우드',
#   '직무': '[제2판교]인공지능 자율주행 SW / MAP / SLAM 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 수정구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38573885'},
#  {'기업명': '뉴로핏 주식회사',
#   '직무': '의료영상 인공지능 엔지니어 모집 (의료인공지능및분석방법개발)',
#   '경력사항': '경력 2년↑',
#   '학력': '석사↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38407604'},
#  {'기업명': '뉴로핏 주식회사',
#   '직무': '소프트웨어 유틸리티 개발 및 유지보수 (경력 1년 이상)모집.',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38602042'},
#  {'기업명': '스토리앤브라더스(주)',
#   '직무': '파이썬(장고) 백엔드 개발 경력자 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558591'},
#  {'기업명': '휴도',
#   '직무': '[휴도] WEB / APP 신규 구축 풀스텍 개발자 채용 (NODE.JS / REACT-NATIVE)',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599290'},
#  {'기업명': '(주)열심히커뮤니케이션즈',
#   '직무': 'IT본부 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 용산구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631839'},
#  {'기업명': '(주)아이디어빈스',
#   '직무': '각 부문 경력사원 모집 (개발/기획/경리총무)',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['기획·전략·경영', '경리·출납·결산']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38618334'},
#  {'기업명': '(주)에이치비테크놀러지',
#   '직무': 'HB테크놀러지 신입/경력사원 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '충남 아산시',
#   '분류': "['기획·전략·경영', '회계·재무·세무·IR']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38615564'},
#  {'기업명': '라인파이낸셜플러스(주)',
#   '직무': '[LINE BIZ PLUS/LINE FINANCIAL] Developer Recruitment',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38630968'},
#  {'기업명': '펀드블록글로벌(주)',
#   '직무': '부동산 금융 프롭테크 개발 부문 경력 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38641707'},
#  {'기업명': '(주)에이트테크',
#   '직무': '2020 하반기 인공지능(AI) 개발자 경력직 채용',
#   '경력사항': '1 ~ 3년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 서구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38629789'},
#  {'기업명': '(주)엑시아',
#   '직무': '[(주)엑시아 소프트] 파이썬Python Django 개발자',
#   '경력사항': '3 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38641613'},
#  {'기업명': '(주)볼드코퍼레이션',
#   '직무': '[스타트업] 담대하게 함께할 개발자를 모십니다 :D - 신입/인턴O',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38621058'},
#  {'기업명': '(주)시큐아이',
#   '직무': '(주)시큐아이 개발직군 경력사원 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38640733'},
#  {'기업명': '도프텍(주)',
#   '직무': 'C#(Winform), Python 개발자(신입/경력) 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38483930'},
#  {'기업명': '(주)에이직스',
#   '직무': '빅데이터 처리 및 AI 알고리즘 연구개발 (R&D)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38514028'},
#  {'기업명': '한국에이치알엠',
#   '직무': '대표 커뮤니티사이트 백앤드 Back-end 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594546'},
#  {'기업명': '(주)인사',
#   '직무': '[신입/경력] 구인구직 플랫폼(반응형) / Python 개발자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38419860'},
#  {'기업명': '렌카(주)',
#   '직무': '모빌리티 기업 렌카(주), 데이터 분석 담당자 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 광진구',
#   '분류': "['회계·재무·세무·IR', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38639097'},
#  {'기업명': '화랑',
#   '직무': 'AI/Machine Learning/Deep learning',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '충남 천안시 동남구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38638524'},
#  {'기업명': '에이블맥스(주)',
#   '직무': 'Python 개발자 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38612137'},
#  {'기업명': '(주)용진시스템',
#   '직무': 'RPA 관련 개발자 또는 운영자 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38638282'},
#  {'기업명': '(주)팀플백',
#   '직무': 'SW개발자 및 PM 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경남 창원시',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38479641'},
#  {'기업명': '㈜해커스교육그룹',
#   '직무': '2020년 해커스 교육그룹 [신입/경력] 각 부문별 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38369849'},
#  {'기업명': '신플렛(주)',
#   '직무': 'Python(파이썬) 경력 개발자 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 용인시 수지구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38637936'},
#  {'기업명': '주식회사 이커머스테크',
#   '직무': '[SI/중급/마곡] AI 기반 시스템 구축',
#   '경력사항': '경력 6년↑',
#   '학력': '학력무관',
#   '근무형태': '프리랜서',
#   '근무지': '서울 강서구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
# ...
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586995'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[유망 AI 스타트업] 백엔드 Engineer',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586883'},
#  {'기업명': 'search square',
#   '직무': 'BI (바이오기업)',
#   '경력사항': '경력 1년↑',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586154'},
#  {'기업명': '라온서치',
#   '직무': '금융대기업 (연구소) NLP (Text Mining) 경력자, 책임-수석급',
#   '경력사항': '8 ~ 18년',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['하드웨어·소프트웨어', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38584122'},
#  {'기업명': '오픈포지션',
#   '직무': '시스템 UI 개발 / 10년이하/구로디지탈',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582562'},
#  {'기업명': '오픈포지션',
#   '직무': '시스템 백엔드 개발 / 10년이상 /구로디지탈',
#   '경력사항': '경력 10년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582549'},
#  {'기업명': '제이케이서치 주식회사',
#   '직무': '[유명 광고 플랫폼 기업] JAVA 개발자 채용',
#   '경력사항': '4 ~ 15년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38581704'},
#  {'기업명': 'FORTISPTS Partners',
#   '직무': '데이터 사이언티스트 - 국내 대기업',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580364'},
#  {'기업명': '로버트월터스코리아(주)',
#   '직무': '[글로벌/소프트웨어/머신러닝] Senior Engineer - Deep Learning',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579253'},
#  {'기업명': 'search square',
#   '직무': 'SW개발 (IoT기업 Backend 개발)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578539'},
#  {'기업명': '터닝포인트HR',
#   '직무': '[No.1 글로벌 커피 프랜차이즈] Data Engineer',
#   '경력사항': '5 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576543'},
#  {'기업명': '(주) 잡뉴스솔로몬서치',
#   '직무': '모바일분야 AI분야리더, 데이터 사이언티스트 (부장급), 강남구',
#   '경력사항': '경력 15년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['하드웨어·소프트웨어', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38564927'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '(가전 및 생활용품 기업) 데이터 엔지니어',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38620398'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '헤드헌터 초빙(전자/전기/에너지/바이오/식품/유통/IT 등)',
#   '경력사항': '경력 15년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '전임 · 프리랜서',
#   '근무지': '서울 서초구',
#   '분류': "['전기·전자·제어', '바이오·제약·식품']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38614919'},
#  {'기업명': '보보스링크(주)',
#   '직무': 'AI개발 신입-사원급 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강동구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38632148'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 소프트웨어 개발자 (JavaScript, Node.js) - e커머스',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38624378'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 회원 플랫폼 기술PM (회원,인증,멤버십,CRM 등) - 대기업',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38624033'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) Technical Product Manager (블록체인)  - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38624336'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 블록체인 Technical Product Manager  - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38624339'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 플랫폼 기술PM - 최고 대기업 - 최우대',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38624350'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 최고 대기업 - 플랫폼 기술PM - 최우대',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38624353'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) Data Manager - 업계 최고 대기업 - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38624354'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 대기업 - 회원 플랫폼 기술PM (회원,인증,멤버십,CRM 등)',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38623915'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) e커머스 - 소프트웨어 개발자 (JavaScript, Node.js)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38623984'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 커머스 통합 주문/재고 시스템 기술PM - 업계 최고 대기업',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38623880'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 업계 최고 대기업 - 커머스 통합 주문/재고 시스템 기술PM',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38623882'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 최고 대기업 - Data Modeler - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38623884'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) Data Modeler - 최고 대기업 - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38623887'},
#  {'기업명': '(주)탑앤스카우트',
#   '직무': '[AI, IoT] 공공프로젝트 PM 충원',
#   '경력사항': '경력 8년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', 'ERP·시스템분석·설계']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601402'},
#  {'기업명': '제이떠블유커리어(JW career)',
#   '직무': '머신비전 전문기업 딥러닝, AI 연구소(소장급)채용',
#   '경력사항': '경력 10년↑',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579925'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[대기업 그룹계열사] 빅데이터 솔루션 팀장급 채용',
#   '경력사항': '경력 12년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648140'},
#  {'기업명': '(주)휴먼디지탈',
#   '직무': '경력직 -(전기차) HILS 장비제어 S/W 개발 (랩뷰 Labview 및 C++',
#   '경력사항': '3 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38627723'},
#  {'기업명': '탑커리어인사이트',
#   '직무': '빅데이터 플랫폼 엔지니어 경력사원 채용 (경력 5년 이상)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38607834'},
#  {'기업명': '굿커리어',
#   '직무': '유명 대기업 합작사 모바일앱 개발자 과장,차장',
#   '경력사항': '7 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592939'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '외국계 반도체회사 R&D S/W 연구원(경력) 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649126'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '외국계 회사 Video System R&D Software Engineer 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649125'},
#  {'기업명': '피플워크(주)',
#   '직무': 'MSA클라우드 기반 사내시스템 웹개발[대기업]',
#   '경력사항': '4 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38620149'},
#  {'기업명': '(주)에이치알인재그룹',
#   '직무': '사무자동화(RPA) 개발 경력채용',
#   '경력사항': '4 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 김포시',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648271'},
#  {'기업명': '(주)쿠자피에이에스',
#   '직무': '개발자 SW개발 팀장급 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '울산 중구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38647730'},
#  {'기업명': '제이떠블유커리어(JW career)',
#   '직무': '(국내 유통대기업) 데이터분석 대리~과장급 채용',
#   '경력사항': '5 ~ 12년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38646769'},
#  {'기업명': 'FNR Consulting',
#   '직무': 'Community Service회사 CTO (글로벌 투자 회사 투자 유치)',
#   '경력사항': '7 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38646287'},
#  {'기업명': '헤리티지서치코어',
#   '직무': '솔루션영업/경력 5년이상/유명 IT 솔루션기업',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38645975'},
#  {'기업명': '그린컴퓨터아트학원 아카데미 성남/분당 ..',
#   '직무': '[국기] JAVA기반(웹,앱,빅데이터) 개발자 과정 훈련교.강사 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '전임 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38629645'},
#  {'기업명': '그린컴퓨터아트학원 아카데미 성남/분당 ..',
#   '직무': '[국가기간] 디지털컨버전스(JAVA기반), 빅데이터취업 국비교육',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '위촉직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38632622'},
#  {'기업명': '그린컴퓨터아카데미',
#   '직무': '자바(JAVA) 개발 / 응용SW 직업훈련교사(강사) 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '울산 남구',
#   '분류': "['웹개발', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38643837'},
#  {'기업명': '(주)핀커스코리아',
#   '직무': '유명기업 웹개발 경력채용(3년~7년)',
#   '경력사항': '3 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38640208'},
#  {'기업명': '햄파트너스',
#   '직무': '유명 IT회사) 프론트엔드 테크니컬 리더 모집',
#   '경력사항': '경력 10년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38637626'},
#  {'기업명': '햄파트너스',
#   '직무': '유명 IT회사) 백엔드 테크니컬 리더 모집',
#   '경력사항': '경력 10년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38637553'},
#  {'기업명': '㈜에이치알맨파워그룹',
#   '직무': '[대기업] AI알고리즘-박사 (서울)',
#   '경력사항': '신입 · 경력',
#   '학력': '박사',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38635195'},
#  {'기업명': '하이잡',
#   '직무': '추천 시스템 연구/개발',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38634020'},
#  {'기업명': '커리어셀파',
#   '직무': '[유통대기업] IT개발 경력사원 채용',
#   '경력사항': '4 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583993'},
#  {'기업명': '비전서치',
#   '직무': '업데이트용 sw 개발',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38622638'},
#  {'기업명': '구루넷',
#   '직무': '인공지능 연구원 모집',
#   '경력사항': '2 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38622038'},
#  {'기업명': '구루넷',
#   '직무': '[일본취업] 소프트웨어 엔지니어 모집',
#   '경력사항': '2 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 해외취업',
#   '근무지': '아시아·중동 일본',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38622036'},
#  {'기업명': '구루넷',
#   '직무': '영상처리 솔루션 개발자 모집',
#   '경력사항': '2 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38622034'},
#  {'기업명': '구루넷',
#   '직무': '[코스닥 상장사] 시스템 소프트웨어 개발자 모집',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38622032'},
#  ...]

# %%
# db 직업 스크래핑

job_list_db = []
page_num = 1
while True:
    url = f'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page={page_num}&cat_cd=416&cat_key=40745&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=2#searchTitle'
    req_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    }
    html = requests.get(url, req_header).text
    soup = BeautifulSoup(html, 'html.parser')
    if soup.select('div.list_body div.list_item') == []:
        break
    for tag in soup.select('div.list_body div.list_item'):
        company_dict = {}
        company_dict["기업명"] = tag.select('div.company_nm a span')[0].text
        company_dict["직무"] = tag.select('div.notification_info a span')[0].text
        company_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
        company_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
        try:
            company_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
        except:
            company_dict["근무형태"] = ""
        try:    
            company_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
        except:
            company_dict["근무지"] = ""
        category_list = []
        for item in tag.select('div.notification_info div.job_meta span span'):
            category_list.append(item.text)
        company_dict["분류"] = str(category_list)
        company_dict["분류필터"] = "db"
        
        detail_url = tag.select_one('div.notification_info a').attrs['href']
        full_detail_url = urljoin(main_url, detail_url)
        company_dict["상세링크"] = full_detail_url
        job_list_db.append(company_dict)
    page_num += 1
job_list_db
# Out:
# [{'기업명': '디지코리아(주)',
#   '직무': 'Java·JSP, MS-SQL, Pro-C 정규직 채용 공고(경력)',
#   '경력사항': '4 ~ 5년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 하남시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38624794&adsCategoryItem=effect_bold&'},
#  {'기업명': '팬비스그룹',
#   '직무': '2020년 팬비스 그룹 공개 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['상품기획·MD', '기획·전략·경영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38615134&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)디지비데이터시스템',
#   '직무': '2020년 하반기 신입(채용연계형 인턴) 및 경력직 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '대구 수성구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38585206&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)디케이비엠시',
#   '직무': 'CRM, BI, SI 컨설팅솔루션 관리/개발자 채용 공고',
#   '경력사항': '2 ~ 17년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['그래픽디자인·CG', '웹기획·PM']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528106&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)데이터스트림즈',
#   '직무': '2020년 IT빅데이터 솔루션 기업 전사 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38642677&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)필옵틱스',
#   '직무': '[비전검사실] Vision SW 설계/개발 엔지니어 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시 권선구',
#   '분류': "['반도체·디스플레이·LCD', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38615872&adsCategoryItem=effect_bold&'},
#  {'기업명': '대영채비(주)',
#   '직무': '소프트웨어 개발(UI, C#, WPF/Winform, C++, C#, .NET, MSSQL, 소켓통신), H/W개발, 펌웨어 개발자 모집',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['전기·전자·제어', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38639476&adsCategoryItem=effect_bold&'},
#  {'기업명': '알에셋마스터리스(주)',
#   '직무': '[스마트하우스] 2020년 부문별 경력사원 채용',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '경리·출납·결산']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38637576&adsCategoryItem=effect_bold&'},
#  {'기업명': '한국학술정보(주)',
#   '직무': '한국학술정보(주) 각 부문 신입 및 경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 파주시',
#   '분류': "['기획·전략·경영', '마케팅·광고·분석']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38639836&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)대성문',
#   '직무': '㈜대성문 웹사이트 개발직 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '부산 연제구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38638581&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)매드업',
#   '직무': '[매드업] 퍼포먼스마케터/개발자 외 대규모 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['인사·교육·노무', '마케팅·광고·분석']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596083&adsCategoryItem=effect_bold&'},
#  {'기업명': '한국기술교육직업전문학교',
#   '직무': '[전액국비] 4차산업 IT전문인력 취업연계교육',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '부산 동래구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539306&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)경일게임아카데미',
#   '직무': '정부무료 게임회사 취업연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38644455&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)아임웹',
#   '직무': '부문별 인재 채용(개발/마케팅/디자인)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서대문구',
#   '분류': "['사무보조·문서작성', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38645780&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)대우능력개발교육원',
#   '직무': '2020년 100% 국비무료 9~10월 개강 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '서울 중랑구',
#   '분류': "['총무·법무·사무', '사무보조·문서작성']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631354&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)디알젬',
#   '직무': '디알젬 경력사원 모집 (연구소,기술지원,구매)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 광명시',
#   '분류': "['구매·자재·재고', '기획·전략·경영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38645213&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)르호봇마이닝',
#   '직무': '본사 리눅스 경력사원 모집 공고',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['반도체·디스플레이·LCD', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653747'},
#  {'기업명': '(주)헥사콘',
#   '직무': 'WEB 개발자 채용',
#   '경력사항': '2 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38643465&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)씨유박스',
#   '직무': '각 부문 신입 및 경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '고졸↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 금천구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591207&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)진미식품',
#   '직무': '전산관리자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '충북 괴산군',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38645578&adsCategoryItem=effect_bold&'},
#  {'기업명': '총신대학교',
#   '직무': '총신대학교 전산정보/상담센터 정규직(일반직 9급) 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 동작구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601738&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)매쓰모카',
#   '직무': '[벤처기업] 백엔드 Backend 개발자[PHP,Mysql(mariaDB),Python]',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '부산 해운대구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38635162&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)클라우즈랩',
#   '직무': '데이터모델링 / ETL 프리랜서 경력 모집',
#   '경력사항': '경력 6년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '프리랜서',
#   '근무지': '서울 강서구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38656306'},
#  {'기업명': '휴먼교육센터학원',
#   '직무': '[전액무료]자바/파이썬 IT교육받고 취업하자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38510654&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)우노스',
#   '직무': '2020년 신입사원 신규 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 의왕시',
#   '분류': "['경리·출납·결산', '홍보·PR·사보']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558570&adsCategoryItem=effect_bold&'},
#  {'기업명': '키움에셋플래너(주)',
#   '직무': '키움에셋플래너㈜ IT팀 정규직 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38636156&adsCategoryItem=effect_bold&'},
#  {'기업명': '노아에이티에스(주)',
#   '직무': '2020년 하반기 신입사원 공개채용',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38630758&adsCategoryItem=effect_bold&'},
#  {'기업명': '이베스트투자증권(주)',
#   '직무': '[이베스트투자증권] 경력직 채용(2개 부문 - 리스크관리, 투자심사 ~8/30)',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['회계·재무·세무·IR', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38651181&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)애드락애드버테인먼트',
#   '직무': '애드락애드버테인먼트 개발자 채용 공고',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38609147&adsCategoryItem=effect_bold&'},
#  {'기업명': '한성기업(주)',
#   '직무': '2020년 한성기업㈜ IT파트(전산) 신입 및 경력사원 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38608210&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)애니게이트',
#   '직무': '병역특례 전문연구요원 소프트웨어 개발직 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38616262&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)버블콘',
#   '직무': '(주)버블콘 하반기 개발 경력/신입 사원 채용(정규직)',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 연수구',
#   '분류': "['웹개발', '컨텐츠·사이트운영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38652747'},
#  {'기업명': '(주)원진월드와이드',
#   '직무': '2020년 원진그룹 하반기 신입/경력사원 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '경남 양산시',
#   '분류': "['기획·전략·경영', '홍보·PR·사보']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38644555'},
#  {'기업명': '(주)잘론네츄럴',
#   '직무': '2020년 하반기 빌리브네이처 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['상품기획·MD', '기획·전략·경영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38573516&adsCategoryItem=effect_bold&'},
#  {'기업명': '이노뎁(주)',
#   '직무': '2020 기술연구그룹 공채',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['사무보조·문서작성', '그래픽디자인·CG']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38637717&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)NE능률',
#   '직무': '2020년 ㈜NE능률 신입 공채 및 경력 수시 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['일반영업', '영업기획·관리·지원']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579763&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)푸드테크',
#   '직무': 'AWS/인프라 부문 경력사원 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631228&adsCategoryItem=effect_bold&'},
#  {'기업명': '창원문성대학교산학협력단',
#   '직무': '빅데이터 전문기술 교육과정 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '교육생',
#   '근무지': '경남 창원시 의창구',
#   '분류': "['회계·재무·세무·IR', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38611128'},
#  {'기업명': '현대비에스앤씨(주)',
#   '직무': '2020년 하반기 각 부문별 채용공고',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 중구',
#   '분류': "['총무·법무·사무', '사무보조·문서작성']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38639455'},
#  {'기업명': '대덕전자(주)',
#   '직무': '각 부문별 신입(인턴)/경력 공개 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '경기 안산시 단원구',
#   '분류': "['구매·자재·재고', '회계·재무·세무·IR']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38611029'},
#  {'기업명': '한양이엔지(주)',
#   '직무': '한양이엔지㈜ 부문별 수시채용 직원모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 화성시',
#   '분류': "['회계·재무·세무·IR', '전기·전자·제어']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631405&adsCategoryItem=effect_bold&'},
#  {'기업명': '티엔에이치(주)',
#   '직무': '하반기 각 부문별 신입/경력 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['그래픽디자인·CG', 'TM·인바운드']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631690&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)엔에스쇼핑',
#   '직무': '온라인 MD 및 IT부문 경력사원 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시',
#   '분류': "['상품기획·MD', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38650264'},
#  {'기업명': '(주)유비케어',
#   '직무': 'GC녹십자헬스케어 가족사 각 직무별 신입/ 경력사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['기획·전략·경영', '회계·재무·세무·IR']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38616985'},
#  {'기업명': '교보라이프플래닛생명보험(주)',
#   '직무': '각 부문 경력 채용(영상, 데이터 분석/모델링, ITA, 리스크관리)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['기획·전략·경영', '금융·보험영업']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38628751&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)시지온',
#   '직무': '라이브리 서비스 광고 플랫폼 개발자 모집',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648078'},
#  {'기업명': '(유)딜리버리히어로 코리아',
#   '직무': '전 개발직군 대규모 채용중',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38476546'},
#  {'기업명': '(주)코스콤',
#   '직무': '2020년 각 부문 기간제 직원 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['TM·인바운드', '웹마스터·QA·테스터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38617900'},
#  {'기업명': '(주)지이씨엘코리아',
#   '직무': 'GECL KOREA 신입/경력직 (MD, PHP, JAVA, 웹디자인, SA/SE, SEO)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 금천구',
#   '분류': "['해외영업·무역영업', '상품기획·MD']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596692'},
#  {'기업명': '(주)퍼플랩스헬스케어',
#   '직무': '[SERY BOX] 각 부문 신입 및 경력 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['해외영업·무역영업', '상품기획·MD']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38640480'},
#  {'기업명': '코드크레인',
#   '직무': '[Node.js] 백엔드 개발',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38416792'},
#  {'기업명': '(주)펄어비스',
#   '직무': '[펄어비스] 2020 전 부문 수시채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['총무·법무·사무', '인사·교육·노무']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37536372'},
#  {'기업명': '(주)위즈더플래닛',
#   '직무': '사진편집/웹개발자/어플리케이션 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['영업기획·관리·지원', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38629369&adsCategoryItem=effect_bold&'},
#  {'기업명': '㈜제릭스테크놀로지',
#   '직무': 'PHP, PowerBuilder 경력 개발자 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38629114'},
#  {'기업명': '주식회사 큐버',
#   '직무': 'Back-end 개발 경력자',
#   '경력사항': '5 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589402'},
#  {'기업명': '(주)더블다운인터액티브',
#   '직무': '[더블유게임즈 자회사] 웹/게임서버 개발자 경력 모집 (1년이상)',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '게임·Game']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38615802'},
#  {'기업명': '글로벌인',
#   '직무': '[국비연수] 국내/일본 현지 호텔 프론트, IT 개발자 정규직 취업 국비 연수',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '교육생',
#   '근무지': '아시아·중동 일본',
#   '분류': "['호텔·카지노·콘도', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38654219'},
#  {'기업명': '(주)유비온',
#   '직무': '[유비온] 에듀테크센터 각 부문 하반기 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['일반영업', 'IT·솔루션영업']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38647311'},
#  {'기업명': '(주)골든플래닛',
#   '직무': 'Google Analytics,구글애널리틱스 온라인고객 행동데이터 분석',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38616879'},
#  {'기업명': '한국IT교육원',
#   '직무': '[기업선발 후 맞춤취업교육]5G기반 스마트웰니스 의료기기 인공',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '대구 동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595914'},
#  {'기업명': '(주)케이알마케팅',
#   '직무': '[KR마케팅] 웹개발자 신입 및 경력사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38638860'},
#  {'기업명': '웹케시(주)',
#   '직무': '개발/사업/상품/법무/인사/재무/홍보 채용연계형 인턴 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '서울 영등포구',
#   '분류': "['상품기획·MD', '기획·전략·경영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38636975'},
#  {'기업명': '에스비아이코스머니(주)',
#   '직무': '2020년 하반기 각 부문별 직원채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38640756'},
#  {'기업명': '(주)뉴트리원',
#   '직무': '2020년 하반기 IT 인력 신입 및 경력 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['상품기획·MD', '사무보조·문서작성']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38645603'},
#  {'기업명': '(주)퓨처젠',
#   '직무': 'JAVA Web 경력 개발자 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38645433'},
#  {'기업명': '오티아이(주)',
#   '직무': '오티아이㈜ 각 부문 신입 및 경력직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38585443'},
#  {'기업명': '(주)후이즈',
#   '직무': '㈜후이즈 쇼핑몰 각 부문별 신입/경력 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563638'},
#  {'기업명': '(주)캐럿글로벌',
#   '직무': '[솔루션개발팀] 웹기획자/웹디자이너/웹개발자 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38618158'},
#  {'기업명': '(주)위메이드',
#   '직무': '[위메이드넥스트] DBA 채용 공고',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38655553'},
#  {'기업명': '오티아이(주)',
#   '직무': '오티아이(주) SW개발 부문 신입 및 경력직 채용(대전)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '대전 유성구',
#   '분류': "['웹개발', '하드웨어·소프트웨어']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38585195'},
#  {'기업명': '(주)두잉랩',
#   '직무': '[Tech Startup 두잉랩] 딥러닝 및 Web 개발 엔지니어 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601542'},
#  {'기업명': '(주)프로씨엔에스',
#   '직무': 'Oracle DBA 경력사원 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['응용프로그램개발', 'ERP·시스템분석·설계']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38612607'},
#  {'기업명': '한국직업전문학교',
#   '직무': '[국비무료/수당지급] 빅데이터/응용 S/W 개발자 과정 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '서울 구로구',
#   '분류': "['그래픽디자인·CG', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38393122'},
#  {'기업명': '조인스중앙(주)',
#   '직무': '20년 조인스중앙 IT 부문별 경력직(N/W, 온라인채널) 채용',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38612122'},
#  {'기업명': '(주)글로벌머니익스프레스',
#   '직무': '2020년 개발직군 대규모 채용外',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['해외영업·무역영업', '기획·전략·경영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38632864'},
#  {'기업명': '(주)리만코리아',
#   '직무': '[리만코리아] 2020 신입 및 경력 정규직 수시채용(서울,대구)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['상품기획·MD', '총무·법무·사무']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38597262'},
#  {'기업명': '(주)와이비시스템',
#   '직무': '개발자 담당 경력 정규직 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579699'},
#  {'기업명': '원투씨엠(주)',
#   '직무': '소프트웨어 개발/서비스기획 경력 채용',
#   '경력사항': '5 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533730'},
#  {'기업명': '(주)아이스크림에듀',
#   '직무': '㈜아이스크림에듀 콘텐츠,개발,마케팅,영업,관리 직군 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['상품기획·MD', '마케팅·광고·분석']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569553'},
#  {'기업명': '다우기술',
#   '직무': '다우기술 인터넷서비스 DBA 경력사원 채용',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653391'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 개발 경력자 대규모 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 송파구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561876'},
#  {'기업명': '(주)비아이씨엔에스',
#   '직무': '[정규직]정보계 ETL / DW 설계/개발자 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38640184'},
#  {'기업명': '주식회사 노벨알엔디',
#   '직무': '[삼성전자 화성] JAVA 개발자(신입/경력) 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 프리랜서',
#   '근무지': '경기 화성시',
#   '분류': "['그래픽디자인·CG', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38612652'},
#  {'기업명': '㈜아이비에스',
#   '직무': '[구미] C#, .NET 개발자를 모집합니다.',
#   '경력사항': '5 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경북 구미시',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38549559'},
#  {'기업명': '(주) 동성모터스',
#   '직무': '[부산] BMW 동성모터스 기획팀 IT 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산전체',
#   '분류': "['서버·네트워크·보안', '하드웨어·소프트웨어']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587859'},
#  {'기업명': '(주)듀얼에스디',
#   '직무': 'Oracle DBA 경력자 모집',
#   '경력사항': '3 ~ 20년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '강원 원주시',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38651175'},
#  {'기업명': '현대오토에버(주)',
#   '직무': '현대오토에버 경력사원 대규모 상시 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579561'},
#  {'기업명': '현대오토에버(주)',
#   '직무': '웹/ 앱/ 시스템/ 인프라/ 네트웍/ 서버/보안 부문 경력모집',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579541'},
#  {'기업명': '현대오토에버(주)',
#   '직무': 'Salesforce 개발/운영 부문 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589914'},
#  {'기업명': 'SK C&C Beijing',
#   '직무': '데이터베이스·DBA(Oracle/DB2/DBA外 1개 부문) 채용',
#   '경력사항': '7 ~ 8년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직',
#   '근무지': '아시아·중동 중국.홍콩',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38650270'},
#  {'기업명': '(주)지팡이',
#   '직무': '[전산실] 웹프로그래머(경력)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38650223'},
#  {'기업명': '(주)티시스',
#   '직무': '태광그룹 ㈜티시스 경력사원 공개채용 (IT, 부동산, 건설, 레저)',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['AS·서비스·수리', '레저·스포츠']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649618'},
#  {'기업명': '국립암센터',
#   '직무': '국립암센터 ( 전산운영파트 ) 과제연구원 채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '경기 고양시 일산동구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38459730'},
#  {'기업명': '(주)비아이매트릭스',
#   '직무': '솔루션 Presales 담당자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['IT·솔루션영업', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565779'},
#  {'기업명': '로크웰오토메이션코리아(주)',
#   '직무': 'Software Lead Engineer 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기계·기계설비', '전기·전자·제어']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567097'},
#  {'기업명': '(주)북큐브네트웍스',
#   '직무': '㈜북큐브네트웍스 DBA/서버관리자 직원 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649371'},
#  {'기업명': '주식회사 이안',
#   '직무': '웹 서버 개발자 경력 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 구로구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38608061'},
#  {'기업명': '하나금융투자(주)',
#   '직무': '하나금융투자 전문직(경력) 인재 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['해외영업·무역영업', '기획·전략·경영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38633389'},
#  {'기업명': '아미쿠스렉스(주)',
#   '직무': '웹개발자 경력직 (대리/과장급) 채용',
#   '경력사항': '5 ~ 7년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38633485'},
#  {'기업명': '(주)보고플레이',
#   '직무': '[Live 커머스 플랫폼] PD,MD,마케팅,CS,JAVA,iOS/Android앱개발',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['상품기획·MD', '홍보·PR·사보']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569631'},
#  {'기업명': '(주)파오스파트너스',
#   '직무': '(주)파오스파트너스 각 분야별 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['기획·전략·경영', '마케팅·광고·분석']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38619277'},
#  {'기업명': '(주)나비엠알오',
#   '직무': '2020년 하반기 각 분야 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['해외영업·무역영업', '구매·자재·재고']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38605703'},
#  {'기업명': '(주)푸드테크',
#   '직무': 'IT부문 신입 및 경력사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 강남구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526283'},
#  {'기업명': '(주)쿠프마케팅',
#   '직무': 'DBA 3년~13년 경력사원을 찾습니다',
#   '경력사항': '3 ~ 13년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648691'},
#  {'기업명': '코코네(주)',
#   '직무': '(COCONE) 인프라 엔지니어 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648353'},
#  {'기업명': '주식회사 칸정보기술',
#   '직무': '자동제어 프로그램 ASP / DB 개발자 정규직 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 부천시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648199'},
#  {'기업명': '(주)텍트원',
#   '직무': 'JAVA/JSP/WEB 개발자 PL/PM[안양/인덕원]',
#   '경력사항': '경력 2년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38647693'},
#  {'기업명': '㈜진학사',
#   '직무': '[경력] 오픈소스/닷넷 기반 웹 개발자',
#   '경력사항': '2 ~ 5년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['웹개발', '퍼블리싱·UI개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601375'},
#  {'기업명': '(주)유비온',
#   '직무': '[유비온] 미래교육사업부(웹 어플리케이션 개발자 채용)',
#   '경력사항': '3 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576322'},
#  {'기업명': '(사)한국물가협회',
#   '직무': '사)한국물가협회 직원 채용 공고',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38646976'},
#  {'기업명': '(주)아이엔에스시스템',
#   '직무': '[분당]대기업 DB운영 및 솔루션 관리 경력자 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38480590'},
#  {'기업명': '(주)로지올',
#   '직무': '[생각대로] 전국1위 배달 플랫폼 백엔드/모바일/웹 개발자',
#   '경력사항': '1 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹개발', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38609242'},
#  {'기업명': '(주)헬로월드',
#   '직무': '[포스피드] 2020년 하반기 신입 및 경력 사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '일반영업']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38604512'},
#  {'기업명': '이지스엔터프라이즈(주)',
#   '직무': '각 부문별 경력직 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['사무보조·문서작성', '마케팅·광고·분석']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38609684'},
#  {'기업명': '(주)트랜스코스모스코리아',
#   '직무': '당사 CX개발사업본부 개발 및 운영 담당자(신입/경력)Mj5E',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38512364'},
#  {'기업명': '(주)클래스액트',
#   '직무': '[클래스액트] 백엔드 시스템 개발자',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38638411'},
#  {'기업명': '(주)위메프',
#   '직무': '[개발] DW Data Engineer(정규직)',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37766173'},
#  {'기업명': '(주)피어스넷',
#   '직무': 'Java,JSP(SSO/리포팅툴)/DB암호화 개발/엔지니어 구인공고',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강서구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591032'},
#  {'기업명': '(주)비트나인',
#   '직무': '[비트나인] DB엔지니어 경력직 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38644465'},
#  {'기업명': '(주)캐롯아이',
#   '직무': '캐롯아이와 함께 성장 할 Developer 모집합니다.',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 고양시 일산동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38395853'},
#  {'기업명': 'SK C&C Beijing',
#   '직무': 'SK(주) C&C중국법인[System/Network/DB]구축&운영/중국无锡근무',
#   '경력사항': '경력 7년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '해외취업',
#   '근무지': '아시아·중동 중국.홍콩',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38644359'},
#  {'기업명': '(주)핀샷',
#   '직무': '개발자 모집 (신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38635226'},
#  {'기업명': '(주)그라비티',
#   '직무': '[그라비티/나스닥 상장] Java 웹 서비스 / 플랫폼 개발자 경력',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38557706'},
#  {'기업명': '전문건설공제조합',
#   '직무': '전문건설공제조합 직원 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '전국',
#   '분류': "['총무·법무·사무', '인사·교육·노무']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598468'},
#  {'기업명': '주식회사 써머스플랫폼',
#   '직무': '[에누리가격비교]써머스플랫폼 개발부문(연구소) 경력직 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38521796'},
#  {'기업명': '(주)센드버드코리아',
#   '직무': '[실리콘밸리 기업] 클라우드 데이터 아키텍트 (DA / NoSQL)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38642318'},
#  {'기업명': '(주)쉐어마인드',
#   '직무': 'WEB 개발/운영(Java/Spring/MSA) 경력직 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 고양시 일산동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599340'},
#  {'기업명': '(주)아이디어빈스',
#   '직무': '각 부문 경력사원 모집 (개발/기획/경리총무)',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['기획·전략·경영', '경리·출납·결산']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38618334'},
#  {'기업명': '(주)아름누리메디컴',
#   '직무': '㈜아름누리메디컴 기술영업, 안드로이드 개발 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 용인시 수지구',
#   '분류': "['IT·솔루션영업', '웹마스터·QA·테스터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38573541'},
#  {'기업명': '(주)컴투스',
#   '직무': '[컴투스/게임빌컴투스플랫폼/게임빌] 각 부문별 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 금천구',
#   '분류': "['기획·전략·경영', '회계·재무·세무·IR']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533467'},
#  {'기업명': '콘센트릭스서비스코리아(유)',
#   '직무': '[콘센트릭스]UX/UI 구축기획 및 디자이너, BX기획 외',
#   '경력사항': '경력 4년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 용산구',
#   '분류': "['기획·전략·경영', '홍보·PR·사보']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580989'},
#  {'기업명': '(주)에이치비테크놀러지',
#   '직무': 'HB테크놀러지 신입/경력사원 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '충남 아산시',
#   '분류': "['기획·전략·경영', '회계·재무·세무·IR']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38615564'},
#  {'기업명': '(주)도움이티에스',
#   '직무': '㈜도움이티에스 2020 영업본부 신입/경력 공채 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['마케팅·광고·분석', '일반영업']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580325'},
#  {'기업명': '(주)빛컨',
#   '직무': '백엔드 개발자 채용(경력5년이상)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592641'},
#  {'기업명': '(주)엑시아',
#   '직무': '[(주)엑시아 소프트 DBA 개발자 모집',
#   '경력사항': '3 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38641337'},
#  {'기업명': '(주)비엠더코리아',
#   '직무': 'DB분야 (DBA 수행) SI/SM 초급/중급 프리랜서 모집',
#   '경력사항': '2 ~ 8년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '프리랜서',
#   '근무지': '서울 송파구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38429069'},
#  {'기업명': '(주)디엠씨미디어',
#   '직무': '[SBS계열사-DMC미디어] 디지털 광고 플랫폼 개발 경력 수시 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38639344'},
#  {'기업명': '(주)에어릭스',
#   '직무': '[경력] 웹개발(프론트엔드/백엔드) 정규직 채용',
#   '경력사항': '7 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38638659'},
#  {'기업명': '㈜해커스교육그룹',
#   '직무': '2020년 해커스 교육그룹 [신입/경력] 각 부문별 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38369849'},
#  {'기업명': '주식회사 이커머스테크',
#   '직무': '[SI/중급/마곡] AI 기반 시스템 구축',
#   '경력사항': '경력 6년↑',
#   '학력': '학력무관',
#   '근무형태': '프리랜서',
#   '근무지': '서울 강서구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38637672'},
#  {'기업명': '트리노드 주식회사',
#   '직무': '[본사] 데이터분석팀 데이터분석가 경력 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 해운대구',
#   '분류': "['게임·Game', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38361089'},
#  {'기업명': '(주)한국코퍼레이션',
#   '직무': '(주)한국클라우드 하반기 개발/유지보수 부문 정규직 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38636447'},
#  {'기업명': '(주)신영이에스디',
#   '직무': '(주)신영이에스디 정보화 분야 신입/경력 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38449841'},
#  {'기업명': '한일후지코리아(주)',
#   '직무': '전산기획부-전산개발 파트 경력직 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '부산 중구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38636214'},
#  {'기업명': '(주)에이스톰테크놀로지',
#   '직무': '[신입/경력] 소프트웨어 엔지니어 정규직 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['하드웨어·소프트웨어', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38609805'},
#  {'기업명': '한국직업능력교육원 안산',
#   '직무': '경기/시흥・안산/군포 국비무료 취업연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '경기 안산시 단원구',
#   '분류': "['회계·재무·세무·IR', '생산관리·품질관리']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38527236&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)트랜스코스모스코리아',
#   '직무': '당사 CX개발사업본부 개발 및 운영 담당자(신입/경력)Mj5E',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38611523'},
#  {'기업명': '(주)인터프로커뮤니케이션',
#   '직무': '[경력] 웹 개발자 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['웹마스터·QA·테스터', '웹기획·PM']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38612398'},
#  {'기업명': '(주)퍼니플럭스',
#   '직무': '애니메이션업 R&D팀 개발자 모집',
#   '경력사항': '1 ~ 3년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574678'},
#  {'기업명': '(주)코오롱',
#   '직무': '2020년 코오롱그룹 8월 정기공채',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 과천시',
#   '분류': "['보안·경호·안전', '회계·재무·세무·IR']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38615757'},
#  {'기업명': '(주)푸시뉴스',
#   '직무': '각 부서별 신입/경력직 공개채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['총무·법무·사무', '경리·출납·결산']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38492003'},
#  {'기업명': '(주)쿠프마케팅',
#   '직무': '정보보안실 개인정보/정보보호 경력사원 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['서버·네트워크·보안', '하드웨어·소프트웨어']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631959'},
#  {'기업명': '(주)디지털알엑스솔루션',
#   '직무': '뉴노멀을 이끌  IT개발팀 개발리더와 개발자를 모십니다.',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38605007'},
#  {'기업명': '(주)락플레이스',
#   '직무': '오픈소스 DBMS 엔지니어 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['하드웨어·소프트웨어', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631784'},
#  {'기업명': '(주)미래아이앤지',
#   '직무': '하반기 금융솔루션 기술지원부문 신입 및 경력 공개채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 광진구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38446923'},
#  {'기업명': '모닝인컨설팅',
#   '직무': '[어학원]웹개발/Java,Orcle,PHP,MySQL/3500만원 이상/압구정역',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576515'},
#  {'기업명': '굿어스데이터(주)',
#   '직무': 'IT솔루션/제품영업 (경력 5년 이상)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['IT·솔루션영업', '영업기획·관리·지원']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38629708'},
#  {'기업명': '굿어스데이터(주)',
#   '직무': 'Oracle 영업담당자 (경력 3년 이상)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['IT·솔루션영업', '영업기획·관리·지원']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38629650'},
#  {'기업명': '(주)마상소프트',
#   '직무': '[부산] 온라인게임 데이터베이스, DBA 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '부산 해운대구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38629625'},
#  {'기업명': '굿어스데이터(주)',
#   '직무': 'Oracle WebLogic 엔지니어 (경력 5년이상)',
#   '경력사항': '5 ~ 12년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38629532'},
#  {'기업명': '(주)사우정보기술',
#   '직무': 'DBA 경력자 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 금천구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38629482'},
#  {'기업명': '엔셀 주식회사',
#   '직무': '반도체 전산/DB/SQL운영, shell 프로그래밍 정규직',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 화성시',
#   '분류': "['서버·네트워크·보안', '컨텐츠·사이트운영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38374345'},
#  {'기업명': '(주)윕스',
#   '직무': '[인프라개발부 기획팀] 웹 기획 담당자 모집',
#   '경력사항': '4 ~ 8년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹기획·PM', '퍼블리싱·UI개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38627926'},
#  {'기업명': '㈜위트콤',
#   '직무': '웹 백엔드 개발(Web Backend)',
#   '경력사항': '경력 7년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹마스터·QA·테스터', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38627593'},
#  {'기업명': '주피타카(주)',
#   '직무': '[Node.js] Back-end/DBA/Scrapping/ProductDesigner 경력채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38568156'},
#  {'기업명': '엔셀 주식회사',
#   '직무': 'Display 전산/DB/SQL운영, shell 프로그래밍 정규직',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '충남 아산시',
#   '분류': "['서버·네트워크·보안', '컨텐츠·사이트운영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38627184'},
#  {'기업명': '㈜다임즈',
#   '직무': '[대전] 프리랜서(계약직) WEB 개발자 충원',
#   '경력사항': '3 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 프리랜서',
#   '근무지': '대전 유성구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
# ...
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38452563'},
#  {'기업명': '(주)아이뱅크',
#   '직무': '크로스 채널 마케팅 자동화 솔루션 개발자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['마케팅·광고·분석', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38450914'},
#  {'기업명': '(주)헬릭스테크',
#   '직무': '서버 백엔드 개발자 및 프리랜서 채용',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직 · 프리랜서',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38450327'},
#  {'기업명': '(주)네오하이테크',
#   '직무': '[정규직] 소프트웨어 개발 경력직 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 군포시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38449789'},
#  {'기업명': '㈜비즈테크파트너스',
#   '직무': '모바일 웹 개발 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38449022'},
#  {'기업명': '(주)유니마이크로테크놀러지',
#   '직무': 'MS-SQL 기술지원 엔지니어(경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38448301'},
#  {'기업명': '(주)프레제니우스메디칼케어코리아',
#   '직무': '외국계기업 IT부문 Clinical System Support Manager',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38362568'},
#  {'기업명': '슈퍼시스템(주)',
#   '직무': '(주)슈퍼시스템 개발자 채용',
#   '경력사항': '2 ~ 7년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 동작구',
#   '분류': "['응용프로그램개발', '퍼블리싱·UI개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38446763'},
#  {'기업명': '(주)플라밍고',
#   '직무': '백엔드 Java·JSP,JavaScript, API , 클라우드 개발 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 광진구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38444129'},
#  {'기업명': '(주)플라밍고',
#   '직무': '웹개발, 응용프로그램개발 정규직/계약직 채용(인재선발)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 광진구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38444106'},
#  {'기업명': '재팬리미트파이낸스(주)',
#   '직무': '[재팬리미트파이낸스] 웹개발 경력자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38441606'},
#  {'기업명': '(주)인플러스',
#   '직무': '앱(Android, iOS) 프론트&백엔드 개발 프리랜서/계약직 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직 · 프리랜서',
#   '근무지': '울산 남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38440228'},
#  {'기업명': '(주)인플러스',
#   '직무': '웹(PHP, JSP)/앱(Android, iOS) 프론트&백엔드 개발자 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '울산 남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38440099'},
#  {'기업명': '씽킹블록체인(주)',
#   '직무': 'PHP 웹 개발자 모집 경력사원 채용 공고(정규직)',
#   '경력사항': '경력 3년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38438745'},
#  {'기업명': '엠포플러스(주)',
#   '직무': '병역특례 보충역 개발자 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 광진구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38438634'},
#  {'기업명': '(주)에이원플랫폼',
#   '직무': '[정규직/탄력근무제] 솔루션 웹 개발 모집',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '퍼블리싱·UI개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38433434'},
#  {'기업명': '(주)네이블커뮤니케이션즈',
#   '직무': 'JAVA 서버개발자 경력직 채용',
#   '경력사항': '5 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38432996'},
#  {'기업명': '(주)와보텍',
#   '직무': 'VR/AR 기획자 / 유니티 개발자 정규직 모집합니다 - 경력.',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38382645'},
#  {'기업명': '주식회사 그린블루',
#   '직무': 'JAVA개발자(경력) 정규직 -10년 이상',
#   '경력사항': '10 ~ 15년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 의왕시',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38432501'},
#  {'기업명': '주식회사 여기에',
#   '직무': '웹개발자 채용 공고',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대구 북구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38432189'},
#  {'기업명': '(주)포위즈시스템',
#   '직무': '[포위즈시스템] 2020년 하반기 경력자 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대구 동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38431194'},
#  {'기업명': '(주)잉카인터넷',
#   '직무': '서버 보안 개발자',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38429539'},
#  {'기업명': '(주)다인리더스',
#   '직무': '(주)다인리더스 기획/컨설팅 직무 채용 공고',
#   '경력사항': '2 ~ 3년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['기획·전략·경영', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38428797'},
#  {'기업명': '솔트웨어(주)',
#   '직무': 'AWS 영업, 컨설팅, 기술지원 및 영업마케팅지원 경력직',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38426925'},
#  {'기업명': '(주)청담홀딩스',
#   '직무': '[대전] [SI개발부] 웹프로그래머 경력직 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['웹개발', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38426538'},
#  {'기업명': '(주)소프트엔지니어소사이어티',
#   '직무': '(Java, Spring, Mybatis, Ajax 기반) 웹 프로그램 개발자 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38423306'},
#  {'기업명': '굿네트워크',
#   '직무': '[스타트업-방굿] IOS/안드로이드 개발자 채용',
#   '경력사항': '경력 7년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38421467'},
#  {'기업명': '굿네트워크',
#   '직무': '[스타트업-방굿] IOS/안드로이드 개발자 채용 (부동산 플랫폼)',
#   '경력사항': '경력 7년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38421456'},
#  {'기업명': '(주)루나소프트',
#   '직무': '[㈜루나소프트] .net(닷넷) 개발 3년 이상 경력자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38419178'},
#  {'기업명': '지오시스 유한회사',
#   '직무': '[Qoo10] Data Architect Team 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38399673'},
#  {'기업명': '(주)구루아이오티',
#   '직무': '[구루IOT] S/W 개발자 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38412563'},
#  {'기업명': '(주)티디아이',
#   '직무': '코로나19 여파에도 성장하는 (주)TDI 채용공고 - 기자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38416616'},
#  {'기업명': '(주)세마그룹',
#   '직무': 'PHP(Laravel) 웹앱 개발 경력직 채용(급여 최고 대우)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '부산 부산진구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38414638'},
#  {'기업명': '(주)웨어밸리',
#   '직무': '소프트웨어(SW) 테스트(QA)경력자 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38413042'},
#  {'기업명': '(주)솔라테크',
#   '직무': '홈페이지 디자인 & 개발',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 광명시',
#   '분류': "['웹개발', '퍼블리싱·UI개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38411916'},
#  {'기업명': '디휴브',
#   '직무': '풀스택 개발자 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 고양시 일산동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38389786'},
#  {'기업명': '㈜다음소프트',
#   '직무': '각 부문별 개발자 모집합니다.',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38408815'},
#  {'기업명': '코어닷투데이',
#   '직무': '데이터 분석 콘텐츠 개발 / 기획 / 분석 구인 (Python 특화)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '울산 울주군',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38353928'},
#  {'기업명': '주식회사 코빗',
#   '직무': 'Exchange Frontend Developer 인턴직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '인턴직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38400173'},
#  {'기업명': '(주)콘샐러드',
#   '직무': '[병역특례] 정보처리 산업기능요원 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 송파구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38399135'},
#  {'기업명': '(주)소리자바',
#   '직무': 'PL 경력사원 모집 공고',
#   '경력사항': '경력 10년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38380896'},
#  {'기업명': '(주)제이이노텍',
#   '직무': 'CIM 파트 팀원 0명 경력&신입 채용 (천안 거주자 채용)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '충남 천안시 서북구',
#   '분류': "['전기·전자·제어', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38395792'},
#  {'기업명': '(주)프래프',
#   '직무': '[(주)프래프] 프론트앤드 개발자 채용 모집 (신입,경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38394281'},
#  {'기업명': '(주)프래프',
#   '직무': '[(주)프래프] 백앤드 개발자 채용 모집 (신입,경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38394278'},
#  {'기업명': '(주)니트로아이',
#   '직무': 'JAVA/JSP 전자정부프레임워크 웹 개발자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '경기 수원시 팔달구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38393613'},
#  {'기업명': '(주)시큐에버',
#   '직무': '연구소(솔루션 개발부) 경력 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38393043'},
#  {'기업명': '(주)교원',
#   '직무': '[교원그룹] 스마트테크부문 경력직 수시채용 (Data Scientist)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38392474'},
#  {'기업명': '인포뱅크(주)',
#   '직무': 'Java 개발자 모집(응용/웹프로그래머)',
#   '경력사항': '2 ~ 6년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38391453'},
#  {'기업명': '주식회사 라이프시맨틱스',
#   '직무': '서버개발, 분석/예측 개발자 모집(병역특례지원 가능)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38385602'},
#  {'기업명': '주식회사 더노디스트',
#   '직무': '[개발팀]  외 경력사원 채용 공고',
#   '경력사항': '2 ~ 20년',
#   '학력': '고졸↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '퍼블리싱·UI개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38384017'},
#  {'기업명': '(주)티에이나인',
#   '직무': '[티에이나인] 온라인 쇼핑몰 운영 정규직 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38378880'},
#  {'기업명': '(주)아이도트',
#   '직무': '[정규직] Java 서버 개발자 경력 채용',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38378728'},
#  {'기업명': '(주)너울정보',
#   '직무': '펫테크 웹앱개발(정규직)',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38376221'},
#  {'기업명': '(주)너울정보',
#   '직무': '사내 시스템 개발자를 찾습니다(정규직)',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38376121'},
#  {'기업명': '주식회사 파수',
#   '직무': 'Server 개발(모바일/웹)',
#   '경력사항': '4 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38368848'},
#  {'기업명': '(주)테크데이타글로벌',
#   '직무': '[TDG] 클라우드 빅데이타 플랫폼 구축 분야 담당 채용(신입/경력',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38366908'},
#  {'기업명': '(주)테크데이타글로벌',
#   '직무': '[TDG] 클라우드 게임 서비스 런치 담당 채용(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38366809'},
#  {'기업명': '일루넥스',
#   '직무': '2020년 상반기 웹 개발, 퍼블리셔, 마케팅 신입및  경력직 채용',
#   '경력사항': '3 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38365757'},
#  ...]

# %%
job_list = job_list_cloud + job_list_python + job_list_db

# %%
# local db에 job_list 저장하기

import pymysql
import sqlalchemy
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("mysql+mysqldb://python:"+"python"+"@localhost/poor_db", encoding="utf-8")
conn = engine.connect()

jobs_df = pd.DataFrame(columns=['기업명', '직무', '경력사항', '학력', '근무형태', '근무지', '분류', '분류필터', '상세링크'])

for post in job_list:
    obj = pd.Series(post)
    jobs_df = jobs_df.append(obj, ignore_index=True)
    
jobs_df.to_sql(name="job_list", con=engine, if_exists='replace', index=True, index_label='id')

# %%
# remote db(멀캠 컴퓨터)에 job_list 저장하기
import pymysql
import sqlalchemy
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("mysql+mysqldb://minji:"+"minji"+"@192.168.0.25:3306/poor_db", encoding="utf-8")
conn = engine.connect()

jobs_dict = {"jobs_cloud": company_list_cloud, "jobs_python": company_list_python, "jobs_db": company_list_db}

for table_name, jobs in jobs_dict.items():
    print("\n", table_name, "\n")
    jobs_df = pd.DataFrame(columns=['기업명', '직무', '경력사항', '학력', '근무형태', '근무지', '분류', '상세링크'])
    
    for post in jobs:
        obj = pd.Series(post)
        jobs_df = jobs_df.append(obj, ignore_index=True)
        print(post)
    
    jobs_df.to_sql(name=table_name, con=engine, if_exists='replace', index=True, index_label='id')
# Out:
#  jobs_cloud
#
# {'기업명': '펜타시큐리티시스템(주)', '직무': '[펜타시큐리티] 보안S/W 개발자 모집 (DB, 인증, 클라우드)', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직 · 계약직', '근무지': '서울 영등포구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595144&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)보고플레이', '직무': '[Live 커머스 플랫폼] PD,MD,마케팅,CS,JAVA,iOS/Android앱개발', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['상품기획·MD', '홍보·PR·사보']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569631&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)레뷰코퍼레이션', '직무': '플랫폼그룹 부문별 신입/경력직 채용', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['캐릭터·만화·애니', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38541335&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)시지온', '직무': '라이브리 서비스 광고 플랫폼 개발자 모집', '경력사항': '3 ~ 15년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38593999'}
# {'기업명': '주식회사 코드베르그', '직무': '코드베르그 Back-end 개발부문 모집 (PHP or Node.js)', '경력사항': '3 ~ 6년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38434985'}
# {'기업명': '파우게임즈', '직무': '[파우게임즈] 기술지원(DB/웹개발) 담당자 채용', '경력사항': '3 ~ 5년', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38406328'}
# {'기업명': '(주)상록아이엔씨', '직무': '[경험자 우대] Python/Linux AI 시스템 개발자 채용', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 부천시', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601843&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)옷딜', '직무': 'Ai솔루션 옷딜 각부분 경력모집', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['기획·전략·경영', '출판·편집디자인']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580264&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)중고나라', '직무': '[중고나라] 개발 부문 전문가 채용', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38573880&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)자비스', '직무': '[코스닥 상장사 ㈜자비스] 2020년 하반기 공개채용', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 중원구', '분류': "['해외영업·무역영업', '사무보조·문서작성']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578169&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)후이즈', '직무': '㈜후이즈 쇼핑몰 각 부문별 신입/경력 정규직 채용', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 구로구', '분류': "['기획·전략·경영', '사무보조·문서작성']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563638&adsCategoryItem=effect_bold&'}
# {'기업명': '한국직업전문학교', '직무': '[국비무료/수당지급] 빅데이터/UI/UX 퍼블리싱/응용 S/W 개발자', '경력사항': '경력무관', '학력': '고졸↑', '근무형태': '교육생', '근무지': '서울 구로구', '분류': "['그래픽디자인·CG', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38393122&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)큐픽스', '직무': '[신입/경력/전문연구요원] AWS/Ruby 백엔드엔지니어(DevOps)', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586042'}
# {'기업명': '네오다임(주)', '직무': '네오다임(주) 웹 개발자 / 웹 디자이너 모집', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38344313'}
# {'기업명': '(재)충남정보문화산업진흥원', '직무': '2020년 제 3차 계약직 직원채용 공고(연장공고)', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '계약직', '근무지': '충남 천안시 동남구', '분류': "['기획·전략·경영', '홍보·PR·사보']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539566&adsCategoryItem=effect_bold&'}
# {'기업명': '주식회사 단비', '직무': 'AI / 머신러닝 / Go / Python / MES 분야별 개발인력 모집합니다', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '부산 해운대구', '분류': "['웹개발', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38377404'}
# {'기업명': '(주)이지다이아텍', '직무': '[기업부설연구소] 응용소프트웨어 개발자 경력직원 모집', '경력사항': '신입 · 경력', '학력': '대학(2,3년)↑', '근무형태': '정규직 · 병역특례', '근무지': '경기 안양시 동안구', '분류': "['응용프로그램개발', '시스템개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552827'}
# {'기업명': '(주)매드업', '직무': '[매드업] 하반기 전 직군 대규모 채용', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['인사·교육·노무', '마케팅·광고·분석']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596083&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)이노와이어리스', '직무': '이노와이어리스/큐셀네트웍스 각 분야 신입/경력 채용', '경력사항': '경력무관', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['생산관리·품질관리', '생산·제조·포장·조립']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590538&adsCategoryItem=effect_bold&'}
# {'기업명': '패스트캠퍼스(주)', '직무': '[패스트캠퍼스] 대규모 인재 채용', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['기획·전략·경영', '마케팅·광고·분석']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38230007'}
# {'기업명': '(주)선진', '직무': '[하림그룹] ㈜선진 신입/경력 수시채용', '경력사항': '경력 2년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울전체', '분류': "['회계·재무·세무·IR', '마케팅·광고·분석']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580036'}
# {'기업명': '(주)세차왕', '직무': '세차왕에서 백엔드 및 웹앱 개발자를 모십니다.', '경력사항': '경력 2년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562173'}
# {'기업명': '㈜아이티언', '직무': '보안 솔루션 및 서비스 운영 엔지니어(신입/경력)', '경력사항': '신입 · 경력', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '경기 안양시 동안구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38414809'}
# {'기업명': '켈리서비스 유한회사', '직무': '[한국화웨이/영어or중국어] IT Engineer (서버유지보수, ICT)', '경력사항': '경력 1년↑', '학력': '대학교(4년)↑', '근무형태': '계약직 · 파견직', '근무지': '서울 중구', '분류': "['기술영업', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38584624'}
# {'기업명': '(주)경일게임아카데미', '직무': '게임회사 취업 협약 교육생 모집', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '교육생', '근무지': '서울전체', '분류': "['서버·네트워크·보안', '웹기획·PM']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38577413&adsCategoryItem=effect_bold&'}
# {'기업명': '휴먼교육센터학원', '직무': '[전액무료]자바/파이썬 IT교육받고 취업하자', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '교육생', '근무지': '서울전체', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38510654&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)지에스아이티엠', '직무': '2020년 하반기 GS ITM 경력사원 공개채용', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 종로구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587357'}
# {'기업명': '(유)딜리버리히어로 코리아', '직무': '전 개발직군 대규모 채용중', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['기획·전략·경영', '총무·법무·사무']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38476546'}
# {'기업명': '한국산업단지공단', '직무': '20년 하반기 신입직원/고졸채용형인턴/체험형청년인턴 모집 공고', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직 · 계약직', '근무지': '대구 달서구', '분류': "['총무·법무·사무', '회계·재무·세무·IR']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596493'}
# {'기업명': '(주)맨파워그룹코리아', '직무': '[삼성물산/연봉상위] 모바일 앱 및 웹 운영 경력 개발자 채용', '경력사항': '3 ~ 20년', '학력': '학력무관', '근무형태': '계약직 · 파견직', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591901'}
# {'기업명': '(주)안랩', '직무': '2020 하반기 안랩 연구소 신입사원 공개채용', '경력사항': '신입', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578654'}
# {'기업명': '(주)씨제이이엔엠', '직무': 'CJ ENM(E&M부문) TVING 경력사원 모집', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38515830'}
# {'기업명': '(주)여우전자', '직무': '여우전자 하반기 신규채용 모집 공고', '경력사항': '신입 · 경력', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['마케팅·광고·분석', '일반영업']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574212'}
# {'기업명': '(주)넷케이티아이', '직무': '각분야 정규직원 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['기획·전략·경영', '기술영업']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578831'}
# {'기업명': '(주)볼트홀', '직무': '[2020년 볼트홀] 웹서버 개발자/Javascript,AWS,php,node.js', '경력사항': '5 ~ 10년', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 수정구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586962'}
# {'기업명': '한국전자통신연구원', '직무': '2020년 3차 박사후연수연구원 및 위촉연구원 공개채용', '경력사항': '경력무관', '학력': '석사↑', '근무형태': '계약직', '근무지': '대전 유성구', '분류': "['화학·에너지', '반도체·디스플레이·LCD']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590666'}
# {'기업명': '(주)월드스폰', '직무': '웹 서비스 유지보수 및 기획자 모집', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹기획·PM']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552512'}
# {'기업명': '펍지(주)', '직무': '펍지㈜ 각 부문별 수시 채용', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['총무·법무·사무', '인사·교육·노무']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38542347'}
# {'기업명': '(주)후이즈', '직무': '(주)후이즈 도메인사업부 개발자 인재 채용', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 구로구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528456'}
# {'기업명': '(주)하나금융티아이', '직무': '[하나금융융합기술원] 부문별 경력사원 모집', '경력사항': '경력', '학력': '석사↑', '근무형태': '정규직 · 계약직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹기획·PM']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565737'}
# {'기업명': '㈜해커스교육그룹', '직무': '2020년 해커스 교육그룹 [신입/경력] 각 부문별 채용공고', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직 · 계약직', '근무지': '서울 서초구', '분류': "['기획·전략·경영', '총무·법무·사무']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38369849'}
# {'기업명': '한국직업능력교육원 안산', '직무': '경기/시흥・안산/군포 국비무료 취업연수생 모집', '경력사항': '경력무관', '학력': '고졸↑', '근무형태': '교육생', '근무지': '경기 안산시 단원구', '분류': "['회계·재무·세무·IR', '생산관리·품질관리']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38527236&adsCategoryItem=effect_bold&'}
# {'기업명': '한밭대학교산학협력단', '직무': '빅데이터 정보보안 S/W 엔지니어 양성과정', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '교육생', '근무지': '대전 유성구', '분류': "['서버·네트워크·보안', '시스템개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38357074'}
# {'기업명': '(주)아임웹', '직무': 'R&D Team  (PHP 개발자) 신입/경력 채용', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서대문구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560119'}
# {'기업명': '(주)LG유플러스', '직무': 'IT개발/운영 신입&경력 개발자 채용', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울전체', '분류': "['웹기획·PM', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533503'}
# {'기업명': '(주)핀크럭스', '직무': '[부산] 서비스를 함께 만들어 가실 웹개발자를 찾습니다.', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '부산 부산진구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562265'}
# {'기업명': '(주) 하트게임즈', '직무': '야근無) 게임 서버 Node.js 개발자 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '게임·Game']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574743'}
# {'기업명': '사운드파이프코리아(주)', '직무': 'H자동차그룹 글로벌 Car Cloud 운영 신입 채용(인도+한국팀)', '경력사항': '신입', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38338895'}
# {'기업명': '사운드파이프코리아(주)', '직무': 'H자동차그룹 카클라우드 리눅스/오픈소스 시스템엔지니어 채용', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38338893'}
# {'기업명': '사운드파이프코리아(주)', '직무': 'H자동차그룹 Car Cloud (오픈스택+쿠버네티스) 시스템엔지니어', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38338892'}
# {'기업명': '메가존(주)', '직무': '[메가존] 프로젝트 개발 경력자 대규모 채용', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직 · 병역특례', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', '웹기획·PM']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561876'}
# {'기업명': '(주)테크데이타', '직무': '[경력] 테크데이타 - AWS 클라우드 엔지니어(SA) 모집', '경력사항': '2 ~ 9년', '학력': '대학(2,3년)↑', '근무형태': '정규직 · 계약직', '근무지': '서울 용산구', '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598106'}
# {'기업명': '리디안솔루션(주)', '직무': 'SAP (Cloud Platform/ CPI / ABAP) 관련 신입, 경력 채용', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['응용프로그램개발', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598068'}
# {'기업명': '(주)트랜스코스모스코리아', '직무': '[월250만/영어우대] MS 클라우드(Azure) 기술지원 엔지니어 Mp3Q', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 종로구', '분류': "['사무보조·문서작성', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38470423'}
# {'기업명': '캐시워크', '직무': '캐시워크와 함께 걸어갈 Node.js 서버 개발자님을 찾습니다', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38597023'}
# {'기업명': '주식회사 블루에이치알', '직무': '[자회사 정규직] 강남구청역 LGU+ 모바일센터 인바운드 상담', '경력사항': '경력무관', '학력': '고졸↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['응용프로그램개발', '시스템개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38446566'}
# {'기업명': '(주)시지온', '직무': '어트랙트 서비스 자바 백엔드 개발자 모집', '경력사항': '5 ~ 15년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594036'}
# {'기업명': '메가존(주)', '직무': '[메가존] 네트워크 운영 및 정보보호 담당 채용', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직 · 병역특례', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', 'IT·디자인·컴퓨터교육']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38333581'}
# {'기업명': '(주)아미크', '직무': '[벤처/강소기업] Cloud Product(AWS) 기획 및 개발 채용', '경력사항': '경력 4년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 성동구', '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38593601'}
# {'기업명': '(주)디모아', '직무': '[쌍방울그룹 계열사] 소프트웨어 영업직 경력/신입 채용', '경력사항': '신입 · 경력', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 용산구', '분류': "['IT·솔루션영업', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551426'}
# {'기업명': '(주)직스엔닥스', '직무': '[개발팀](웹/앱)우수한 React 프론트엔드 개발자 채용 모집', '경력사항': '경력무관', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592735'}
# {'기업명': '베스핀글로벌(주)', '직무': 'Software QA 채용(경력 3년이상)', '경력사항': '3 ~ 12년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592386'}
# {'기업명': '주식회사 위주', '직무': '[주식회사위주]놀러와요시장 어플 서버개발 경력직채용(7년이상)', '경력사항': '경력 7년↑', '학력': '고졸↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38466824'}
# {'기업명': '(주)크로센트', '직무': '클라우드 엔지니어 및 아키텍트 (신입/경력) 정규직 모집', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591760'}
# {'기업명': '포디리플레이코리아(주)', '직무': '[4DReplay] 클라우드 서비스 및 Platform Back End 개발자 모집', '경력사항': '3 ~ 10년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558326'}
# {'기업명': '컴즈(주)', '직무': 'S/W QA & Test Engineer 채용의 件', '경력사항': '신입 · 경력', '학력': '대학(2,3년)↑', '근무형태': '정규직 · 프리랜서', '근무지': '서울 구로구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38588604'}
# {'기업명': '(주)이젠아카데미인재개발원', '직무': '[취업연수 국비교육]자바/파이썬/빅데이터/웹/영상/건축', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '교육생', '근무지': '서울전체', '분류': "['캐릭터·만화·애니', '광고·시각디자인']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=36825236'}
# {'기업명': '굿어스㈜', '직무': 'Cisco SD-WAN 엔지니어 (경력 2년 이상)', '경력사항': '2 ~ 7년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587238'}
# {'기업명': '(주)더블다운인터액티브', '직무': '웹/게임서버 개발자(경력), 클라이언트 개발자(신입/경력) 모집', '경력사항': '경력무관', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '게임·Game']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580038'}
# {'기업명': '(주)민병철교육그룹', '직무': '[민병철유폰] AWS 시스템 엔지니어 (총 경력 5년 이상)', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586234'}
# {'기업명': '스마일샤크', '직무': '[신입] AWS 솔루션 아키텍트(SA)를 스마일샤크팀으로 모십니다.', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586155'}
# {'기업명': '(주)에이프릴세븐', '직무': '[스타트업] 서버개발자 채용 공고', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38585353'}
# {'기업명': '(주)아모레퍼시픽', '직무': "[경력] '20년 AMOREPACIFIC 경력채용_플랫폼 Back-end 개발", '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 용산구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569683'}
# {'기업명': '(주)피타소프트', '직무': '2020년 하반기 각 부문 채용', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['기획·전략·경영', '총무·법무·사무']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38542206'}
# {'기업명': '(주)이노그리드', '직무': '2020 하반기 클라우드 전문기업 이노그리드 신입·경력 채용', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['상품기획·MD', '홍보·PR·사보']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38415519'}
# {'기업명': '(주)앨리스헬스케어', '직무': '(경력) 백엔드(Back-end) 개발자', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582494'}
# {'기업명': '호스트웨이아이디씨(주)', '직무': '[정규직] 시스템 엔지니어 모집(신입/경력)', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', 'IT·디자인·컴퓨터교육']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582146'}
# {'기업명': '(주)아모레퍼시픽', '직무': "[경력] '20년 AMOREPACIFIC 경력채용_통합 OMS 기술PM", '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 용산구', '분류': "['서버·네트워크·보안', '웹기획·PM']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570465'}
# {'기업명': '(주)하나금융티아이', '직무': '[하나금융TI] 금융IT 경력사원 모집', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직 · 계약직', '근무지': '인천전체', '분류': "['기획·전략·경영', '인사·교육·노무']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38572965'}
# {'기업명': '(주)아모레퍼시픽', '직무': "[경력] '20년 AMOREPACIFIC 경력채용_플랫폼 기술 PM", '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 용산구', '분류': "['웹기획·PM', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570239'}
# {'기업명': '(주)아톤', '직무': '[ATON] 신규 서비스 개발팀장 / 서버개발 경력 채용', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['서버·네트워크·보안', '웹기획·PM']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38553981'}
# {'기업명': '주식회사 포티투마루', '직무': '[포티투마루] 인공지능 프론트엔드 개발 채용(경력)', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 관악구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580784'}
# {'기업명': '카이스컴퍼니', '직무': 'React js, AWS, IoT外 1개 부문 개발자 채용 - 정규직&계약직', '경력사항': '경력무관', '학력': '대학(2,3년)↑', '근무형태': '정규직 · 계약직', '근무지': '충북 청주시 서원구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580459'}
# {'기업명': '(주)딤커뮤니케이션', '직무': '[딤커뮤니케이션] 2020년 하반기 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['홍보·PR·사보', '회계·재무·세무·IR']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38464294'}
# {'기업명': '주식회사 오파테크', '직무': '서버개발 정규직 모집 공고(경력)', '경력사항': '3 ~ 6년', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 성동구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38483345'}
# {'기업명': '(주)웰데이타시스템', '직무': 'H자동차그룹 Car Cloud(오픈스택+쿠버네티스) 서비스 운영', '경력사항': '3 ~ 15년', '학력': '학력무관', '근무형태': '정규직 · 계약직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579660'}
# {'기업명': '원투씨엠(주)', '직무': '2020년 하반기 개발자 채용', '경력사항': '5 ~ 10년', '학력': '학력무관', '근무형태': '정규직 · 프리랜서', '근무지': '경기 성남시 분당구', '분류': "['웹개발', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533730'}
# {'기업명': '(주)웰데이타시스템', '직무': '[엔클라우드24] [클라우드&IDC 기술영업/컨설팅/ 공공영업] 채용', '경력사항': '경력무관', '학력': '대학(2,3년)↑', '근무형태': '정규직 · 계약직', '근무지': '경기 성남시 분당구', '분류': "['IT·솔루션영업', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579626'}
# {'기업명': '(주)웰데이타시스템', '직무': '프런트앤드 앱/웹 자바(JAVA) PHP, 클라우드 서비스 개발자 모집', '경력사항': '경력무관', '학력': '대학(2,3년)↑', '근무형태': '정규직 · 계약직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579619'}
# {'기업명': '(주)피처링', '직무': '(정규직) 서버 및 웹 Backend 웹개발자를 채용합니다.', '경력사항': '2 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '인천 연수구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563022'}
# {'기업명': '소상공인연합회', '직무': '2020년 위탁사업담당 (경력/신입) 직원 모집', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '계약직', '근무지': '서울 동작구', '분류': "['기획·전략·경영', '총무·법무·사무']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576477'}
# {'기업명': '(주)두잇시스템', '직무': 'Linux서버 운영 (서울 강서구, 경력 3년이상)', '경력사항': '경력 3년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 강서구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576103'}
# {'기업명': '(주)트위그팜', '직무': '웹 개발 (php, laravel 스페셜리스트) 모집', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38549173'}
# {'기업명': '(주)그로브소프트', '직무': '㈜그로브소프트 2020 하반기 경력직 추가 채용(기획, 개발, 퍼블리셔)', '경력사항': '경력 2년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['기획·전략·경영', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38566074'}
# {'기업명': '(주)케어랩스', '직무': '병원갈땐 굿닥) Java 백엔드 서버 개발자 채용', '경력사항': '3 ~ 10년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575281'}
# {'기업명': '(주)케어랩스', '직무': '병원갈땐 굿닥) PHP서버 개발자 대규모 채용', '경력사항': '5 ~ 10년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575280'}
# {'기업명': '디딤365 주식회사', '직무': '멀티 클라우드 포털 개발 신입/경력사원 모집', '경력사항': '신입 · 경력', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['서버·네트워크·보안', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575121'}
# {'기업명': '디딤365 주식회사', '직무': '클라우드 및 시스템 엔지니어 신입/경력(청년내일채움공제 가능)', '경력사항': '경력무관', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['서버·네트워크·보안', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575060'}
# {'기업명': '(주)에스비에스아이앤엠', '직무': 'SBS I&M 인프라 기획 및 AWS 클라우드 시스템 운영관리자 모집', '경력사항': '5 ~ 10년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562661'}
# {'기업명': '(주)카카오페이', '직무': '[카카오페이] 빅데이터, 하둡(Hadoop)플랫폼 운영 엔지니어 영입', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574921'}
# {'기업명': '라인게임즈 주식회사', '직무': '[라인게임즈] 기술PM 모집', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', '웹기획·PM']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574275'}
# {'기업명': '네오위즈', '직무': '[네오위즈] 각 부문 신입 / 경력자모집', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직 · 계약직', '근무지': '경기 성남시 분당구', '분류': "['회계·재무·세무·IR', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38447372'}
# {'기업명': '주식회사오션라이트에이아이', '직무': '서버·네트워크·보안(서버관리&AWS外 3개 부문) 채용합니다', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직 · 계약직', '근무지': '대구 북구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38571517'}
# {'기업명': '스마일샤크', '직무': '[경력] AWS 솔루션 아키텍트(SA)를 스마일샤크팀으로 모십니다.', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38550815'}
# {'기업명': '(주)웨어포인트', '직무': '(잠실/운영)시스템 엔지니어(SE/TA) 모집', '경력사항': '경력 3년↑', '학력': '대학(2,3년)↑', '근무형태': '계약직 · 프리랜서', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570404'}
# {'기업명': '(주)디타임', '직무': '(주)디타임 서버개발자 경력직 채용', '경력사항': '6 ~ 20년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565481'}
# {'기업명': '(주)립페이', '직무': '[정규직] IoT 플랫폼(백엔드) 개발자 모집', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['응용프로그램개발', '통신·모바일']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560508'}
# {'기업명': '(주)엔픽셀', '직무': '[인프라팀] 클라우드 엔지니어 채용', '경력사항': '경력 5년↑', '학력': '고졸↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38413525'}
# {'기업명': '(주)에스오월드테크놀리지', '직무': '서버관리자(AWS) 채용', '경력사항': '2 ~ 5년', '학력': '대학교(4년)↑', '근무형태': '인턴직', '근무지': '서울 영등포구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38568005'}
# {'기업명': '(주)지에스아이엘', '직무': '(주)지에스아아엘 - 시스템개발팀 경력직 채용', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직 · 계약직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567524'}
# {'기업명': '삼양데이타시스템㈜', '직무': '그룹 Infra 분야 운영 인력 모집', '경력사항': '경력무관', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 종로구', '분류': "['서버·네트워크·보안', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38550753'}
# {'기업명': '오픈플랜(주)', '직무': '[오픈플랜] back-end Developer 우수 인재를 모십니다.', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38505378'}
# {'기업명': '베스핀글로벌(주)', '직무': 'BigData 전문인력 채용(경력 5년 이상)', '경력사항': '5 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['응용프로그램개발', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38566513'}
# {'기업명': '메가존(주)', '직무': '[메가존] 구글클라우드 부문 채용', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['일반영업', 'IT·솔루션영업']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38409477'}
# {'기업명': '(주)앨리스헬스케어', '직무': '백엔드(Back-end) 개발자(경력)', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565409'}
# {'기업명': '(주)이카운트', '직무': '㈜이카운트 시스템관리자(SA팀) 채용', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 구로구', '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565193'}
# {'기업명': '쿠팡 주식회사', '직무': '[쿠팡페이] System Engineer', '경력사항': '경력 8년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38398255'}
# {'기업명': '㈜지에스아이티엠', '직무': 'SE/NE/DBA 경력사원 모집', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 종로구', '분류': "['응용프로그램개발', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38519641'}
# {'기업명': '(주)크리에이트코리아', '직무': '백엔드 개발자/ 웹 & 모바일 개발자 모집', '경력사항': '경력 1년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 중랑구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563318'}
# {'기업명': '대한상공회의소 광주인력개발원', '직무': '2020년도 국비 기술교육생 모집', '경력사항': '경력무관', '학력': '고졸↑', '근무형태': '교육생', '근무지': '광주 광산구', '분류': "['기계·기계설비', '전기·전자·제어']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38404367'}
# {'기업명': '대한상공회의소 충남인력개발원', '직무': '4차산업/전기전자/기계설계/자동화 교육생 모집', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '교육생', '근무지': '충남전체', '분류': "['전기·전자·제어', '설계·CAD·CAM']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38445379'}
# {'기업명': '오케스트로(주)', '직무': '클라우드연구소 PaaS 엔지니어', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 영등포구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552496'}
# {'기업명': '이투스교육(주)', '직무': '이투스교육 IT기획직군 공개 채용', '경력사항': '경력', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551714'}
# {'기업명': '(주)푸드테크', '직무': 'IT부문 신입 및 경력사원 모집', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526283'}
# {'기업명': '매드업', '직무': '[테크사업부] 백엔드 개발자 채용', '경력사항': '3 ~ 10년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38553452'}
# {'기업명': '(주) 딥노이드', '직무': '인공지능, 의료영상 연구원 모집[경력, 병역특례 지원가능]', '경력사항': '신입 · 경력', '학력': '석사↑', '근무형태': '정규직 · 병역특례', '근무지': '서울 구로구', '분류': "['인공지능(AI)·빅데이터', '연구소·R&D']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38362204'}
# {'기업명': '(주)씨알에스큐브', '직무': 'AWS(DevOps) 엔지니어 채용', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561608'}
# {'기업명': '모나일렉트릭(주)', '직무': '웹개발(Java·JSP/ASP) 채용 공고', '경력사항': '3 ~ 5년', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 광명시', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554785'}
# {'기업명': '(주)판도라티비', '직무': '[ 코박(COBAK) ]  Back-end 개발자 채용', '경력사항': '1 ~ 5년', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561269'}
# {'기업명': '(주)키위플러스', '직무': '서버 Backend 개발자 영입', '경력사항': '3 ~ 5년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560578'}
# {'기업명': '주식회사 메먼트', '직무': '(연 3000만 이상) 시스템엔지니어 채용', '경력사항': '경력무관', '학력': '고졸↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526643'}
# {'기업명': '(주)웨어포인트', '직무': '[잠실/운영] DBA 업무 담당자 채용', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직 · 계약직', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38559704'}
# {'기업명': '(주)온빛', '직무': '병원 플랫폼 앱 개발자 모집 (안드로이드/iOS/백엔드)', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '대구 북구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38534946'}
# {'기업명': '아카라코리아', '직무': 'AWS 플랫폼기반 서비스운영 정규직 모집(경력사원)', '경력사항': '경력 10년↓', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38559238'}
# {'기업명': '주식회사 미로', '직무': '(주)미로 IoT & 스마트홈 개발자채용 (신입/경력/전문연구요원)', '경력사항': '경력무관', '학력': '대학교(4년)↑', '근무형태': '정규직 · 병역특례', '근무지': '인천 연수구', '분류': "['전기·전자·제어', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38559164'}
# {'기업명': '충북대학교', '직무': '[국비무료]취업연계 채용예정자 양성 과정 교육생 모집', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '교육생', '근무지': '충북 청주시', '분류': "['상품기획·MD', '기획·전략·경영']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38460768'}
# {'기업명': '(주)바디프랜드', '직무': '(주)바디프랜드 AI/서버/퍼블리셔/아이폰/프론트/기획 모집', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직 · 계약직', '근무지': '서울 강남구', '분류': "['웹기획·PM', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554220'}
# {'기업명': '(주)소프트웨어인라이프', '직무': '[Docswave] 2020년 하반기 프리세일즈 채용 (경력)', '경력사항': '경력 1년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '하드웨어·소프트웨어']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38477097'}
# {'기업명': '이원다이애그노믹스(주)', '직무': 'EDGC : 글로벌R&D본부 IT팀 인재 채용 件', '경력사항': '3 ~ 5년', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38489038'}
# {'기업명': '(주)인터웹', '직무': '4차산업혁명 기반의 신사업 참여 개발자 모집', '경력사항': '경력 6년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38553142'}
# {'기업명': '케이웨어(주)', '직무': '[R&D] 연구과제 기획/관리', '경력사항': '신입 · 경력', '학력': '석사↑', '근무형태': '정규직', '근무지': '서울 구로구', '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551504'}
# {'기업명': '이투스교육(주)', '직무': '이투스교육 8월 개발자 신입/경력 채용', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38545141'}
# {'기업명': '(주)아이아이컴바인드', '직무': '젠틀몬스터 백엔드&PHP 정규직 채용(경력/신입)', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38412821'}
# {'기업명': '주식회사 메디칼파크', '직무': '응용소프트웨어 프로그래머 연구원 모집', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 용인시 수지구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38353503'}
# {'기업명': '아토리서치(주)', '직무': '[아토리서치]전문연구요원(병역특례) 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38545903'}
# {'기업명': '메가존(주)', '직무': '[메가존] 개발 경력자 대규모 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직 · 병역특례', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37872627'}
# {'기업명': '오케스트로(주)', '직무': '(경력) 인공지능 연구소 플랫폼 개발팀 채용', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 영등포구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38532722'}
# {'기업명': '㈜안랩', '직무': '[안랩] DevOps 엔지니어 모집', '경력사항': '경력 4년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38538973'}
# {'기업명': '타이트(주)', '직무': '타이트(주) 제품개발팀 백엔드 / 웹 개발자 모집', '경력사항': '경력 2년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '대구 남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533831'}
# {'기업명': '클라우드그램(주)', '직무': '[클라우드그램] 경영지원', '경력사항': '경력 1년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['사무보조·문서작성', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38364180'}
# {'기업명': '메가존(주)', '직무': '[메가존클라우드] Mass Migration Center 부문별 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직 · 병역특례', '근무지': '서울 강남구', '분류': "['IT·솔루션영업', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38348572'}
# {'기업명': '메가존(주)', '직무': '[메가존] DMP(데이터 관리 플랫폼) 개발', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38405474'}
# {'기업명': '(주)아이뱅크', '직무': '클라우드/DataAnalysis/로그분석外 정규직 채용 - 경력사원', '경력사항': '경력 1년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['웹기획·PM', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38380134'}
# {'기업명': '(주)아이담', '직무': '개발본부 백엔드 개발자(Node.js) 경력직 채용', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533890'}
# {'기업명': '(주)두댓', '직무': '반려동물 서버 프로그래머 경력직 채용', '경력사항': '경력 10년↑', '학력': '고졸↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38532714'}
# {'기업명': '㈜날리지큐브', '직무': '날리지큐브 2020년 클라우드 신입/경력 개발자 채용', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38527975'}
# {'기업명': '(주)소셜라디오컴퍼니', '직무': '[글로벌 라이브·레코드 오디오기반 소셜앱] Backend개발자모집', '경력사항': '3 ~ 10년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38506920'}
# {'기업명': '주식회사 해줌', '직무': '고객관리 시스템 백엔드 개발자 채용', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38394524'}
# {'기업명': '에스피테크놀러지', '직무': '에스피테크놀러지(주) AR/VR 개발자 모집', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 관악구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38524760'}
# {'기업명': '에스피테크놀러지', '직무': '에스피테크놀러지(주) 프론트엔드&백엔드 개발', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 관악구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38524705'}
# {'기업명': '에스피테크놀러지', '직무': '에스피테크놀러지(주) Java 개발자 모집', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 관악구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38523836'}
# {'기업명': '디딤365 주식회사', '직무': 'AWS 클라우드 기술영업 신입사원 모집', '경력사항': '신입', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['IT·솔루션영업', '기술영업']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38523449'}
# {'기업명': '(주)모비젠', '직무': '(주)모비젠 부문별 개발자 모집', '경력사항': '경력무관', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['웹개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38523366'}
# {'기업명': '모티프컨설팅', '직무': '대기업 AWS 엔지니어 (클라우드 아키텍트/클라우드데이터엔지니', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38522797'}
# {'기업명': '(주)락플레이스', '직무': 'Azure 엔지니어 모집', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38520918'}
# {'기업명': '굿어스데이터(주)', '직무': 'Cloud 엔지니어 경력 3년 이상', '경력사항': '3 ~ 10년', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38520348'}
# {'기업명': '조이시티', '직무': '[JOYCITY] 플랫폼 서버 개발자 모집 (경력무관)', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38519268'}
# {'기업명': '(주)필로시스생명과학', '직무': '[정규직] 서버개발자 모집', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38516156'}
# {'기업명': '(주)스쿱미디어', '직무': 'AWS엔지니어 채용 경력 모집(정규직)', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38511682'}
# {'기업명': '(주)오케이산업', '직무': 'AWS/PHP 정규직 채용 - 경력', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 부천시', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38511008'}
# {'기업명': '(주)뉴트리션코트', '직무': '백엔드개발 경력직 채용', '경력사항': '1 ~ 8년', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38355299'}
# {'기업명': '(주)아르카에이치알', '직무': '[WinnersK] 서비스 플랫폼 연구소 중급개발자 모집', '경력사항': '3 ~ 5년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38508488'}
# {'기업명': '(주)위메프', '직무': '[보안]클라우드 보안운영 담당자(정규직)', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37608770'}
# {'기업명': '(주)위메프', '직무': '[개발]위메프 시스템엔지니어(정규직)', '경력사항': '경력 1년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38502145'}
# {'기업명': '(주)위메프', '직무': '[개발]위메프오 DevOps Engineer(정규직)', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38502034'}
# {'기업명': '(주)코레이즈', '직무': '[신입/경력] 클라우드팀 채용 (SaaS · S/W)', '경력사항': '경력무관', '학력': '대학(2,3년)↑', '근무형태': '계약직 · 인턴직', '근무지': '서울 성동구', '분류': "['IT·솔루션영업', '하드웨어·소프트웨어']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38500624'}
# {'기업명': '(주)원더피플', '직무': '글로벌 플랫폼 서버 개발자 모집', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '게임·Game']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38497413'}
# {'기업명': '(주)데브툴즈', '직무': 'Back end 개발자 정규직 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 안양시 동안구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38485192'}
# {'기업명': '아토리서치(주)', '직무': '인공지능/머신러닝 개발 및 클라우드/네트워크 개발', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38494339'}
# {'기업명': '컴즈(주)', '직무': 'S/W Test & QA Engineer 채용의 件', '경력사항': '신입 · 경력', '학력': '대학(2,3년)↑', '근무형태': '정규직 · 프리랜서', '근무지': '서울 구로구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38464382'}
# {'기업명': '나무기술(주)', '직무': 'Cloud 유지보수 엔지니어 모집', '경력사항': '경력 2년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38440590'}
# {'기업명': '나무기술(주)', '직무': '클라우드 SaaS개발 경력 채용합니다', '경력사항': '경력 3년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38470236'}
# {'기업명': '(주)제이티넷', '직무': '[나이스그룹] (주)제이티넷 채용 (시스템 운영관리)', '경력사항': '8 ~ 12년', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 구로구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38482290'}
# {'기업명': '(주)아이콘루프', '직무': '정보보안 / 개인정보보호 담당자 채용 (경력)', '경력사항': '경력 5년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 중구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38458811'}
# {'기업명': '(주) 와이더플래닛', '직무': '빅데이터 플랫폼 엔지니어', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38470987'}
# {'기업명': '메가존(주)', '직무': '[메가존클라우드] VDI Helpdesk / 24x7 Service 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직 · 병역특례', '근무지': '서울 강남구', '분류': "['사무보조·문서작성', '기술영업']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38439227'}
# {'기업명': '메가존(주)', '직무': '[메가존클라우드] Product Development 부문 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직 · 병역특례', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38438571'}
# {'기업명': '(주)여기어때컴퍼니', '직무': '[여기어때] 서비스제품개발실 서버 개발자 채용', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38390850'}
# {'기업명': '(주)여기어때컴퍼니', '직무': '[여기어때] 이커머스플랫폼개발실 서버개발자 채용', '경력사항': '3 ~ 12년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38149596'}
# {'기업명': '유한책임회사딜리버리히어로코리아', '직무': 'IT System Engineer (Cloud)', '경력사항': '3 ~ 20년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38464548'}
# {'기업명': '에스지에이(주)', '직무': '클라우드/AI/빅데이터 분야 영업/기술지원 분야 채용', '경력사항': '경력무관', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38345151'}
# ...
# {'기업명': '피플워크(주)', '직무': '[ IT대기업]데이터 모델링 - 4-15년', '경력사항': '4 ~ 16년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38548699'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': '유통산업 및 커머스 분야 시스템 설계 개발자', '경력사항': '경력 6년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592716'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': '그룹 HR 공유 Infra HRIS 시스템 구축', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592712'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': '렌탈 시스템 구축 프로젝트 PL업무 수행 시스템 개발', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 중구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592708'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': 'Battery 생산지원시스템(QMS/SCM/EMS) 구축 및 Global 확산/운영', '경력사항': '경력 6년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '대전 동구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592694'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': 'ITS 또는 QT등 소프트웨어 개발', '경력사항': '경력 3년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['전기·전자·제어', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592691'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 java', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592671'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': '그룹 HR 공유 Infra HRIS 시스템 구축 SaaS  Cloud', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592664'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자 SAP', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 중구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592662'}
# {'기업명': '(주)헬로서치', '직무': '[국내우량기업]딥러닝 개발자를 모십니다.', '경력사항': '2 ~ 12년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589871'}
# {'기업명': '위키에이드', '직무': '[화성/동탄] 머신비전 검사 SW 개발 경력', '경력사항': '경력 3년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '경기 화성시', '분류': "['응용프로그램개발', '하드웨어·소프트웨어']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589729'}
# {'기업명': '(주)핀커스코리아', '직무': '유명기업 웹개발 경력채용(3년~7년)', '경력사항': '3 ~ 7년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587971'}
# {'기업명': '(주)바른인사컨설팅', '직무': '[S/W개발 상장사]C/C++ 개발자 경력직 정규직 채용(프로그램개발', '경력사항': '경력 3년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38543403'}
# {'기업명': '(주)수커리어컨설팅', '직무': '백엔드 개발(Java,리눅스 등 사용중) 네트워크,보안 기업', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 양천구', '분류': "['웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586023'}
# {'기업명': '그린컴퓨터아트학원 아카데미 성남/분당 ..', '직무': '[국가기간] JAVA기반 개발자 훈련과정 훈련교.강사님 모집', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '전임 · 계약직', '근무지': '경기 성남시 분당구', '분류': "['웹마스터·QA·테스터', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554225'}
# {'기업명': '그린컴퓨터아트학원 아카데미 성남/분당 ..', '직무': '[국가기간] 디지털컨버전스(JAVA기반), 빅데이터취업 국비교육', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '위촉직', '근무지': '경기 성남시 분당구', '분류': "['웹마스터·QA·테스터', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38485946'}
# {'기업명': '커리어셀파', '직무': '[유통대기업] IT개발 경력사원 채용', '경력사항': '4 ~ 12년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583993'}
# {'기업명': '(주)투비파트너즈', '직무': 'IT/ICT 소프트웨어 엔지니어', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 수원시 영통구', '분류': "['시스템개발', 'IT·디자인·컴퓨터교육']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583588'}
# {'기업명': '인비즈써치', '직무': '국내 대형증권사 로보어드바이저 서비스 기획 담당', '경력사항': '4 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '계약직', '근무지': '서울 영등포구', '분류': "['ERP·시스템분석·설계', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583528'}
# {'기업명': '굿커리어', '직무': '대기업 MES(LOT 개발 운영,경북,충북) 대리,과장급 (굿커리어)', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38547779'}
# {'기업명': '제이떠블유커리어(JW career)', '직무': '머신비전 전문기업 딥러닝, AI 연구소(소장급)채용', '경력사항': '경력 10년↑', '학력': '석사↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['응용프로그램개발', '하드웨어·소프트웨어']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579925'}
# {'기업명': '(주)헬로서치', '직무': '[국내우량기업]딥러닝 개발 인재를 모십니다.', '경력사항': '2 ~ 10년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578846'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자 시스템통합 IT 아웃소싱', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 중구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575270'}
# {'기업명': '(주)잡뉴스솔로몬서치', '직무': '일본어가능 JAVA .NET CS연구개발 경력자', '경력사항': '2 ~ 7년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570183'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': '그룹 HR 공유 Infra HRIS 시스템 구축 SaaS 솔루션 클라우드', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569026'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 중구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569023'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 Java, Oracle', '경력사항': '경력 6년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569021'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': '렌탈 시스템 구축 프로젝트 PL업무 수행 Spring framework', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 중구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569019'}
# {'기업명': '(주)케이맨파워', '직무': '[최고대우] IT기획 (ERP 운영, 3년이상)', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567425'}
# {'기업명': '(주)맨파워그룹코리아', '직무': '외국계 반도체회사 R&D S/W 연구원(경력) 모집', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['응용프로그램개발', '시스템개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563105'}
# {'기업명': '(주)맨파워그룹코리아', '직무': '외국계 회사 Video System R&D Software Engineer 모집', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['응용프로그램개발', '시스템개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563093'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': 'ITS 또는 QT등 소프트웨어 개발 C, C++, JAVA', '경력사항': '경력 3년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['전기·전자·제어', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562755'}
# {'기업명': '(주)바인컨설팅', '직무': '대기업그룹사/안드로이드 앱개발자 대리과장급 채용', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562646'}
# {'기업명': '(주) 허브브레인', '직무': '대기업 IT 사 데이터 엔지니어링 경력 채용', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561511'}
# {'기업명': '(주) 허브브레인', '직무': '대기업 IT 사 빅데이터 플랫폼 구축 경력 채용', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561500'}
# {'기업명': '(주) 허브브레인', '직무': '대기업 IT 사 고객데이터 기반 컨설팅 채용', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561489'}
# {'기업명': '(주) 허브브레인', '직무': '대기업 IT 사 빅데이터 기술 경력 채용', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561461'}
# {'기업명': '(주) 허브브레인', '직무': '대기업 계열 IT 사 AI 알고리즘 개발 신입, 경력 채용', '경력사항': '신입 · 경력', '학력': '석사↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558368'}
# {'기업명': '(주)피플렙', '직무': '의료기기 Sales Manager 과차장급/글로벌 기업', '경력사항': '6 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558343'}
# {'기업명': '(주) 허브브레인', '직무': '대기업 IT 사 고객데이터 분석 관련 오퍼링 발굴 채용', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558047'}
# {'기업명': '헤리티지서치코어', '직무': '빅데이터 수집 분석 시스템 UI /프론트엔드/유명 솔루션 기업', '경력사항': '2 ~ 10년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554760'}
# {'기업명': '헤리티지서치코어', '직무': '인프라솔루션 엔진파트 개발/C++, SQL,Socket /유명 솔루션 기업', '경력사항': '4 ~ 8년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554752'}
# {'기업명': '(주)피플렙', '직무': '의료기기 Sales Manager 과차장급', '경력사항': '6 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554192'}
# {'기업명': '(주)에이치알그룹', '직무': '로봇 SW 개발자 (5년이상) - 로봇기업', '경력사항': '경력 5년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38548759'}
# {'기업명': '주식회사 코어포인트', '직무': '클라우드 컨설팅/ DevOps, Open API 전문인력 채용(차장,과장급)', '경력사항': '7 ~ 14년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38548744'}
# {'기업명': '비전서치', '직무': '업데이트용 sw 개발', '경력사항': '3 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 성동구', '분류': "['응용프로그램개발', '하드웨어·소프트웨어']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38548178'}
# {'기업명': '(주)에이치알그룹', '직무': '[경력] IT 프로덕트 엔지니어 채용-유망 스타트업', '경력사항': '3 ~ 10년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['응용프로그램개발', '하드웨어·소프트웨어']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539011'}
# {'기업명': '헤리티지서치코어', '직무': '솔루션영업/경력 5년이상/유명 IT 솔루션기업', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38543031'}
# {'기업명': '하이잡', '직무': '추천 시스템 연구/개발', '경력사항': '경력 2년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38541014'}
# {'기업명': '㈜에이치알맨파워그룹', '직무': '[대기업] AI알고리즘-박사 (서울)', '경력사항': '신입 · 경력', '학력': '박사', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38540948'}
# {'기업명': '(주)피플렙', '직무': 'Medical Device Sales Manager 경력(과차장급)', '경력사항': '7 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38540319'}
# {'기업명': '구루넷', '직무': '[일본취업] 소프트웨어 엔지니어 모집', '경력사항': '2 ~ 15년', '학력': '학력무관', '근무형태': '정규직 · 해외취업', '근무지': '아시아·중동 일본', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539305'}
# {'기업명': '구루넷', '직무': '인공지능 연구원 모집', '경력사항': '2 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539294'}
# {'기업명': '구루넷', '직무': '영상처리 솔루션 개발자 모집', '경력사항': '2 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['응용프로그램개발', '시스템개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539278'}
# {'기업명': '구루넷', '직무': '[코스닥 상장사] 시스템 소프트웨어 개발자 모집', '경력사항': '3 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539273'}
# {'기업명': '(주)에이치알인재그룹', '직무': '(RPA) 자동화시스템 개발 경력채용', '경력사항': '1 ~ 12년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 오산시', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38537627'}
# {'기업명': '(주)피플렙', '직무': 'Medical Device Sales Manager 경력', '경력사항': '7 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38535004'}
# {'기업명': '(주)커리어멘토', '직무': '(1.VISION제어/ 2 PC제어/ 3.VISION SW개발/4.VISION FAE)', '경력사항': '4 ~ 12년', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['반도체·디스플레이·LCD', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38534541'}
# {'기업명': 'ES Group', '직무': '[구인구직 Platform] PL/Backend 개발 팀장님 채용', '경력사항': '경력 9년↑', '학력': '대학교(4년)↑', '근무형태': '정규직 · 계약직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38534411'}
# {'기업명': '그레이프 파트너즈', '직무': '모빌리티 기업 Business Information Analyst 데이터 분석가', '경력사항': '2 ~ 12년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533546'}
# {'기업명': '굿커리어', '직무': '유명 대기업 바이오회사 헬스케어 플랫폼 서비스 기획 대리,과장', '경력사항': '경력 4년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['기획·전략·경영', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38531221'}
# {'기업명': '굿커리어', '직무': '유명 대기업 바이오회사 빅데이터 플랫폼 개발 대리,과장', '경력사항': '경력 4년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['기획·전략·경영', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38531206'}
# {'기업명': '(주)코어잡', '직무': '패션 중견 기업 자사몰 개발 Product Manager 정규직 과장-부장', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38530623'}

# %%
# Web Scrapping Function
def scrapping(url_front, url_back, name):
    page_num = 1
    job_list = []
    while True:
        url = urljoin(url_front, str(page_num), url_back)
        req_header = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
        }
        html = requests.get(url, req_header).text
        soup = BeautifulSoup(html, 'html.parser')

        # 만약 더이상 페이지 리스트에 공고가 없을 경우 break
        if soup.select('div.list_body div.list_item') == []:
            break


        for tag in soup.select('div.list_body div.list_item'):

            # 기본정보
            job_dict = {}
            job_dict["기업명"] = tag.select('div.company_nm a span')[0].text
            job_dict["직무"] = tag.select('div.notification_info a span')[0].text
            job_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
            job_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
            job_dict["분류필터"] = name


            # 근무형태 / 근무지 - 빈칸인 경우도 있음
            try:
                job_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
            except:
                job_dict["근무형태"] = ""
            try:    
                job_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
            except:
                job_dict["근무지"] = ""

            # 분류는 여러가지가 있기 때문에 리스트 형태로 저장              
            category_list = []
            for item in tag.select('div.notification_info div.job_meta span span'):
                category_list.append(item.text)
            job_dict["분류"] = str(category_list)

            #상세 url
            detail_url = tag.select_one('div.notification_info a').attrs['href']
            full_detail_url = urljoin(main_url, detail_url)
            job_dict["상세링크"] = full_detail_url
            job_list.append(job_dict)
        page_num += 1
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     189                                          self.max_stmt_length,
# --> 190                                          self._get_db().encoding)
#     191
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     226             sql += v
# --> 227         rows += self.execute(sql + postfix)
#     228         self.rowcount = rows
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     723             result = MySQLResult(self)
# --> 724             result.read()
#     725         self._result = result
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1068         try:
# -> 1069             first_packet = self.connection._read_packet()
#    1070
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     675                 self._result.unbuffered_active = False
# --> 676             packet.raise_for_error()
#     677         return packet
#
# C:\Anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     222         if DEBUG: print("errno =", errno)
# --> 223         err.raise_mysql_exception(self._data)
#     224
#
# C:\Anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     106         errorclass = InternalError if errno < 1000 else OperationalError
# --> 107     raise errorclass(errno, errval)
#
# OperationalError: (1241, 'Operand should contain 1 column(s)')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-47-4cff80685313> in <module>()
# ----> 1 python_df.to_sql(name='jobs_python', con=engine, if_exists='replace', index=False)
#       2 db_Df.to_sql(name='jobs_db', con=engine, if_exists='replace', index=False)
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2128         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2129                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2130                    dtype=dtype)
#    2131
#    2132     def to_pickle(self, path, compression='infer',
#
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1125                          schema=schema, dtype=dtype)
#    1126         table.create()
# -> 1127         table.insert(chunksize)
#    1128         if (not name.isdigit() and not name.islower()):
#    1129             # check for potentially case sensitivity issues (GH7815)
#
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize)
#     639
#     640                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 641                 self._execute_insert(conn, keys, chunk_iter)
#     642
#     643     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     614     def _execute_insert(self, conn, keys, data_iter):
#     615         data = [{k: v for k, v in zip(keys, row)} for row in data_iter]
# --> 616         conn.execute(self.insert_statement(), data)
#     617
#     618     def insert(self, chunksize=None):
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1168                         statement,
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#    1172                 if self.dialect._has_events:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     103
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#     107             context._rowcount = rowcount
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     188             return self._do_execute_many(q_prefix, q_values, q_postfix, args,
#     189                                          self.max_stmt_length,
# --> 190                                          self._get_db().encoding)
#     191
#     192         self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     225                 sql += b','
#     226             sql += v
# --> 227         rows += self.execute(sql + postfix)
#     228         self.rowcount = rows
#     229         return rows
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     161         query = self.mogrify(query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#     165         return result
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     319         self._last_executed = q
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     503                 sql = sql.encode(self.encoding, 'surrogateescape')
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#     507
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     722         else:
#     723             result = MySQLResult(self)
# --> 724             result.read()
#     725         self._result = result
#     726         if result.server_status is not None:
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1067     def read(self):
#    1068         try:
# -> 1069             first_packet = self.connection._read_packet()
#    1070
#    1071             if first_packet.is_ok_packet():
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     674             if self._result is not None and self._result.unbuffered_active is True:
#     675                 self._result.unbuffered_active = False
# --> 676             packet.raise_for_error()
#     677         return packet
#     678
#
# C:\Anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     221         errno = self.read_uint16()
#     222         if DEBUG: print("errno =", errno)
# --> 223         err.raise_mysql_exception(self._data)
#     224
#     225     def dump(self):
#
# C:\Anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     105     if errorclass is None:
#     106         errorclass = InternalError if errno < 1000 else OperationalError
# --> 107     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1241, 'Operand should contain 1 column(s)') [SQL: 'INSERT INTO jobs_python (`기업명`, `직무`, `경력사항`, `학력`, `근무형태`, `근무지`, `분류`, `상세링크`) VALUES (%(기업명)s, %(직무)s, %(경력사항)s, %(학력)s, %(근무형태)s, %(근무지)s, %(분류)s, %(상세링크)s)'] [parameters: ({'\uae30\uc5c5\uba85': '스윙로드', '\uc9c1\ubb34': '스윙로드 (백엔드 부문) 정규직 채용', '\uacbd\ub825\uc0ac\ud56d': '경력 3년↑', '\ud559\ub825': '대학(2,3년)↑', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 강남구', '\ubd84\ub958': ['웹개발'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38423092'}, {'\uae30\uc5c5\uba85': '더조은컴퓨터아트학원', '\uc9c1\ubb34': '[100%무료 취업준비생모집]웹디/건축/게임/프로그래밍/3D프린터', '\uacbd\ub825\uc0ac\ud56d': '신입 · 경력', '\ud559\ub825': '학력무관', '\uadfc\ubb34\ud615\ud0dc': '교육생', '\uadfc\ubb34\uc9c0': '서울전체', '\ubd84\ub958': ['그래픽디자인·CG', '제품·산업디자인'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=34529977&adsCategoryItem=effect_bold&'}, {'\uae30\uc5c5\uba85': '(주)쎄미시스코', '\uc9c1\ubb34': '㈜쎄미시스코 소프트웨어 개발자 경력직 모집', '\uacbd\ub825\uc0ac\ud56d': '경력 1년↑', '\ud559\ub825': '대학(2,3년)↑', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '경기 수원시', '\ubd84\ub958': ['반도체·디스플레이·LCD', '서버·네트워크·보안'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38597487&adsCategoryItem=effect_bold&'}, {'\uae30\uc5c5\uba85': '(주)와이비시스템', '\uc9c1\ubb34': '개발자 담당 경력 정규직 채용', '\uacbd\ub825\uc0ac\ud56d': '경력', '\ud559\ub825': '학력무관', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 서초구', '\ubd84\ub958': ['웹기획·PM', '웹개발'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579699&adsCategoryItem=effect_bold&'}, {'\uae30\uc5c5\uba85': '국제컴퓨터아카데미', '\uc9c1\ubb34': '[100%무료 취업준비생모집]웹디/건축/게임/프로그래밍/3D프린터', '\uacbd\ub825\uc0ac\ud56d': '신입 · 경력', '\ud559\ub825': '학력무관', '\uadfc\ubb34\ud615\ud0dc': '교육생', '\uadfc\ubb34\uc9c0': '서울 관악구', '\ubd84\ub958': ['그래픽디자인·CG', '제품·산업디자인'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=34393991'}, {'\uae30\uc5c5\uba85': '(주)트랜스코스모스코리아', '\uc9c1\ubb34': '당사 프로젝트 개발 및 유지보수 담당자(신입/경력)Mj5E', '\uacbd\ub825\uc0ac\ud56d': '신입 · 경력', '\ud559\ub825': '학력무관', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 용산구', '\ubd84\ub958': ['웹개발', '응용프로그램개발'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38512364'}, {'\uae30\uc5c5\uba85': '행복쇼핑(주)', '\uc9c1\ubb34': 'PHP/REACT/PYTHON/퍼블리셔 경력자 채용', '\uacbd\ub825\uc0ac\ud56d': '경력 3년↑', '\ud559\ub825': '대학(2,3년)↑', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 영등포구', '\ubd84\ub958': ['웹개발', '응용프로그램개발'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38550645&adsCategoryItem=effect_bold&'}, {'\uae30\uc5c5\uba85': '(주)세원아토스', '\uc9c1\ubb34': 'ERP 신입, 경력 개발자를 모십니다.', '\uacbd\ub825\uc0ac\ud56d': '신입 · 경력', '\ud559\ub825': '대학(2,3년)↑', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 구로구', '\ubd84\ub958': ['웹개발', '응용프로그램개발'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38602619'}  ... displaying 10 of 1038 total bound parameter sets ...  {'\uae30\uc5c5\uba85': '굿커리어', '\uc9c1\ubb34': '유명 대기업 바이오회사 빅데이터 플랫폼 개발 대리,과장', '\uacbd\ub825\uc0ac\ud56d': '경력 4년↑', '\ud559\ub825': '대학교(4년)↑', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 강남구', '\ubd84\ub958': ['기획·전략·경영', '응용프로그램개발'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38531206'}, {'\uae30\uc5c5\uba85': '(주)코어잡', '\uc9c1\ubb34': '패션 중견 기업 자사몰 개발 Product Manager 정규직 과장-부장', '\uacbd\ub825\uc0ac\ud56d': '경력 5년↑', '\ud559\ub825': '대학교(4년)↑', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 강남구', '\ubd84\ub958': ['웹개발'], '\uc0c1\uc ...
