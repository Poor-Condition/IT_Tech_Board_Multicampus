# %%
#library import 하기

import requests
from bs4 import BeautifulSoup
import re
from urllib.parse import urljoin

# %%
# 클라우드 직업 스크래핑

job_list_cloud = []
page_num = 1
main_url = 'http://www.saramin.co.kr'

while True:
    url = f'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page={page_num}&cat_key=41704%2C40220&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=1'
    req_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    }
    html = requests.get(url, req_header).text
    soup = BeautifulSoup(html, 'html.parser')
    
    # 만약 더이상 페이지 리스트에 공고가 없을 경우 break
    if soup.select('div.list_body div.list_item') == []:
        break
    for tag in soup.select('div.list_body div.list_item'):
        company_dict = {}
        company_dict["기업명"] = tag.select('div.company_nm a span')[0].text
        company_dict["직무"] = tag.select('div.notification_info a span')[0].text
        company_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
        company_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
        # 근무형태가 빈칸인 직무들도 있음
        try:
            company_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
        except:
            company_dict["근무형태"] = ""
        try:    
            company_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
        except:
            company_dict["근무지"] = ""
        category_list = []
        # 분류는 여러가지가 있기 때문에 리스트 형태로 저장
        for item in tag.select('div.notification_info div.job_meta span span'):
            category_list.append(item.text)
        company_dict["분류"] = str(category_list)
        company_dict["분류필터"] = "cloud"
        
        detail_url = tag.select_one('div.notification_info a').attrs['href']
        full_detail_url = urljoin(main_url, detail_url)
        company_dict["상세링크"] = full_detail_url
        job_list_cloud.append(company_dict)
    page_num += 1
job_list_cloud
# Out:
#  '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38803014'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 서비스플랫폼 기획 경력직 채용',
#   '경력사항': '경력 10년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38803012'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 사업기획 경력직 채용',
#   '경력사항': '5 ~ 12년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['기획·전략·경영', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38803011'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 백엔드(BackEnd) 개발 경력자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38803010'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 플랫폼 영업(Sales) 경력직 채용',
#   '경력사항': '경력 7년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['IT·솔루션영업', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38803007'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 프론트엔드(FrontEnd) 개발 경력자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38803003'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 인프라 가상화 기술기반 서비스 개발 경력자',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38803002'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[아마존웹서비스] Cloud Infrastructure Architect',
#   '경력사항': '7 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38800887'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[아마존웹서비스] Cloud Application Architect',
#   '경력사항': '7 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38800875'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[국내대기업 IT계열사] Cloud Data Scientist',
#   '경력사항': '6 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38800734'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[국내대기업 IT계열사] Cloud Sales',
#   '경력사항': '6 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38800725'},
#  {'기업명': '(주)스카우트',
#   '직무': '블록체인 플랫폼 / SDK 개발 (유명기업)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38800719'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[국내대기업 IT계열사] Cloud Solution Architect',
#   '경력사항': '6 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38800718'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[국내대기업 IT계열사] Cloud Application Architect',
#   '경력사항': '6 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38800715'},
#  {'기업명': '(주)브이비젼',
#   '직무': '[외국계 안면인식기술]  프론트엔드(모바일 위젯) 개발',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38799760'},
#  {'기업명': '프로페셔날핸즈인핸즈코리아(주)',
#   '직무': '1.클라우드(AWS) SA',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '경영분석·컨설턴트']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38793747'},
#  {'기업명': '(주)브이비젼',
#   '직무': '[외국계 안면인식기술]  백엔드 서버 개발',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38798435'},
#  {'기업명': '(주)브이비젼',
#   '직무': '[외국계 안면인식기술]  모바일 위젯 개발',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38798403'},
#  {'기업명': 'HR컨설팅(주)',
#   '직무': '[대기업/금융/IT계열] 투자 AI Platform 연구 [Architecture]',
#   '경력사항': '경력 2년↑',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['ERP·시스템분석·설계', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38795584'},
#  {'기업명': '(주)헤리티지에이치알코리아',
#   '직무': '[환경가전 1위기업] 정보시스템 운영/개발(정보시스템 담당자)',
#   '경력사항': '5 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38789763'},
#  {'기업명': '오픈포지션',
#   '직무': 'System Admin/Unix서버/5년이상/대리과장/중견그룹계열사',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38787910'},
#  {'기업명': '오픈포지션',
#   '직무': '온라인 서비스 서버 개발자 / 과차장급/ 환경 가전 대기업',
#   '경력사항': '7 ~ 17년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38785330'},
#  {'기업명': '오픈포지션',
#   '직무': '온라인 서비스 Front-End 개발자/ 대리과장급/ 환경 가전 대기업',
#   '경력사항': '5 ~ 14년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38785311'},
#  {'기업명': '엔터웨이파트너스',
#   '직무': 'DevSecOps 엔지니어-국내 유망 교육 콘텐츠 업체',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38779114'},
#  {'기업명': '휴먼파워컨설팅 (주)',
#   '직무': '커머스 백엔드시스템 개발 팀장급',
#   '경력사항': '10 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38773627'},
#  {'기업명': '(주)씨앤에이코리아',
#   '직무': '[코스닥상장 중견그룹사] IT인프라(AWS) 담당 과장급 채용',
#   '경력사항': '7 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38767436'},
#  {'기업명': '(주)브이비젼',
#   '직무': '[글로벌벤처그룹] React-Native 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38766565'},
#  {'기업명': '제이케이서치 주식회사',
#   '직무': '[유명 화장품 중견기업] 인프라 엔지니어 채용',
#   '경력사항': '5 ~ 8년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38766363'},
#  {'기업명': '(주)코어포인트',
#   '직무': 'AI / Data Scientist , 클라우드 컨설팅 전문인력 채용(차장,과',
#   '경력사항': '6 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38766357'},
#  {'기업명': '(주)탑앤스카우트',
#   '직무': '[벤처 No.1 헬스케어 플랫폼] 백엔드 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38763595'},
#  {'기업명': '(주)아데코코리아',
#   '직무': '[신논현/의료기기기업] 소프트웨어 개발자 채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38763366'},
#  {'기업명': '오픈포지션',
#   '직무': '인프라보안관리/시스템(네트워크) 엔지니어/과장/환경가전대기업',
#   '경력사항': '8 ~ 14년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38750035'},
#  {'기업명': '(주)맨파워코리아',
#   '직무': '[외국계 IT 기업] Manufacturing consulting & Presales Lead',
#   '경력사항': '경력 10년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38761514'},
#  {'기업명': '(주)브이비젼',
#   '직무': '[글로벌벤처그룹] Back-end 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38760363'},
#  {'기업명': '(주)유니코써치',
#   '직무': '[유명 패션이커머스사] 커머스 개발팀장',
#   '경력사항': '경력 7년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38757613'},
#  {'기업명': '(주)잡뉴스솔로몬서치',
#   '직무': 'DevOps 엔지니어 경력직  (E-Commerce)',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38757163'},
#  {'기업명': '(주)에이치알맨파워그룹',
#   '직무': '블록체인 기반 서비스개발(플랫폼개발) 대리~과(차)장급 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38754590'},
#  {'기업명': '로버트월터스코리아(주)',
#   '직무': '[글로벌/IT/엔지니어] DevOps/System Engineer',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38754033'},
#  {'기업명': '프로페셔날핸즈인핸즈코리아(주)',
#   '직무': 'IT Shared Service Manager[부장급]',
#   '경력사항': '경력 15년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 고양시 덕양구',
#   '분류': "['바이오·제약·식품', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38753611'},
#  {'기업명': '(주)연세교육아카데미ㅣ연세직업전문학교',
#   '직무': '정보보안(모의해킹) 및 클라우드 강사 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '전임 · 계약직',
#   '근무지': '경기 수원시 장안구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38659283'},
#  {'기업명': '(주)티아이에스정보시스템',
#   '직무': '[국비지원 재직자교육]CCNA(네트워크)/자바스크립트/프론트엔드/웹퍼블리싱/빅데이터/파이썬 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['그래픽디자인·CG', '전기·전자·제어']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38378560'},
#  {'기업명': '피플워크(주)',
#   '직무': '딥러닝기반 의료영상처리 알고리즘 개발(5-12년)AI(인공지능)',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '통신·모바일']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38765686'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '안드로이드 아이폰 회사내 앱 개발 iOS android',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 부천시',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38823918'},
#  {'기업명': '(주)탑앤스카우트',
#   '직무': '[AI, IoT] 공공프로젝트 PM 충원',
#   '경력사항': '경력 8년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38775897'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '(국내 대기업) 모바일 앱(안드로이드) 개발자',
#   '경력사항': '경력 7년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38766053'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[모바일 애드테크 전문기업] 백엔드 엔지니어(대리-과장)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38752637'},
#  {'기업명': '㈜커리어텍',
#   '직무': 'SK텔레콤 서비스기획 NUGU 컨텐츠 운영지원 ~24일 목요일',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 중구',
#   '분류': "['홍보·PR·사보', '사무보조·문서작성']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38807274'},
#  {'기업명': '피플워크(주)',
#   '직무': 'AI(인공지능) 딥러닝기반 의료영상처리 알고리즘 개발(5-12년)',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '통신·모바일']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38801779'},
#  {'기업명': '피플워크(주)',
#   '직무': '인공지능 딥러닝기반 영상인식 처리 알고리즘 개발',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '통신·모바일']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38765709'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '웹 프론트엔드 개발 인천 송도 근무 frontend',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 연수구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38818203'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '안드로이드 앱개발  인천 송도 근무 application iOS',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 연수구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38818201'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Azure Architect 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38818168'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '안드로이드 아이폰 회사내 앱 개발',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 부천시',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38818165'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '웹 프론트엔드 개발 인천 송도 근무',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 연수구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38818153'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '안드로이드 앱개발  인천 송도 근무',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 연수구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38818151'},
#  {'기업명': '구루넷',
#   '직무': '웹 개발자 모집',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38815420'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 온라인 플랫폼 사업개발/기획 (10년이상) - 초일류 대기업',
#   '경력사항': '경력 10년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38802791'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 초일류 대기업 - 온라인 플랫폼 사업개발/기획 (10년이상)',
#   '경력사항': '경력 10년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38802792'},
#  {'기업명': '(주)맨파워코리아',
#   '직무': '[외국계 SCM 기업] DevOps Engineer (Big data) (Hong)',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['ERP·시스템분석·설계', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38748073'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[분당] 인공지능 유지보수 업무-신입가능/javascript가능자',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38796480'},
#  {'기업명': '(주)스카우트플랜',
#   '직무': '스토리지 엔지니어',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38801686'},
#  {'기업명': '(주)휴먼트리월드와이드',
#   '직무': '[국내 보안솔루션업체]서버 Back-End 개발 팀장급',
#   '경력사항': '경력 12년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38786309'},
#  {'기업명': '굿커리어',
#   '직무': '중견기업 머신비젼장비 SW개발 팀원,팀장급 구함(굿커리어)',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38767739'},
#  {'기업명': '(주)HR컨설팅그룹',
#   '직무': '(코스닥상장사) 웹어플리케이션 개발 경력자',
#   '경력사항': '3 ~ 12년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38783571'},
#  {'기업명': '피플워크(주)',
#   '직무': 'AI(인공지능) 딥러닝기반 영상인식 처리 알고리즘 개발',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '통신·모바일']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38768039'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Azure Architect 채용 Cloud',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38795578'},
#  {'기업명': '제이에이씨리크루트먼트코리아(주)',
#   '직무': '[외국계] IT기업 기술서포트 (영어 필수)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '위촉직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38784745'},
#  {'기업명': '(주)브이비젼',
#   '직무': '[글로벌벤처그룹] front-end 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38760355'},
#  {'기업명': '(주)드림잡스쿨',
#   '직무': 'AI코딩스쿨 방과후 학교 프로그램 개발 관리자 모집',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '광주 광산구',
#   '분류': "['퍼블리싱·UI개발', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38745204'}]

# %%
# 파이썬 직업 스크래핑

job_list_python = []
page_num = 1
main_url = 'http://www.saramin.co.kr'

while True:
    url = f'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page={page_num}&cat_key=41711%2C40721%2C40426&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=1#searchTitle'
    req_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    }
    html = requests.get(url, req_header).text
    soup = BeautifulSoup(html, 'html.parser')
    if soup.select('div.list_body div.list_item') == []:
        break
    for tag in soup.select('div.list_body div.list_item'):
        company_dict = {}
        company_dict["기업명"] = tag.select('div.company_nm a span')[0].text
        company_dict["직무"] = tag.select('div.notification_info a span')[0].text
        company_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
        company_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
        try:
            company_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
        except:
            company_dict["근무형태"] = ""
        try:    
            company_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
        except:
            company_dict["근무지"] = ""
        category_list = []
        for item in tag.select('div.notification_info div.job_meta span span'):
            category_list.append(item.text)
        company_dict["분류"] = str(category_list)
        company_dict["분류필터"] = "python"
        
        detail_url = tag.select_one('div.notification_info a').attrs['href']
        full_detail_url = urljoin(main_url, detail_url)
        company_dict["상세링크"] = full_detail_url
        job_list_python.append(company_dict)
    page_num += 1
job_list_python
# Out:
# x=38813655'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[모바일 애드테크 전문기업] Back-end 엔지니어(대리-과장)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38752571'},
#  {'기업명': '(주)아데코코리아',
#   '직무': 'MES엔지니어 -제조업체',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경남 양산시',
#   '분류': "['ERP·시스템분석·설계', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38762259'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': 'CRM 데이터분석',
#   '경력사항': '3 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['마케팅·광고·분석', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38760331'},
#  {'기업명': '(주)HR컨설팅그룹',
#   '직무': '(경력)인공지능(AI) 데이터사이언티스트외 5개 부문 채용',
#   '경력사항': '4 ~ 14년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38788941'},
#  {'기업명': '(주)인큐브시스템',
#   '직무': '[대기업계열사]  Data Scientist 경력직 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38748629'},
#  {'기업명': '(주)인큐브시스템',
#   '직무': '[대기업계열사]  Technical Architect 경력직 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38748637'},
#  {'기업명': '파워에이치알',
#   '직무': '[그룹계열 SI업체] 스마트팩토리 구축개발(4년  - 7년)',
#   '경력사항': '4 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '충북 청주시 흥덕구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38817121'},
#  {'기업명': '파워에이치알',
#   '직무': '[주요SI 대기업] 데이터 분석(Data Scientist, 2개포지션)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['마케팅·광고·분석', '영업기획·관리·지원']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38748332'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[스페이스워크] 알고리즘 엔지니어(경력 3년 이상)',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38818791'},
#  {'기업명': '(주)HR컨설팅그룹',
#   '직무': '(모바일 커머스 플랫폼 기업) IT 개발팀장',
#   '경력사항': '경력 10년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38818606'},
#  {'기업명': '굿커리어',
#   '직무': '유명 대기업 AI, 딥러닝, 컴퓨터 Vision 등 AI 유관분야 연구',
#   '경력사항': '경력무관',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38765759'},
#  {'기업명': '주식회사 라온서치',
#   '직무': '[통신대기업]AI 대화SDK 솔루션 기술 개발(3년-10년)',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38804085'},
#  {'기업명': '주식회사 라온서치',
#   '직무': '[통신대기업] IoT Intelligence 기술 개발    (3년-10년)',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', '통신·모바일']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38804086'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '[광화문역/연봉협의] 대형로펌 전산실 개발자 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '파견직',
#   '근무지': '서울 종로구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38807115'},
#  {'기업명': '(사)벤처기업협회',
#   '직무': '2020년 제 5차 우수벤처기업 공동채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['해외영업·무역영업', '기획·전략·경영']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38774591'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '반도체 디자인 검증 엔지니어 C/C++, python, perl, tcl등 프로',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 동작구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38818157'},
#  {'기업명': '라온서치',
#   '직무': 'Data Scientist 전문가 모집 (금융그룹사/석사이상 )',
#   '경력사항': '3 ~ 15년',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38817888'},
#  {'기업명': '커리어셀파',
#   '직무': '[그룹계열사] 개발자 (스마트팩토리 구축 개발) (대리급)',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38817584'},
#  {'기업명': '헤리티지서치코어',
#   '직무': '빅데이터 수집 분석 시스템 백엔드 개발/시니어급',
#   '경력사항': '경력 10년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38817035'},
#  {'기업명': '이랜서',
#   '직무': '[본사근무/정규직]  (주)이랜서 PHP 개발자 구인',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679187'},
#  {'기업명': '이랜서',
#   '직무': '[정규직] (주)이랜서 PHP 개발 인재 구인',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38772099'},
#  {'기업명': '(주)핀커스코리아',
#   '직무': '[외국계소비재] 데이터분석 (대리-과장)',
#   '경력사항': '5 ~ 9년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['회계·재무·세무·IR', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38814513'},
#  {'기업명': 'HeNny & McCoy',
#   '직무': '외국계소비재 - Strategic Data Analyst',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38814367'},
#  {'기업명': 'KY컨설팅그룹',
#   '직무': '[의료영상 AI 플랫폼]  응용소프트웨어 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 남동구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38814325'},
#  {'기업명': 'KY컨설팅그룹',
#   '직무': '[의료영상 AI 플랫폼]  영상기반 AI 분석 솔루션 개발 경력자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 남동구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38814314'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 커머스/플랫폼 백엔드 개발 (Java,Spring,AWS 등) -최우대',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38802420'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 커머스/플랫폼 웹개발 (Back-End) - 최고 대기업 - 최우대',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38802789'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 최고 대기업 - 커머스/플랫폼 웹개발 (Back-End) - 최우대',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38802790'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) Cloud Infra Platform Architect - 업계 최고 대기업',
#   '경력사항': '경력 10년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38802800'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 업계 최고 대기업 - Cloud Infra Platform Architect',
#   '경력사항': '경력 10년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38802801'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) (Java,Spring,AWS 등) 커머스/플랫폼 백엔드 개발 -최우대',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38802421'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) Cloud System Engineer - 업계 최고 대기업 - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38802422'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 업계 최고 대기업 - Cloud System Engineer  - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38802423'},
#  {'기업명': '(주)에이치앤티어세스',
#   '직무': '화장품 회사 데이터 사이언티스트 초빙',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38811354'},
#  {'기업명': '(주)핀커스코리아',
#   '직무': '외국계  -  디지털  분석   전문가  채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['마케팅·광고·분석', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38800708'},
#  {'기업명': '(주)핀커스코리아',
#   '직무': '외국계  -  Web   분석   채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['마케팅·광고·분석', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38800832'},
#  {'기업명': '(주)피플렙',
#   '직무': '인공지능 SW개발 총괄 리더/경력 5년이상~',
#   '경력사항': '5 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38810524'},
#  {'기업명': '(주) 잡뉴스솔로몬서치',
#   '직무': '딥러닝 기반 AI 모델 개발자 (대리-차장급), 서초구',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38809229'},
#  {'기업명': 'KY컨설팅그룹',
#   '직무': '지도데이터 기술스타트업 AI 엔지니어 모집',
#   '경력사항': '2 ~ 5년',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38807916'},
#  {'기업명': '제이떠블유커리어(JW career)',
#   '직무': '[R&D] AI, 딥러닝 영상처리 연구소장',
#   '경력사항': '경력 15년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38807866'},
#  {'기업명': '(주)핀커스코리아',
#   '직무': '[응용프로그래머] C# .Net Windows 어플리케이션 개발자',
#   '경력사항': '3 ~ 6년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38807297'},
#  {'기업명': 'KY컨설팅그룹',
#   '직무': '인공지능 영상분석 스타트업 컴퓨터비전 및 AI 엔지니어 모집',
#   '경력사항': '1 ~ 7년',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38806077'},
#  {'기업명': 'HR컨설팅(주)',
#   '직무': '[대기업/금융/IT계열] NLP(자연어처리) Text Mining 연구원',
#   '경력사항': '경력 2년↑',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38805669'},
#  {'기업명': 'HR컨설팅(주)',
#   '직무': '[대형금융계열/연구원] AI Platform 연구개발 석/박사 연구원',
#   '경력사항': '2 ~ 15년',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38805653'},
#  {'기업명': '하이잡',
#   '직무': '추천 시스템 연구/개발',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38805049'},
#  {'기업명': '굿커리어',
#   '직무': '중견기업 영상기반 인공지능 모델개발 주임,대리,과장,차장급',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '동영상·편집·코덱']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38747330'},
#  {'기업명': 'HR컨설팅(주)',
#   '직무': '10대 대기업 IT계열사 IT경력직 각 부문별 채용 4년~16년',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['ERP·시스템분석·설계', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38803556'},
#  {'기업명': '(주)인큐브시스템',
#   '직무': '[코스피상장사]  데이터 분석(전문계약직) 경력직 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 금천구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38753791'},
#  {'기업명': '굿커리어',
#   '직무': '중견기업 의료영상 SW개발 주임,대리,과장,차장급 구함(굿커리어',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '동영상·편집·코덱']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38747328'},
#  {'기업명': '(주)휴먼디지탈',
#   '직무': '() 미국 수율관리 S/W기업() 시스템 통합 엔지니어',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38802121'},
#  {'기업명': '에이치알포유(주)',
#   '직무': '[]미국계 수율관리 솔루션 [] 시스템 통합 엔지니어',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38802054'},
#  {'기업명': '(주)피플렙',
#   '직무': 'Data Science팀 [저축은행그룹 모기업]',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38801922'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[쿼드마이너] python개발자 - 2년차 이상',
#   '경력사항': '2 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38800737'},
#  {'기업명': '(주)스카우트',
#   '직무': '블록체인 플랫폼 / SDK 개발 (유명기업)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38800719'},
#  {'기업명': '(주)피플렙',
#   '직무': 'AI Platform 개발 Lead 경력자(5년이상 경력자~)',
#   '경력사항': '5 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38800282'},
#  {'기업명': '(주)스카우트',
#   '직무': '블록체인 거버넌스 전략 / 블록체인 사업개발',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38800172'},
#  {'기업명': '(주)베스트에치알 (Best HR)',
#   '직무': '[중요] 파이썬/ Back-end 개발 (직급협의)',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38800049'},
#  {'기업명': 'KY컨설팅그룹',
#   '직무': '[의료영상 AI 바이오]  영상기반 AI 분석 솔루션 개발 경력자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 남동구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38799648'},
#  {'기업명': 'KY컨설팅그룹',
#   '직무': '[의료영상 AI 바이오]  응용소프트웨어 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 남동구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38799571'},
#  {'기업명': '(주)비비파트너스',
#   '직무': '[의료기기] 의료영상 소프트웨어 개발 경력직 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38799311'},
#  {'기업명': '베스트네트워크㈜',
#   '직무': '16. [핀테크기업] Back-end SW 엔지니어 정규직 채용',
#   '경력사항': '5 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38797322'},
#  {'기업명': 'FNR Consulting',
#   '직무': '외국계 가전사 / SW Engineer Mobile IOS',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38796415'},
#  {'기업명': '주식회사 라온서치',
#   '직무': '[대기업] IoT Intelligence 기술 개발    (3년-10년)',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', '통신·모바일']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38795881'},
#  {'기업명': '주식회사 라온서치',
#   '직무': '[대기업]AI 대화SDK 솔루션 기술  개발(3년-10년)',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38795880'},
#  {'기업명': 'HR컨설팅(주)',
#   '직무': '[대기업/금융/IT계열] Computer Vision 분야 연구개발 (석/박사)',
#   '경력사항': '경력 2년↑',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38795575'},
#  {'기업명': '(주)드림에이치알',
#   '직무': '글로벌 비지니스 서비스기업 웹사이트 및 온라인 캠페인 성과분석',
#   '경력사항': '1 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['마케팅·광고·분석', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38794135'},
#  {'기업명': '인비즈써치',
#   '직무': '대형증권사 머신러닝 퀀트모델링 및 데이터분석 경력자 모집',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['ERP·시스템분석·설계', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38794076'},
#  {'기업명': '디퍼런트에이치알',
#   '직무': '딥러닝 경력 채용(정규직)',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38790613'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '반도체 High speed IO Circuit Design Engineer',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['전기·전자·제어', '반도체·디스플레이·LCD']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38789745'},
#  ...]

# %%
# db 직업 스크래핑

job_list_db = []
page_num = 1
while True:
    url = f'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page={page_num}&cat_cd=416&cat_key=40745&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=2#searchTitle'
    req_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    }
    html = requests.get(url, req_header).text
    soup = BeautifulSoup(html, 'html.parser')
    if soup.select('div.list_body div.list_item') == []:
        break
    for tag in soup.select('div.list_body div.list_item'):
        company_dict = {}
        company_dict["기업명"] = tag.select('div.company_nm a span')[0].text
        company_dict["직무"] = tag.select('div.notification_info a span')[0].text
        company_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
        company_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
        try:
            company_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
        except:
            company_dict["근무형태"] = ""
        try:    
            company_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
        except:
            company_dict["근무지"] = ""
        category_list = []
        for item in tag.select('div.notification_info div.job_meta span span'):
            category_list.append(item.text)
        company_dict["분류"] = str(category_list)
        company_dict["분류필터"] = "db"
        
        detail_url = tag.select_one('div.notification_info a').attrs['href']
        full_detail_url = urljoin(main_url, detail_url)
        company_dict["상세링크"] = full_detail_url
        job_list_db.append(company_dict)
    page_num += 1
job_list_db
# Out:
#  채용 공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38695345'},
#  {'기업명': '(주)후이즈시스템',
#   '직무': '(주)후이즈시스템 솔루션사업부 PHP개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38695336'},
#  {'기업명': '(주)니트로아이',
#   '직무': 'JAVA/JSP 전자정부프레임워크 웹 개발자 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '경기 수원시 팔달구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38694804'},
#  {'기업명': '(주)비츠로테크',
#   '직무': '비츠로그룹 경력직(정보DB화) 모집',
#   '경력사항': '5 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 광진구',
#   '분류': "['마케팅·광고·분석', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38694585'},
#  {'기업명': '바이브컴퍼니',
#   '직무': '바이브컴퍼니에서 경력직 개발자 모집합니다.',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38694547'},
#  {'기업명': '(주)미래아이씨티',
#   '직무': '어플리케이션 개발,유지보수 - C#, WPF (중급)',
#   '경력사항': '6 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '프리랜서',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38641748'},
#  {'기업명': '와이피랩스(주)',
#   '직무': '[보충역 신규 대상] 데이터 엔지니어(Data engineer) 개발자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38691842'},
#  {'기업명': '사단법인 한국국제연합봉사단',
#   '직무': '[한국국제연합봉사단] 개발자(PC소프트웨어/앱개발) 경력직 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38691056'},
#  {'기업명': '(주) 보고바이오',
#   '직무': '[보고바이오] 개발자 (PC소프트웨어/앱개발) 경력직 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690846'},
#  {'기업명': '㈜네오플',
#   '직무': '[네오플] 서버/클라이언트 프로그래머 인재 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '제주 제주시',
#   '분류': "['서버·네트워크·보안', '게임·Game']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690719'},
#  {'기업명': '(주)시닉스레이',
#   '직무': '의료영상소프트웨어 UI 및 프로그램 개발',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중랑구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38662076'},
#  {'기업명': '(주)위플레이라이트',
#   '직무': '클레이튼  파트너사 - Project WITH 블록체인/서버 개발자 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 중구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690200'},
#  {'기업명': '솔트웨어(주)',
#   '직무': 'AWS 영업, 컨설팅, 기술지원 및 영업마케팅지원 경력직',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38689827'},
#  {'기업명': '(주)하이퍼커넥트',
#   '직무': '[하이퍼커넥트] Service Operation Specialist',
#   '경력사항': '1 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['사무보조·문서작성', '게임·Game']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38654595'},
#  {'기업명': '(주)엠에스벤터',
#   '직무': '(주)엠에스벤터에서 웹개발자 채용합니다.',
#   '경력사항': '경력 5년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '인천 연수구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38689542'},
#  {'기업명': '(주)아이빌드',
#   '직무': '앱개발 (하이브리드/네이티브) 경력직 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38689416'},
#  {'기업명': '(주)다인리더스',
#   '직무': '(주)다인리더스 php 개발 (4년 이상) 경력사원 채용',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38618089'},
#  {'기업명': '(주)다인리더스',
#   '직무': '(주)다인리더스 웹개발(Java·JSP/Ajax) 경력사원 채용',
#   '경력사항': '3 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38685029'},
#  {'기업명': '(사)한국유엔봉사단',
#   '직무': '[한국유엔봉사단] 개발자 (PC소프트웨어/앱개발) 경력직 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '퍼블리싱·UI개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38688342'},
#  {'기업명': '(주)빗썸코리아',
#   '직무': '빗썸 IT 개발자 경력직 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38688124'},
#  {'기업명': '(주)서울소프트',
#   '직무': '서울소프트  프론트/백앤드 개발자 모십니다.',
#   '경력사항': '경력 2년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38564206'},
#  {'기업명': '스마트데이터(주)',
#   '직무': '[핀테크] 정규직 웹개발자(JAVA) 경력 모집',
#   '경력사항': '3 ~ 7년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38524641'},
#  {'기업명': '주식회사 새집다오',
#   '직무': '2020년 하반기 웹/모바일 개발자 경력사원 모집 공고',
#   '경력사항': '5 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528063'},
#  {'기업명': '시앤피컨설팅(주)',
#   '직무': 'VB.NET(MVC), ASP.NET, ASP 경력직 프로그래머를 모십니다.',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596670'},
#  {'기업명': '한국씨아이엠(주)',
#   '직무': '경영관리본부 전산총무 담당자 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['총무·법무·사무', '웹마스터·QA·테스터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38678591'},
#  {'기업명': '(주)그레이스타인그룹',
#   '직무': '(주)그레이스타인그룹 웹 개발자를 모집합니다.',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38518683'},
#  {'기업명': '(주)미스테리코',
#   '직무': '[청년디지털일자리사업] 앱 개발, 인공지능(AI), 빅데이터 개발',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38685054'},
#  {'기업명': '인터라인',
#   '직무': '개발자(풀스텍) 정규직 모집공고 - 연구소',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 수정구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38682398'},
#  {'기업명': '인터라인',
#   '직무': '개발자(풀스텍) 정규직 모집공고',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대구 수성구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38682388'},
#  {'기업명': '(주)두베',
#   '직무': '[정규직/경력] 금융SI 부문 개발자 모집 (서버/웹/모바일)',
#   '경력사항': '5 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38681047'},
#  {'기업명': '(주)바이오스타코리아',
#   '직무': '바이오스타 전산실에서 운영/정책 수립 담당자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679268'},
#  {'기업명': '한국전자인증㈜',
#   '직무': '시스템 엔지니어 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시 영통구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38680377'},
#  {'기업명': '(주)에코인사이트글로벌',
#   '직무': '[정규직] 정부과제 행정업무',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38656930'},
#  {'기업명': '㈜이지엠소프트',
#   '직무': '웹개발(PHP, MySql, Ajax, jQuery, node.js, CSS 안드로이드)',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '대구 수성구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38678784'},
#  {'기업명': '(주)얼티온',
#   '직무': '솔루션 & SI 개발자 신입/경력 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38677338'},
#  {'기업명': '(주)소프트파워',
#   '직무': 'SW기술지원직 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['고객센터·CS', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38676651'},
#  {'기업명': '유니코아',
#   '직무': 'PM/전자금융업(pg)&웹서비스기획外 정규직 채용(경력사원)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹기획·PM', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38566644'},
#  {'기업명': '(주)뉴트리션코트',
#   '직무': '백엔드개발 경력직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38675684'},
#  {'기업명': '예스이십사㈜',
#   '직무': '[YES24]제휴연동API개발//쇼핑몰 개발,유지보수 경력직 채용',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38675420'},
#  {'기업명': '(주)플랜아이',
#   '직무': '[플랜아이] Java /JSP 소프트웨어 엔지니어 채용합니다.',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['웹개발', 'ERP·시스템분석·설계']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38636235'},
#  {'기업명': '(주)유투바이오',
#   '직무': 'IT연구소 S/W 개발자 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38605637'},
#  {'기업명': '(주)엘아이텍',
#   '직무': '(경력) 응용프로그램개발, 웹개발 JAVA 개발자 정규직 채용',
#   '경력사항': '3 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38674940'},
#  {'기업명': '주식회사 북레일',
#   '직무': '개발운영팀 웹개발 채용 공고(신입/경력)',
#   '경력사항': '신입',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38674754'},
#  {'기업명': '주식회사 인텐트시큐어',
#   '직무': '응용프로그램개발(리눅스) 채용합니다',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 수정구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38674677'},
#  {'기업명': '미디어젠㈜',
#   '직무': 'NLU 2팀-개발자 모집 (신입)',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38674379'},
#  {'기업명': '한국IT교육원',
#   '직무': 'IT교육 기획/운영/행정 채용 공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '대구 동구',
#   '분류': "['기획·전략·경영', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38674085'},
#  {'기업명': '(주)디지털알엑스솔루션',
#   '직무': '뉴노멀을 이끌  IT개발팀 개발리더와 개발자를 모십니다.',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38605007'},
#  {'기업명': '(주)곰앤컴퍼니',
#   '직무': '(주)곰앤컴퍼니 웹(PHP) 개발자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38367456'},
#  {'기업명': '(주)웹플레이',
#   '직무': '[웹플레이] 웹하드 시스템 엔지니어 채용 공고',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹마스터·QA·테스터', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38671826'},
#  {'기업명': '더 에이치알더(주)',
#   '직무': '풀 스택 개발자(MERN  Stack) [경력,신입]',
#   '경력사항': '2 ~ 6년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38671504'},
#  {'기업명': '(주)모히또게임즈',
#   '직무': '플랫폼 웹 개발자(경력) 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38668843'},
#  {'기업명': '(주)더블다운인터액티브',
#   '직무': '[더블유게임즈 자회사] 웹/게임서버 개발자 경력 모집 (1년이상)',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '게임·Game']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38615802'},
#  {'기업명': '차봇 모빌리티 주식회사',
#   '직무': '[강소기업 차봇 모빌리티] PHP/웹 개발자 채용공고',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '계약직',
#   '근무지': '서울 성동구',
#   '분류': "['웹개발', '퍼블리싱·UI개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38668060'},
#  {'기업명': '네이버시스템(주)',
#   '직무': '데이터 분석가 Data Scientist 경력자 모집',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38667111'},
#  {'기업명': '(주)아이메디신',
#   '직무': '웹 풀스택 개발자 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666967'},
#  {'기업명': '(주)모이기술',
#   '직무': '웹서비스 개발 (IoT 시스템)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '인천 서구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38664634'},
#  {'기업명': '키네마스터 주식회사',
#   '직무': '서버 개발자 모집',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38664579'},
#  {'기업명': '스마트트래커',
#   '직무': '2020년 하반기 앱개발/마케팅 정규직 채용합니다',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '충북 청주시 청원구',
#   '분류': "['그래픽디자인·CG', '광고·시각디자인']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38663442'},
#  {'기업명': '(주)그리드텍',
#   '직무': 'JAVA/JSP 개발 및 유지보수 신입 직원 채용',
#   '경력사항': '신입',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '전남 나주시',
#   '분류': "['웹개발', '퍼블리싱·UI개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38660982'},
#  {'기업명': '(주)차바이오텍',
#   '직무': '[차바이오텍] IT사업본부 부문별 경력 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38555666'},
#  {'기업명': '(주)매쓰모카',
#   '직무': '[벤처기업] 백엔드 Backend 개발자[PHP,Mysql(mariaDB),Python]',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '부산 해운대구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38635162'},
#  {'기업명': '디지코리아(주)',
#   '직무': 'Java·JSP, MS-SQL, Pro-C 정규직 채용 공고(경력)',
#   '경력사항': '4 ~ 5년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 하남시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38624794'},
#  {'기업명': '21라인',
#   '직무': '[개발부 연령 28세] 젊은기업 21라인에서 개발자를 채용합니다',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 고양시 일산동구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38656088'},
#  {'기업명': '(주)페칭',
#   '직무': 'React/React-Native 개발자 팀원을 구합니다',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38655434'},
#  {'기업명': '(주)망고',
#   '직무': '백엔드 웹 개발자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 의정부시',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38652824'},
#  {'기업명': '(주)밀버스',
#   '직무': '[MILVUS]빅데이터분석 마케팅(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['마케팅·광고·분석', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38651165'},
#  {'기업명': '(주)밀버스',
#   '직무': '[MILVUS] Java 경력 개발자 채용 안내',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['마케팅·광고·분석', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38651094'},
#  {'기업명': '(주)이베이테크',
#   '직무': 'PHP 웹 개발',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649712'},
#  {'기업명': '(주)모아데이타',
#   '직무': '모바일 앱 및 UI 개발자 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 수정구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38581218'},
#  {'기업명': '케이비즈소프트(KBIZ-soft)',
#   '직무': '자바 개발자 모집(신입/경력, SI/SM)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38644815'},
#  {'기업명': '(주)리버스랩',
#   '직무': 'Back-End / Web Front-end 개발자 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38644368'},
#  {'기업명': '(주)크레이벤쳐스',
#   '직무': '[정규직] 웹개발자(PHP, .NET, 백엔드, ASP, C#) 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 부천시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38642720'},
#  ...]

# %%
job_list = job_list_cloud + job_list_python + job_list_db

# %%
# local db에 job_list 저장하기

import pymysql
import sqlalchemy
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("mysql+mysqldb://root:"+"root"+"@localhost:3307/it_wave_db", encoding="utf-8")
conn = engine.connect()

jobs_df = pd.DataFrame(columns=['기업명', '직무', '경력사항', '학력', '근무형태', '근무지', '분류', '분류필터', '상세링크'])

for post in job_list:
    obj = pd.Series(post)
    jobs_df = jobs_df.append(obj, ignore_index=True)
    jobs_df["job_like_count"]=0
    
jobs_df.to_sql(name="job_list", con=engine, if_exists='append', index=False, index_label='id')
