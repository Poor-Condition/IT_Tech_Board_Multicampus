# %%
import requests
from bs4 import BeautifulSoup
import re
from urllib.parse import urljoin

# %%
# page_num = 1
# while True:
#     url = f'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page={page_num}&cat_key=41711%2C40721%2C40426&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=1#searchTitle'
#     req_header = {
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
#     }
#     html = requests.get(url, req_header).text
#     soup = BeautifulSoup(html, 'html.parser')
#     if soup.select('div.list_body div.list_item') == []:
#         break
#     print(url)
#     page_num += 1

# %%
url = f'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page={page_num}&cat_key=41711%2C40721%2C40426&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=1#searchTitle'
req_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    }
html = requests.get(url, req_header).text
soup = BeautifulSoup(html, 'html.parser')

# %%
#url = 'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page=2&cat_key=41704%2C40220&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=1#searchTitle'
#url = 'http://www.saramin.co.kr/zf_user/jobs/api/get-search-count?type=job-category&cat_key=41704%2C40220&smart_tag='
main_url = 'http://www.saramin.co.kr'
url = 'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page=1&cat_key=41704%2C40220&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=1'

req_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    
}
html = requests.get(url, req_header).text
soup = BeautifulSoup(html, 'html.parser')
#print(soup.select('div.list_body div.list_item'))

company_list = []
for tag in soup.select('div.list_body div.list_item'):
    company_dict = {}
    company_dict["기업명"] = tag.select('div.company_nm a span')[0].text
    company_dict["직무"] = tag.select('div.notification_info a span')[0].text
    company_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
    company_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
    company_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
    company_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
    category_list = []
    for item in tag.select('div.notification_info div.job_meta span span'):
        category_list.append(item.text)
    company_dict["분류"] = category_list
    
    detail_url = tag.select_one('div.notification_info a').attrs['href']
    full_detail_url = urljoin(main_url, detail_url)
    company_dict["상세링크"] = full_detail_url
    company_list.append(company_dict)

company_list
# Out:
# [{'기업명': '(주)레뷰코퍼레이션',
#   '직무': '플랫폼그룹 부문별 신입/경력직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': ['캐릭터·만화·애니', '서버·네트워크·보안'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38541335&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)시지온',
#   '직무': '라이브리 서비스 광고 플랫폼 개발자 모집',
#   '경력사항': '3 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': ['서버·네트워크·보안', '웹개발'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38593999'},
#  {'기업명': '주식회사 코드베르그',
#   '직무': '코드베르그 Back-end 개발부문 모집 (PHP or Node.js)',
#   '경력사항': '3 ~ 6년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': ['서버·네트워크·보안'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38434985'},
#  {'기업명': '파우게임즈',
#   '직무': '[파우게임즈] 기술지원(DB/웹개발) 담당자 채용',
#   '경력사항': '3 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': ['서버·네트워크·보안', '웹개발'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38406328'},
#  {'기업명': '(주)상록아이엔씨',
#   '직무': '[경험자 우대] Python/Linux AI 시스템 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 부천시',
#   '분류': ['서버·네트워크·보안', '응용프로그램개발'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601843&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)옷딜',
#   '직무': 'Ai솔루션 옷딜 각부분 경력모집',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': ['기획·전략·경영', '출판·편집디자인'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580264&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)중고나라',
#   '직무': '[중고나라] 개발 부문 전문가 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': ['웹마스터·QA·테스터', '서버·네트워크·보안'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38573880&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)자비스',
#   '직무': '[코스닥 상장사 ㈜자비스] 2020년 하반기 공개채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 중원구',
#   '분류': ['해외영업·무역영업', '사무보조·문서작성'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578169&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)후이즈',
#   '직무': '㈜후이즈 쇼핑몰 각 부문별 신입/경력 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': ['기획·전략·경영', '사무보조·문서작성'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563638&adsCategoryItem=effect_bold&'},
#  {'기업명': '한국직업전문학교',
#   '직무': '[국비무료/수당지급] 빅데이터/UI/UX 퍼블리싱/응용 S/W 개발자',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '서울 구로구',
#   '분류': ['그래픽디자인·CG', '서버·네트워크·보안'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38393122&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)큐픽스',
#   '직무': '[신입/경력/전문연구요원] AWS/Ruby 백엔드엔지니어(DevOps)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': ['서버·네트워크·보안', '웹개발'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586042'},
#  {'기업명': '네오다임(주)',
#   '직무': '네오다임(주) 웹 개발자 / 웹 디자이너 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': ['서버·네트워크·보안', '웹개발'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38344313'},
#  {'기업명': '(재)충남정보문화산업진흥원',
#   '직무': '2020년 제 3차 계약직 직원채용 공고(연장공고)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '충남 천안시 동남구',
#   '분류': ['기획·전략·경영', '홍보·PR·사보'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539566&adsCategoryItem=effect_bold&'},
#  {'기업명': '주식회사 단비',
#   '직무': 'AI / 머신러닝 / Go / Python / MES 분야별 개발인력 모집합니다',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 해운대구',
#   '분류': ['웹개발', '데이터베이스·DBA'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38377404'},
#  {'기업명': '(주)이지다이아텍',
#   '직무': '[기업부설연구소] 응용소프트웨어 개발자 경력직원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '경기 안양시 동안구',
#   '분류': ['응용프로그램개발', '시스템개발'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552827'},
#  {'기업명': '(주)매드업',
#   '직무': '[매드업] 하반기 전 직군 대규모 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': ['인사·교육·노무', '마케팅·광고·분석'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596083&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)이노와이어리스',
#   '직무': '이노와이어리스/큐셀네트웍스 각 분야 신입/경력 채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': ['생산관리·품질관리', '생산·제조·포장·조립'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590538&adsCategoryItem=effect_bold&'},
#  {'기업명': '패스트캠퍼스(주)',
#   '직무': '[패스트캠퍼스] 대규모 인재 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': ['기획·전략·경영', '마케팅·광고·분석'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38230007'},
#  {'기업명': '(주)선진',
#   '직무': '[하림그룹] ㈜선진 신입/경력 수시채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': ['회계·재무·세무·IR', '마케팅·광고·분석'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580036'},
#  {'기업명': '(주)세차왕',
#   '직무': '세차왕에서 백엔드 및 웹앱 개발자를 모십니다.',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': ['서버·네트워크·보안', '웹개발'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562173'},
#  {'기업명': '㈜아이티언',
#   '직무': '보안 솔루션 및 서비스 운영 엔지니어(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시 동안구',
#   '분류': ['서버·네트워크·보안'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38414809'},
#  {'기업명': '켈리서비스 유한회사',
#   '직무': '[한국화웨이/영어or중국어] IT Engineer (서버유지보수, ICT)',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 중구',
#   '분류': ['기술영업', '서버·네트워크·보안'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38584624'},
#  {'기업명': '(주)경일게임아카데미',
#   '직무': '게임회사 취업 협약 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': ['서버·네트워크·보안', '웹기획·PM'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38577413&adsCategoryItem=effect_bold&'},
#  {'기업명': '휴먼교육센터학원',
#   '직무': '[전액무료]자바/파이썬 IT교육받고 취업하자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': ['서버·네트워크·보안', '웹개발'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38510654&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)지에스아이티엠',
#   '직무': '2020년 하반기 GS ITM 경력사원 공개채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': ['웹마스터·QA·테스터', '서버·네트워크·보안'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587357'},
#  {'기업명': '펜타시큐리티시스템(주)',
#   '직무': '[펜타시큐리티] 보안S/W 개발자 모집 (DB, 인증, 클라우드)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 영등포구',
#   '분류': ['웹마스터·QA·테스터', '서버·네트워크·보안'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595144&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)보고플레이',
#   '직무': '[Live 커머스 플랫폼] PD,MD,마케팅,CS,JAVA,iOS/Android앱개발',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': ['상품기획·MD', '홍보·PR·사보'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569631&adsCategoryItem=effect_bold&'},
#  {'기업명': '(유)딜리버리히어로 코리아',
#   '직무': '전 개발직군 대규모 채용중',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': ['기획·전략·경영', '총무·법무·사무'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38476546'},
#  {'기업명': '한국산업단지공단',
#   '직무': '20년 하반기 신입직원/고졸채용형인턴/체험형청년인턴 모집 공고',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '대구 달서구',
#   '분류': ['총무·법무·사무', '회계·재무·세무·IR'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596493'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '[삼성물산/연봉상위] 모바일 앱 및 웹 운영 경력 개발자 채용',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 송파구',
#   '분류': ['서버·네트워크·보안', '웹개발'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591901'},
#  {'기업명': '(주)안랩',
#   '직무': '2020 하반기 안랩 연구소 신입사원 공개채용',
#   '경력사항': '신입',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': ['웹마스터·QA·테스터', '서버·네트워크·보안'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578654'},
#  {'기업명': '(주)씨제이이엔엠',
#   '직무': 'CJ ENM(E&M부문) TVING 경력사원 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': ['웹마스터·QA·테스터', '서버·네트워크·보안'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38515830'},
#  {'기업명': '(주)여우전자',
#   '직무': '여우전자 하반기 신규채용 모집 공고',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': ['마케팅·광고·분석', '일반영업'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574212'},
#  {'기업명': '(주)넷케이티아이',
#   '직무': '각분야 정규직원 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': ['기획·전략·경영', '기술영업'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578831'},
#  {'기업명': '(주)볼트홀',
#   '직무': '[2020년 볼트홀] 웹서버 개발자/Javascript,AWS,php,node.js',
#   '경력사항': '5 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 수정구',
#   '분류': ['서버·네트워크·보안', '웹개발'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586962'},
#  {'기업명': '한국전자통신연구원',
#   '직무': '2020년 3차 박사후연수연구원 및 위촉연구원 공개채용',
#   '경력사항': '경력무관',
#   '학력': '석사↑',
#   '근무형태': '계약직',
#   '근무지': '대전 유성구',
#   '분류': ['화학·에너지', '반도체·디스플레이·LCD'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590666'},
#  {'기업명': '(주)월드스폰',
#   '직무': '웹 서비스 유지보수 및 기획자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': ['서버·네트워크·보안', '웹기획·PM'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552512'},
#  {'기업명': '펍지(주)',
#   '직무': '펍지㈜ 각 부문별 수시 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': ['총무·법무·사무', '인사·교육·노무'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38542347'},
#  {'기업명': '(주)후이즈',
#   '직무': '(주)후이즈 도메인사업부 개발자 인재 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': ['웹마스터·QA·테스터', '서버·네트워크·보안'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528456'},
#  {'기업명': '(주)하나금융티아이',
#   '직무': '[하나금융융합기술원] 부문별 경력사원 모집',
#   '경력사항': '경력',
#   '학력': '석사↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': ['서버·네트워크·보안', '웹기획·PM'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565737'},
#  {'기업명': '㈜해커스교육그룹',
#   '직무': '2020년 해커스 교육그룹 [신입/경력] 각 부문별 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 서초구',
#   '분류': ['기획·전략·경영', '총무·법무·사무'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38369849'},
#  {'기업명': '한국직업능력교육원 안산',
#   '직무': '경기/시흥・안산/군포 국비무료 취업연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '경기 안산시 단원구',
#   '분류': ['회계·재무·세무·IR', '생산관리·품질관리'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38527236&adsCategoryItem=effect_bold&'},
#  {'기업명': '한밭대학교산학협력단',
#   '직무': '빅데이터 정보보안 S/W 엔지니어 양성과정',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '대전 유성구',
#   '분류': ['서버·네트워크·보안', '시스템개발'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38357074'},
#  {'기업명': '(주)아임웹',
#   '직무': 'R&D Team  (PHP 개발자) 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서대문구',
#   '분류': ['서버·네트워크·보안', '웹개발'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560119'},
#  {'기업명': '(주)LG유플러스',
#   '직무': 'IT개발/운영 신입&경력 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': ['웹기획·PM', '웹개발'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533503'},
#  {'기업명': '(주)핀크럭스',
#   '직무': '[부산] 서비스를 함께 만들어 가실 웹개발자를 찾습니다.',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 부산진구',
#   '분류': ['서버·네트워크·보안', '웹개발'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562265'},
#  {'기업명': '(주) 하트게임즈',
#   '직무': '야근無) 게임 서버 Node.js 개발자 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': ['서버·네트워크·보안', '게임·Game'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574743'},
#  {'기업명': '사운드파이프코리아(주)',
#   '직무': 'H자동차그룹 글로벌 Car Cloud 운영 신입 채용(인도+한국팀)',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': ['서버·네트워크·보안', '인공지능(AI)·빅데이터'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38338895'},
#  {'기업명': '사운드파이프코리아(주)',
#   '직무': 'H자동차그룹 카클라우드 리눅스/오픈소스 시스템엔지니어 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': ['서버·네트워크·보안', '응용프로그램개발'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38338893'},
#  {'기업명': '사운드파이프코리아(주)',
#   '직무': 'H자동차그룹 Car Cloud (오픈스택+쿠버네티스) 시스템엔지니어',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': ['서버·네트워크·보안', '인공지능(AI)·빅데이터'],
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38338892'}]

# %%
company_list_cloud = []
page_num = 1
main_url = 'http://www.saramin.co.kr'

while True:
    url = f'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page={page_num}&cat_key=41704%2C40220&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=1'
    req_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    }
    html = requests.get(url, req_header).text
    soup = BeautifulSoup(html, 'html.parser')
    
    # 만약 더이상 페이지 리스트에 공고가 없을 경우 break
    if soup.select('div.list_body div.list_item') == []:
        break
    for tag in soup.select('div.list_body div.list_item'):
        company_dict = {}
        company_dict["기업명"] = tag.select('div.company_nm a span')[0].text
        company_dict["직무"] = tag.select('div.notification_info a span')[0].text
        company_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
        company_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
        # 근무형태가 빈칸인 직무들도 있음
        try:
            company_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
        except:
            company_dict["근무형태"] = ""
        company_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
        category_list = []
        # 분류는 여러가지가 있기 때문에 리스트 형태로 저장
        for item in tag.select('div.notification_info div.job_meta span span'):
            category_list.append(item.text)
        company_dict["분류"] = str(category_list)
        
        detail_url = tag.select_one('div.notification_info a').attrs['href']
        full_detail_url = urljoin(main_url, detail_url)
        company_dict["상세링크"] = full_detail_url
        company_list_cloud.append(company_dict)
    page_num += 1
company_list_cloud
# Out:
# [{'기업명': '펜타시큐리티시스템(주)',
#   '직무': '[펜타시큐리티] 보안S/W 개발자 모집 (DB, 인증, 클라우드)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595144&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)보고플레이',
#   '직무': '[Live 커머스 플랫폼] PD,MD,마케팅,CS,JAVA,iOS/Android앱개발',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['상품기획·MD', '홍보·PR·사보']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569631&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)레뷰코퍼레이션',
#   '직무': '플랫폼그룹 부문별 신입/경력직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['캐릭터·만화·애니', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38541335&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)시지온',
#   '직무': '라이브리 서비스 광고 플랫폼 개발자 모집',
#   '경력사항': '3 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38593999'},
#  {'기업명': '주식회사 코드베르그',
#   '직무': '코드베르그 Back-end 개발부문 모집 (PHP or Node.js)',
#   '경력사항': '3 ~ 6년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38434985'},
#  {'기업명': '파우게임즈',
#   '직무': '[파우게임즈] 기술지원(DB/웹개발) 담당자 채용',
#   '경력사항': '3 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38406328'},
#  {'기업명': '(주)상록아이엔씨',
#   '직무': '[경험자 우대] Python/Linux AI 시스템 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 부천시',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601843&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)옷딜',
#   '직무': 'Ai솔루션 옷딜 각부분 경력모집',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['기획·전략·경영', '출판·편집디자인']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580264&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)중고나라',
#   '직무': '[중고나라] 개발 부문 전문가 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38573880&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)자비스',
#   '직무': '[코스닥 상장사 ㈜자비스] 2020년 하반기 공개채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 중원구',
#   '분류': "['해외영업·무역영업', '사무보조·문서작성']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578169&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)후이즈',
#   '직무': '㈜후이즈 쇼핑몰 각 부문별 신입/경력 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563638&adsCategoryItem=effect_bold&'},
#  {'기업명': '한국직업전문학교',
#   '직무': '[국비무료/수당지급] 빅데이터/UI/UX 퍼블리싱/응용 S/W 개발자',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '서울 구로구',
#   '분류': "['그래픽디자인·CG', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38393122&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)큐픽스',
#   '직무': '[신입/경력/전문연구요원] AWS/Ruby 백엔드엔지니어(DevOps)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586042'},
#  {'기업명': '네오다임(주)',
#   '직무': '네오다임(주) 웹 개발자 / 웹 디자이너 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38344313'},
#  {'기업명': '(재)충남정보문화산업진흥원',
#   '직무': '2020년 제 3차 계약직 직원채용 공고(연장공고)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '충남 천안시 동남구',
#   '분류': "['기획·전략·경영', '홍보·PR·사보']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539566&adsCategoryItem=effect_bold&'},
#  {'기업명': '주식회사 단비',
#   '직무': 'AI / 머신러닝 / Go / Python / MES 분야별 개발인력 모집합니다',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 해운대구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38377404'},
#  {'기업명': '(주)이지다이아텍',
#   '직무': '[기업부설연구소] 응용소프트웨어 개발자 경력직원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552827'},
#  {'기업명': '(주)매드업',
#   '직무': '[매드업] 하반기 전 직군 대규모 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['인사·교육·노무', '마케팅·광고·분석']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596083&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)이노와이어리스',
#   '직무': '이노와이어리스/큐셀네트웍스 각 분야 신입/경력 채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['생산관리·품질관리', '생산·제조·포장·조립']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590538&adsCategoryItem=effect_bold&'},
#  {'기업명': '패스트캠퍼스(주)',
#   '직무': '[패스트캠퍼스] 대규모 인재 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '마케팅·광고·분석']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38230007'},
#  {'기업명': '(주)선진',
#   '직무': '[하림그룹] ㈜선진 신입/경력 수시채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['회계·재무·세무·IR', '마케팅·광고·분석']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580036'},
#  {'기업명': '(주)세차왕',
#   '직무': '세차왕에서 백엔드 및 웹앱 개발자를 모십니다.',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562173'},
#  {'기업명': '㈜아이티언',
#   '직무': '보안 솔루션 및 서비스 운영 엔지니어(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38414809'},
#  {'기업명': '켈리서비스 유한회사',
#   '직무': '[한국화웨이/영어or중국어] IT Engineer (서버유지보수, ICT)',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 중구',
#   '분류': "['기술영업', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38584624'},
#  {'기업명': '(주)경일게임아카데미',
#   '직무': '게임회사 취업 협약 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38577413&adsCategoryItem=effect_bold&'},
#  {'기업명': '휴먼교육센터학원',
#   '직무': '[전액무료]자바/파이썬 IT교육받고 취업하자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38510654&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)지에스아이티엠',
#   '직무': '2020년 하반기 GS ITM 경력사원 공개채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587357'},
#  {'기업명': '(유)딜리버리히어로 코리아',
#   '직무': '전 개발직군 대규모 채용중',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38476546'},
#  {'기업명': '한국산업단지공단',
#   '직무': '20년 하반기 신입직원/고졸채용형인턴/체험형청년인턴 모집 공고',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '대구 달서구',
#   '분류': "['총무·법무·사무', '회계·재무·세무·IR']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596493'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '[삼성물산/연봉상위] 모바일 앱 및 웹 운영 경력 개발자 채용',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591901'},
#  {'기업명': '(주)안랩',
#   '직무': '2020 하반기 안랩 연구소 신입사원 공개채용',
#   '경력사항': '신입',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578654'},
#  {'기업명': '(주)씨제이이엔엠',
#   '직무': 'CJ ENM(E&M부문) TVING 경력사원 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38515830'},
#  {'기업명': '(주)여우전자',
#   '직무': '여우전자 하반기 신규채용 모집 공고',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['마케팅·광고·분석', '일반영업']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574212'},
#  {'기업명': '(주)넷케이티아이',
#   '직무': '각분야 정규직원 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['기획·전략·경영', '기술영업']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578831'},
#  {'기업명': '(주)볼트홀',
#   '직무': '[2020년 볼트홀] 웹서버 개발자/Javascript,AWS,php,node.js',
#   '경력사항': '5 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 수정구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586962'},
#  {'기업명': '한국전자통신연구원',
#   '직무': '2020년 3차 박사후연수연구원 및 위촉연구원 공개채용',
#   '경력사항': '경력무관',
#   '학력': '석사↑',
#   '근무형태': '계약직',
#   '근무지': '대전 유성구',
#   '분류': "['화학·에너지', '반도체·디스플레이·LCD']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590666'},
#  {'기업명': '(주)월드스폰',
#   '직무': '웹 서비스 유지보수 및 기획자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552512'},
#  {'기업명': '펍지(주)',
#   '직무': '펍지㈜ 각 부문별 수시 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['총무·법무·사무', '인사·교육·노무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38542347'},
#  {'기업명': '(주)후이즈',
#   '직무': '(주)후이즈 도메인사업부 개발자 인재 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528456'},
#  {'기업명': '(주)하나금융티아이',
#   '직무': '[하나금융융합기술원] 부문별 경력사원 모집',
#   '경력사항': '경력',
#   '학력': '석사↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565737'},
#  {'기업명': '㈜해커스교육그룹',
#   '직무': '2020년 해커스 교육그룹 [신입/경력] 각 부문별 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38369849'},
#  {'기업명': '한국직업능력교육원 안산',
#   '직무': '경기/시흥・안산/군포 국비무료 취업연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '경기 안산시 단원구',
#   '분류': "['회계·재무·세무·IR', '생산관리·품질관리']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38527236&adsCategoryItem=effect_bold&'},
#  {'기업명': '한밭대학교산학협력단',
#   '직무': '빅데이터 정보보안 S/W 엔지니어 양성과정',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '대전 유성구',
#   '분류': "['서버·네트워크·보안', '시스템개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38357074'},
#  {'기업명': '(주)아임웹',
#   '직무': 'R&D Team  (PHP 개발자) 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서대문구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560119'},
#  {'기업명': '(주)LG유플러스',
#   '직무': 'IT개발/운영 신입&경력 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533503'},
#  {'기업명': '(주)핀크럭스',
#   '직무': '[부산] 서비스를 함께 만들어 가실 웹개발자를 찾습니다.',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 부산진구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562265'},
#  {'기업명': '(주) 하트게임즈',
#   '직무': '야근無) 게임 서버 Node.js 개발자 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '게임·Game']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574743'},
#  {'기업명': '사운드파이프코리아(주)',
#   '직무': 'H자동차그룹 글로벌 Car Cloud 운영 신입 채용(인도+한국팀)',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38338895'},
#  {'기업명': '사운드파이프코리아(주)',
#   '직무': 'H자동차그룹 카클라우드 리눅스/오픈소스 시스템엔지니어 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38338893'},
#  {'기업명': '사운드파이프코리아(주)',
#   '직무': 'H자동차그룹 Car Cloud (오픈스택+쿠버네티스) 시스템엔지니어',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38338892'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 프로젝트 개발 경력자 대규모 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561876'},
#  {'기업명': '(주)테크데이타',
#   '직무': '[경력] 테크데이타 - AWS 클라우드 엔지니어(SA) 모집',
#   '경력사항': '2 ~ 9년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 용산구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598106'},
#  {'기업명': '리디안솔루션(주)',
#   '직무': 'SAP (Cloud Platform/ CPI / ABAP) 관련 신입, 경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598068'},
#  {'기업명': '(주)트랜스코스모스코리아',
#   '직무': '[월250만/영어우대] MS 클라우드(Azure) 기술지원 엔지니어 Mp3Q',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['사무보조·문서작성', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38470423'},
#  {'기업명': '캐시워크',
#   '직무': '캐시워크와 함께 걸어갈 Node.js 서버 개발자님을 찾습니다',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38597023'},
#  {'기업명': '주식회사 블루에이치알',
#   '직무': '[자회사 정규직] 강남구청역 LGU+ 모바일센터 인바운드 상담',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38446566'},
#  {'기업명': '(주)시지온',
#   '직무': '어트랙트 서비스 자바 백엔드 개발자 모집',
#   '경력사항': '5 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594036'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 네트워크 운영 및 정보보호 담당 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'IT·디자인·컴퓨터교육']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38333581'},
#  {'기업명': '(주)아미크',
#   '직무': '[벤처/강소기업] Cloud Product(AWS) 기획 및 개발 채용',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38593601'},
#  {'기업명': '(주)디모아',
#   '직무': '[쌍방울그룹 계열사] 소프트웨어 영업직 경력/신입 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['IT·솔루션영업', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551426'},
#  {'기업명': '(주)직스엔닥스',
#   '직무': '[개발팀](웹/앱)우수한 React 프론트엔드 개발자 채용 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592735'},
#  {'기업명': '베스핀글로벌(주)',
#   '직무': 'Software QA 채용(경력 3년이상)',
#   '경력사항': '3 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592386'},
#  {'기업명': '주식회사 위주',
#   '직무': '[주식회사위주]놀러와요시장 어플 서버개발 경력직채용(7년이상)',
#   '경력사항': '경력 7년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38466824'},
#  {'기업명': '(주)크로센트',
#   '직무': '클라우드 엔지니어 및 아키텍트 (신입/경력) 정규직 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591760'},
#  {'기업명': '포디리플레이코리아(주)',
#   '직무': '[4DReplay] 클라우드 서비스 및 Platform Back End 개발자 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558326'},
#  {'기업명': '컴즈(주)',
#   '직무': 'S/W QA & Test Engineer 채용의 件',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 구로구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38588604'},
#  {'기업명': '(주)이젠아카데미인재개발원',
#   '직무': '[취업연수 국비교육]자바/파이썬/빅데이터/웹/영상/건축',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['캐릭터·만화·애니', '광고·시각디자인']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=36825236'},
#  {'기업명': '굿어스㈜',
#   '직무': 'Cisco SD-WAN 엔지니어 (경력 2년 이상)',
#   '경력사항': '2 ~ 7년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587238'},
#  {'기업명': '(주)더블다운인터액티브',
#   '직무': '웹/게임서버 개발자(경력), 클라이언트 개발자(신입/경력) 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '게임·Game']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580038'},
#  {'기업명': '(주)민병철교육그룹',
#   '직무': '[민병철유폰] AWS 시스템 엔지니어 (총 경력 5년 이상)',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586234'},
#  {'기업명': '스마일샤크',
#   '직무': '[신입] AWS 솔루션 아키텍트(SA)를 스마일샤크팀으로 모십니다.',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586155'},
#  {'기업명': '(주)에이프릴세븐',
#   '직무': '[스타트업] 서버개발자 채용 공고',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38585353'},
#  {'기업명': '(주)아모레퍼시픽',
#   '직무': "[경력] '20년 AMOREPACIFIC 경력채용_플랫폼 Back-end 개발",
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569683'},
#  {'기업명': '(주)피타소프트',
#   '직무': '2020년 하반기 각 부문 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38542206'},
#  {'기업명': '(주)이노그리드',
#   '직무': '2020 하반기 클라우드 전문기업 이노그리드 신입·경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['상품기획·MD', '홍보·PR·사보']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38415519'},
#  {'기업명': '(주)앨리스헬스케어',
#   '직무': '(경력) 백엔드(Back-end) 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582494'},
#  {'기업명': '호스트웨이아이디씨(주)',
#   '직무': '[정규직] 시스템 엔지니어 모집(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', 'IT·디자인·컴퓨터교육']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582146'},
#  {'기업명': '(주)아모레퍼시픽',
#   '직무': "[경력] '20년 AMOREPACIFIC 경력채용_통합 OMS 기술PM",
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570465'},
#  {'기업명': '(주)하나금융티아이',
#   '직무': '[하나금융TI] 금융IT 경력사원 모집',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '인천전체',
#   '분류': "['기획·전략·경영', '인사·교육·노무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38572965'},
#  {'기업명': '(주)아모레퍼시픽',
#   '직무': "[경력] '20년 AMOREPACIFIC 경력채용_플랫폼 기술 PM",
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570239'},
#  {'기업명': '(주)아톤',
#   '직무': '[ATON] 신규 서비스 개발팀장 / 서버개발 경력 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38553981'},
#  {'기업명': '주식회사 포티투마루',
#   '직무': '[포티투마루] 인공지능 프론트엔드 개발 채용(경력)',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 관악구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580784'},
#  {'기업명': '카이스컴퍼니',
#   '직무': 'React js, AWS, IoT外 1개 부문 개발자 채용 - 정규직&계약직',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '충북 청주시 서원구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580459'},
#  {'기업명': '(주)딤커뮤니케이션',
#   '직무': '[딤커뮤니케이션] 2020년 하반기 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['홍보·PR·사보', '회계·재무·세무·IR']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38464294'},
#  {'기업명': '주식회사 오파테크',
#   '직무': '서버개발 정규직 모집 공고(경력)',
#   '경력사항': '3 ~ 6년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38483345'},
#  {'기업명': '(주)웰데이타시스템',
#   '직무': 'H자동차그룹 Car Cloud(오픈스택+쿠버네티스) 서비스 운영',
#   '경력사항': '3 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579660'},
#  {'기업명': '원투씨엠(주)',
#   '직무': '2020년 하반기 개발자 채용',
#   '경력사항': '5 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533730'},
#  {'기업명': '(주)웰데이타시스템',
#   '직무': '[엔클라우드24] [클라우드&IDC 기술영업/컨설팅/ 공공영업] 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['IT·솔루션영업', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579626'},
#  {'기업명': '(주)웰데이타시스템',
#   '직무': '프런트앤드 앱/웹 자바(JAVA) PHP, 클라우드 서비스 개발자 모집',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579619'},
#  {'기업명': '(주)피처링',
#   '직무': '(정규직) 서버 및 웹 Backend 웹개발자를 채용합니다.',
#   '경력사항': '2 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 연수구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563022'},
#  {'기업명': '소상공인연합회',
#   '직무': '2020년 위탁사업담당 (경력/신입) 직원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '서울 동작구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576477'},
#  {'기업명': '(주)두잇시스템',
#   '직무': 'Linux서버 운영 (서울 강서구, 경력 3년이상)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576103'},
#  {'기업명': '(주)트위그팜',
#   '직무': '웹 개발 (php, laravel 스페셜리스트) 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38549173'},
#  {'기업명': '(주)그로브소프트',
#   '직무': '㈜그로브소프트 2020 하반기 경력직 추가 채용(기획, 개발, 퍼블리셔)',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38566074'},
#  {'기업명': '(주)케어랩스',
#   '직무': '병원갈땐 굿닥) Java 백엔드 서버 개발자 채용',
#   '경력사항': '3 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575281'},
#  {'기업명': '(주)케어랩스',
#   '직무': '병원갈땐 굿닥) PHP서버 개발자 대규모 채용',
#   '경력사항': '5 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575280'},
#  {'기업명': '디딤365 주식회사',
#   '직무': '멀티 클라우드 포털 개발 신입/경력사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575121'},
#  {'기업명': '디딤365 주식회사',
#   '직무': '클라우드 및 시스템 엔지니어 신입/경력(청년내일채움공제 가능)',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575060'},
#  {'기업명': '(주)에스비에스아이앤엠',
#   '직무': 'SBS I&M 인프라 기획 및 AWS 클라우드 시스템 운영관리자 모집',
#   '경력사항': '5 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562661'},
#  {'기업명': '(주)카카오페이',
#   '직무': '[카카오페이] 빅데이터, 하둡(Hadoop)플랫폼 운영 엔지니어 영입',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574921'},
#  {'기업명': '라인게임즈 주식회사',
#   '직무': '[라인게임즈] 기술PM 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574275'},
#  {'기업명': '네오위즈',
#   '직무': '[네오위즈] 각 부문 신입 / 경력자모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['회계·재무·세무·IR', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38447372'},
#  {'기업명': '주식회사오션라이트에이아이',
#   '직무': '서버·네트워크·보안(서버관리&AWS外 3개 부문) 채용합니다',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '대구 북구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38571517'},
#  {'기업명': '스마일샤크',
#   '직무': '[경력] AWS 솔루션 아키텍트(SA)를 스마일샤크팀으로 모십니다.',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38550815'},
#  {'기업명': '(주)웨어포인트',
#   '직무': '(잠실/운영)시스템 엔지니어(SE/TA) 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직 · 프리랜서',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570404'},
#  {'기업명': '(주)디타임',
#   '직무': '(주)디타임 서버개발자 경력직 채용',
#   '경력사항': '6 ~ 20년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565481'},
#  {'기업명': '(주)립페이',
#   '직무': '[정규직] IoT 플랫폼(백엔드) 개발자 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '통신·모바일']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560508'},
#  {'기업명': '(주)엔픽셀',
#   '직무': '[인프라팀] 클라우드 엔지니어 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38413525'},
#  {'기업명': '(주)에스오월드테크놀리지',
#   '직무': '서버관리자(AWS) 채용',
#   '경력사항': '2 ~ 5년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '인턴직',
#   '근무지': '서울 영등포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38568005'},
#  {'기업명': '(주)지에스아이엘',
#   '직무': '(주)지에스아아엘 - 시스템개발팀 경력직 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567524'},
#  {'기업명': '삼양데이타시스템㈜',
#   '직무': '그룹 Infra 분야 운영 인력 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38550753'},
#  {'기업명': '오픈플랜(주)',
#   '직무': '[오픈플랜] back-end Developer 우수 인재를 모십니다.',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38505378'},
#  {'기업명': '베스핀글로벌(주)',
#   '직무': 'BigData 전문인력 채용(경력 5년 이상)',
#   '경력사항': '5 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38566513'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 구글클라우드 부문 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['일반영업', 'IT·솔루션영업']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38409477'},
#  {'기업명': '(주)앨리스헬스케어',
#   '직무': '백엔드(Back-end) 개발자(경력)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565409'},
#  {'기업명': '(주)이카운트',
#   '직무': '㈜이카운트 시스템관리자(SA팀) 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565193'},
#  {'기업명': '쿠팡 주식회사',
#   '직무': '[쿠팡페이] System Engineer',
#   '경력사항': '경력 8년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38398255'},
#  {'기업명': '㈜지에스아이티엠',
#   '직무': 'SE/NE/DBA 경력사원 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38519641'},
#  {'기업명': '(주)크리에이트코리아',
#   '직무': '백엔드 개발자/ 웹 & 모바일 개발자 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중랑구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563318'},
#  {'기업명': '대한상공회의소 광주인력개발원',
#   '직무': '2020년도 국비 기술교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '광주 광산구',
#   '분류': "['기계·기계설비', '전기·전자·제어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38404367'},
#  {'기업명': '대한상공회의소 충남인력개발원',
#   '직무': '4차산업/전기전자/기계설계/자동화 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '충남전체',
#   '분류': "['전기·전자·제어', '설계·CAD·CAM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38445379'},
#  {'기업명': '오케스트로(주)',
#   '직무': '클라우드연구소 PaaS 엔지니어',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552496'},
#  {'기업명': '이투스교육(주)',
#   '직무': '이투스교육 IT기획직군 공개 채용',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551714'},
#  {'기업명': '(주)푸드테크',
#   '직무': 'IT부문 신입 및 경력사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526283'},
#  {'기업명': '매드업',
#   '직무': '[테크사업부] 백엔드 개발자 채용',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38553452'},
#  {'기업명': '(주) 딥노이드',
#   '직무': '인공지능, 의료영상 연구원 모집[경력, 병역특례 지원가능]',
#   '경력사항': '신입 · 경력',
#   '학력': '석사↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 구로구',
#   '분류': "['인공지능(AI)·빅데이터', '연구소·R&D']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38362204'},
#  {'기업명': '(주)씨알에스큐브',
#   '직무': 'AWS(DevOps) 엔지니어 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561608'},
#  {'기업명': '모나일렉트릭(주)',
#   '직무': '웹개발(Java·JSP/ASP) 채용 공고',
#   '경력사항': '3 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 광명시',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554785'},
#  {'기업명': '(주)판도라티비',
#   '직무': '[ 코박(COBAK) ]  Back-end 개발자 채용',
#   '경력사항': '1 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561269'},
#  {'기업명': '(주)키위플러스',
#   '직무': '서버 Backend 개발자 영입',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560578'},
#  {'기업명': '주식회사 메먼트',
#   '직무': '(연 3000만 이상) 시스템엔지니어 채용',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526643'},
#  {'기업명': '(주)웨어포인트',
#   '직무': '[잠실/운영] DBA 업무 담당자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38559704'},
#  {'기업명': '(주)온빛',
#   '직무': '병원 플랫폼 앱 개발자 모집 (안드로이드/iOS/백엔드)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대구 북구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38534946'},
#  {'기업명': '아카라코리아',
#   '직무': 'AWS 플랫폼기반 서비스운영 정규직 모집(경력사원)',
#   '경력사항': '경력 10년↓',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38559238'},
#  {'기업명': '주식회사 미로',
#   '직무': '(주)미로 IoT & 스마트홈 개발자채용 (신입/경력/전문연구요원)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '인천 연수구',
#   '분류': "['전기·전자·제어', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38559164'},
#  {'기업명': '충북대학교',
#   '직무': '[국비무료]취업연계 채용예정자 양성 과정 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '충북 청주시',
#   '분류': "['상품기획·MD', '기획·전략·경영']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38460768'},
#  {'기업명': '(주)바디프랜드',
#   '직무': '(주)바디프랜드 AI/서버/퍼블리셔/아이폰/프론트/기획 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554220'},
#  {'기업명': '(주)소프트웨어인라이프',
#   '직무': '[Docswave] 2020년 하반기 프리세일즈 채용 (경력)',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '하드웨어·소프트웨어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38477097'},
#  {'기업명': '이원다이애그노믹스(주)',
#   '직무': 'EDGC : 글로벌R&D본부 IT팀 인재 채용 件',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38489038'},
#  {'기업명': '(주)인터웹',
#   '직무': '4차산업혁명 기반의 신사업 참여 개발자 모집',
#   '경력사항': '경력 6년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38553142'},
#  {'기업명': '케이웨어(주)',
#   '직무': '[R&D] 연구과제 기획/관리',
#   '경력사항': '신입 · 경력',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551504'},
#  {'기업명': '이투스교육(주)',
#   '직무': '이투스교육 8월 개발자 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38545141'},
#  {'기업명': '(주)아이아이컴바인드',
#   '직무': '젠틀몬스터 백엔드&PHP 정규직 채용(경력/신입)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38412821'},
#  {'기업명': '주식회사 메디칼파크',
#   '직무': '응용소프트웨어 프로그래머 연구원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 용인시 수지구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38353503'},
#  {'기업명': '아토리서치(주)',
#   '직무': '[아토리서치]전문연구요원(병역특례) 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38545903'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 개발 경력자 대규모 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37872627'},
#  {'기업명': '오케스트로(주)',
#   '직무': '(경력) 인공지능 연구소 플랫폼 개발팀 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38532722'},
#  {'기업명': '㈜안랩',
#   '직무': '[안랩] DevOps 엔지니어 모집',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38538973'},
#  {'기업명': '타이트(주)',
#   '직무': '타이트(주) 제품개발팀 백엔드 / 웹 개발자 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대구 남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533831'},
#  {'기업명': '클라우드그램(주)',
#   '직무': '[클라우드그램] 경영지원',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['사무보조·문서작성', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38364180'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존클라우드] Mass Migration Center 부문별 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['IT·솔루션영업', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38348572'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] DMP(데이터 관리 플랫폼) 개발',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38405474'},
#  {'기업명': '(주)아이뱅크',
#   '직무': '클라우드/DataAnalysis/로그분석外 정규직 채용 - 경력사원',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38380134'},
#  {'기업명': '(주)아이담',
#   '직무': '개발본부 백엔드 개발자(Node.js) 경력직 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533890'},
#  {'기업명': '(주)두댓',
#   '직무': '반려동물 서버 프로그래머 경력직 채용',
#   '경력사항': '경력 10년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38532714'},
#  {'기업명': '㈜날리지큐브',
#   '직무': '날리지큐브 2020년 클라우드 신입/경력 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38527975'},
#  {'기업명': '(주)소셜라디오컴퍼니',
#   '직무': '[글로벌 라이브·레코드 오디오기반 소셜앱] Backend개발자모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38506920'},
#  {'기업명': '주식회사 해줌',
#   '직무': '고객관리 시스템 백엔드 개발자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38394524'},
#  {'기업명': '에스피테크놀러지',
#   '직무': '에스피테크놀러지(주) AR/VR 개발자 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 관악구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38524760'},
#  {'기업명': '에스피테크놀러지',
#   '직무': '에스피테크놀러지(주) 프론트엔드&백엔드 개발',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 관악구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38524705'},
#  {'기업명': '에스피테크놀러지',
#   '직무': '에스피테크놀러지(주) Java 개발자 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 관악구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38523836'},
#  {'기업명': '디딤365 주식회사',
#   '직무': 'AWS 클라우드 기술영업 신입사원 모집',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['IT·솔루션영업', '기술영업']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38523449'},
#  {'기업명': '(주)모비젠',
#   '직무': '(주)모비젠 부문별 개발자 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38523366'},
#  {'기업명': '모티프컨설팅',
#   '직무': '대기업 AWS 엔지니어 (클라우드 아키텍트/클라우드데이터엔지니',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38522797'},
#  {'기업명': '(주)락플레이스',
#   '직무': 'Azure 엔지니어 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38520918'},
#  {'기업명': '굿어스데이터(주)',
#   '직무': 'Cloud 엔지니어 경력 3년 이상',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38520348'},
#  {'기업명': '조이시티',
#   '직무': '[JOYCITY] 플랫폼 서버 개발자 모집 (경력무관)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38519268'},
#  {'기업명': '(주)필로시스생명과학',
#   '직무': '[정규직] 서버개발자 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38516156'},
#  {'기업명': '(주)스쿱미디어',
#   '직무': 'AWS엔지니어 채용 경력 모집(정규직)',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38511682'},
#  {'기업명': '(주)오케이산업',
#   '직무': 'AWS/PHP 정규직 채용 - 경력',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 부천시',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38511008'},
#  {'기업명': '(주)뉴트리션코트',
#   '직무': '백엔드개발 경력직 채용',
#   '경력사항': '1 ~ 8년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38355299'},
#  {'기업명': '(주)아르카에이치알',
#   '직무': '[WinnersK] 서비스 플랫폼 연구소 중급개발자 모집',
#   '경력사항': '3 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38508488'},
#  {'기업명': '(주)위메프',
#   '직무': '[보안]클라우드 보안운영 담당자(정규직)',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37608770'},
#  {'기업명': '(주)위메프',
#   '직무': '[개발]위메프 시스템엔지니어(정규직)',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38502145'},
#  {'기업명': '(주)위메프',
#   '직무': '[개발]위메프오 DevOps Engineer(정규직)',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38502034'},
#  {'기업명': '(주)코레이즈',
#   '직무': '[신입/경력] 클라우드팀 채용 (SaaS · S/W)',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직 · 인턴직',
#   '근무지': '서울 성동구',
#   '분류': "['IT·솔루션영업', '하드웨어·소프트웨어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38500624'},
#  {'기업명': '(주)원더피플',
#   '직무': '글로벌 플랫폼 서버 개발자 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '게임·Game']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38497413'},
#  {'기업명': '(주)데브툴즈',
#   '직무': 'Back end 개발자 정규직 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38485192'},
#  {'기업명': '아토리서치(주)',
#   '직무': '인공지능/머신러닝 개발 및 클라우드/네트워크 개발',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38494339'},
#  {'기업명': '컴즈(주)',
#   '직무': 'S/W Test & QA Engineer 채용의 件',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 프리랜서',
# ...
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38568746'},
#  {'기업명': '에이치알코어스',
#   '직무': '클라우드 기획(대기업 / 계약직)',
#   '경력사항': '경력 7년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38568667'},
#  {'기업명': '(주)스카우트',
#   '직무': '[국내 유명 스타트업] Backend Developer (Java)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567876'},
#  {'기업명': '오픈포지션',
#   '직무': 'IT 개발자 (Mobile App-Android)/대리과장급/ 환경가전 대기업',
#   '경력사항': '5 ~ 13년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565511'},
#  {'기업명': '오픈포지션',
#   '직무': 'IT 개발자 (Front-end) / 대리과장급/ 환경 가전 대기업',
#   '경력사항': '5 ~ 13년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565505'},
#  {'기업명': '오픈포지션',
#   '직무': 'IT 개발자 (서버) / 과차장급/ 환경 가전 대기업',
#   '경력사항': '10 ~ 17년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565503'},
#  {'기업명': '(주)티아이에스정보시스템',
#   '직무': '[국비무료 취업교육]자바 응용SW&웹개발 및 AI(인공지능) 개발자 양성 취업 연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['그래픽디자인·CG', '전기·전자·제어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38378514'},
#  {'기업명': '(주)티아이에스정보시스템',
#   '직무': '[국비지원 재직자교육]프론트엔드/자바스크립트/Vue/React/CCNA/빅데이터/파이썬 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['그래픽디자인·CG', '전기·전자·제어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38378560'},
#  {'기업명': '엔터웨이파트너스',
#   '직무': 'ORACLE DBA-국내 유명 대기업 IT 개발사',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560187'},
#  {'기업명': '(주)브레인센터',
#   '직무': '대기업 클라우드 기획자 (계약직 : 과장~차장급)',
#   '경력사항': '6 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 중구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38556612'},
#  {'기업명': '로버트월터스코리아(주)',
#   '직무': '[글로벌/IT/개발자] Full Stack Developer',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38553380'},
#  {'기업명': '프로페셔날핸즈인핸즈코리아(주)',
#   '직무': 'IT Shared Service Manager[부장급]',
#   '경력사항': '경력 15년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 고양시 덕양구',
#   '분류': "['바이오·제약·식품', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38553189'},
#  {'기업명': '햄파트너스',
#   '직무': '애플리케이션 엔지니어(Fullstack Web, Devops등) 모집 공고',
#   '경력사항': '5 ~ 8년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552931'},
#  {'기업명': '(주)HR컨설팅그룹',
#   '직무': '(코스닥상장사) 클라우드엔지니어',
#   '경력사항': '5 ~ 14년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38549197'},
#  {'기업명': '주식회사 코어포인트',
#   '직무': '클라우드 컨설팅/ DevOps, Open API 전문인력 채용(차장,과장급)',
#   '경력사항': '7 ~ 14년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38548744'},
#  {'기업명': '베스트네트워크㈜',
#   '직무': '16. [수입자동차] IT 인프라 구축 전문가 정규직 채용',
#   '경력사항': '2 ~ 8년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38548577'},
#  {'기업명': '코리아써치',
#   '직무': 'Sr Technical Account Manager  Architect  미국 IT회사--Cloud',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38538868'},
#  {'기업명': '에이피써치',
#   '직무': '[외국계 대기업] IT부서 Shared Service Manager / 부장급',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38543724'},
#  {'기업명': '(주)HR컨설팅그룹',
#   '직무': '[대기업계열 종합상사] 클라우드 기획자, 과장 에서 차장급 채용',
#   '경력사항': '6 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38537619'},
#  {'기업명': '닥터파인드',
#   '직무': '리눅스 윈도우 서버관리 유지보수 경력 긴급',
#   '경력사항': '3 ~ 7년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539864'},
#  {'기업명': '(주)브이비젼',
#   '직무': '[의사커뮤니티 서비스기업] CTO 채용',
#   '경력사항': '경력 10년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38538381'},
#  {'기업명': '(주)헬로서치',
#   '직무': '대형게임그룹 계열사 플랫폼 시스템 엔지니어 모집',
#   '경력사항': '2 ~ 16년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38537282'},
#  {'기업명': '제이앤피에이치알컨설팅',
#   '직무': '[유명 금융그룹사] 클라우드 사업기획 PM',
#   '경력사항': '10 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38531680'},
#  {'기업명': '제이앤피에이치알컨설팅',
#   '직무': '[유명 인터넷 금융사] 클라우드 플랫폼 개발자 (과장급)',
#   '경력사항': '7 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38531473'},
#  {'기업명': '(주)맨파워코리아',
#   '직무': 'Machine Learning & AI  (대리-과장급, 경력 5년 이상)',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533405'},
#  {'기업명': '(주)에이치앤티어세스',
#   '직무': '화장품 회사 인프라 엔지니어',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '컨텐츠·사이트운영']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38532455'},
#  {'기업명': '㈜ 에프앤이그재큐티브',
#   '직무': '[글로벌컨설팅펌] Cloud 컨설턴트 (과장급이상)',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['인공지능(AI)·빅데이터', '경영분석·컨설턴트']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38529738'},
#  {'기업명': '㈜ 에프앤이그재큐티브',
#   '직무': '[글로벌컨설팅펌] Digital Transformation 컨설턴트(과장급이상)',
#   '경력사항': '경력 7년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['인공지능(AI)·빅데이터', '경영분석·컨설턴트']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38529724'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[분당] Javascript활용 자동화 개발 및 유지보수 지원-신입가능',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575996'},
#  {'기업명': '(주)맨파워코리아',
#   '직무': '[외국계 SCM 기업] DevOps Engineer (Big data) (Hong)',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['ERP·시스템분석·설계', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38568345'},
#  {'기업명': '(주)탑앤스카우트',
#   '직무': '[AI, IoT] 공공프로젝트 PM 충원',
#   '경력사항': '경력 8년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601402'},
#  {'기업명': '(주)헬로서치',
#   '직무': '(대기업) 인프라보안 담당자 채용',
#   '경력사항': '8 ~ 14년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574445'},
#  {'기업명': '(주)연세교육아카데미ㅣ연세직업전문학교',
#   '직무': '[연세직업전문학교]  정보보안(모의해킹) 강사 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '전임 · 계약직',
#   '근무지': '경기 수원시 장안구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38597574'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '(가전 및 생활용품 기업) 모바일 앱(안드로이드) 개발자',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38546840'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[모바일 애드테크 전문기업] 백엔드 엔지니어(대리-과장)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38564002'},
#  {'기업명': '피플워크(주)',
#   '직무': '[ IT대기업]데이터 모델링 - 4-15년',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38548699'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592716'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Digital Healthcare 빅데이터 플랫폼 전문가',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592696'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Battery 생산지원시스템(QMS/SCM/EMS) 구축 및 Global 확산/운영',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 동구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592694'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 java',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592671'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자 SAP',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592662'},
#  {'기업명': '(주)브이비젼',
#   '직무': '[글로벌벤처그룹] front-end 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38588743'},
#  {'기업명': '피플워크(주)',
#   '직무': 'AI(인공지능) 딥러닝기반 영상인식 처리 알고리즘 개발',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '통신·모바일']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38584287'},
#  {'기업명': '굿커리어',
#   '직무': '중견기업 머신비젼장비 SW개발 팀원,팀장급 구함(굿커리어)',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576789'},
#  {'기업명': '(주)피플케어코리아',
#   '직무': 'Partner Sales Enablement Manager (SW/Solution)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['IT·솔루션영업', '영업기획·관리·지원']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583253'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '[삼성물산/잠실역] 모바일 앱 및 웹 운영 경력 개발자 채용',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570689'},
#  {'기업명': '에이피써치',
#   '직무': '세일즈포스(Salesforce) 개발자 (대리-과장급) / 패션 상장기업',
#   '경력사항': '3 ~ 8년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578164'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자 시스템통합 IT 아웃소싱',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575270'},
#  {'기업명': '(주)맨파워코리아',
#   '직무': '[ERP/SCM 솔루션기업] Big data DevOps Engineer',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['ERP·시스템분석·설계', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562591'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569023'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 Java, Oracle',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569021'},
#  {'기업명': '(주)헬로서치',
#   '직무': '[대기업 IT사] 빅데이터 엔지니어 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38568281'},
#  {'기업명': '(주)케이맨파워',
#   '직무': '[최고대우] 머신러닝 모델 개발 (Tensorflow)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567598'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[국내대기업 IT계열사] 로봇분야 전문가',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['하드웨어·소프트웨어', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38557834'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Digital Healthcare 빅데이터 플랫폼 전문가 유전체 분석',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38555950'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Digital Healthcare 플랫폼 서비스 기획원 신약개발 상장사',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38555860'},
#  {'기업명': '(주)스카우트',
#   '직무': '대기업 IT 서비스 기획운영 디지털라이징 5Y+',
#   '경력사항': '7 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38547071'},
#  {'기업명': '구루넷',
#   '직무': '웹 개발자 모집',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539245'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '[삼성물산/잠실] 모바일 앱 및 웹 운영 경력 개발자 채용',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38508132'}]

# %%
company_list_python = []
page_num = 1
main_url = 'http://www.saramin.co.kr'

while True:
    url = f'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page={page_num}&cat_key=41711%2C40721%2C40426&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=1#searchTitle'
    req_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    }
    html = requests.get(url, req_header).text
    soup = BeautifulSoup(html, 'html.parser')
    if soup.select('div.list_body div.list_item') == []:
        break
    for tag in soup.select('div.list_body div.list_item'):
        company_dict = {}
        company_dict["기업명"] = tag.select('div.company_nm a span')[0].text
        company_dict["직무"] = tag.select('div.notification_info a span')[0].text
        company_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
        company_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
        try:
            company_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
        except:
            company_dict["근무형태"] = ""
        company_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
        category_list = []
        for item in tag.select('div.notification_info div.job_meta span span'):
            category_list.append(item.text)
        company_dict["분류"] = str(category_list)
        
        detail_url = tag.select_one('div.notification_info a').attrs['href']
        full_detail_url = urljoin(main_url, detail_url)
        company_dict["상세링크"] = full_detail_url
        company_list_python.append(company_dict)
    page_num += 1
company_list_python
# Out:
# [{'기업명': '(주)페이타랩',
#   '직무': '현대인의 필수인 패스오더 개발자를 모십니다.[5개 직군]',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 부산진구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38365421'},
#  {'기업명': '펜타시큐리티시스템(주)',
#   '직무': '[펜타시큐리티] 보안S/W 개발자 모집 (DB, 인증, 클라우드)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595144&adsCategoryItem=effect_bold&'},
#  {'기업명': '국제컴퓨터아카데미',
#   '직무': '[100%무료 취업준비생모집]웹디/건축/게임/프로그래밍/3D프린터',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울 관악구',
#   '분류': "['그래픽디자인·CG', '제품·산업디자인']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=34393991'},
#  {'기업명': '스윙로드',
#   '직무': '스윙로드 (백엔드 부문) 정규직 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38423092'},
#  {'기업명': '더조은컴퓨터아트학원',
#   '직무': '[100%무료 취업준비생모집]웹디/건축/게임/프로그래밍/3D프린터',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['그래픽디자인·CG', '제품·산업디자인']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=34529977&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)쎄미시스코',
#   '직무': '㈜쎄미시스코 소프트웨어 개발자 경력직 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시',
#   '분류': "['반도체·디스플레이·LCD', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38597487&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)와이비시스템',
#   '직무': '개발자 담당 경력 정규직 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579699&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)트랜스코스모스코리아',
#   '직무': '당사 프로젝트 개발 및 유지보수 담당자(신입/경력)Mj5E',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38512364'},
#  {'기업명': '행복쇼핑(주)',
#   '직무': 'PHP/REACT/PYTHON/퍼블리셔 경력자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38550645&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)세원아토스',
#   '직무': 'ERP 신입, 경력 개발자를 모십니다.',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38602619'},
#  {'기업명': '(주)시지온',
#   '직무': '라이브리 서비스 광고 플랫폼 개발자 모집',
#   '경력사항': '3 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38593999'},
#  {'기업명': '에스케이플래닛(주)',
#   '직무': '각 부문 경력사원 채용',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시',
#   '분류': "['기획·전략·경영', '광고영업']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38083118&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)헥사콘',
#   '직무': '데이터분석/AI용 이미지 및 영상처리 각 부문 채용',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528160&adsCategoryItem=effect_bold&'},
#  {'기업명': '켈리서비스 유한회사',
#   '직무': '[글로벌 포털 G사 ] Technical Solutions Consultant',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 강남구',
#   '분류': "['AS·서비스·수리', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569889'},
#  {'기업명': '사단법인 한국산업기술협회',
#   '직무': '산업계주도 청년 맞춤형 취업지원 아카데미 연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울 금천구',
#   '분류': "['금속·금형', '설계·CAD·CAM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38425715'},
#  {'기업명': '(주)데브구루',
#   '직무': '[신입/경력] 실력있는 개발자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38602229'},
#  {'기업명': '(주)상록아이엔씨',
#   '직무': '[경험자 우대] Python/Linux AI 시스템 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 부천시',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601843&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)유노믹',
#   '직무': '[부산] ㈜유노믹 신입 및 경력 채용 (기술영업/마케팅, SW개발자)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '부산 동구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579931&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)아이스크림에듀',
#   '직무': '㈜아이스크림에듀 콘텐츠,개발,마케팅,영업,관리 직군 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['상품기획·MD', '마케팅·광고·분석']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569553&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)옷딜',
#   '직무': 'Ai솔루션 옷딜 각부분 경력모집',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['기획·전략·경영', '출판·편집디자인']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580264&adsCategoryItem=effect_bold&'},
#  {'기업명': '디아이티(주)',
#   '직무': '2020 DIT 하반기 공개 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시 영통구',
#   '분류': "['기계·기계설비', '전기·전자·제어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38577337&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)슈프리마',
#   '직무': '[슈프리마] UX 기획 및 개발',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시',
#   '분류': "['웹마스터·QA·테스터', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38451606&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)제머나이소프트',
#   '직무': '웹 개발(프론트엔드/백엔드) 경력사원 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533221&adsCategoryItem=effect_bold&'},
#  {'기업명': '네모커머스(주)',
#   '직무': '2020 하반기 네모커머스 신입·경력 채용(웹개발,서비스가이드,서비스기획)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['기획·전략·경영', 'IT·솔루션영업']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560537&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)유비온',
#   '직무': '[유비온] 미래교육사업부(웹 어플리케이션 개발자 채용)',
#   '경력사항': '5 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576322&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)어니언스',
#   '직무': '파프리카케어 부분별 채용(UI디자이너, 백엔드/프론트엔드 개발)',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['그래픽디자인·CG', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578724&adsCategoryItem=effect_bold&'},
#  {'기업명': '에이치투오시스템테크놀로지(주)',
#   '직무': 'IT개발 담당자 신입, 경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['사무보조·문서작성', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578092&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)NE능률',
#   '직무': '2020년 ㈜NE능률 신입 공채 및 경력 수시 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['일반영업', '영업기획·관리·지원']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579763&adsCategoryItem=effect_bold&'},
#  {'기업명': '대화제약(주)',
#   '직무': '신입/경력 채용공고(전산(IT), 의원영업, 종합병원영업, 개발학술, 연구개발)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '서울 서초구',
#   '분류': "['총무·법무·사무', '사무보조·문서작성']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570702&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)아이스크림에듀',
#   '직무': '㈜아이스크림에듀 AI연구실, 마케팅실 팀장 채용',
#   '경력사항': '경력 12년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['마케팅·광고·분석', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570291&adsCategoryItem=effect_bold&'},
#  {'기업명': '글로벌인',
#   '직무': '[국비취업연수] 일본 현지 호텔 프론트, IT 개발자 정규직 일자리확보형 취업 국비 연수 과정',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '교육생 · 해외취업',
#   '근무지': '아시아·중동 일본',
#   '분류': "['호텔·카지노·콘도', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579651&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)후이즈',
#   '직무': '㈜후이즈 쇼핑몰 각 부문별 신입/경력 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563638&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)아이하트',
#   '직무': '㈜아이하트 신입/경력사원 모집[청년내일채움공제가능]',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38568215&adsCategoryItem=effect_bold&'},
#  {'기업명': '(사)스마트미디어인재개발원',
#   '직무': '빅데이터·인공지능·IoT 무료 취업교육 모집!',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '광주 남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38024536&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)아이엔지스토리',
#   '직무': '[아이엔지스토리]웹기획자 / 영업 / 설계디자인 담당자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['전시·공간디자인', '일반영업']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567115&adsCategoryItem=effect_bold&'},
#  {'기업명': '한국직업전문학교',
#   '직무': '[국비무료/수당지급] 빅데이터/UI/UX 퍼블리싱/응용 S/W 개발자',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '서울 구로구',
#   '분류': "['그래픽디자인·CG', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38393122&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)큐픽스',
#   '직무': '[신입/경력/전문연구요원] AWS/Ruby 백엔드엔지니어(DevOps)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586042'},
#  {'기업명': '(주)큐픽스',
#   '직무': '[신입/경력/전문연구요원] 컴퓨터비전/딥러닝/SLAM 영상처리',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586016'},
#  {'기업명': '주식회사 엔디소프트',
#   '직무': '(주)NDSOFT 2020년 개발자 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 해운대구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38572298'},
#  {'기업명': '(재)충남정보문화산업진흥원',
#   '직무': '2020년 제 3차 계약직 직원채용 공고(연장공고)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '충남 천안시 동남구',
#   '분류': "['기획·전략·경영', '홍보·PR·사보']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539566&adsCategoryItem=effect_bold&'},
#  {'기업명': '뉴로핏 주식회사',
#   '직무': '소프트웨어 유틸리티 개발 및 유지보수 (경력 1년 이상)모집',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38602042'},
#  {'기업명': '켐아이넷(주)',
#   '직무': '청년디지털일자리사업 참여인력 모집 (인공지능, 통계, SW개발)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 양천구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592271'},
#  {'기업명': '(주)옷딜',
#   '직무': '[ Ai스타트업 ] 기획 ㆍ인공지능ㆍ백엔드 개발자 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551843'},
#  {'기업명': '(주)옷딜',
#   '직무': '[ Ai 스타트업 ] 딥러닝ㆍ 데이터엔지니어 경력개발자모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['ERP·시스템분석·설계', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551913'},
#  {'기업명': '(주)씨앤테크',
#   '직무': '[신입/경력무관] Web 개발 및 유지보수 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38602004'},
#  {'기업명': '(주)매드업',
#   '직무': '[매드업] 하반기 전 직군 대규모 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['인사·교육·노무', '마케팅·광고·분석']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596083&adsCategoryItem=effect_bold&'},
#  {'기업명': '㈜타이호인스트',
#   '직무': '기술연구소 경력개발자 채용',
#   '경력사항': '경력 6년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601886'},
#  {'기업명': '모닝인컨설팅',
#   '직무': '[건대역/웹어플개발] 경력3년/연봉협의(경력별)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 광진구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576669'},
#  {'기업명': '신한양직업전문학교',
#   '직무': '[국비지원] 하반기 취업대비 4차 산업 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '부산 부산진구',
#   '분류': "['물류·유통·운송', '기계·기계설비']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38541577&adsCategoryItem=effect_bold&'},
#  {'기업명': '무브(주)',
#   '직무': 'Python 경력직 정규직 개발자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38577743'},
#  {'기업명': '주식회사 와이즈인컴퍼니',
#   '직무': '빅데이터분석 및 개발자 모집(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590627'},
#  {'기업명': '(주)투윈스컴',
#   '직무': '[보안설비연구소] 신규 프로그래머 채용 (신입)',
#   '경력사항': '신입',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['웹마스터·QA·테스터', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601783'},
#  {'기업명': '(주)슈프리마',
#   '직무': '[슈프리마] 웹개발 채용',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37957886&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)이노와이어리스',
#   '직무': '이노와이어리스/큐셀네트웍스 각 분야 신입/경력 채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['생산관리·품질관리', '생산·제조·포장·조립']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590538&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)상록아이엔씨',
#   '직무': '[경험자 우대] Python/Linux AI 시스템 개발자 모집 합니다',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 부천시',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601610'},
#  {'기업명': '쿠팡(주)',
#   '직무': '경영지원 대규모 채용 (Finance,HR,Business Data Analyst)',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 송파구',
#   '분류': "['총무·법무·사무', '인사·교육·노무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589504'},
#  {'기업명': '(주)강림직업전문학교',
#   '직무': '빅데이터 전문가(자바&파이썬&R) 과정 훈련교사 모집.',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 평택시',
#   '분류': "['응용프로그램개발', 'IT·디자인·컴퓨터교육']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601520'},
#  {'기업명': '(주)프렌츠',
#   '직무': '웹 개발 및 기획 담당자 채용',
#   '경력사항': '1 ~ 4년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['웹마스터·QA·테스터', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590376&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)메디벨바이오',
#   '직무': '헬스케어 시스템 개발 (AI알고리즘, 구동S/W, APP.) 정규직 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580234&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)엔씨아이티에스',
#   '직무': '[NCSOFT자회사] 엔씨아이티에스 게임웹운영,  보안관제, 시스템 엔지니어 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586493&adsCategoryItem=effect_bold&'},
#  {'기업명': '스토리앤브라더스(주)',
#   '직무': '파이썬(장고) 백엔드 개발 경력자 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558591'},
#  {'기업명': '(주)엔티엘헬스케어',
#   '직무': '개발기획팀(소프트웨어 개발) 경력 직원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 수정구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601419'},
#  {'기업명': '(주)디케이비엠시',
#   '직무': 'CRM, BI, SI 컨설팅솔루션 관리/개발자 채용 공고',
#   '경력사항': '2 ~ 17년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['그래픽디자인·CG', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528106&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)유노믹',
#   '직무': '[서울] ㈜유노믹 신입 및 경력 채용(기술영업/마케팅, SW개발자)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['기획·전략·경영', '홍보·PR·사보']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567864&adsCategoryItem=effect_bold&'},
#  {'기업명': '패스트캠퍼스(주)',
#   '직무': '[패스트캠퍼스] 대규모 인재 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '마케팅·광고·분석']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38230007'},
#  {'기업명': '(주)모비노마',
#   '직무': '신사업 헬스케어 관련 서버/백엔드 개발자 채용(경력 )',
#   '경력사항': '4 ~ 8년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38540502'},
#  {'기업명': '(주)선진',
#   '직무': '[하림그룹] ㈜선진 신입/경력 수시채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['회계·재무·세무·IR', '마케팅·광고·분석']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580036'},
#  {'기업명': '한국정보기술단',
#   '직무': '[한국정보기술단] 빅데이터 분석 기술인력 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 과천시',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38508480'},
#  {'기업명': '(주)세차왕',
#   '직무': '세차왕에서 백엔드 및 웹앱 개발자를 모십니다.',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562173'},
#  {'기업명': '신한카드(주)',
#   '직무': '2020년 B2사원 수시채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['그래픽디자인·CG', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567189'},
#  {'기업명': '(주)알리아스',
#   '직무': '[ VR / AR ] 콘텐츠 코딩 엔지니어 신입/경력사원 모집(정규직)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경남 김해시',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38359878'},
#  {'기업명': '녹십자지놈',
#   '직무': '[GC녹십자지놈]  BI팀 팀원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '경기 용인시 기흥구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528636'},
#  {'기업명': '(주)크레스콤',
#   '직무': '소프트웨어 개발 (인공지능 AI 풀스택 서버 웹개발 의료영상)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38309368'},
#  {'기업명': '지스펙(주)',
#   '직무': '(전액무료)파이썬기반 빅데이터 플랫폼&분석 전문가 취업연계과정',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38525507&adsCategoryItem=effect_bold&'},
#  {'기업명': '트리니티엔지니어링(주)',
#   '직무': '트리니티엔지니어링 CAE(해석 및 개발), 프로그래밍 엔지니어 채용',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 양천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598627&adsCategoryItem=effect_bold&'},
#  {'기업명': '콴텍(주)',
#   '직무': '[콴텍, 금융] 함께 성장할 금융 데이터 분석 전문가 모십니다.',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['금융·보험영업', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38482773'},
#  {'기업명': '한국기술교육직업전문학교',
#   '직무': '[전액국비] 4차산업 IT전문인력 취업연계교육',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '부산 동래구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539306&adsCategoryItem=effect_bold&'},
#  {'기업명': '지엔소프트(주)',
#   '직무': '[경력] 데이터 검증 및 분석 개발자 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '대전 서구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38386450'},
#  {'기업명': '휴먼교육센터학원',
#   '직무': '[전액무료]자바/파이썬 IT교육받고 취업하자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38510654&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)지에스아이티엠',
#   '직무': '2020년 하반기 GS ITM 경력사원 공개채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587357'},
#  {'기업명': '(주)비바리퍼블리카',
#   '직무': '[토스/토스뱅크] Data Analyst 분을 모십니다.',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591688'},
#  {'기업명': '주식회사 성진에이치디에스',
#   '직무': "최고의 복지로 함께 성장할 '데이터 분석가' 를 찾습니다",
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['마케팅·광고·분석', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38600944'},
#  {'기업명': '(주)엔키아',
#   '직무': '2020년 엔키아 각 부문 공개채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['기획·전략·경영', '웹마스터·QA·테스터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38538595&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)케이몰글로벌',
#   '직무': 'Kmall 쇼핑몰 (PHP,Mysql,Java) 정규직 직원 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599888'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '[분당/외국계]글로벌 반도체 기업, Web Developer 채용',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '파견직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590576'},
#  {'기업명': '(주)트레이지',
#   '직무': '글로벌 여행스타트업 Trazy - 백엔드 개발자 (Python) 채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38600867'},
#  {'기업명': '(주)소프트케잌',
#   '직무': '웹개발자 (경력) - 웹프로그래머',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '부산 연제구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38529377'},
#  {'기업명': '휴도',
#   '직무': '[휴도] WEB / APP 신규 구축 풀스텍 개발자 채용 (NODE.JS / REACT-NATIVE)',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599290'},
#  {'기업명': '(유)딜리버리히어로 코리아',
#   '직무': '전 개발직군 대규모 채용중',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38476546'},
#  {'기업명': '현대오트론(주)',
#   '직무': '현대오트론 시스템반도체/전장SW 전문가 경력 상시채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['구매·자재·재고', '기획·전략·경영']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38544124'},
#  {'기업명': '(주)파이버프로',
#   '직무': '㈜파이버프로 SW개발 부문 신입/경력사원 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590763'},
#  {'기업명': '(주)안랩',
#   '직무': '2020 하반기 안랩 연구소 신입사원 공개채용',
#   '경력사항': '신입',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578654'},
#  {'기업명': '(주)씨제이이엔엠',
#   '직무': 'CJ ENM(E&M부문) TVING 경력사원 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38515830'},
#  {'기업명': '(주)휴넷',
#   '직무': '2020년 ㈜휴넷 웹 개발자 경력직 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594512'},
#  {'기업명': '주식회사 로원홀딩스',
#   '직무': '[로원홀딩스] MD/개발자/CS 경력사원 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['상품기획·MD', '고객센터·CS']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561891'},
#  {'기업명': '(주)헬스메디',
#   '직무': '2020년 각 부문별 신입/경력 채용(새로운 프로젝트 진행중)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['홍보·PR·사보', '사무보조·문서작성']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570966'},
#  {'기업명': '펍지(주)',
#   '직무': '펍지㈜ 각 부문별 수시 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['총무·법무·사무', '인사·교육·노무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38542347'},
#  {'기업명': '(주)이상투자그룹',
#   '직무': '㈜이상투자그룹 각 부문별 인재 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38544985'},
#  {'기업명': '(주)하나금융티아이',
#   '직무': '[하나금융융합기술원] 부문별 경력사원 모집',
#   '경력사항': '경력',
#   '학력': '석사↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565737'},
#  {'기업명': '㈜해커스교육그룹',
#   '직무': '2020년 해커스 교육그룹 [신입/경력] 각 부문별 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38369849'},
#  {'기업명': '한국직업능력교육원 안산',
#   '직무': '경기/시흥・안산/군포 국비무료 취업연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '경기 안산시 단원구',
#   '분류': "['회계·재무·세무·IR', '생산관리·품질관리']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38527236&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)LG유플러스',
#   '직무': 'IT개발/운영 신입&경력 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533503'},
#  {'기업명': '엔사이크(주)',
#   '직무': '파이썬 머신러닝 백엔드, 응용프로그램 개발자 모집',
#   '경력사항': '1 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38513699'},
#  {'기업명': '메디픽셀',
#   '직무': '[병특/일반] 의료 인공지능 전문연구요원 채용 (메디픽셀)',
#   '경력사항': '경력무관',
#   '학력': '석사↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 마포구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38481522'},
#  {'기업명': '스펙트럼',
#   '직무': 'VR/AR 콘텐츠 개발자 및 AI/딥러닝 개발자 모집(Unity, C#, C++)',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '게임·Game']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38572585'},
#  {'기업명': '네이버파이낸셜(주)',
#   '직무': '[네이버파이낸셜] FDS 데이터 분석 / 정책 담당자 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['기획·전략·경영', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38600150'},
#  {'기업명': '트래블라이(주)',
#   '직무': '[알루 서비스 개발팀]  서버 경력, 클라이언트 신입  및 경력 채',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599968'},
#  {'기업명': '몬드리안에이아이(주)',
#   '직무': 'AI / Big Data Platform Backend Developer',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '인천 연수구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38457823'},
#  {'기업명': '몬드리안에이아이(주)',
#   '직무': 'AI / Big Data Researcher',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '인천 연수구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38545832'},
#  {'기업명': '(주)유니콤넷',
#   '직무': '개발팀(기술연구소) 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['응용프로그램개발', '웹디자인']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599654'},
#  {'기업명': '주식회사 에이치이엠',
#   '직무': '광교지사 3분기 수시채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 수원시 영통구',
#   '분류': "['바이오·제약·식품', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599553'},
#  {'기업명': '(주)모비젠',
#   '직무': '2020년 하반기 (주)모비젠 부문별 경력 모집 공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599066'},
#  {'기업명': '굿모니터링(주)',
#   '직무': '웹.앱 프로그래밍 개발자 채용',
#   '경력사항': '1 ~ 3년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서대문구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569719'},
#  {'기업명': '(주)케이씨넷',
#   '직무': '데이터사업부 JAVA개발 경력직 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['기획·전략·경영', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560795'},
#  {'기업명': '테크빌교육(주)',
#   '직무': '[테크빌교육] 개발PM·프로그래머·기획·데이터분석 등 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38363291'},
#  {'기업명': '메이븐코리아(주)',
#   '직무': 'BI 데이터 시각화 개발자 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596953'},
#  {'기업명': '(주)하미글로벌',
#   '직무': '하반기 각 부문 신입 / 경력 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['상품기획·MD', '기획·전략·경영']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552878'},
#  {'기업명': '(주)쓰리웨이소프트',
#   '직무': '전력설비 DeepLearning 및 응용 개발자모심',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596507'},
#  {'기업명': '(주)큐빅테크',
#   '직무': '데이터가공,분석,인공지능(AI)·빅데이터外 경력직 채용',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['생산관리·품질관리', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590373'},
#  {'기업명': '(주)팀플백',
#   '직무': 'SW개발자 및 PM 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경남 창원시',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38479641'},
#  {'기업명': '주식회사 노벨알엔디',
#   '직무': '[삼성전자 화성] 시스템 개발/운영 경력 개발자 (java)',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 프리랜서',
#   '근무지': '경기 화성시',
#   '분류': "['그래픽디자인·CG', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38481159'},
#  {'기업명': '주식회사 블루에이치알',
#   '직무': '[자회사 정규직] 강남구청역 LGU+ 모바일센터 인바운드 상담',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38446566'},
#  {'기업명': '한국IT교육원',
#   '직무': '2020년 취업연계 교육훈련 양성과정',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '대구 동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595914'},
#  {'기업명': '(주)두플',
#   '직무': '제조 빅데이터 솔루션 개발자 모집 -C#, Java, Python',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38384415'},
#  {'기업명': '(주)케이씨피드',
#   '직무': '(주)케이씨피드 전산팀(웹 프로그램 개발 및 유지보수) 경력사원',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경북 영천시',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595525'},
#  {'기업명': '(주)스트라티오코리아',
#   '직무': '(주)스트라티오코리아 2020 하반기 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 서초구',
#   '분류': "['광고·시각디자인', '웹마스터·QA·테스터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38508258'},
#  {'기업명': '(주)애드픽네트워크',
#   '직무': '자바스크립트, c언어, 파이썬 웹개발자 채용공고',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595297'},
#  {'기업명': '(주)커넥트히어로',
#   '직무': '서버개발자, ios개발자, UX/UI 부문 담당자 모집',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595199'},
#  {'기업명': '(주)애드픽네트워크',
#   '직무': '프리랜서 단기프로젝트 웹개발자 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38572899'},
#  {'기업명': '분당서울대학교병원',
#   '직무': '분당서울대학교병원 연구사업단 행정연구원 채용공고',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592972'},
#  {'기업명': '효성컴퓨터학원',
#   '직무': '효성컴퓨터학원 C / JAVA 프로그래밍/정보보안/PC정비 강사 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '대전 서구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594843'},
#  {'기업명': '주식회사 인공지능연구원',
#   '직무': '자동화 소프트웨어 RPA 워크플로우 개발자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594653'},
#  {'기업명': '(주)쓰리웨이소프트',
#   '직무': '스마트 그리드 솔루션 개발자모심',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38447295'},
#  {'기업명': '한국에이치알엠',
#   '직무': '대표 커뮤니티사이트 백앤드 Back-end 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594546'},
#  {'기업명': '비젠트로(주)',
#   '직무': '(삼성SDS분사社) 비젠트로㈜ MES부문 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38566203'},
#  {'기업명': '워크픽(주)',
#   '직무': '(워라벨/복지깡패)웹개발(Python&백엔드&Java·JSP) 채용 공고',
#   '경력사항': '3 ~ 8년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594220'},
#  {'기업명': '(주)알체라',
#   '직무': '백엔드 개발자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594076'},
#  {'기업명': '(주)지비소프트',
#   '직무': '영상처리 및 프론트엔드 개발 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대구 수성구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586088'},
#  {'기업명': '(주)올엠',
#   '직무': '통계/데이터 분석(DA) 담당자를 모십니다.',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587922'},
#  {'기업명': '(주)아이엠비디엑스',
#   '직무': '2020 하반기 각 부문 직원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591579'},
#  {'기업명': '로크웰오토메이션코리아(주)',
#   '직무': 'Software Lead Engineer 채용',
#   '경력사항': '경력 7년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기계·기계설비', '전기·전자·제어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567097'},
#  {'기업명': '(주)티제이팜',
#   '직무': '각 부문별 신입/경력사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['상품기획·MD', '마케팅·광고·분석']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570373'},
#  {'기업명': '신플렛(주)',
#   '직무': '이미지 딥러닝 (파이썬) 개발자 추가모집',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 용인시 수지구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38593006'},
#  {'기업명': '(주)코인원트랜스퍼',
#   '직무': '크로스 서비스 Core system & Server 개발자 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592891'},
#  {'기업명': '(주)디비엔텍',
#   '직무': '인공지능(AI, 딥러닝, 컴퓨터 비전) 연구개발 연구원 신입채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 서구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592620'},
#  {'기업명': '베스핀글로벌(주)',
#   '직무': 'Software QA 채용(경력 3년이상)',
#   '경력사항': '3 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592386'},
#  {'기업명': '(주)아이콘루프',
#   '직무': '[ICONLOOP] 소프트웨어/블록체인/DID 개발자 채용 (FE/BE/SI)',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 중구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38357521'},
#  {'기업명': '(주)엘젠아이씨티',
#   '직무': 'AI 빅데이터 챗봇 전문가가 되고자 하는 개발자 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38495947'},
#  {'기업명': '소프트젠',
#   '직무': '웹 프로그램 개발자 (Node.js, Spring, Database, PHP) 모집',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 수정구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528609'},
#  {'기업명': '포디리플레이코리아(주)',
#   '직무': '[4DReplay] 클라우드 서비스 및 Platform Back End 개발자 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558326'},
#  {'기업명': '(주)록스',
#   '직무': '[신입] AI/머신러닝 연구원 채용',
#   '경력사항': '신입',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 금정구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591412'},
#  {'기업명': '알테어엔지니어링(주)',
#   '직무': '[Altair Korea]Data analytics expert(Pre-sales consultant)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38355791'},
#  {'기업명': '(주)골든플래닛',
#   '직무': '구글애널리틱스,시스템개발,클라우드 데이터엔지니어,데이터분석',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['마케팅·광고·분석', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526529'},
#  {'기업명': '(주)세원이디에스',
#   '직무': 'ERP개발자를 모십니다.',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590655'},
#  {'기업명': '베스핀글로벌(주)',
#   '직무': 'Public Cloud System Architect(SA) 채용(경력 3년이상)',
#   '경력사항': '3 ~ 20년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589952'},
#  {'기업명': '(주)에이직스',
#   '직무': '빅데이터 처리 및 AI 알고리즘 연구개발 (R&D)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38514028'},
#  {'기업명': '(주)인라이플',
#   '직무': '(업계1위/JAVA개발) 얘네 재밌는거 개발한데 가보자',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹마스터·QA·테스터', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587699'},
#  {'기업명': '(주)인라이플',
#   '직무': '가치있는 데이터를 같이 만들 JAVA개발자 채용 (백엔드 부문)',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹마스터·QA·테스터', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587682'},
#  {'기업명': '㈜이지메디컴',
#   '직무': 'IT 연구소 헬스케어 SCM 웹솔루션 개발자 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587603'},
#  {'기업명': '(주)이젠아카데미인재개발원',
#   '직무': '[취업연수 국비교육]자바/파이썬/빅데이터/웹/영상/건축',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['캐릭터·만화·애니', '광고·시각디자인']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=36825236'},
#  {'기업명': '전북대병원 의생명연구원',
#   '직무': '전북대학교병원 전북빅데이터센터 연구직[S/W개발자] 모집',
#   '경력사항': '경력무관',
#   '학력': '석사↑',
#   '근무형태': '계약직 · 인턴직',
#   '근무지': '전북 전주시 덕진구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576899'},
#  {'기업명': '㈜알앤비소프트',
#   '직무': '대기업 프로젝트 페이 부가서비스 운영개발 경력자  모집(긴급',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587080'},
#  {'기업명': '(주)헬로네이처',
#   '직무': '[헬로네이처] 데이터랩 팀원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586533'},
#  {'기업명': '(주)누리콘',
#   '직무': '병역특례 전문연구요원-영상 솔루션 소프트웨어 연구개발',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586159'},
#  {'기업명': '(주)알큐브',
#   '직무': '(주)알큐브 솔루션 / AI 연구원 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38440195'},
#  {'기업명': '(주)알큐브',
#   '직무': '(주)알큐브 솔루션 / AI 보조 연구원 채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38466936'},
#  {'기업명': '앰진시큐러스',
#   '직무': '(주)앰진시큐러스 백엔드 개발자 모집(Python / Java / C / C++)',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38376405'},
#  {'기업명': '(주)에이프릴세븐',
#   '직무': '[스타트업] 서버개발자 채용 공고',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38585353'},
#  {'기업명': '이파로스',
#   '직무': '펌웨어, C#, Python, C·C++ 정규직 채용(경력)',
#   '경력사항': '3 ~ 7년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '충북 청주시 청원구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38559628'},
#  {'기업명': '(주)에프앤가이드',
#   '직무': '[인덱스팀] 신입직원 채용',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38445026'},
#  {'기업명': '(주)컴트루테크놀로지',
#   '직무': '[인공지능 보안솔루션] 딥러닝아키텍쳐 / AI 개발자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '서울 마포구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38585016'},
#  {'기업명': '(주)컴트루테크놀로지',
#   '직무': '[병역특례(보충역)] Web개발, iOS개발, AI개발, 응용개발 모집',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38584994'},
#  {'기업명': '더모임컴퍼니(주)',
#   '직무': '자동차 VR 콘텐츠 개발자(경력사원)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38511089'},
#  {'기업명': '(주)포아시스',
#   '직무': '포아시스 ICT/빅데이터 인력채용 (경력무관)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '경북 포항시 남구',
#   '분류': "['무역사무·수출입', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38520334'},
#  {'기업명': '(주)비트나인',
#   '직무': '[비트나인] DB엔지니어 및 java 개발자 경력직 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38512320'},
#  {'기업명': '(주)아모레퍼시픽',
#   '직무': "[경력] '20년 AMOREPACIFIC 경력채용_플랫폼 Back-end 개발",
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569683'},
#  {'기업명': '(주)윈디플랜',
# ...
#  {'기업명': '(사)대덕이노폴리스벤처협회',
#   '직무': '[우수벤처공동채용](주)꿀비 빅데이터분석소프트웨어개발자모집',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 서구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38457749'},
#  {'기업명': '엔터웨이파트너스',
#   '직무': '퀀트투자회사 - Quantitative Researcher',
#   '경력사항': '경력무관',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '증권·투자·펀드·외환']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533474'},
#  {'기업명': '(주)에이치앤티어세스',
#   '직무': '화장품 회사 데이터 사이언티스트',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['회계·재무·세무·IR', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38532423'},
#  {'기업명': '(주)스마트미디어인텐시브',
#   '직무': 'CSS 설계 & 운영(리스크 분석) 인재 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528892'},
#  {'기업명': '헌터파트너스(주)',
#   '직무': '웹개발자(python) 채용 - 숙박 웹 서비스 업체',
#   '경력사항': '3 ~ 8년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38525294'},
#  {'기업명': '맨쉬 컨설팅 주식회사',
#   '직무': '대기업/차세대 내비게이션 검색엔진 개발/JAVA',
#   '경력사항': '3 ~ 13년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38524313'},
#  {'기업명': '보보스링크(주)',
#   '직무': 'AI개발 신입-사원급 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강동구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579345'},
#  {'기업명': '파워에이치알',
#   '직무': '[주요SI 대기업] 디지털금융 시스템 분석, 설계, 개발',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['마케팅·광고·분석', '영업기획·관리·지원']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38534260'},
#  {'기업명': '(주)탑앤스카우트',
#   '직무': '[AI, IoT] 공공프로젝트 PM 충원',
#   '경력사항': '경력 8년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601402'},
#  {'기업명': '굿커리어',
#   '직무': '유명 대기업 합작사 모바일앱 개발자 과장,차장',
#   '경력사항': '7 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592939'},
#  {'기업명': '그린컴퓨터아카데미',
#   '직무': '자바(JAVA) 웹프로그래밍개발 직업훈련교사(강사) 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '울산 남구',
#   '분류': "['웹개발', 'IT·디자인·컴퓨터교육']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38600945'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 최고 대기업 - Data Modeler - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582261'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) Data Modeler - 최고 대기업 - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582262'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 대기업 - 회원 플랫폼 기술PM (회원,인증,멤버십,CRM 등)',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582302'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) e커머스 - 소프트웨어 개발자 (JavaScript, Node.js)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582307'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 회원 플랫폼 기술PM (회원,인증,멤버십,CRM 등) - 대기업',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582334'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 커머스 통합 주문/재고 시스템 기술PM - 업계 최고 대기업',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583856'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 업계 최고 대기업 - 커머스 통합 주문/재고 시스템 기술PM',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583857'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) Technical Product Manager (블록체인)  - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582249'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 블록체인 Technical Product Manager  - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582250'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 소프트웨어 개발자 (JavaScript, Node.js) - e커머스',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582047'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 플랫폼 기술PM - 최고 대기업 - 최우대',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582201'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 최고 대기업 - 플랫폼 기술PM - 최우대',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582205'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) Data Manager - 업계 최고 대기업 - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582209'},
#  {'기업명': '(주)키스템프',
#   '직무': '[정규직채용/국내 Global 대기업] TV App개발 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 파주시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591522'},
#  {'기업명': '(주)키스템프',
#   '직무': '[정규직채용/급여협의/강남역] 중견기업 Java 개발자 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589947'},
#  {'기업명': '주식회사 엘리튜드',
#   '직무': '[대기업 계열사] 머신러닝 개발 신입~ 과장급',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598278'},
#  {'기업명': '(주)연세교육아카데미ㅣ연세직업전문학교',
#   '직무': '[연세직업전문학교]  정보보안(모의해킹) 강사 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '전임 · 계약직',
#   '근무지': '경기 수원시 장안구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38597574'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '헤드헌터 초빙(전자/전기/에너지/바이오/식품/IT 등)',
#   '경력사항': '경력 15년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '전임 · 계약직',
#   '근무지': '서울 서초구',
#   '분류': "['전기·전자·제어', '바이오·제약·식품']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38542008'},
#  {'기업명': '(주)커리어앤스카우트',
#   '직무': '글로벌 초일류 항만기업 IT개발센터 데이터 프로비저닝 경력직',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38597045'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[모바일 애드테크 전문기업] 프론트엔드 엔지니어(대리-과장)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38564013'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[모바일 애드테크 전문기업] 백엔드 엔지니어(대리-과장)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38564002'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[모바일 애드테크 전문기업] Front-end 엔지니어(대리-과장)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563840'},
#  {'기업명': '헬로우파트너스',
#   '직무': '자동차부품 대기업 내비게이션 Software Engineer 채용',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526894'},
#  {'기업명': '피플워크(주)',
#   '직무': '[ IT대기업]데이터 모델링 - 4-15년',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38548699'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592716'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '그룹 HR 공유 Infra HRIS 시스템 구축',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592712'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '렌탈 시스템 구축 프로젝트 PL업무 수행 시스템 개발',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592708'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Battery 생산지원시스템(QMS/SCM/EMS) 구축 및 Global 확산/운영',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 동구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592694'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'ITS 또는 QT등 소프트웨어 개발',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['전기·전자·제어', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592691'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 java',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592671'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '그룹 HR 공유 Infra HRIS 시스템 구축 SaaS  Cloud',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592664'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자 SAP',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592662'},
#  {'기업명': '(주)헬로서치',
#   '직무': '[국내우량기업]딥러닝 개발자를 모십니다.',
#   '경력사항': '2 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589871'},
#  {'기업명': '위키에이드',
#   '직무': '[화성/동탄] 머신비전 검사 SW 개발 경력',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 화성시',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589729'},
#  {'기업명': '(주)핀커스코리아',
#   '직무': '유명기업 웹개발 경력채용(3년~7년)',
#   '경력사항': '3 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587971'},
#  {'기업명': '(주)바른인사컨설팅',
#   '직무': '[S/W개발 상장사]C/C++ 개발자 경력직 정규직 채용(프로그램개발',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38543403'},
#  {'기업명': '(주)수커리어컨설팅',
#   '직무': '백엔드 개발(Java,리눅스 등 사용중) 네트워크,보안 기업',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 양천구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586023'},
#  {'기업명': '그린컴퓨터아트학원 아카데미 성남/분당 ..',
#   '직무': '[국가기간] JAVA기반 개발자 훈련과정 훈련교.강사님 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '전임 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554225'},
#  {'기업명': '그린컴퓨터아트학원 아카데미 성남/분당 ..',
#   '직무': '[국가기간] 디지털컨버전스(JAVA기반), 빅데이터취업 국비교육',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '위촉직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38485946'},
#  {'기업명': '커리어셀파',
#   '직무': '[유통대기업] IT개발 경력사원 채용',
#   '경력사항': '4 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583993'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': 'IT/ICT 소프트웨어 엔지니어',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시 영통구',
#   '분류': "['시스템개발', 'IT·디자인·컴퓨터교육']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583588'},
#  {'기업명': '인비즈써치',
#   '직무': '국내 대형증권사 로보어드바이저 서비스 기획 담당',
#   '경력사항': '4 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['ERP·시스템분석·설계', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583528'},
#  {'기업명': '굿커리어',
#   '직무': '대기업 MES(LOT 개발 운영,경북,충북) 대리,과장급 (굿커리어)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38547779'},
#  {'기업명': '제이떠블유커리어(JW career)',
#   '직무': '머신비전 전문기업 딥러닝, AI 연구소(소장급)채용',
#   '경력사항': '경력 10년↑',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579925'},
#  {'기업명': '(주)헬로서치',
#   '직무': '[국내우량기업]딥러닝 개발 인재를 모십니다.',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578846'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자 시스템통합 IT 아웃소싱',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575270'},
#  {'기업명': '(주)잡뉴스솔로몬서치',
#   '직무': '일본어가능 JAVA .NET CS연구개발 경력자',
#   '경력사항': '2 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570183'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '그룹 HR 공유 Infra HRIS 시스템 구축 SaaS 솔루션 클라우드',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569026'},
#  ...]

# %%
company_list_db = []
page_num = 1
while True:
    url = f'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page={page_num}&cat_key=41711%2C40721%2C40426&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=1#searchTitle'
    req_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    }
    html = requests.get(url, req_header).text
    soup = BeautifulSoup(html, 'html.parser')
    if soup.select('div.list_body div.list_item') == []:
        break
    for tag in soup.select('div.list_body div.list_item'):
        company_dict = {}
        company_dict["기업명"] = tag.select('div.company_nm a span')[0].text
        company_dict["직무"] = tag.select('div.notification_info a span')[0].text
        company_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
        company_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
        try:
            company_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
        except:
            company_dict["근무형태"] = ""
        company_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
        category_list = []
        for item in tag.select('div.notification_info div.job_meta span span'):
            category_list.append(item.text)
        company_dict["분류"] = str(category_list)
        
        detail_url = tag.select_one('div.notification_info a').attrs['href']
        full_detail_url = urljoin(main_url, detail_url)
        company_dict["상세링크"] = full_detail_url
        company_list_db.append(company_dict)
    page_num += 1
company_list_db
# Out:
# [{'기업명': '(주)페이타랩',
#   '직무': '현대인의 필수인 패스오더 개발자를 모십니다.[5개 직군]',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 부산진구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38365421'},
#  {'기업명': '펜타시큐리티시스템(주)',
#   '직무': '[펜타시큐리티] 보안S/W 개발자 모집 (DB, 인증, 클라우드)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595144&adsCategoryItem=effect_bold&'},
#  {'기업명': '국제컴퓨터아카데미',
#   '직무': '[100%무료 취업준비생모집]웹디/건축/게임/프로그래밍/3D프린터',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울 관악구',
#   '분류': "['그래픽디자인·CG', '제품·산업디자인']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=34393991'},
#  {'기업명': '스윙로드',
#   '직무': '스윙로드 (백엔드 부문) 정규직 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38423092'},
#  {'기업명': '더조은컴퓨터아트학원',
#   '직무': '[100%무료 취업준비생모집]웹디/건축/게임/프로그래밍/3D프린터',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['그래픽디자인·CG', '제품·산업디자인']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=34529977&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)쎄미시스코',
#   '직무': '㈜쎄미시스코 소프트웨어 개발자 경력직 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시',
#   '분류': "['반도체·디스플레이·LCD', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38597487&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)와이비시스템',
#   '직무': '개발자 담당 경력 정규직 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579699&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)트랜스코스모스코리아',
#   '직무': '당사 프로젝트 개발 및 유지보수 담당자(신입/경력)Mj5E',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38512364'},
#  {'기업명': '행복쇼핑(주)',
#   '직무': 'PHP/REACT/PYTHON/퍼블리셔 경력자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38550645&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)세원아토스',
#   '직무': 'ERP 신입, 경력 개발자를 모십니다.',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38602619'},
#  {'기업명': '(주)시지온',
#   '직무': '라이브리 서비스 광고 플랫폼 개발자 모집',
#   '경력사항': '3 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38593999'},
#  {'기업명': '에스케이플래닛(주)',
#   '직무': '각 부문 경력사원 채용',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시',
#   '분류': "['기획·전략·경영', '광고영업']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38083118&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)헥사콘',
#   '직무': '데이터분석/AI용 이미지 및 영상처리 각 부문 채용',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528160&adsCategoryItem=effect_bold&'},
#  {'기업명': '켈리서비스 유한회사',
#   '직무': '[글로벌 포털 G사 ] Technical Solutions Consultant',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 강남구',
#   '분류': "['AS·서비스·수리', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569889'},
#  {'기업명': '사단법인 한국산업기술협회',
#   '직무': '산업계주도 청년 맞춤형 취업지원 아카데미 연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울 금천구',
#   '분류': "['금속·금형', '설계·CAD·CAM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38425715'},
#  {'기업명': '(주)데브구루',
#   '직무': '[신입/경력] 실력있는 개발자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38602229'},
#  {'기업명': '(주)상록아이엔씨',
#   '직무': '[경험자 우대] Python/Linux AI 시스템 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 부천시',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601843&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)유노믹',
#   '직무': '[부산] ㈜유노믹 신입 및 경력 채용 (기술영업/마케팅, SW개발자)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '부산 동구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579931&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)아이스크림에듀',
#   '직무': '㈜아이스크림에듀 콘텐츠,개발,마케팅,영업,관리 직군 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['상품기획·MD', '마케팅·광고·분석']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569553&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)옷딜',
#   '직무': 'Ai솔루션 옷딜 각부분 경력모집',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['기획·전략·경영', '출판·편집디자인']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580264&adsCategoryItem=effect_bold&'},
#  {'기업명': '디아이티(주)',
#   '직무': '2020 DIT 하반기 공개 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시 영통구',
#   '분류': "['기계·기계설비', '전기·전자·제어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38577337&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)슈프리마',
#   '직무': '[슈프리마] UX 기획 및 개발',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시',
#   '분류': "['웹마스터·QA·테스터', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38451606&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)제머나이소프트',
#   '직무': '웹 개발(프론트엔드/백엔드) 경력사원 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533221&adsCategoryItem=effect_bold&'},
#  {'기업명': '네모커머스(주)',
#   '직무': '2020 하반기 네모커머스 신입·경력 채용(웹개발,서비스가이드,서비스기획)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['기획·전략·경영', 'IT·솔루션영업']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560537&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)유비온',
#   '직무': '[유비온] 미래교육사업부(웹 어플리케이션 개발자 채용)',
#   '경력사항': '5 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576322&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)어니언스',
#   '직무': '파프리카케어 부분별 채용(UI디자이너, 백엔드/프론트엔드 개발)',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['그래픽디자인·CG', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578724&adsCategoryItem=effect_bold&'},
#  {'기업명': '에이치투오시스템테크놀로지(주)',
#   '직무': 'IT개발 담당자 신입, 경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['사무보조·문서작성', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578092&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)NE능률',
#   '직무': '2020년 ㈜NE능률 신입 공채 및 경력 수시 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['일반영업', '영업기획·관리·지원']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579763&adsCategoryItem=effect_bold&'},
#  {'기업명': '대화제약(주)',
#   '직무': '신입/경력 채용공고(전산(IT), 의원영업, 종합병원영업, 개발학술, 연구개발)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '서울 서초구',
#   '분류': "['총무·법무·사무', '사무보조·문서작성']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570702&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)아이스크림에듀',
#   '직무': '㈜아이스크림에듀 AI연구실, 마케팅실 팀장 채용',
#   '경력사항': '경력 12년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['마케팅·광고·분석', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570291&adsCategoryItem=effect_bold&'},
#  {'기업명': '글로벌인',
#   '직무': '[국비취업연수] 일본 현지 호텔 프론트, IT 개발자 정규직 일자리확보형 취업 국비 연수 과정',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '교육생 · 해외취업',
#   '근무지': '아시아·중동 일본',
#   '분류': "['호텔·카지노·콘도', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579651&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)후이즈',
#   '직무': '㈜후이즈 쇼핑몰 각 부문별 신입/경력 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563638&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)아이하트',
#   '직무': '㈜아이하트 신입/경력사원 모집[청년내일채움공제가능]',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38568215&adsCategoryItem=effect_bold&'},
#  {'기업명': '(사)스마트미디어인재개발원',
#   '직무': '빅데이터·인공지능·IoT 무료 취업교육 모집!',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '광주 남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38024536&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)아이엔지스토리',
#   '직무': '[아이엔지스토리]웹기획자 / 영업 / 설계디자인 담당자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['전시·공간디자인', '일반영업']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567115&adsCategoryItem=effect_bold&'},
#  {'기업명': '한국직업전문학교',
#   '직무': '[국비무료/수당지급] 빅데이터/UI/UX 퍼블리싱/응용 S/W 개발자',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '서울 구로구',
#   '분류': "['그래픽디자인·CG', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38393122&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)큐픽스',
#   '직무': '[신입/경력/전문연구요원] AWS/Ruby 백엔드엔지니어(DevOps)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586042'},
#  {'기업명': '(주)큐픽스',
#   '직무': '[신입/경력/전문연구요원] 컴퓨터비전/딥러닝/SLAM 영상처리',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586016'},
#  {'기업명': '주식회사 엔디소프트',
#   '직무': '(주)NDSOFT 2020년 개발자 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 해운대구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38572298'},
#  {'기업명': '(재)충남정보문화산업진흥원',
#   '직무': '2020년 제 3차 계약직 직원채용 공고(연장공고)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '충남 천안시 동남구',
#   '분류': "['기획·전략·경영', '홍보·PR·사보']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539566&adsCategoryItem=effect_bold&'},
#  {'기업명': '뉴로핏 주식회사',
#   '직무': '소프트웨어 유틸리티 개발 및 유지보수 (경력 1년 이상)모집',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38602042'},
#  {'기업명': '켐아이넷(주)',
#   '직무': '청년디지털일자리사업 참여인력 모집 (인공지능, 통계, SW개발)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 양천구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592271'},
#  {'기업명': '(주)옷딜',
#   '직무': '[ Ai스타트업 ] 기획 ㆍ인공지능ㆍ백엔드 개발자 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551843'},
#  {'기업명': '(주)옷딜',
#   '직무': '[ Ai 스타트업 ] 딥러닝ㆍ 데이터엔지니어 경력개발자모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['ERP·시스템분석·설계', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551913'},
#  {'기업명': '(주)씨앤테크',
#   '직무': '[신입/경력무관] Web 개발 및 유지보수 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38602004'},
#  {'기업명': '(주)매드업',
#   '직무': '[매드업] 하반기 전 직군 대규모 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['인사·교육·노무', '마케팅·광고·분석']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596083&adsCategoryItem=effect_bold&'},
#  {'기업명': '㈜타이호인스트',
#   '직무': '기술연구소 경력개발자 채용',
#   '경력사항': '경력 6년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601886'},
#  {'기업명': '모닝인컨설팅',
#   '직무': '[건대역/웹어플개발] 경력3년/연봉협의(경력별)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 광진구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576669'},
#  {'기업명': '신한양직업전문학교',
#   '직무': '[국비지원] 하반기 취업대비 4차 산업 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '부산 부산진구',
#   '분류': "['물류·유통·운송', '기계·기계설비']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38541577&adsCategoryItem=effect_bold&'},
#  {'기업명': '무브(주)',
#   '직무': 'Python 경력직 정규직 개발자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38577743'},
#  {'기업명': '주식회사 와이즈인컴퍼니',
#   '직무': '빅데이터분석 및 개발자 모집(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590627'},
#  {'기업명': '(주)투윈스컴',
#   '직무': '[보안설비연구소] 신규 프로그래머 채용 (신입)',
#   '경력사항': '신입',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['웹마스터·QA·테스터', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601783'},
#  {'기업명': '(주)슈프리마',
#   '직무': '[슈프리마] 웹개발 채용',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37957886&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)이노와이어리스',
#   '직무': '이노와이어리스/큐셀네트웍스 각 분야 신입/경력 채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['생산관리·품질관리', '생산·제조·포장·조립']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590538&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)상록아이엔씨',
#   '직무': '[경험자 우대] Python/Linux AI 시스템 개발자 모집 합니다',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 부천시',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601610'},
#  {'기업명': '쿠팡(주)',
#   '직무': '경영지원 대규모 채용 (Finance,HR,Business Data Analyst)',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 송파구',
#   '분류': "['총무·법무·사무', '인사·교육·노무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589504'},
#  {'기업명': '(주)강림직업전문학교',
#   '직무': '빅데이터 전문가(자바&파이썬&R) 과정 훈련교사 모집.',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 평택시',
#   '분류': "['응용프로그램개발', 'IT·디자인·컴퓨터교육']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601520'},
#  {'기업명': '(주)프렌츠',
#   '직무': '웹 개발 및 기획 담당자 채용',
#   '경력사항': '1 ~ 4년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['웹마스터·QA·테스터', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590376&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)메디벨바이오',
#   '직무': '헬스케어 시스템 개발 (AI알고리즘, 구동S/W, APP.) 정규직 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580234&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)엔씨아이티에스',
#   '직무': '[NCSOFT자회사] 엔씨아이티에스 게임웹운영,  보안관제, 시스템 엔지니어 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586493&adsCategoryItem=effect_bold&'},
#  {'기업명': '스토리앤브라더스(주)',
#   '직무': '파이썬(장고) 백엔드 개발 경력자 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558591'},
#  {'기업명': '(주)엔티엘헬스케어',
#   '직무': '개발기획팀(소프트웨어 개발) 경력 직원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 수정구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601419'},
#  {'기업명': '(주)디케이비엠시',
#   '직무': 'CRM, BI, SI 컨설팅솔루션 관리/개발자 채용 공고',
#   '경력사항': '2 ~ 17년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['그래픽디자인·CG', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528106&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)유노믹',
#   '직무': '[서울] ㈜유노믹 신입 및 경력 채용(기술영업/마케팅, SW개발자)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['기획·전략·경영', '홍보·PR·사보']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567864&adsCategoryItem=effect_bold&'},
#  {'기업명': '패스트캠퍼스(주)',
#   '직무': '[패스트캠퍼스] 대규모 인재 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '마케팅·광고·분석']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38230007'},
#  {'기업명': '(주)모비노마',
#   '직무': '신사업 헬스케어 관련 서버/백엔드 개발자 채용(경력 )',
#   '경력사항': '4 ~ 8년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38540502'},
#  {'기업명': '(주)선진',
#   '직무': '[하림그룹] ㈜선진 신입/경력 수시채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['회계·재무·세무·IR', '마케팅·광고·분석']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580036'},
#  {'기업명': '한국정보기술단',
#   '직무': '[한국정보기술단] 빅데이터 분석 기술인력 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 과천시',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38508480'},
#  {'기업명': '(주)세차왕',
#   '직무': '세차왕에서 백엔드 및 웹앱 개발자를 모십니다.',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562173'},
#  {'기업명': '신한카드(주)',
#   '직무': '2020년 B2사원 수시채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['그래픽디자인·CG', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567189'},
#  {'기업명': '(주)알리아스',
#   '직무': '[ VR / AR ] 콘텐츠 코딩 엔지니어 신입/경력사원 모집(정규직)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경남 김해시',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38359878'},
#  {'기업명': '녹십자지놈',
#   '직무': '[GC녹십자지놈]  BI팀 팀원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '경기 용인시 기흥구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528636'},
#  {'기업명': '(주)크레스콤',
#   '직무': '소프트웨어 개발 (인공지능 AI 풀스택 서버 웹개발 의료영상)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38309368'},
#  {'기업명': '지스펙(주)',
#   '직무': '(전액무료)파이썬기반 빅데이터 플랫폼&분석 전문가 취업연계과정',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38525507&adsCategoryItem=effect_bold&'},
#  {'기업명': '트리니티엔지니어링(주)',
#   '직무': '트리니티엔지니어링 CAE(해석 및 개발), 프로그래밍 엔지니어 채용',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 양천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598627&adsCategoryItem=effect_bold&'},
#  {'기업명': '콴텍(주)',
#   '직무': '[콴텍, 금융] 함께 성장할 금융 데이터 분석 전문가 모십니다.',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['금융·보험영업', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38482773'},
#  {'기업명': '한국기술교육직업전문학교',
#   '직무': '[전액국비] 4차산업 IT전문인력 취업연계교육',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '부산 동래구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539306&adsCategoryItem=effect_bold&'},
#  {'기업명': '지엔소프트(주)',
#   '직무': '[경력] 데이터 검증 및 분석 개발자 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '대전 서구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38386450'},
#  {'기업명': '휴먼교육센터학원',
#   '직무': '[전액무료]자바/파이썬 IT교육받고 취업하자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38510654&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)지에스아이티엠',
#   '직무': '2020년 하반기 GS ITM 경력사원 공개채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587357'},
#  {'기업명': '(주)비바리퍼블리카',
#   '직무': '[토스/토스뱅크] Data Analyst 분을 모십니다.',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591688'},
#  {'기업명': '주식회사 성진에이치디에스',
#   '직무': "최고의 복지로 함께 성장할 '데이터 분석가' 를 찾습니다",
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['마케팅·광고·분석', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38600944'},
#  {'기업명': '(주)엔키아',
#   '직무': '2020년 엔키아 각 부문 공개채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['기획·전략·경영', '웹마스터·QA·테스터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38538595&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)케이몰글로벌',
#   '직무': 'Kmall 쇼핑몰 (PHP,Mysql,Java) 정규직 직원 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599888'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '[분당/외국계]글로벌 반도체 기업, Web Developer 채용',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '파견직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590576'},
#  {'기업명': '(주)트레이지',
#   '직무': '글로벌 여행스타트업 Trazy - 백엔드 개발자 (Python) 채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38600867'},
#  {'기업명': '(주)소프트케잌',
#   '직무': '웹개발자 (경력) - 웹프로그래머',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '부산 연제구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38529377'},
#  {'기업명': '휴도',
#   '직무': '[휴도] WEB / APP 신규 구축 풀스텍 개발자 채용 (NODE.JS / REACT-NATIVE)',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599290'},
#  {'기업명': '(유)딜리버리히어로 코리아',
#   '직무': '전 개발직군 대규모 채용중',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38476546'},
#  {'기업명': '현대오트론(주)',
#   '직무': '현대오트론 시스템반도체/전장SW 전문가 경력 상시채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['구매·자재·재고', '기획·전략·경영']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38544124'},
#  {'기업명': '(주)파이버프로',
#   '직무': '㈜파이버프로 SW개발 부문 신입/경력사원 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590763'},
#  {'기업명': '(주)안랩',
#   '직무': '2020 하반기 안랩 연구소 신입사원 공개채용',
#   '경력사항': '신입',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578654'},
#  {'기업명': '(주)씨제이이엔엠',
#   '직무': 'CJ ENM(E&M부문) TVING 경력사원 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38515830'},
#  {'기업명': '(주)휴넷',
#   '직무': '2020년 ㈜휴넷 웹 개발자 경력직 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594512'},
#  {'기업명': '주식회사 로원홀딩스',
#   '직무': '[로원홀딩스] MD/개발자/CS 경력사원 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['상품기획·MD', '고객센터·CS']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561891'},
#  {'기업명': '(주)헬스메디',
#   '직무': '2020년 각 부문별 신입/경력 채용(새로운 프로젝트 진행중)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['홍보·PR·사보', '사무보조·문서작성']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570966'},
#  {'기업명': '펍지(주)',
#   '직무': '펍지㈜ 각 부문별 수시 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['총무·법무·사무', '인사·교육·노무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38542347'},
#  {'기업명': '(주)이상투자그룹',
#   '직무': '㈜이상투자그룹 각 부문별 인재 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38544985'},
#  {'기업명': '(주)하나금융티아이',
#   '직무': '[하나금융융합기술원] 부문별 경력사원 모집',
#   '경력사항': '경력',
#   '학력': '석사↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565737'},
#  {'기업명': '㈜해커스교육그룹',
#   '직무': '2020년 해커스 교육그룹 [신입/경력] 각 부문별 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38369849'},
#  {'기업명': '한국직업능력교육원 안산',
#   '직무': '경기/시흥・안산/군포 국비무료 취업연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '경기 안산시 단원구',
#   '분류': "['회계·재무·세무·IR', '생산관리·품질관리']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38527236&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)LG유플러스',
#   '직무': 'IT개발/운영 신입&경력 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533503'},
#  {'기업명': '엔사이크(주)',
#   '직무': '파이썬 머신러닝 백엔드, 응용프로그램 개발자 모집',
#   '경력사항': '1 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38513699'},
#  {'기업명': '메디픽셀',
#   '직무': '[병특/일반] 의료 인공지능 전문연구요원 채용 (메디픽셀)',
#   '경력사항': '경력무관',
#   '학력': '석사↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 마포구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38481522'},
#  {'기업명': '스펙트럼',
#   '직무': 'VR/AR 콘텐츠 개발자 및 AI/딥러닝 개발자 모집(Unity, C#, C++)',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '게임·Game']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38572585'},
#  {'기업명': '네이버파이낸셜(주)',
#   '직무': '[네이버파이낸셜] FDS 데이터 분석 / 정책 담당자 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['기획·전략·경영', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38600150'},
#  {'기업명': '트래블라이(주)',
#   '직무': '[알루 서비스 개발팀]  서버 경력, 클라이언트 신입  및 경력 채',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599968'},
#  {'기업명': '몬드리안에이아이(주)',
#   '직무': 'AI / Big Data Platform Backend Developer',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '인천 연수구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38457823'},
#  {'기업명': '몬드리안에이아이(주)',
#   '직무': 'AI / Big Data Researcher',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '인천 연수구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38545832'},
#  {'기업명': '(주)유니콤넷',
#   '직무': '개발팀(기술연구소) 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['응용프로그램개발', '웹디자인']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599654'},
#  {'기업명': '주식회사 에이치이엠',
#   '직무': '광교지사 3분기 수시채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 수원시 영통구',
#   '분류': "['바이오·제약·식품', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599553'},
#  {'기업명': '(주)모비젠',
#   '직무': '2020년 하반기 (주)모비젠 부문별 경력 모집 공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599066'},
#  {'기업명': '굿모니터링(주)',
#   '직무': '웹.앱 프로그래밍 개발자 채용',
#   '경력사항': '1 ~ 3년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서대문구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569719'},
#  {'기업명': '(주)케이씨넷',
#   '직무': '데이터사업부 JAVA개발 경력직 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['기획·전략·경영', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560795'},
#  {'기업명': '테크빌교육(주)',
#   '직무': '[테크빌교육] 개발PM·프로그래머·기획·데이터분석 등 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38363291'},
#  {'기업명': '메이븐코리아(주)',
#   '직무': 'BI 데이터 시각화 개발자 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596953'},
#  {'기업명': '(주)하미글로벌',
#   '직무': '하반기 각 부문 신입 / 경력 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['상품기획·MD', '기획·전략·경영']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552878'},
#  {'기업명': '(주)쓰리웨이소프트',
#   '직무': '전력설비 DeepLearning 및 응용 개발자모심',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596507'},
#  {'기업명': '(주)큐빅테크',
#   '직무': '데이터가공,분석,인공지능(AI)·빅데이터外 경력직 채용',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['생산관리·품질관리', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590373'},
#  {'기업명': '(주)팀플백',
#   '직무': 'SW개발자 및 PM 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경남 창원시',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38479641'},
#  {'기업명': '주식회사 노벨알엔디',
#   '직무': '[삼성전자 화성] 시스템 개발/운영 경력 개발자 (java)',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 프리랜서',
#   '근무지': '경기 화성시',
#   '분류': "['그래픽디자인·CG', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38481159'},
#  {'기업명': '주식회사 블루에이치알',
#   '직무': '[자회사 정규직] 강남구청역 LGU+ 모바일센터 인바운드 상담',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38446566'},
#  {'기업명': '한국IT교육원',
#   '직무': '2020년 취업연계 교육훈련 양성과정',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '대구 동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595914'},
#  {'기업명': '(주)두플',
#   '직무': '제조 빅데이터 솔루션 개발자 모집 -C#, Java, Python',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38384415'},
#  {'기업명': '(주)케이씨피드',
#   '직무': '(주)케이씨피드 전산팀(웹 프로그램 개발 및 유지보수) 경력사원',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경북 영천시',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595525'},
#  {'기업명': '(주)스트라티오코리아',
#   '직무': '(주)스트라티오코리아 2020 하반기 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 서초구',
#   '분류': "['광고·시각디자인', '웹마스터·QA·테스터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38508258'},
#  {'기업명': '(주)애드픽네트워크',
#   '직무': '자바스크립트, c언어, 파이썬 웹개발자 채용공고',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595297'},
#  {'기업명': '(주)커넥트히어로',
#   '직무': '서버개발자, ios개발자, UX/UI 부문 담당자 모집',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595199'},
#  {'기업명': '(주)애드픽네트워크',
#   '직무': '프리랜서 단기프로젝트 웹개발자 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38572899'},
#  {'기업명': '분당서울대학교병원',
#   '직무': '분당서울대학교병원 연구사업단 행정연구원 채용공고',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592972'},
#  {'기업명': '효성컴퓨터학원',
#   '직무': '효성컴퓨터학원 C / JAVA 프로그래밍/정보보안/PC정비 강사 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '대전 서구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594843'},
#  {'기업명': '주식회사 인공지능연구원',
#   '직무': '자동화 소프트웨어 RPA 워크플로우 개발자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594653'},
#  {'기업명': '(주)쓰리웨이소프트',
#   '직무': '스마트 그리드 솔루션 개발자모심',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38447295'},
#  {'기업명': '한국에이치알엠',
#   '직무': '대표 커뮤니티사이트 백앤드 Back-end 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594546'},
#  {'기업명': '비젠트로(주)',
#   '직무': '(삼성SDS분사社) 비젠트로㈜ MES부문 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38566203'},
#  {'기업명': '워크픽(주)',
#   '직무': '(워라벨/복지깡패)웹개발(Python&백엔드&Java·JSP) 채용 공고',
#   '경력사항': '3 ~ 8년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594220'},
#  {'기업명': '(주)알체라',
#   '직무': '백엔드 개발자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594076'},
#  {'기업명': '(주)지비소프트',
#   '직무': '영상처리 및 프론트엔드 개발 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대구 수성구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586088'},
#  {'기업명': '(주)올엠',
#   '직무': '통계/데이터 분석(DA) 담당자를 모십니다.',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587922'},
#  {'기업명': '(주)아이엠비디엑스',
#   '직무': '2020 하반기 각 부문 직원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591579'},
#  {'기업명': '로크웰오토메이션코리아(주)',
#   '직무': 'Software Lead Engineer 채용',
#   '경력사항': '경력 7년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기계·기계설비', '전기·전자·제어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567097'},
#  {'기업명': '(주)티제이팜',
#   '직무': '각 부문별 신입/경력사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['상품기획·MD', '마케팅·광고·분석']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570373'},
#  {'기업명': '신플렛(주)',
#   '직무': '이미지 딥러닝 (파이썬) 개발자 추가모집',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 용인시 수지구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38593006'},
#  {'기업명': '(주)코인원트랜스퍼',
#   '직무': '크로스 서비스 Core system & Server 개발자 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592891'},
#  {'기업명': '(주)디비엔텍',
#   '직무': '인공지능(AI, 딥러닝, 컴퓨터 비전) 연구개발 연구원 신입채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 서구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592620'},
#  {'기업명': '베스핀글로벌(주)',
#   '직무': 'Software QA 채용(경력 3년이상)',
#   '경력사항': '3 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592386'},
#  {'기업명': '(주)아이콘루프',
#   '직무': '[ICONLOOP] 소프트웨어/블록체인/DID 개발자 채용 (FE/BE/SI)',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 중구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38357521'},
#  {'기업명': '(주)엘젠아이씨티',
#   '직무': 'AI 빅데이터 챗봇 전문가가 되고자 하는 개발자 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38495947'},
#  {'기업명': '소프트젠',
#   '직무': '웹 프로그램 개발자 (Node.js, Spring, Database, PHP) 모집',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 수정구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528609'},
#  {'기업명': '포디리플레이코리아(주)',
#   '직무': '[4DReplay] 클라우드 서비스 및 Platform Back End 개발자 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558326'},
#  {'기업명': '(주)록스',
#   '직무': '[신입] AI/머신러닝 연구원 채용',
#   '경력사항': '신입',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 금정구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591412'},
#  {'기업명': '알테어엔지니어링(주)',
#   '직무': '[Altair Korea]Data analytics expert(Pre-sales consultant)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38355791'},
#  {'기업명': '(주)골든플래닛',
#   '직무': '구글애널리틱스,시스템개발,클라우드 데이터엔지니어,데이터분석',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['마케팅·광고·분석', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526529'},
#  {'기업명': '(주)세원이디에스',
#   '직무': 'ERP개발자를 모십니다.',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590655'},
#  {'기업명': '베스핀글로벌(주)',
#   '직무': 'Public Cloud System Architect(SA) 채용(경력 3년이상)',
#   '경력사항': '3 ~ 20년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589952'},
#  {'기업명': '(주)에이직스',
#   '직무': '빅데이터 처리 및 AI 알고리즘 연구개발 (R&D)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38514028'},
#  {'기업명': '(주)인라이플',
#   '직무': '(업계1위/JAVA개발) 얘네 재밌는거 개발한데 가보자',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹마스터·QA·테스터', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587699'},
#  {'기업명': '(주)인라이플',
#   '직무': '가치있는 데이터를 같이 만들 JAVA개발자 채용 (백엔드 부문)',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹마스터·QA·테스터', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587682'},
#  {'기업명': '㈜이지메디컴',
#   '직무': 'IT 연구소 헬스케어 SCM 웹솔루션 개발자 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587603'},
#  {'기업명': '(주)이젠아카데미인재개발원',
#   '직무': '[취업연수 국비교육]자바/파이썬/빅데이터/웹/영상/건축',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['캐릭터·만화·애니', '광고·시각디자인']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=36825236'},
#  {'기업명': '전북대병원 의생명연구원',
#   '직무': '전북대학교병원 전북빅데이터센터 연구직[S/W개발자] 모집',
#   '경력사항': '경력무관',
#   '학력': '석사↑',
#   '근무형태': '계약직 · 인턴직',
#   '근무지': '전북 전주시 덕진구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576899'},
#  {'기업명': '㈜알앤비소프트',
#   '직무': '대기업 프로젝트 페이 부가서비스 운영개발 경력자  모집(긴급',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587080'},
#  {'기업명': '(주)헬로네이처',
#   '직무': '[헬로네이처] 데이터랩 팀원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586533'},
#  {'기업명': '(주)누리콘',
#   '직무': '병역특례 전문연구요원-영상 솔루션 소프트웨어 연구개발',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586159'},
#  {'기업명': '(주)알큐브',
#   '직무': '(주)알큐브 솔루션 / AI 연구원 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38440195'},
#  {'기업명': '(주)알큐브',
#   '직무': '(주)알큐브 솔루션 / AI 보조 연구원 채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38466936'},
#  {'기업명': '앰진시큐러스',
#   '직무': '(주)앰진시큐러스 백엔드 개발자 모집(Python / Java / C / C++)',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38376405'},
#  {'기업명': '(주)에이프릴세븐',
#   '직무': '[스타트업] 서버개발자 채용 공고',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38585353'},
#  {'기업명': '이파로스',
#   '직무': '펌웨어, C#, Python, C·C++ 정규직 채용(경력)',
#   '경력사항': '3 ~ 7년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '충북 청주시 청원구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38559628'},
#  {'기업명': '(주)에프앤가이드',
#   '직무': '[인덱스팀] 신입직원 채용',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38445026'},
#  {'기업명': '(주)컴트루테크놀로지',
#   '직무': '[인공지능 보안솔루션] 딥러닝아키텍쳐 / AI 개발자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '서울 마포구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38585016'},
#  {'기업명': '(주)컴트루테크놀로지',
#   '직무': '[병역특례(보충역)] Web개발, iOS개발, AI개발, 응용개발 모집',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38584994'},
#  {'기업명': '더모임컴퍼니(주)',
#   '직무': '자동차 VR 콘텐츠 개발자(경력사원)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38511089'},
#  {'기업명': '(주)포아시스',
#   '직무': '포아시스 ICT/빅데이터 인력채용 (경력무관)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '경북 포항시 남구',
#   '분류': "['무역사무·수출입', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38520334'},
#  {'기업명': '(주)비트나인',
#   '직무': '[비트나인] DB엔지니어 및 java 개발자 경력직 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38512320'},
#  {'기업명': '(주)아모레퍼시픽',
#   '직무': "[경력] '20년 AMOREPACIFIC 경력채용_플랫폼 Back-end 개발",
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569683'},
#  {'기업명': '(주)윈디플랜',
# ...
#  {'기업명': '(사)대덕이노폴리스벤처협회',
#   '직무': '[우수벤처공동채용](주)꿀비 빅데이터분석소프트웨어개발자모집',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 서구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38457749'},
#  {'기업명': '엔터웨이파트너스',
#   '직무': '퀀트투자회사 - Quantitative Researcher',
#   '경력사항': '경력무관',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '증권·투자·펀드·외환']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533474'},
#  {'기업명': '(주)에이치앤티어세스',
#   '직무': '화장품 회사 데이터 사이언티스트',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['회계·재무·세무·IR', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38532423'},
#  {'기업명': '(주)스마트미디어인텐시브',
#   '직무': 'CSS 설계 & 운영(리스크 분석) 인재 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528892'},
#  {'기업명': '헌터파트너스(주)',
#   '직무': '웹개발자(python) 채용 - 숙박 웹 서비스 업체',
#   '경력사항': '3 ~ 8년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38525294'},
#  {'기업명': '맨쉬 컨설팅 주식회사',
#   '직무': '대기업/차세대 내비게이션 검색엔진 개발/JAVA',
#   '경력사항': '3 ~ 13년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38524313'},
#  {'기업명': '보보스링크(주)',
#   '직무': 'AI개발 신입-사원급 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강동구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579345'},
#  {'기업명': '파워에이치알',
#   '직무': '[주요SI 대기업] 디지털금융 시스템 분석, 설계, 개발',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['마케팅·광고·분석', '영업기획·관리·지원']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38534260'},
#  {'기업명': '(주)탑앤스카우트',
#   '직무': '[AI, IoT] 공공프로젝트 PM 충원',
#   '경력사항': '경력 8년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601402'},
#  {'기업명': '굿커리어',
#   '직무': '유명 대기업 합작사 모바일앱 개발자 과장,차장',
#   '경력사항': '7 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592939'},
#  {'기업명': '그린컴퓨터아카데미',
#   '직무': '자바(JAVA) 웹프로그래밍개발 직업훈련교사(강사) 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '울산 남구',
#   '분류': "['웹개발', 'IT·디자인·컴퓨터교육']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38600945'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 최고 대기업 - Data Modeler - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582261'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) Data Modeler - 최고 대기업 - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582262'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 대기업 - 회원 플랫폼 기술PM (회원,인증,멤버십,CRM 등)',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582302'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) e커머스 - 소프트웨어 개발자 (JavaScript, Node.js)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582307'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 회원 플랫폼 기술PM (회원,인증,멤버십,CRM 등) - 대기업',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582334'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 커머스 통합 주문/재고 시스템 기술PM - 업계 최고 대기업',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583856'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 업계 최고 대기업 - 커머스 통합 주문/재고 시스템 기술PM',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583857'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) Technical Product Manager (블록체인)  - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582249'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 블록체인 Technical Product Manager  - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582250'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 소프트웨어 개발자 (JavaScript, Node.js) - e커머스',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582047'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 플랫폼 기술PM - 최고 대기업 - 최우대',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582201'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 최고 대기업 - 플랫폼 기술PM - 최우대',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582205'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) Data Manager - 업계 최고 대기업 - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582209'},
#  {'기업명': '(주)키스템프',
#   '직무': '[정규직채용/국내 Global 대기업] TV App개발 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 파주시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591522'},
#  {'기업명': '(주)키스템프',
#   '직무': '[정규직채용/급여협의/강남역] 중견기업 Java 개발자 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589947'},
#  {'기업명': '주식회사 엘리튜드',
#   '직무': '[대기업 계열사] 머신러닝 개발 신입~ 과장급',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598278'},
#  {'기업명': '(주)연세교육아카데미ㅣ연세직업전문학교',
#   '직무': '[연세직업전문학교]  정보보안(모의해킹) 강사 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '전임 · 계약직',
#   '근무지': '경기 수원시 장안구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38597574'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '헤드헌터 초빙(전자/전기/에너지/바이오/식품/IT 등)',
#   '경력사항': '경력 15년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '전임 · 계약직',
#   '근무지': '서울 서초구',
#   '분류': "['전기·전자·제어', '바이오·제약·식품']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38542008'},
#  {'기업명': '(주)커리어앤스카우트',
#   '직무': '글로벌 초일류 항만기업 IT개발센터 데이터 프로비저닝 경력직',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38597045'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[모바일 애드테크 전문기업] 프론트엔드 엔지니어(대리-과장)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38564013'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[모바일 애드테크 전문기업] 백엔드 엔지니어(대리-과장)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38564002'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[모바일 애드테크 전문기업] Front-end 엔지니어(대리-과장)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563840'},
#  {'기업명': '헬로우파트너스',
#   '직무': '자동차부품 대기업 내비게이션 Software Engineer 채용',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526894'},
#  {'기업명': '피플워크(주)',
#   '직무': '[ IT대기업]데이터 모델링 - 4-15년',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38548699'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592716'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '그룹 HR 공유 Infra HRIS 시스템 구축',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592712'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '렌탈 시스템 구축 프로젝트 PL업무 수행 시스템 개발',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592708'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Battery 생산지원시스템(QMS/SCM/EMS) 구축 및 Global 확산/운영',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 동구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592694'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'ITS 또는 QT등 소프트웨어 개발',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['전기·전자·제어', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592691'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 java',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592671'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '그룹 HR 공유 Infra HRIS 시스템 구축 SaaS  Cloud',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592664'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자 SAP',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592662'},
#  {'기업명': '(주)헬로서치',
#   '직무': '[국내우량기업]딥러닝 개발자를 모십니다.',
#   '경력사항': '2 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589871'},
#  {'기업명': '위키에이드',
#   '직무': '[화성/동탄] 머신비전 검사 SW 개발 경력',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 화성시',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589729'},
#  {'기업명': '(주)핀커스코리아',
#   '직무': '유명기업 웹개발 경력채용(3년~7년)',
#   '경력사항': '3 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587971'},
#  {'기업명': '(주)바른인사컨설팅',
#   '직무': '[S/W개발 상장사]C/C++ 개발자 경력직 정규직 채용(프로그램개발',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38543403'},
#  {'기업명': '(주)수커리어컨설팅',
#   '직무': '백엔드 개발(Java,리눅스 등 사용중) 네트워크,보안 기업',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 양천구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586023'},
#  {'기업명': '그린컴퓨터아트학원 아카데미 성남/분당 ..',
#   '직무': '[국가기간] JAVA기반 개발자 훈련과정 훈련교.강사님 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '전임 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554225'},
#  {'기업명': '그린컴퓨터아트학원 아카데미 성남/분당 ..',
#   '직무': '[국가기간] 디지털컨버전스(JAVA기반), 빅데이터취업 국비교육',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '위촉직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38485946'},
#  {'기업명': '커리어셀파',
#   '직무': '[유통대기업] IT개발 경력사원 채용',
#   '경력사항': '4 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583993'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': 'IT/ICT 소프트웨어 엔지니어',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시 영통구',
#   '분류': "['시스템개발', 'IT·디자인·컴퓨터교육']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583588'},
#  {'기업명': '인비즈써치',
#   '직무': '국내 대형증권사 로보어드바이저 서비스 기획 담당',
#   '경력사항': '4 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['ERP·시스템분석·설계', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583528'},
#  {'기업명': '굿커리어',
#   '직무': '대기업 MES(LOT 개발 운영,경북,충북) 대리,과장급 (굿커리어)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38547779'},
#  {'기업명': '제이떠블유커리어(JW career)',
#   '직무': '머신비전 전문기업 딥러닝, AI 연구소(소장급)채용',
#   '경력사항': '경력 10년↑',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579925'},
#  {'기업명': '(주)헬로서치',
#   '직무': '[국내우량기업]딥러닝 개발 인재를 모십니다.',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578846'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자 시스템통합 IT 아웃소싱',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575270'},
#  {'기업명': '(주)잡뉴스솔로몬서치',
#   '직무': '일본어가능 JAVA .NET CS연구개발 경력자',
#   '경력사항': '2 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570183'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '그룹 HR 공유 Infra HRIS 시스템 구축 SaaS 솔루션 클라우드',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569026'},
#  ...]

# %%
company_list_all = company_list_cloud + company_list_python + company_list_db
company_list_all
# Out:
# [{'기업명': '펜타시큐리티시스템(주)',
#   '직무': '[펜타시큐리티] 보안S/W 개발자 모집 (DB, 인증, 클라우드)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595144&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)보고플레이',
#   '직무': '[Live 커머스 플랫폼] PD,MD,마케팅,CS,JAVA,iOS/Android앱개발',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['상품기획·MD', '홍보·PR·사보']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569631&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)레뷰코퍼레이션',
#   '직무': '플랫폼그룹 부문별 신입/경력직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['캐릭터·만화·애니', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38541335&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)시지온',
#   '직무': '라이브리 서비스 광고 플랫폼 개발자 모집',
#   '경력사항': '3 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38593999'},
#  {'기업명': '주식회사 코드베르그',
#   '직무': '코드베르그 Back-end 개발부문 모집 (PHP or Node.js)',
#   '경력사항': '3 ~ 6년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38434985'},
#  {'기업명': '파우게임즈',
#   '직무': '[파우게임즈] 기술지원(DB/웹개발) 담당자 채용',
#   '경력사항': '3 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38406328'},
#  {'기업명': '(주)상록아이엔씨',
#   '직무': '[경험자 우대] Python/Linux AI 시스템 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 부천시',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601843&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)옷딜',
#   '직무': 'Ai솔루션 옷딜 각부분 경력모집',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['기획·전략·경영', '출판·편집디자인']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580264&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)중고나라',
#   '직무': '[중고나라] 개발 부문 전문가 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38573880&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)자비스',
#   '직무': '[코스닥 상장사 ㈜자비스] 2020년 하반기 공개채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 중원구',
#   '분류': "['해외영업·무역영업', '사무보조·문서작성']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578169&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)후이즈',
#   '직무': '㈜후이즈 쇼핑몰 각 부문별 신입/경력 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563638&adsCategoryItem=effect_bold&'},
#  {'기업명': '한국직업전문학교',
#   '직무': '[국비무료/수당지급] 빅데이터/UI/UX 퍼블리싱/응용 S/W 개발자',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '서울 구로구',
#   '분류': "['그래픽디자인·CG', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38393122&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)큐픽스',
#   '직무': '[신입/경력/전문연구요원] AWS/Ruby 백엔드엔지니어(DevOps)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586042'},
#  {'기업명': '네오다임(주)',
#   '직무': '네오다임(주) 웹 개발자 / 웹 디자이너 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38344313'},
#  {'기업명': '(재)충남정보문화산업진흥원',
#   '직무': '2020년 제 3차 계약직 직원채용 공고(연장공고)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '충남 천안시 동남구',
#   '분류': "['기획·전략·경영', '홍보·PR·사보']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539566&adsCategoryItem=effect_bold&'},
#  {'기업명': '주식회사 단비',
#   '직무': 'AI / 머신러닝 / Go / Python / MES 분야별 개발인력 모집합니다',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 해운대구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38377404'},
#  {'기업명': '(주)이지다이아텍',
#   '직무': '[기업부설연구소] 응용소프트웨어 개발자 경력직원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552827'},
#  {'기업명': '(주)매드업',
#   '직무': '[매드업] 하반기 전 직군 대규모 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['인사·교육·노무', '마케팅·광고·분석']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596083&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)이노와이어리스',
#   '직무': '이노와이어리스/큐셀네트웍스 각 분야 신입/경력 채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['생산관리·품질관리', '생산·제조·포장·조립']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590538&adsCategoryItem=effect_bold&'},
#  {'기업명': '패스트캠퍼스(주)',
#   '직무': '[패스트캠퍼스] 대규모 인재 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '마케팅·광고·분석']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38230007'},
#  {'기업명': '(주)선진',
#   '직무': '[하림그룹] ㈜선진 신입/경력 수시채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['회계·재무·세무·IR', '마케팅·광고·분석']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580036'},
#  {'기업명': '(주)세차왕',
#   '직무': '세차왕에서 백엔드 및 웹앱 개발자를 모십니다.',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562173'},
#  {'기업명': '㈜아이티언',
#   '직무': '보안 솔루션 및 서비스 운영 엔지니어(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38414809'},
#  {'기업명': '켈리서비스 유한회사',
#   '직무': '[한국화웨이/영어or중국어] IT Engineer (서버유지보수, ICT)',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 중구',
#   '분류': "['기술영업', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38584624'},
#  {'기업명': '(주)경일게임아카데미',
#   '직무': '게임회사 취업 협약 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38577413&adsCategoryItem=effect_bold&'},
#  {'기업명': '휴먼교육센터학원',
#   '직무': '[전액무료]자바/파이썬 IT교육받고 취업하자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38510654&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)지에스아이티엠',
#   '직무': '2020년 하반기 GS ITM 경력사원 공개채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587357'},
#  {'기업명': '(유)딜리버리히어로 코리아',
#   '직무': '전 개발직군 대규모 채용중',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38476546'},
#  {'기업명': '한국산업단지공단',
#   '직무': '20년 하반기 신입직원/고졸채용형인턴/체험형청년인턴 모집 공고',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '대구 달서구',
#   '분류': "['총무·법무·사무', '회계·재무·세무·IR']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596493'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '[삼성물산/연봉상위] 모바일 앱 및 웹 운영 경력 개발자 채용',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591901'},
#  {'기업명': '(주)안랩',
#   '직무': '2020 하반기 안랩 연구소 신입사원 공개채용',
#   '경력사항': '신입',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578654'},
#  {'기업명': '(주)씨제이이엔엠',
#   '직무': 'CJ ENM(E&M부문) TVING 경력사원 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38515830'},
#  {'기업명': '(주)여우전자',
#   '직무': '여우전자 하반기 신규채용 모집 공고',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['마케팅·광고·분석', '일반영업']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574212'},
#  {'기업명': '(주)넷케이티아이',
#   '직무': '각분야 정규직원 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['기획·전략·경영', '기술영업']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578831'},
#  {'기업명': '(주)볼트홀',
#   '직무': '[2020년 볼트홀] 웹서버 개발자/Javascript,AWS,php,node.js',
#   '경력사항': '5 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 수정구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586962'},
#  {'기업명': '한국전자통신연구원',
#   '직무': '2020년 3차 박사후연수연구원 및 위촉연구원 공개채용',
#   '경력사항': '경력무관',
#   '학력': '석사↑',
#   '근무형태': '계약직',
#   '근무지': '대전 유성구',
#   '분류': "['화학·에너지', '반도체·디스플레이·LCD']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590666'},
#  {'기업명': '(주)월드스폰',
#   '직무': '웹 서비스 유지보수 및 기획자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552512'},
#  {'기업명': '펍지(주)',
#   '직무': '펍지㈜ 각 부문별 수시 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['총무·법무·사무', '인사·교육·노무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38542347'},
#  {'기업명': '(주)후이즈',
#   '직무': '(주)후이즈 도메인사업부 개발자 인재 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528456'},
#  {'기업명': '(주)하나금융티아이',
#   '직무': '[하나금융융합기술원] 부문별 경력사원 모집',
#   '경력사항': '경력',
#   '학력': '석사↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565737'},
#  {'기업명': '㈜해커스교육그룹',
#   '직무': '2020년 해커스 교육그룹 [신입/경력] 각 부문별 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38369849'},
#  {'기업명': '한국직업능력교육원 안산',
#   '직무': '경기/시흥・안산/군포 국비무료 취업연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '경기 안산시 단원구',
#   '분류': "['회계·재무·세무·IR', '생산관리·품질관리']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38527236&adsCategoryItem=effect_bold&'},
#  {'기업명': '한밭대학교산학협력단',
#   '직무': '빅데이터 정보보안 S/W 엔지니어 양성과정',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '대전 유성구',
#   '분류': "['서버·네트워크·보안', '시스템개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38357074'},
#  {'기업명': '(주)아임웹',
#   '직무': 'R&D Team  (PHP 개발자) 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서대문구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560119'},
#  {'기업명': '(주)LG유플러스',
#   '직무': 'IT개발/운영 신입&경력 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533503'},
#  {'기업명': '(주)핀크럭스',
#   '직무': '[부산] 서비스를 함께 만들어 가실 웹개발자를 찾습니다.',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 부산진구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562265'},
#  {'기업명': '(주) 하트게임즈',
#   '직무': '야근無) 게임 서버 Node.js 개발자 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '게임·Game']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574743'},
#  {'기업명': '사운드파이프코리아(주)',
#   '직무': 'H자동차그룹 글로벌 Car Cloud 운영 신입 채용(인도+한국팀)',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38338895'},
#  {'기업명': '사운드파이프코리아(주)',
#   '직무': 'H자동차그룹 카클라우드 리눅스/오픈소스 시스템엔지니어 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38338893'},
#  {'기업명': '사운드파이프코리아(주)',
#   '직무': 'H자동차그룹 Car Cloud (오픈스택+쿠버네티스) 시스템엔지니어',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38338892'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 프로젝트 개발 경력자 대규모 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561876'},
#  {'기업명': '(주)테크데이타',
#   '직무': '[경력] 테크데이타 - AWS 클라우드 엔지니어(SA) 모집',
#   '경력사항': '2 ~ 9년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 용산구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598106'},
#  {'기업명': '리디안솔루션(주)',
#   '직무': 'SAP (Cloud Platform/ CPI / ABAP) 관련 신입, 경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598068'},
#  {'기업명': '(주)트랜스코스모스코리아',
#   '직무': '[월250만/영어우대] MS 클라우드(Azure) 기술지원 엔지니어 Mp3Q',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['사무보조·문서작성', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38470423'},
#  {'기업명': '캐시워크',
#   '직무': '캐시워크와 함께 걸어갈 Node.js 서버 개발자님을 찾습니다',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38597023'},
#  {'기업명': '주식회사 블루에이치알',
#   '직무': '[자회사 정규직] 강남구청역 LGU+ 모바일센터 인바운드 상담',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38446566'},
#  {'기업명': '(주)시지온',
#   '직무': '어트랙트 서비스 자바 백엔드 개발자 모집',
#   '경력사항': '5 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594036'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 네트워크 운영 및 정보보호 담당 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'IT·디자인·컴퓨터교육']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38333581'},
#  {'기업명': '(주)아미크',
#   '직무': '[벤처/강소기업] Cloud Product(AWS) 기획 및 개발 채용',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38593601'},
#  {'기업명': '(주)디모아',
#   '직무': '[쌍방울그룹 계열사] 소프트웨어 영업직 경력/신입 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['IT·솔루션영업', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551426'},
#  {'기업명': '(주)직스엔닥스',
#   '직무': '[개발팀](웹/앱)우수한 React 프론트엔드 개발자 채용 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592735'},
#  {'기업명': '베스핀글로벌(주)',
#   '직무': 'Software QA 채용(경력 3년이상)',
#   '경력사항': '3 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592386'},
#  {'기업명': '주식회사 위주',
#   '직무': '[주식회사위주]놀러와요시장 어플 서버개발 경력직채용(7년이상)',
#   '경력사항': '경력 7년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38466824'},
#  {'기업명': '(주)크로센트',
#   '직무': '클라우드 엔지니어 및 아키텍트 (신입/경력) 정규직 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591760'},
#  {'기업명': '포디리플레이코리아(주)',
#   '직무': '[4DReplay] 클라우드 서비스 및 Platform Back End 개발자 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558326'},
#  {'기업명': '컴즈(주)',
#   '직무': 'S/W QA & Test Engineer 채용의 件',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 구로구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38588604'},
#  {'기업명': '(주)이젠아카데미인재개발원',
#   '직무': '[취업연수 국비교육]자바/파이썬/빅데이터/웹/영상/건축',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['캐릭터·만화·애니', '광고·시각디자인']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=36825236'},
#  {'기업명': '굿어스㈜',
#   '직무': 'Cisco SD-WAN 엔지니어 (경력 2년 이상)',
#   '경력사항': '2 ~ 7년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587238'},
#  {'기업명': '(주)더블다운인터액티브',
#   '직무': '웹/게임서버 개발자(경력), 클라이언트 개발자(신입/경력) 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '게임·Game']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580038'},
#  {'기업명': '(주)민병철교육그룹',
#   '직무': '[민병철유폰] AWS 시스템 엔지니어 (총 경력 5년 이상)',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586234'},
#  {'기업명': '스마일샤크',
#   '직무': '[신입] AWS 솔루션 아키텍트(SA)를 스마일샤크팀으로 모십니다.',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586155'},
#  {'기업명': '(주)에이프릴세븐',
#   '직무': '[스타트업] 서버개발자 채용 공고',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38585353'},
#  {'기업명': '(주)아모레퍼시픽',
#   '직무': "[경력] '20년 AMOREPACIFIC 경력채용_플랫폼 Back-end 개발",
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569683'},
#  {'기업명': '(주)피타소프트',
#   '직무': '2020년 하반기 각 부문 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38542206'},
#  {'기업명': '(주)이노그리드',
#   '직무': '2020 하반기 클라우드 전문기업 이노그리드 신입·경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['상품기획·MD', '홍보·PR·사보']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38415519'},
#  {'기업명': '(주)앨리스헬스케어',
#   '직무': '(경력) 백엔드(Back-end) 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582494'},
#  {'기업명': '호스트웨이아이디씨(주)',
#   '직무': '[정규직] 시스템 엔지니어 모집(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', 'IT·디자인·컴퓨터교육']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582146'},
#  {'기업명': '(주)아모레퍼시픽',
#   '직무': "[경력] '20년 AMOREPACIFIC 경력채용_통합 OMS 기술PM",
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570465'},
#  {'기업명': '(주)하나금융티아이',
#   '직무': '[하나금융TI] 금융IT 경력사원 모집',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '인천전체',
#   '분류': "['기획·전략·경영', '인사·교육·노무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38572965'},
#  {'기업명': '(주)아모레퍼시픽',
#   '직무': "[경력] '20년 AMOREPACIFIC 경력채용_플랫폼 기술 PM",
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570239'},
#  {'기업명': '(주)아톤',
#   '직무': '[ATON] 신규 서비스 개발팀장 / 서버개발 경력 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38553981'},
#  {'기업명': '주식회사 포티투마루',
#   '직무': '[포티투마루] 인공지능 프론트엔드 개발 채용(경력)',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 관악구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580784'},
#  {'기업명': '카이스컴퍼니',
#   '직무': 'React js, AWS, IoT外 1개 부문 개발자 채용 - 정규직&계약직',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '충북 청주시 서원구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580459'},
#  {'기업명': '(주)딤커뮤니케이션',
#   '직무': '[딤커뮤니케이션] 2020년 하반기 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['홍보·PR·사보', '회계·재무·세무·IR']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38464294'},
#  {'기업명': '주식회사 오파테크',
#   '직무': '서버개발 정규직 모집 공고(경력)',
#   '경력사항': '3 ~ 6년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38483345'},
#  {'기업명': '(주)웰데이타시스템',
#   '직무': 'H자동차그룹 Car Cloud(오픈스택+쿠버네티스) 서비스 운영',
#   '경력사항': '3 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579660'},
#  {'기업명': '원투씨엠(주)',
#   '직무': '2020년 하반기 개발자 채용',
#   '경력사항': '5 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533730'},
#  {'기업명': '(주)웰데이타시스템',
#   '직무': '[엔클라우드24] [클라우드&IDC 기술영업/컨설팅/ 공공영업] 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['IT·솔루션영업', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579626'},
#  {'기업명': '(주)웰데이타시스템',
#   '직무': '프런트앤드 앱/웹 자바(JAVA) PHP, 클라우드 서비스 개발자 모집',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579619'},
#  {'기업명': '(주)피처링',
#   '직무': '(정규직) 서버 및 웹 Backend 웹개발자를 채용합니다.',
#   '경력사항': '2 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 연수구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563022'},
#  {'기업명': '소상공인연합회',
#   '직무': '2020년 위탁사업담당 (경력/신입) 직원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '서울 동작구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576477'},
#  {'기업명': '(주)두잇시스템',
#   '직무': 'Linux서버 운영 (서울 강서구, 경력 3년이상)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576103'},
#  {'기업명': '(주)트위그팜',
#   '직무': '웹 개발 (php, laravel 스페셜리스트) 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38549173'},
#  {'기업명': '(주)그로브소프트',
#   '직무': '㈜그로브소프트 2020 하반기 경력직 추가 채용(기획, 개발, 퍼블리셔)',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38566074'},
#  {'기업명': '(주)케어랩스',
#   '직무': '병원갈땐 굿닥) Java 백엔드 서버 개발자 채용',
#   '경력사항': '3 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575281'},
#  {'기업명': '(주)케어랩스',
#   '직무': '병원갈땐 굿닥) PHP서버 개발자 대규모 채용',
#   '경력사항': '5 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575280'},
#  {'기업명': '디딤365 주식회사',
#   '직무': '멀티 클라우드 포털 개발 신입/경력사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575121'},
#  {'기업명': '디딤365 주식회사',
#   '직무': '클라우드 및 시스템 엔지니어 신입/경력(청년내일채움공제 가능)',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575060'},
#  {'기업명': '(주)에스비에스아이앤엠',
#   '직무': 'SBS I&M 인프라 기획 및 AWS 클라우드 시스템 운영관리자 모집',
#   '경력사항': '5 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562661'},
#  {'기업명': '(주)카카오페이',
#   '직무': '[카카오페이] 빅데이터, 하둡(Hadoop)플랫폼 운영 엔지니어 영입',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574921'},
#  {'기업명': '라인게임즈 주식회사',
#   '직무': '[라인게임즈] 기술PM 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574275'},
#  {'기업명': '네오위즈',
#   '직무': '[네오위즈] 각 부문 신입 / 경력자모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['회계·재무·세무·IR', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38447372'},
#  {'기업명': '주식회사오션라이트에이아이',
#   '직무': '서버·네트워크·보안(서버관리&AWS外 3개 부문) 채용합니다',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '대구 북구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38571517'},
#  {'기업명': '스마일샤크',
#   '직무': '[경력] AWS 솔루션 아키텍트(SA)를 스마일샤크팀으로 모십니다.',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38550815'},
#  {'기업명': '(주)웨어포인트',
#   '직무': '(잠실/운영)시스템 엔지니어(SE/TA) 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직 · 프리랜서',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570404'},
#  {'기업명': '(주)디타임',
#   '직무': '(주)디타임 서버개발자 경력직 채용',
#   '경력사항': '6 ~ 20년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565481'},
#  {'기업명': '(주)립페이',
#   '직무': '[정규직] IoT 플랫폼(백엔드) 개발자 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '통신·모바일']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560508'},
#  {'기업명': '(주)엔픽셀',
#   '직무': '[인프라팀] 클라우드 엔지니어 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38413525'},
#  {'기업명': '(주)에스오월드테크놀리지',
#   '직무': '서버관리자(AWS) 채용',
#   '경력사항': '2 ~ 5년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '인턴직',
#   '근무지': '서울 영등포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38568005'},
#  {'기업명': '(주)지에스아이엘',
#   '직무': '(주)지에스아아엘 - 시스템개발팀 경력직 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567524'},
#  {'기업명': '삼양데이타시스템㈜',
#   '직무': '그룹 Infra 분야 운영 인력 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38550753'},
#  {'기업명': '오픈플랜(주)',
#   '직무': '[오픈플랜] back-end Developer 우수 인재를 모십니다.',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38505378'},
#  {'기업명': '베스핀글로벌(주)',
#   '직무': 'BigData 전문인력 채용(경력 5년 이상)',
#   '경력사항': '5 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38566513'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 구글클라우드 부문 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['일반영업', 'IT·솔루션영업']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38409477'},
#  {'기업명': '(주)앨리스헬스케어',
#   '직무': '백엔드(Back-end) 개발자(경력)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565409'},
#  {'기업명': '(주)이카운트',
#   '직무': '㈜이카운트 시스템관리자(SA팀) 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565193'},
#  {'기업명': '쿠팡 주식회사',
#   '직무': '[쿠팡페이] System Engineer',
#   '경력사항': '경력 8년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38398255'},
#  {'기업명': '㈜지에스아이티엠',
#   '직무': 'SE/NE/DBA 경력사원 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38519641'},
#  {'기업명': '(주)크리에이트코리아',
#   '직무': '백엔드 개발자/ 웹 & 모바일 개발자 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중랑구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563318'},
#  {'기업명': '대한상공회의소 광주인력개발원',
#   '직무': '2020년도 국비 기술교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '광주 광산구',
#   '분류': "['기계·기계설비', '전기·전자·제어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38404367'},
#  {'기업명': '대한상공회의소 충남인력개발원',
#   '직무': '4차산업/전기전자/기계설계/자동화 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '충남전체',
#   '분류': "['전기·전자·제어', '설계·CAD·CAM']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38445379'},
#  {'기업명': '오케스트로(주)',
#   '직무': '클라우드연구소 PaaS 엔지니어',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552496'},
#  {'기업명': '이투스교육(주)',
#   '직무': '이투스교육 IT기획직군 공개 채용',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551714'},
#  {'기업명': '(주)푸드테크',
#   '직무': 'IT부문 신입 및 경력사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526283'},
#  {'기업명': '매드업',
#   '직무': '[테크사업부] 백엔드 개발자 채용',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38553452'},
#  {'기업명': '(주) 딥노이드',
#   '직무': '인공지능, 의료영상 연구원 모집[경력, 병역특례 지원가능]',
#   '경력사항': '신입 · 경력',
#   '학력': '석사↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 구로구',
#   '분류': "['인공지능(AI)·빅데이터', '연구소·R&D']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38362204'},
#  {'기업명': '(주)씨알에스큐브',
#   '직무': 'AWS(DevOps) 엔지니어 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561608'},
#  {'기업명': '모나일렉트릭(주)',
#   '직무': '웹개발(Java·JSP/ASP) 채용 공고',
#   '경력사항': '3 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 광명시',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554785'},
#  {'기업명': '(주)판도라티비',
#   '직무': '[ 코박(COBAK) ]  Back-end 개발자 채용',
#   '경력사항': '1 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561269'},
#  {'기업명': '(주)키위플러스',
#   '직무': '서버 Backend 개발자 영입',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560578'},
#  {'기업명': '주식회사 메먼트',
#   '직무': '(연 3000만 이상) 시스템엔지니어 채용',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526643'},
#  {'기업명': '(주)웨어포인트',
#   '직무': '[잠실/운영] DBA 업무 담당자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38559704'},
#  {'기업명': '(주)온빛',
#   '직무': '병원 플랫폼 앱 개발자 모집 (안드로이드/iOS/백엔드)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대구 북구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38534946'},
#  {'기업명': '아카라코리아',
#   '직무': 'AWS 플랫폼기반 서비스운영 정규직 모집(경력사원)',
#   '경력사항': '경력 10년↓',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38559238'},
#  {'기업명': '주식회사 미로',
#   '직무': '(주)미로 IoT & 스마트홈 개발자채용 (신입/경력/전문연구요원)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '인천 연수구',
#   '분류': "['전기·전자·제어', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38559164'},
#  {'기업명': '충북대학교',
#   '직무': '[국비무료]취업연계 채용예정자 양성 과정 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '충북 청주시',
#   '분류': "['상품기획·MD', '기획·전략·경영']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38460768'},
#  {'기업명': '(주)바디프랜드',
#   '직무': '(주)바디프랜드 AI/서버/퍼블리셔/아이폰/프론트/기획 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554220'},
#  {'기업명': '(주)소프트웨어인라이프',
#   '직무': '[Docswave] 2020년 하반기 프리세일즈 채용 (경력)',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '하드웨어·소프트웨어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38477097'},
#  {'기업명': '이원다이애그노믹스(주)',
#   '직무': 'EDGC : 글로벌R&D본부 IT팀 인재 채용 件',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38489038'},
#  {'기업명': '(주)인터웹',
#   '직무': '4차산업혁명 기반의 신사업 참여 개발자 모집',
#   '경력사항': '경력 6년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38553142'},
#  {'기업명': '케이웨어(주)',
#   '직무': '[R&D] 연구과제 기획/관리',
#   '경력사항': '신입 · 경력',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551504'},
#  {'기업명': '이투스교육(주)',
#   '직무': '이투스교육 8월 개발자 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38545141'},
#  {'기업명': '(주)아이아이컴바인드',
#   '직무': '젠틀몬스터 백엔드&PHP 정규직 채용(경력/신입)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38412821'},
#  {'기업명': '주식회사 메디칼파크',
#   '직무': '응용소프트웨어 프로그래머 연구원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 용인시 수지구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38353503'},
#  {'기업명': '아토리서치(주)',
#   '직무': '[아토리서치]전문연구요원(병역특례) 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38545903'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 개발 경력자 대규모 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37872627'},
#  {'기업명': '오케스트로(주)',
#   '직무': '(경력) 인공지능 연구소 플랫폼 개발팀 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38532722'},
#  {'기업명': '㈜안랩',
#   '직무': '[안랩] DevOps 엔지니어 모집',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38538973'},
#  {'기업명': '타이트(주)',
#   '직무': '타이트(주) 제품개발팀 백엔드 / 웹 개발자 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대구 남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533831'},
#  {'기업명': '클라우드그램(주)',
#   '직무': '[클라우드그램] 경영지원',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['사무보조·문서작성', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38364180'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존클라우드] Mass Migration Center 부문별 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['IT·솔루션영업', '서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38348572'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] DMP(데이터 관리 플랫폼) 개발',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38405474'},
#  {'기업명': '(주)아이뱅크',
#   '직무': '클라우드/DataAnalysis/로그분석外 정규직 채용 - 경력사원',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38380134'},
#  {'기업명': '(주)아이담',
#   '직무': '개발본부 백엔드 개발자(Node.js) 경력직 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533890'},
#  {'기업명': '(주)두댓',
#   '직무': '반려동물 서버 프로그래머 경력직 채용',
#   '경력사항': '경력 10년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38532714'},
#  {'기업명': '㈜날리지큐브',
#   '직무': '날리지큐브 2020년 클라우드 신입/경력 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38527975'},
#  {'기업명': '(주)소셜라디오컴퍼니',
#   '직무': '[글로벌 라이브·레코드 오디오기반 소셜앱] Backend개발자모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38506920'},
#  {'기업명': '주식회사 해줌',
#   '직무': '고객관리 시스템 백엔드 개발자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38394524'},
#  {'기업명': '에스피테크놀러지',
#   '직무': '에스피테크놀러지(주) AR/VR 개발자 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 관악구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38524760'},
#  {'기업명': '에스피테크놀러지',
#   '직무': '에스피테크놀러지(주) 프론트엔드&백엔드 개발',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 관악구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38524705'},
#  {'기업명': '에스피테크놀러지',
#   '직무': '에스피테크놀러지(주) Java 개발자 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 관악구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38523836'},
#  {'기업명': '디딤365 주식회사',
#   '직무': 'AWS 클라우드 기술영업 신입사원 모집',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['IT·솔루션영업', '기술영업']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38523449'},
#  {'기업명': '(주)모비젠',
#   '직무': '(주)모비젠 부문별 개발자 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38523366'},
#  {'기업명': '모티프컨설팅',
#   '직무': '대기업 AWS 엔지니어 (클라우드 아키텍트/클라우드데이터엔지니',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38522797'},
#  {'기업명': '(주)락플레이스',
#   '직무': 'Azure 엔지니어 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38520918'},
#  {'기업명': '굿어스데이터(주)',
#   '직무': 'Cloud 엔지니어 경력 3년 이상',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38520348'},
#  {'기업명': '조이시티',
#   '직무': '[JOYCITY] 플랫폼 서버 개발자 모집 (경력무관)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38519268'},
#  {'기업명': '(주)필로시스생명과학',
#   '직무': '[정규직] 서버개발자 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38516156'},
#  {'기업명': '(주)스쿱미디어',
#   '직무': 'AWS엔지니어 채용 경력 모집(정규직)',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38511682'},
#  {'기업명': '(주)오케이산업',
#   '직무': 'AWS/PHP 정규직 채용 - 경력',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 부천시',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38511008'},
#  {'기업명': '(주)뉴트리션코트',
#   '직무': '백엔드개발 경력직 채용',
#   '경력사항': '1 ~ 8년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38355299'},
#  {'기업명': '(주)아르카에이치알',
#   '직무': '[WinnersK] 서비스 플랫폼 연구소 중급개발자 모집',
#   '경력사항': '3 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38508488'},
#  {'기업명': '(주)위메프',
#   '직무': '[보안]클라우드 보안운영 담당자(정규직)',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37608770'},
#  {'기업명': '(주)위메프',
#   '직무': '[개발]위메프 시스템엔지니어(정규직)',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38502145'},
#  {'기업명': '(주)위메프',
#   '직무': '[개발]위메프오 DevOps Engineer(정규직)',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38502034'},
#  {'기업명': '(주)코레이즈',
#   '직무': '[신입/경력] 클라우드팀 채용 (SaaS · S/W)',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직 · 인턴직',
#   '근무지': '서울 성동구',
#   '분류': "['IT·솔루션영업', '하드웨어·소프트웨어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38500624'},
#  {'기업명': '(주)원더피플',
#   '직무': '글로벌 플랫폼 서버 개발자 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '게임·Game']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38497413'},
#  {'기업명': '(주)데브툴즈',
#   '직무': 'Back end 개발자 정규직 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38485192'},
#  {'기업명': '아토리서치(주)',
#   '직무': '인공지능/머신러닝 개발 및 클라우드/네트워크 개발',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38494339'},
#  {'기업명': '컴즈(주)',
#   '직무': 'S/W Test & QA Engineer 채용의 件',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 프리랜서',
# ...
#  {'기업명': '(주)동연에스엔티',
#   '직무': '스마트공장 솔루션 개발 및 데이터 분석가 모집 (정규직&계약직)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '부산 동래구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38312448'},
#  {'기업명': '디지털원(주)',
#   '직무': 'IT강사님 모집합니다. ( JAVA, 빅데이터, 파이썬 외)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 전임',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38312302'},
#  {'기업명': '㈜인텔리코드',
#   '직무': 'AWS Serverless 기반 Web 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38311019'},
#  {'기업명': '(주)애드펄스',
#   '직무': '웹개발(프론트엔드/백엔드/PHP/Ajax) 채용(카페24 파트너사)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38310015'},
#  {'기업명': '㈜알앤비소프트',
#   '직무': '금융SI부문,의료SI부문,정부공공기관SI부문 프로젝트 3년 이상',
#   '경력사항': '3 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578081'},
#  {'기업명': '(주)코리아센터',
#   '직무': 'PHP 웹 개발자 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38602736'},
#  {'기업명': '(주)리퓨터',
#   '직무': '웹&앱개발, 빅데이터&인공지능 외 경력직/중급 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '전북 익산시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38602675'},
#  {'기업명': '(주)아톰소프트',
#   '직무': '응용프로그램 및 웹개발 인재 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38602613'},
#  {'기업명': '(주)아이티공간',
#   '직무': '응용프로그램/웹 개발  3년차 이상 경력자 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '울산 남구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38602603'},
#  {'기업명': '(주)아이오티플렉스',
#   '직무': '[기업부설연구소]GPS Tracker 펌웨어개발 경력자 채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '부산 해운대구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38602556'},
#  {'기업명': '㈜키트넷',
#   '직무': '설비공정 프로세스관리 C#',
#   '경력사항': '1 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '충남 천안시 서북구',
#   '분류': "['웹개발', '컨텐츠·사이트운영']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594524'},
#  {'기업명': '㈜키트넷',
#   '직무': '천안 C#.net 운영  초급 모집',
#   '경력사항': '1 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '충남 천안시 서북구',
#   '분류': "['웹개발', '컨텐츠·사이트운영']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594568'},
#  {'기업명': '㈜키트넷',
#   '직무': '초급,부산지역 Java ,C#.Net, VB.Net, ASP, Shell Script 모집',
#   '경력사항': '1 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '부산 강서구',
#   '분류': "['웹개발', '컨텐츠·사이트운영']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594623'},
#  {'기업명': '비엔비컴퍼니(주)',
#   '직무': 'PHP/JAVA 웹 개발 및 안드로이드 APP 개발',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38556561'},
#  {'기업명': '(주)솔릭',
#   '직무': '프로그램 개발자를 모집합니다.',
#   '경력사항': '2 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601782'},
#  {'기업명': '주식회사 와이즈인컴퍼니',
#   '직무': '데이터분석 신입/경력직원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터', '설문·통계·리서치']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38564488'},
#  {'기업명': '(주)펨트론',
#   '직무': '기업부설연구소 (응용프로그래머, 영상처리, AI) 전문연구요원',
#   '경력사항': '신입',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['응용프로그램개발', 'IT·디자인·컴퓨터교육']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38480051'},
#  {'기업명': '(주)펨트론',
#   '직무': '응용프로그래머 및 머신비전, 알고리즘, 영상처리, AI 개발자',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['응용프로그램개발', 'IT·디자인·컴퓨터교육']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38480047'},
#  {'기업명': '(주)알리아스',
#   '직무': '[앱/PC] 얼굴에 AR 소스 붙이는 개발자 모집(반상주 가능)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경남 김해시',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38404652'},
#  {'기업명': '(주)지오블루랩',
#   '직무': '[경력] 웹 개발자 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38409662'},
#  {'기업명': '소스팜(주)',
#   '직무': '[경력] 웹퍼블리셔 모집',
#   '경력사항': '2 ~ 4년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38444559'},
#  {'기업명': '소스팜(주)',
#   '직무': '[경력] 웹 개발자 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38409640'},
#  {'기업명': '(주)에이치포테크',
#   '직무': '빅데이터 처리 및 웹백ㅇ 소프트웨어 개발 신입/경력 채용(정규',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38600890'},
#  {'기업명': '(주)피플커넥트',
#   '직무': '2020년 기술개발팀 JAVA 개발자 채용',
#   '경력사항': '3 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594043'},
#  {'기업명': '(주)여우전자',
#   '직무': '여우전자 하반기 신규채용 모집 공고',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['마케팅·광고·분석', '일반영업']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574212'},
#  {'기업명': '트리컴퍼니',
#   '직무': '반응형 웹 개발/기획 실무자 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560823'},
#  {'기업명': '(주)좋은정보기술',
#   '직무': '인공지능 및 빅데이터 사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '전북 전주시 덕진구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38303071'},
#  {'기업명': '(주)키즈노트',
#   '직무': '키즈노트 웹 프론트엔드 개발자 채용(경력직)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '퍼블리싱·UI개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38600508'},
#  {'기업명': '주식회사 포티투마루',
#   '직무': '[포티투마루] 전문연구요원 병역특례 개발자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 관악구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38217300'},
#  {'기업명': '㈜더아이엠씨',
#   '직무': '2020년 8월 더아이엠씨 AI R팀 & 데이터사이언스 연구소 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대구 수성구',
#   '분류': "['기획·전략·경영', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38600153'},
#  {'기업명': '(주)딥인스펙션',
#   '직무': '딥러닝 기반 S/W 개발자 채용(팀장급,사원)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599517'},
#  {'기업명': '(주)씨티아이랩',
#   '직무': '인공지능/데이터사이언스(AI/Data Science) 신입/경력',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599115'},
#  {'기업명': '(주)이피엠솔루션즈',
#   '직무': 'SW개발 경력자 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '울산 남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598662'},
#  {'기업명': '(주)폰템',
#   '직무': '[주식회사 리앤노 하반기 경력직 WEB개발자(백엔드) 채용]',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598552'},
#  {'기업명': '(주)사이버테크프랜드',
#   '직무': '스마트팩토리 MES/POP 개발 .C#(WinForm,asp.net) 경력',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 하남시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598425'},
#  {'기업명': '(주)앱도',
#   '직무': '(주)앱도 RPA/소프트웨어 개발 프로그래머 직원 증원 채용 공고',
#   '경력사항': '1 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '부산 동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598339'},
#  {'기업명': '(주)제오시스',
#   '직무': '소프트웨어 개발자 경력 및 신입 정규채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '충북 청주시 흥덕구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38547606'},
#  {'기업명': '시어스랩',
#   '직무': '[병역특례가능] React Native 모바일 개발자 /  iOS앱 개발 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['게임·Game', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38597494'},
#  {'기업명': '(주)파이낸셜데이타시스템',
#   '직무': '(경력 3년이상/인덕원) NH농협차세대 수탁 개발자 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '프리랜서',
#   '근무지': '경기 의왕시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38597479'},
#  {'기업명': '메이븐코리아(주)',
#   '직무': '데이터 모델링 개발자 채용',
#   '경력사항': '3 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596958'},
#  {'기업명': '디랩',
#   '직무': '코딩교육연구원 정규직/인턴직 채용 (잠실캠퍼스)',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '서울 송파구',
#   '분류': "['웹개발', 'IT·디자인·컴퓨터교육']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38501067'},
#  {'기업명': '(주)오픈이노베이션랩',
#   '직무': '인공지능 AI 공공기관 프로젝트 사업관리 신규/경력직 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['웹기획·PM', 'IT·디자인·컴퓨터교육']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587448'},
#  {'기업명': '(주)앱도',
#   '직무': '(주)앱도 RPA / 소프트웨어 프로그래머 직원 증원 채용 공고',
#   '경력사항': '1 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '부산 동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596730'},
#  {'기업명': '주식회사 먹깨비',
#   '직무': '경기도 공공배달앱 웹,모바일분야 개발자 및 웹디자이너 추가채',
#   '경력사항': '1 ~ 10년',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595273'},
#  {'기업명': '(주)클래스소프트',
#   '직무': '응용프로그램개발 정규직 채용(경력)',
#   '경력사항': '경력 7년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38577662'},
#  {'기업명': '(주)지팡이',
#   '직무': '[전산실] 웹프로그래머(경력)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594853'},
#  {'기업명': '(주)알체라',
#   '직무': '기술연구소 딥러닝 연구개발자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594445'},
#  {'기업명': '(주)나이츠넷',
#   '직무': '[정규직]강소기업(주)나이츠넷 소프트웨어 JAVA 웹개발 경력자',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594432'},
#  {'기업명': '(주)미래새한감정평가법인',
#   '직무': '(주)미래새한감정평가법인 전산개발팀 경력 채용',
#   '경력사항': '1 ~ 4년',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38517930'},
#  {'기업명': '(주)알체라',
#   '직무': '프론트엔드 개발자 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594133'},
#  {'기업명': '(주)시지온',
#   '직무': '어트랙트 서비스 자바 백엔드 개발자 모집',
#   '경력사항': '5 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594036'},
#  {'기업명': '(주)시지온',
#   '직무': '어트랙트 서비스 프론트엔드 개발자 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594005'},
#  {'기업명': '(주)엠넥스',
#   '직무': '[연구소] 서버 및 어플리케이션(백엔드&프론트엔드)',
#   '경력사항': '2 ~ 15년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38527661'},
#  {'기업명': '(주)도서출판길벗',
#   '직무': 'IT 자원 관리와 웹 서비스 개발 담당 경력직 채용',
#   '경력사항': '2 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38532538'},
#  {'기업명': '(주)지아이컴퍼니',
#   '직무': '2020년 소프트웨어 개발자 채용공고',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569955'},
#  {'기업명': '이노데이터',
#   '직무': 'ios,android 개발자 채용 공고',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '대구 북구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38477612'},
#  {'기업명': '㈜더아이엠씨',
#   '직무': '2020년 8월 더아이엠씨 본부장(이사급) 채용',
#   '경력사항': '경력 10년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대구 수성구',
#   '분류': "['기획·전략·경영', '웹개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592250'},
#  {'기업명': '주식회사 오늘앤파트너스',
#   '직무': '[정규직] 블록체인 개발자 경력사원 채용 공고',
#   '경력사항': '1 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38568301'},
#  {'기업명': '포디리플레이코리아(주)',
#   '직무': '[4DReplay] 안드로이드(Android) 개발자 모집',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38573730'},
#  {'기업명': '(주)카비',
#   '직무': 'Back-End, Front-End 개발자 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '통신·모바일']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590046'},
#  {'기업명': '베스핀글로벌(주)',
#   '직무': 'Cloud Operations Engineer(NBP) 채용(경력 3년이상)',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589940'},
#  ...]

# %%
import pymysql
import sqlalchemy
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("mysql+mysqldb://minji:"+"minji"+"@192.168.0.25:3306/poor_db", encoding="utf-8")
conn = engine.connect()

jobs_dict = {"jobs_cloud": company_list_cloud, "jobs_python": company_list_python, "jobs_db": company_list_db}

for table_name, jobs in jobs_dict.items():
    print("\n", table_name, "\n")
    jobs_df = pd.DataFrame(columns=['기업명', '직무', '경력사항', '학력', '근무형태', '근무지', '분류', '상세링크'])
    
    for post in jobs:
        obj = pd.Series(post)
        jobs_df = jobs_df.append(obj, ignore_index=True)
        print(post)
    
    jobs_df.to_sql(name=table_name, con=engine, if_exists='replace', index=False, index_label='id')
# Out:
#  jobs_cloud
#
# {'기업명': '펜타시큐리티시스템(주)', '직무': '[펜타시큐리티] 보안S/W 개발자 모집 (DB, 인증, 클라우드)', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직 · 계약직', '근무지': '서울 영등포구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595144&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)보고플레이', '직무': '[Live 커머스 플랫폼] PD,MD,마케팅,CS,JAVA,iOS/Android앱개발', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['상품기획·MD', '홍보·PR·사보']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569631&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)레뷰코퍼레이션', '직무': '플랫폼그룹 부문별 신입/경력직 채용', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['캐릭터·만화·애니', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38541335&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)시지온', '직무': '라이브리 서비스 광고 플랫폼 개발자 모집', '경력사항': '3 ~ 15년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38593999'}
# {'기업명': '주식회사 코드베르그', '직무': '코드베르그 Back-end 개발부문 모집 (PHP or Node.js)', '경력사항': '3 ~ 6년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38434985'}
# {'기업명': '파우게임즈', '직무': '[파우게임즈] 기술지원(DB/웹개발) 담당자 채용', '경력사항': '3 ~ 5년', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38406328'}
# {'기업명': '(주)상록아이엔씨', '직무': '[경험자 우대] Python/Linux AI 시스템 개발자 채용', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 부천시', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601843&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)옷딜', '직무': 'Ai솔루션 옷딜 각부분 경력모집', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['기획·전략·경영', '출판·편집디자인']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580264&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)중고나라', '직무': '[중고나라] 개발 부문 전문가 채용', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38573880&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)자비스', '직무': '[코스닥 상장사 ㈜자비스] 2020년 하반기 공개채용', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 중원구', '분류': "['해외영업·무역영업', '사무보조·문서작성']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578169&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)후이즈', '직무': '㈜후이즈 쇼핑몰 각 부문별 신입/경력 정규직 채용', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 구로구', '분류': "['기획·전략·경영', '사무보조·문서작성']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563638&adsCategoryItem=effect_bold&'}
# {'기업명': '한국직업전문학교', '직무': '[국비무료/수당지급] 빅데이터/UI/UX 퍼블리싱/응용 S/W 개발자', '경력사항': '경력무관', '학력': '고졸↑', '근무형태': '교육생', '근무지': '서울 구로구', '분류': "['그래픽디자인·CG', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38393122&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)큐픽스', '직무': '[신입/경력/전문연구요원] AWS/Ruby 백엔드엔지니어(DevOps)', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586042'}
# {'기업명': '네오다임(주)', '직무': '네오다임(주) 웹 개발자 / 웹 디자이너 모집', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38344313'}
# {'기업명': '(재)충남정보문화산업진흥원', '직무': '2020년 제 3차 계약직 직원채용 공고(연장공고)', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '계약직', '근무지': '충남 천안시 동남구', '분류': "['기획·전략·경영', '홍보·PR·사보']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539566&adsCategoryItem=effect_bold&'}
# {'기업명': '주식회사 단비', '직무': 'AI / 머신러닝 / Go / Python / MES 분야별 개발인력 모집합니다', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '부산 해운대구', '분류': "['웹개발', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38377404'}
# {'기업명': '(주)이지다이아텍', '직무': '[기업부설연구소] 응용소프트웨어 개발자 경력직원 모집', '경력사항': '신입 · 경력', '학력': '대학(2,3년)↑', '근무형태': '정규직 · 병역특례', '근무지': '경기 안양시 동안구', '분류': "['응용프로그램개발', '시스템개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552827'}
# {'기업명': '(주)매드업', '직무': '[매드업] 하반기 전 직군 대규모 채용', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['인사·교육·노무', '마케팅·광고·분석']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596083&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)이노와이어리스', '직무': '이노와이어리스/큐셀네트웍스 각 분야 신입/경력 채용', '경력사항': '경력무관', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['생산관리·품질관리', '생산·제조·포장·조립']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590538&adsCategoryItem=effect_bold&'}
# {'기업명': '패스트캠퍼스(주)', '직무': '[패스트캠퍼스] 대규모 인재 채용', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['기획·전략·경영', '마케팅·광고·분석']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38230007'}
# {'기업명': '(주)선진', '직무': '[하림그룹] ㈜선진 신입/경력 수시채용', '경력사항': '경력 2년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울전체', '분류': "['회계·재무·세무·IR', '마케팅·광고·분석']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580036'}
# {'기업명': '(주)세차왕', '직무': '세차왕에서 백엔드 및 웹앱 개발자를 모십니다.', '경력사항': '경력 2년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562173'}
# {'기업명': '㈜아이티언', '직무': '보안 솔루션 및 서비스 운영 엔지니어(신입/경력)', '경력사항': '신입 · 경력', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '경기 안양시 동안구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38414809'}
# {'기업명': '켈리서비스 유한회사', '직무': '[한국화웨이/영어or중국어] IT Engineer (서버유지보수, ICT)', '경력사항': '경력 1년↑', '학력': '대학교(4년)↑', '근무형태': '계약직 · 파견직', '근무지': '서울 중구', '분류': "['기술영업', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38584624'}
# {'기업명': '(주)경일게임아카데미', '직무': '게임회사 취업 협약 교육생 모집', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '교육생', '근무지': '서울전체', '분류': "['서버·네트워크·보안', '웹기획·PM']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38577413&adsCategoryItem=effect_bold&'}
# {'기업명': '휴먼교육센터학원', '직무': '[전액무료]자바/파이썬 IT교육받고 취업하자', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '교육생', '근무지': '서울전체', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38510654&adsCategoryItem=effect_bold&'}
# {'기업명': '(주)지에스아이티엠', '직무': '2020년 하반기 GS ITM 경력사원 공개채용', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 종로구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587357'}
# {'기업명': '(유)딜리버리히어로 코리아', '직무': '전 개발직군 대규모 채용중', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['기획·전략·경영', '총무·법무·사무']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38476546'}
# {'기업명': '한국산업단지공단', '직무': '20년 하반기 신입직원/고졸채용형인턴/체험형청년인턴 모집 공고', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직 · 계약직', '근무지': '대구 달서구', '분류': "['총무·법무·사무', '회계·재무·세무·IR']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596493'}
# {'기업명': '(주)맨파워그룹코리아', '직무': '[삼성물산/연봉상위] 모바일 앱 및 웹 운영 경력 개발자 채용', '경력사항': '3 ~ 20년', '학력': '학력무관', '근무형태': '계약직 · 파견직', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591901'}
# {'기업명': '(주)안랩', '직무': '2020 하반기 안랩 연구소 신입사원 공개채용', '경력사항': '신입', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578654'}
# {'기업명': '(주)씨제이이엔엠', '직무': 'CJ ENM(E&M부문) TVING 경력사원 모집', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38515830'}
# {'기업명': '(주)여우전자', '직무': '여우전자 하반기 신규채용 모집 공고', '경력사항': '신입 · 경력', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['마케팅·광고·분석', '일반영업']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574212'}
# {'기업명': '(주)넷케이티아이', '직무': '각분야 정규직원 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['기획·전략·경영', '기술영업']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578831'}
# {'기업명': '(주)볼트홀', '직무': '[2020년 볼트홀] 웹서버 개발자/Javascript,AWS,php,node.js', '경력사항': '5 ~ 10년', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 수정구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586962'}
# {'기업명': '한국전자통신연구원', '직무': '2020년 3차 박사후연수연구원 및 위촉연구원 공개채용', '경력사항': '경력무관', '학력': '석사↑', '근무형태': '계약직', '근무지': '대전 유성구', '분류': "['화학·에너지', '반도체·디스플레이·LCD']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38590666'}
# {'기업명': '(주)월드스폰', '직무': '웹 서비스 유지보수 및 기획자 모집', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹기획·PM']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552512'}
# {'기업명': '펍지(주)', '직무': '펍지㈜ 각 부문별 수시 채용', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['총무·법무·사무', '인사·교육·노무']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38542347'}
# {'기업명': '(주)후이즈', '직무': '(주)후이즈 도메인사업부 개발자 인재 채용', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 구로구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528456'}
# {'기업명': '(주)하나금융티아이', '직무': '[하나금융융합기술원] 부문별 경력사원 모집', '경력사항': '경력', '학력': '석사↑', '근무형태': '정규직 · 계약직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹기획·PM']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565737'}
# {'기업명': '㈜해커스교육그룹', '직무': '2020년 해커스 교육그룹 [신입/경력] 각 부문별 채용공고', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직 · 계약직', '근무지': '서울 서초구', '분류': "['기획·전략·경영', '총무·법무·사무']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38369849'}
# {'기업명': '한국직업능력교육원 안산', '직무': '경기/시흥・안산/군포 국비무료 취업연수생 모집', '경력사항': '경력무관', '학력': '고졸↑', '근무형태': '교육생', '근무지': '경기 안산시 단원구', '분류': "['회계·재무·세무·IR', '생산관리·품질관리']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38527236&adsCategoryItem=effect_bold&'}
# {'기업명': '한밭대학교산학협력단', '직무': '빅데이터 정보보안 S/W 엔지니어 양성과정', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '교육생', '근무지': '대전 유성구', '분류': "['서버·네트워크·보안', '시스템개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38357074'}
# {'기업명': '(주)아임웹', '직무': 'R&D Team  (PHP 개발자) 신입/경력 채용', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서대문구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560119'}
# {'기업명': '(주)LG유플러스', '직무': 'IT개발/운영 신입&경력 개발자 채용', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울전체', '분류': "['웹기획·PM', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533503'}
# {'기업명': '(주)핀크럭스', '직무': '[부산] 서비스를 함께 만들어 가실 웹개발자를 찾습니다.', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '부산 부산진구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562265'}
# {'기업명': '(주) 하트게임즈', '직무': '야근無) 게임 서버 Node.js 개발자 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '게임·Game']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574743'}
# {'기업명': '사운드파이프코리아(주)', '직무': 'H자동차그룹 글로벌 Car Cloud 운영 신입 채용(인도+한국팀)', '경력사항': '신입', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38338895'}
# {'기업명': '사운드파이프코리아(주)', '직무': 'H자동차그룹 카클라우드 리눅스/오픈소스 시스템엔지니어 채용', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38338893'}
# {'기업명': '사운드파이프코리아(주)', '직무': 'H자동차그룹 Car Cloud (오픈스택+쿠버네티스) 시스템엔지니어', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38338892'}
# {'기업명': '메가존(주)', '직무': '[메가존] 프로젝트 개발 경력자 대규모 채용', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직 · 병역특례', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', '웹기획·PM']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561876'}
# {'기업명': '(주)테크데이타', '직무': '[경력] 테크데이타 - AWS 클라우드 엔지니어(SA) 모집', '경력사항': '2 ~ 9년', '학력': '대학(2,3년)↑', '근무형태': '정규직 · 계약직', '근무지': '서울 용산구', '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598106'}
# {'기업명': '리디안솔루션(주)', '직무': 'SAP (Cloud Platform/ CPI / ABAP) 관련 신입, 경력 채용', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['응용프로그램개발', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38598068'}
# {'기업명': '(주)트랜스코스모스코리아', '직무': '[월250만/영어우대] MS 클라우드(Azure) 기술지원 엔지니어 Mp3Q', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 종로구', '분류': "['사무보조·문서작성', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38470423'}
# {'기업명': '캐시워크', '직무': '캐시워크와 함께 걸어갈 Node.js 서버 개발자님을 찾습니다', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38597023'}
# {'기업명': '주식회사 블루에이치알', '직무': '[자회사 정규직] 강남구청역 LGU+ 모바일센터 인바운드 상담', '경력사항': '경력무관', '학력': '고졸↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['응용프로그램개발', '시스템개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38446566'}
# {'기업명': '(주)시지온', '직무': '어트랙트 서비스 자바 백엔드 개발자 모집', '경력사항': '5 ~ 15년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38594036'}
# {'기업명': '메가존(주)', '직무': '[메가존] 네트워크 운영 및 정보보호 담당 채용', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직 · 병역특례', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', 'IT·디자인·컴퓨터교육']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38333581'}
# {'기업명': '(주)아미크', '직무': '[벤처/강소기업] Cloud Product(AWS) 기획 및 개발 채용', '경력사항': '경력 4년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 성동구', '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38593601'}
# {'기업명': '(주)디모아', '직무': '[쌍방울그룹 계열사] 소프트웨어 영업직 경력/신입 채용', '경력사항': '신입 · 경력', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 용산구', '분류': "['IT·솔루션영업', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551426'}
# {'기업명': '(주)직스엔닥스', '직무': '[개발팀](웹/앱)우수한 React 프론트엔드 개발자 채용 모집', '경력사항': '경력무관', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592735'}
# {'기업명': '베스핀글로벌(주)', '직무': 'Software QA 채용(경력 3년이상)', '경력사항': '3 ~ 12년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592386'}
# {'기업명': '주식회사 위주', '직무': '[주식회사위주]놀러와요시장 어플 서버개발 경력직채용(7년이상)', '경력사항': '경력 7년↑', '학력': '고졸↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38466824'}
# {'기업명': '(주)크로센트', '직무': '클라우드 엔지니어 및 아키텍트 (신입/경력) 정규직 모집', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591760'}
# {'기업명': '포디리플레이코리아(주)', '직무': '[4DReplay] 클라우드 서비스 및 Platform Back End 개발자 모집', '경력사항': '3 ~ 10년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558326'}
# {'기업명': '컴즈(주)', '직무': 'S/W QA & Test Engineer 채용의 件', '경력사항': '신입 · 경력', '학력': '대학(2,3년)↑', '근무형태': '정규직 · 프리랜서', '근무지': '서울 구로구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38588604'}
# {'기업명': '(주)이젠아카데미인재개발원', '직무': '[취업연수 국비교육]자바/파이썬/빅데이터/웹/영상/건축', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '교육생', '근무지': '서울전체', '분류': "['캐릭터·만화·애니', '광고·시각디자인']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=36825236'}
# {'기업명': '굿어스㈜', '직무': 'Cisco SD-WAN 엔지니어 (경력 2년 이상)', '경력사항': '2 ~ 7년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587238'}
# {'기업명': '(주)더블다운인터액티브', '직무': '웹/게임서버 개발자(경력), 클라이언트 개발자(신입/경력) 모집', '경력사항': '경력무관', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '게임·Game']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580038'}
# {'기업명': '(주)민병철교육그룹', '직무': '[민병철유폰] AWS 시스템 엔지니어 (총 경력 5년 이상)', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586234'}
# {'기업명': '스마일샤크', '직무': '[신입] AWS 솔루션 아키텍트(SA)를 스마일샤크팀으로 모십니다.', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586155'}
# {'기업명': '(주)에이프릴세븐', '직무': '[스타트업] 서버개발자 채용 공고', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38585353'}
# {'기업명': '(주)아모레퍼시픽', '직무': "[경력] '20년 AMOREPACIFIC 경력채용_플랫폼 Back-end 개발", '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 용산구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569683'}
# {'기업명': '(주)피타소프트', '직무': '2020년 하반기 각 부문 채용', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['기획·전략·경영', '총무·법무·사무']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38542206'}
# {'기업명': '(주)이노그리드', '직무': '2020 하반기 클라우드 전문기업 이노그리드 신입·경력 채용', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['상품기획·MD', '홍보·PR·사보']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38415519'}
# {'기업명': '(주)앨리스헬스케어', '직무': '(경력) 백엔드(Back-end) 개발자', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582494'}
# {'기업명': '호스트웨이아이디씨(주)', '직무': '[정규직] 시스템 엔지니어 모집(신입/경력)', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', 'IT·디자인·컴퓨터교육']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582146'}
# {'기업명': '(주)아모레퍼시픽', '직무': "[경력] '20년 AMOREPACIFIC 경력채용_통합 OMS 기술PM", '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 용산구', '분류': "['서버·네트워크·보안', '웹기획·PM']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570465'}
# {'기업명': '(주)하나금융티아이', '직무': '[하나금융TI] 금융IT 경력사원 모집', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직 · 계약직', '근무지': '인천전체', '분류': "['기획·전략·경영', '인사·교육·노무']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38572965'}
# {'기업명': '(주)아모레퍼시픽', '직무': "[경력] '20년 AMOREPACIFIC 경력채용_플랫폼 기술 PM", '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 용산구', '분류': "['웹기획·PM', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570239'}
# {'기업명': '(주)아톤', '직무': '[ATON] 신규 서비스 개발팀장 / 서버개발 경력 채용', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['서버·네트워크·보안', '웹기획·PM']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38553981'}
# {'기업명': '주식회사 포티투마루', '직무': '[포티투마루] 인공지능 프론트엔드 개발 채용(경력)', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 관악구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580784'}
# {'기업명': '카이스컴퍼니', '직무': 'React js, AWS, IoT外 1개 부문 개발자 채용 - 정규직&계약직', '경력사항': '경력무관', '학력': '대학(2,3년)↑', '근무형태': '정규직 · 계약직', '근무지': '충북 청주시 서원구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580459'}
# {'기업명': '(주)딤커뮤니케이션', '직무': '[딤커뮤니케이션] 2020년 하반기 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['홍보·PR·사보', '회계·재무·세무·IR']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38464294'}
# {'기업명': '주식회사 오파테크', '직무': '서버개발 정규직 모집 공고(경력)', '경력사항': '3 ~ 6년', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 성동구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38483345'}
# {'기업명': '(주)웰데이타시스템', '직무': 'H자동차그룹 Car Cloud(오픈스택+쿠버네티스) 서비스 운영', '경력사항': '3 ~ 15년', '학력': '학력무관', '근무형태': '정규직 · 계약직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579660'}
# {'기업명': '원투씨엠(주)', '직무': '2020년 하반기 개발자 채용', '경력사항': '5 ~ 10년', '학력': '학력무관', '근무형태': '정규직 · 프리랜서', '근무지': '경기 성남시 분당구', '분류': "['웹개발', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533730'}
# {'기업명': '(주)웰데이타시스템', '직무': '[엔클라우드24] [클라우드&IDC 기술영업/컨설팅/ 공공영업] 채용', '경력사항': '경력무관', '학력': '대학(2,3년)↑', '근무형태': '정규직 · 계약직', '근무지': '경기 성남시 분당구', '분류': "['IT·솔루션영업', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579626'}
# {'기업명': '(주)웰데이타시스템', '직무': '프런트앤드 앱/웹 자바(JAVA) PHP, 클라우드 서비스 개발자 모집', '경력사항': '경력무관', '학력': '대학(2,3년)↑', '근무형태': '정규직 · 계약직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579619'}
# {'기업명': '(주)피처링', '직무': '(정규직) 서버 및 웹 Backend 웹개발자를 채용합니다.', '경력사항': '2 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '인천 연수구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563022'}
# {'기업명': '소상공인연합회', '직무': '2020년 위탁사업담당 (경력/신입) 직원 모집', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '계약직', '근무지': '서울 동작구', '분류': "['기획·전략·경영', '총무·법무·사무']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576477'}
# {'기업명': '(주)두잇시스템', '직무': 'Linux서버 운영 (서울 강서구, 경력 3년이상)', '경력사항': '경력 3년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 강서구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38576103'}
# {'기업명': '(주)트위그팜', '직무': '웹 개발 (php, laravel 스페셜리스트) 모집', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38549173'}
# {'기업명': '(주)그로브소프트', '직무': '㈜그로브소프트 2020 하반기 경력직 추가 채용(기획, 개발, 퍼블리셔)', '경력사항': '경력 2년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['기획·전략·경영', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38566074'}
# {'기업명': '(주)케어랩스', '직무': '병원갈땐 굿닥) Java 백엔드 서버 개발자 채용', '경력사항': '3 ~ 10년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575281'}
# {'기업명': '(주)케어랩스', '직무': '병원갈땐 굿닥) PHP서버 개발자 대규모 채용', '경력사항': '5 ~ 10년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575280'}
# {'기업명': '디딤365 주식회사', '직무': '멀티 클라우드 포털 개발 신입/경력사원 모집', '경력사항': '신입 · 경력', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['서버·네트워크·보안', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575121'}
# {'기업명': '디딤365 주식회사', '직무': '클라우드 및 시스템 엔지니어 신입/경력(청년내일채움공제 가능)', '경력사항': '경력무관', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['서버·네트워크·보안', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575060'}
# {'기업명': '(주)에스비에스아이앤엠', '직무': 'SBS I&M 인프라 기획 및 AWS 클라우드 시스템 운영관리자 모집', '경력사항': '5 ~ 10년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562661'}
# {'기업명': '(주)카카오페이', '직무': '[카카오페이] 빅데이터, 하둡(Hadoop)플랫폼 운영 엔지니어 영입', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574921'}
# {'기업명': '라인게임즈 주식회사', '직무': '[라인게임즈] 기술PM 모집', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', '웹기획·PM']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574275'}
# {'기업명': '네오위즈', '직무': '[네오위즈] 각 부문 신입 / 경력자모집', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직 · 계약직', '근무지': '경기 성남시 분당구', '분류': "['회계·재무·세무·IR', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38447372'}
# {'기업명': '주식회사오션라이트에이아이', '직무': '서버·네트워크·보안(서버관리&AWS外 3개 부문) 채용합니다', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직 · 계약직', '근무지': '대구 북구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38571517'}
# {'기업명': '스마일샤크', '직무': '[경력] AWS 솔루션 아키텍트(SA)를 스마일샤크팀으로 모십니다.', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38550815'}
# {'기업명': '(주)웨어포인트', '직무': '(잠실/운영)시스템 엔지니어(SE/TA) 모집', '경력사항': '경력 3년↑', '학력': '대학(2,3년)↑', '근무형태': '계약직 · 프리랜서', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570404'}
# {'기업명': '(주)디타임', '직무': '(주)디타임 서버개발자 경력직 채용', '경력사항': '6 ~ 20년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565481'}
# {'기업명': '(주)립페이', '직무': '[정규직] IoT 플랫폼(백엔드) 개발자 모집', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['응용프로그램개발', '통신·모바일']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560508'}
# {'기업명': '(주)엔픽셀', '직무': '[인프라팀] 클라우드 엔지니어 채용', '경력사항': '경력 5년↑', '학력': '고졸↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38413525'}
# {'기업명': '(주)에스오월드테크놀리지', '직무': '서버관리자(AWS) 채용', '경력사항': '2 ~ 5년', '학력': '대학교(4년)↑', '근무형태': '인턴직', '근무지': '서울 영등포구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38568005'}
# {'기업명': '(주)지에스아이엘', '직무': '(주)지에스아아엘 - 시스템개발팀 경력직 채용', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직 · 계약직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567524'}
# {'기업명': '삼양데이타시스템㈜', '직무': '그룹 Infra 분야 운영 인력 모집', '경력사항': '경력무관', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 종로구', '분류': "['서버·네트워크·보안', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38550753'}
# {'기업명': '오픈플랜(주)', '직무': '[오픈플랜] back-end Developer 우수 인재를 모십니다.', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38505378'}
# {'기업명': '베스핀글로벌(주)', '직무': 'BigData 전문인력 채용(경력 5년 이상)', '경력사항': '5 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['응용프로그램개발', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38566513'}
# {'기업명': '메가존(주)', '직무': '[메가존] 구글클라우드 부문 채용', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['일반영업', 'IT·솔루션영업']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38409477'}
# {'기업명': '(주)앨리스헬스케어', '직무': '백엔드(Back-end) 개발자(경력)', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565409'}
# {'기업명': '(주)이카운트', '직무': '㈜이카운트 시스템관리자(SA팀) 채용', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 구로구', '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565193'}
# {'기업명': '쿠팡 주식회사', '직무': '[쿠팡페이] System Engineer', '경력사항': '경력 8년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38398255'}
# {'기업명': '㈜지에스아이티엠', '직무': 'SE/NE/DBA 경력사원 모집', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 종로구', '분류': "['응용프로그램개발', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38519641'}
# {'기업명': '(주)크리에이트코리아', '직무': '백엔드 개발자/ 웹 & 모바일 개발자 모집', '경력사항': '경력 1년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 중랑구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563318'}
# {'기업명': '대한상공회의소 광주인력개발원', '직무': '2020년도 국비 기술교육생 모집', '경력사항': '경력무관', '학력': '고졸↑', '근무형태': '교육생', '근무지': '광주 광산구', '분류': "['기계·기계설비', '전기·전자·제어']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38404367'}
# {'기업명': '대한상공회의소 충남인력개발원', '직무': '4차산업/전기전자/기계설계/자동화 교육생 모집', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '교육생', '근무지': '충남전체', '분류': "['전기·전자·제어', '설계·CAD·CAM']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38445379'}
# {'기업명': '오케스트로(주)', '직무': '클라우드연구소 PaaS 엔지니어', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 영등포구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38552496'}
# {'기업명': '이투스교육(주)', '직무': '이투스교육 IT기획직군 공개 채용', '경력사항': '경력', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551714'}
# {'기업명': '(주)푸드테크', '직무': 'IT부문 신입 및 경력사원 모집', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526283'}
# {'기업명': '매드업', '직무': '[테크사업부] 백엔드 개발자 채용', '경력사항': '3 ~ 10년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38553452'}
# {'기업명': '(주) 딥노이드', '직무': '인공지능, 의료영상 연구원 모집[경력, 병역특례 지원가능]', '경력사항': '신입 · 경력', '학력': '석사↑', '근무형태': '정규직 · 병역특례', '근무지': '서울 구로구', '분류': "['인공지능(AI)·빅데이터', '연구소·R&D']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38362204'}
# {'기업명': '(주)씨알에스큐브', '직무': 'AWS(DevOps) 엔지니어 채용', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561608'}
# {'기업명': '모나일렉트릭(주)', '직무': '웹개발(Java·JSP/ASP) 채용 공고', '경력사항': '3 ~ 5년', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 광명시', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554785'}
# {'기업명': '(주)판도라티비', '직무': '[ 코박(COBAK) ]  Back-end 개발자 채용', '경력사항': '1 ~ 5년', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561269'}
# {'기업명': '(주)키위플러스', '직무': '서버 Backend 개발자 영입', '경력사항': '3 ~ 5년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560578'}
# {'기업명': '주식회사 메먼트', '직무': '(연 3000만 이상) 시스템엔지니어 채용', '경력사항': '경력무관', '학력': '고졸↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526643'}
# {'기업명': '(주)웨어포인트', '직무': '[잠실/운영] DBA 업무 담당자 채용', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직 · 계약직', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38559704'}
# {'기업명': '(주)온빛', '직무': '병원 플랫폼 앱 개발자 모집 (안드로이드/iOS/백엔드)', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '대구 북구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38534946'}
# {'기업명': '아카라코리아', '직무': 'AWS 플랫폼기반 서비스운영 정규직 모집(경력사원)', '경력사항': '경력 10년↓', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38559238'}
# {'기업명': '주식회사 미로', '직무': '(주)미로 IoT & 스마트홈 개발자채용 (신입/경력/전문연구요원)', '경력사항': '경력무관', '학력': '대학교(4년)↑', '근무형태': '정규직 · 병역특례', '근무지': '인천 연수구', '분류': "['전기·전자·제어', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38559164'}
# {'기업명': '충북대학교', '직무': '[국비무료]취업연계 채용예정자 양성 과정 교육생 모집', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '교육생', '근무지': '충북 청주시', '분류': "['상품기획·MD', '기획·전략·경영']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38460768'}
# {'기업명': '(주)바디프랜드', '직무': '(주)바디프랜드 AI/서버/퍼블리셔/아이폰/프론트/기획 모집', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직 · 계약직', '근무지': '서울 강남구', '분류': "['웹기획·PM', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554220'}
# {'기업명': '(주)소프트웨어인라이프', '직무': '[Docswave] 2020년 하반기 프리세일즈 채용 (경력)', '경력사항': '경력 1년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '하드웨어·소프트웨어']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38477097'}
# {'기업명': '이원다이애그노믹스(주)', '직무': 'EDGC : 글로벌R&D본부 IT팀 인재 채용 件', '경력사항': '3 ~ 5년', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38489038'}
# {'기업명': '(주)인터웹', '직무': '4차산업혁명 기반의 신사업 참여 개발자 모집', '경력사항': '경력 6년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38553142'}
# {'기업명': '케이웨어(주)', '직무': '[R&D] 연구과제 기획/관리', '경력사항': '신입 · 경력', '학력': '석사↑', '근무형태': '정규직', '근무지': '서울 구로구', '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551504'}
# {'기업명': '이투스교육(주)', '직무': '이투스교육 8월 개발자 신입/경력 채용', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38545141'}
# {'기업명': '(주)아이아이컴바인드', '직무': '젠틀몬스터 백엔드&PHP 정규직 채용(경력/신입)', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38412821'}
# {'기업명': '주식회사 메디칼파크', '직무': '응용소프트웨어 프로그래머 연구원 모집', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 용인시 수지구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38353503'}
# {'기업명': '아토리서치(주)', '직무': '[아토리서치]전문연구요원(병역특례) 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38545903'}
# {'기업명': '메가존(주)', '직무': '[메가존] 개발 경력자 대규모 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직 · 병역특례', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37872627'}
# {'기업명': '오케스트로(주)', '직무': '(경력) 인공지능 연구소 플랫폼 개발팀 채용', '경력사항': '경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 영등포구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38532722'}
# {'기업명': '㈜안랩', '직무': '[안랩] DevOps 엔지니어 모집', '경력사항': '경력 4년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38538973'}
# {'기업명': '타이트(주)', '직무': '타이트(주) 제품개발팀 백엔드 / 웹 개발자 모집', '경력사항': '경력 2년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '대구 남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533831'}
# {'기업명': '클라우드그램(주)', '직무': '[클라우드그램] 경영지원', '경력사항': '경력 1년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['사무보조·문서작성', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38364180'}
# {'기업명': '메가존(주)', '직무': '[메가존클라우드] Mass Migration Center 부문별 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직 · 병역특례', '근무지': '서울 강남구', '분류': "['IT·솔루션영업', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38348572'}
# {'기업명': '메가존(주)', '직무': '[메가존] DMP(데이터 관리 플랫폼) 개발', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38405474'}
# {'기업명': '(주)아이뱅크', '직무': '클라우드/DataAnalysis/로그분석外 정규직 채용 - 경력사원', '경력사항': '경력 1년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['웹기획·PM', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38380134'}
# {'기업명': '(주)아이담', '직무': '개발본부 백엔드 개발자(Node.js) 경력직 채용', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533890'}
# {'기업명': '(주)두댓', '직무': '반려동물 서버 프로그래머 경력직 채용', '경력사항': '경력 10년↑', '학력': '고졸↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38532714'}
# {'기업명': '㈜날리지큐브', '직무': '날리지큐브 2020년 클라우드 신입/경력 개발자 채용', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38527975'}
# {'기업명': '(주)소셜라디오컴퍼니', '직무': '[글로벌 라이브·레코드 오디오기반 소셜앱] Backend개발자모집', '경력사항': '3 ~ 10년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38506920'}
# {'기업명': '주식회사 해줌', '직무': '고객관리 시스템 백엔드 개발자 채용', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38394524'}
# {'기업명': '에스피테크놀러지', '직무': '에스피테크놀러지(주) AR/VR 개발자 모집', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 관악구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38524760'}
# {'기업명': '에스피테크놀러지', '직무': '에스피테크놀러지(주) 프론트엔드&백엔드 개발', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 관악구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38524705'}
# {'기업명': '에스피테크놀러지', '직무': '에스피테크놀러지(주) Java 개발자 모집', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 관악구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38523836'}
# {'기업명': '디딤365 주식회사', '직무': 'AWS 클라우드 기술영업 신입사원 모집', '경력사항': '신입', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['IT·솔루션영업', '기술영업']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38523449'}
# {'기업명': '(주)모비젠', '직무': '(주)모비젠 부문별 개발자 모집', '경력사항': '경력무관', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['웹개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38523366'}
# {'기업명': '모티프컨설팅', '직무': '대기업 AWS 엔지니어 (클라우드 아키텍트/클라우드데이터엔지니', '경력사항': '신입 · 경력', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38522797'}
# {'기업명': '(주)락플레이스', '직무': 'Azure 엔지니어 모집', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38520918'}
# {'기업명': '굿어스데이터(주)', '직무': 'Cloud 엔지니어 경력 3년 이상', '경력사항': '3 ~ 10년', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38520348'}
# {'기업명': '조이시티', '직무': '[JOYCITY] 플랫폼 서버 개발자 모집 (경력무관)', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38519268'}
# {'기업명': '(주)필로시스생명과학', '직무': '[정규직] 서버개발자 모집', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38516156'}
# {'기업명': '(주)스쿱미디어', '직무': 'AWS엔지니어 채용 경력 모집(정규직)', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38511682'}
# {'기업명': '(주)오케이산업', '직무': 'AWS/PHP 정규직 채용 - 경력', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 부천시', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38511008'}
# {'기업명': '(주)뉴트리션코트', '직무': '백엔드개발 경력직 채용', '경력사항': '1 ~ 8년', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38355299'}
# {'기업명': '(주)아르카에이치알', '직무': '[WinnersK] 서비스 플랫폼 연구소 중급개발자 모집', '경력사항': '3 ~ 5년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38508488'}
# {'기업명': '(주)위메프', '직무': '[보안]클라우드 보안운영 담당자(정규직)', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37608770'}
# {'기업명': '(주)위메프', '직무': '[개발]위메프 시스템엔지니어(정규직)', '경력사항': '경력 1년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38502145'}
# {'기업명': '(주)위메프', '직무': '[개발]위메프오 DevOps Engineer(정규직)', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38502034'}
# {'기업명': '(주)코레이즈', '직무': '[신입/경력] 클라우드팀 채용 (SaaS · S/W)', '경력사항': '경력무관', '학력': '대학(2,3년)↑', '근무형태': '계약직 · 인턴직', '근무지': '서울 성동구', '분류': "['IT·솔루션영업', '하드웨어·소프트웨어']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38500624'}
# {'기업명': '(주)원더피플', '직무': '글로벌 플랫폼 서버 개발자 모집', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '게임·Game']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38497413'}
# {'기업명': '(주)데브툴즈', '직무': 'Back end 개발자 정규직 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '경기 안양시 동안구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38485192'}
# {'기업명': '아토리서치(주)', '직무': '인공지능/머신러닝 개발 및 클라우드/네트워크 개발', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38494339'}
# {'기업명': '컴즈(주)', '직무': 'S/W Test & QA Engineer 채용의 件', '경력사항': '신입 · 경력', '학력': '대학(2,3년)↑', '근무형태': '정규직 · 프리랜서', '근무지': '서울 구로구', '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38464382'}
# {'기업명': '나무기술(주)', '직무': 'Cloud 유지보수 엔지니어 모집', '경력사항': '경력 2년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38440590'}
# {'기업명': '나무기술(주)', '직무': '클라우드 SaaS개발 경력 채용합니다', '경력사항': '경력 3년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38470236'}
# {'기업명': '(주)제이티넷', '직무': '[나이스그룹] (주)제이티넷 채용 (시스템 운영관리)', '경력사항': '8 ~ 12년', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 구로구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38482290'}
# {'기업명': '(주)아이콘루프', '직무': '정보보안 / 개인정보보호 담당자 채용 (경력)', '경력사항': '경력 5년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 중구', '분류': "['서버·네트워크·보안']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38458811'}
# {'기업명': '(주) 와이더플래닛', '직무': '빅데이터 플랫폼 엔지니어', '경력사항': '경력 5년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38470987'}
# {'기업명': '메가존(주)', '직무': '[메가존클라우드] VDI Helpdesk / 24x7 Service 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직 · 병역특례', '근무지': '서울 강남구', '분류': "['사무보조·문서작성', '기술영업']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38439227'}
# {'기업명': '메가존(주)', '직무': '[메가존클라우드] Product Development 부문 채용', '경력사항': '경력무관', '학력': '학력무관', '근무형태': '정규직 · 병역특례', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38438571'}
# {'기업명': '(주)여기어때컴퍼니', '직무': '[여기어때] 서비스제품개발실 서버 개발자 채용', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38390850'}
# {'기업명': '(주)여기어때컴퍼니', '직무': '[여기어때] 이커머스플랫폼개발실 서버개발자 채용', '경력사항': '3 ~ 12년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38149596'}
# {'기업명': '유한책임회사딜리버리히어로코리아', '직무': 'IT System Engineer (Cloud)', '경력사항': '3 ~ 20년', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38464548'}
# {'기업명': '에스지에이(주)', '직무': '클라우드/AI/빅데이터 분야 영업/기술지원 분야 채용', '경력사항': '경력무관', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 송파구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38345151'}
# ...
# {'기업명': '피플워크(주)', '직무': '[ IT대기업]데이터 모델링 - 4-15년', '경력사항': '4 ~ 16년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38548699'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': '유통산업 및 커머스 분야 시스템 설계 개발자', '경력사항': '경력 6년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592716'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': '그룹 HR 공유 Infra HRIS 시스템 구축', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592712'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': '렌탈 시스템 구축 프로젝트 PL업무 수행 시스템 개발', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 중구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592708'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': 'Battery 생산지원시스템(QMS/SCM/EMS) 구축 및 Global 확산/운영', '경력사항': '경력 6년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '대전 동구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592694'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': 'ITS 또는 QT등 소프트웨어 개발', '경력사항': '경력 3년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['전기·전자·제어', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592691'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 java', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592671'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': '그룹 HR 공유 Infra HRIS 시스템 구축 SaaS  Cloud', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592664'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자 SAP', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 중구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38592662'}
# {'기업명': '(주)헬로서치', '직무': '[국내우량기업]딥러닝 개발자를 모십니다.', '경력사항': '2 ~ 12년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589871'}
# {'기업명': '위키에이드', '직무': '[화성/동탄] 머신비전 검사 SW 개발 경력', '경력사항': '경력 3년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '경기 화성시', '분류': "['응용프로그램개발', '하드웨어·소프트웨어']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589729'}
# {'기업명': '(주)핀커스코리아', '직무': '유명기업 웹개발 경력채용(3년~7년)', '경력사항': '3 ~ 7년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587971'}
# {'기업명': '(주)바른인사컨설팅', '직무': '[S/W개발 상장사]C/C++ 개발자 경력직 정규직 채용(프로그램개발', '경력사항': '경력 3년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38543403'}
# {'기업명': '(주)수커리어컨설팅', '직무': '백엔드 개발(Java,리눅스 등 사용중) 네트워크,보안 기업', '경력사항': '경력 3년↑', '학력': '학력무관', '근무형태': '정규직', '근무지': '서울 양천구', '분류': "['웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586023'}
# {'기업명': '그린컴퓨터아트학원 아카데미 성남/분당 ..', '직무': '[국가기간] JAVA기반 개발자 훈련과정 훈련교.강사님 모집', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '전임 · 계약직', '근무지': '경기 성남시 분당구', '분류': "['웹마스터·QA·테스터', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554225'}
# {'기업명': '그린컴퓨터아트학원 아카데미 성남/분당 ..', '직무': '[국가기간] 디지털컨버전스(JAVA기반), 빅데이터취업 국비교육', '경력사항': '경력 2년↑', '학력': '학력무관', '근무형태': '위촉직', '근무지': '경기 성남시 분당구', '분류': "['웹마스터·QA·테스터', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38485946'}
# {'기업명': '커리어셀파', '직무': '[유통대기업] IT개발 경력사원 채용', '경력사항': '4 ~ 12년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583993'}
# {'기업명': '(주)투비파트너즈', '직무': 'IT/ICT 소프트웨어 엔지니어', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 수원시 영통구', '분류': "['시스템개발', 'IT·디자인·컴퓨터교육']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583588'}
# {'기업명': '인비즈써치', '직무': '국내 대형증권사 로보어드바이저 서비스 기획 담당', '경력사항': '4 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '계약직', '근무지': '서울 영등포구', '분류': "['ERP·시스템분석·설계', '데이터베이스·DBA']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38583528'}
# {'기업명': '굿커리어', '직무': '대기업 MES(LOT 개발 운영,경북,충북) 대리,과장급 (굿커리어)', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38547779'}
# {'기업명': '제이떠블유커리어(JW career)', '직무': '머신비전 전문기업 딥러닝, AI 연구소(소장급)채용', '경력사항': '경력 10년↑', '학력': '석사↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['응용프로그램개발', '하드웨어·소프트웨어']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579925'}
# {'기업명': '(주)헬로서치', '직무': '[국내우량기업]딥러닝 개발 인재를 모십니다.', '경력사항': '2 ~ 10년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578846'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자 시스템통합 IT 아웃소싱', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 중구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38575270'}
# {'기업명': '(주)잡뉴스솔로몬서치', '직무': '일본어가능 JAVA .NET CS연구개발 경력자', '경력사항': '2 ~ 7년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570183'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': '그룹 HR 공유 Infra HRIS 시스템 구축 SaaS 솔루션 클라우드', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569026'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 중구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569023'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 Java, Oracle', '경력사항': '경력 6년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569021'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': '렌탈 시스템 구축 프로젝트 PL업무 수행 Spring framework', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 중구', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569019'}
# {'기업명': '(주)케이맨파워', '직무': '[최고대우] IT기획 (ERP 운영, 3년이상)', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', 'ERP·시스템분석·설계']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567425'}
# {'기업명': '(주)맨파워그룹코리아', '직무': '외국계 반도체회사 R&D S/W 연구원(경력) 모집', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['응용프로그램개발', '시스템개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563105'}
# {'기업명': '(주)맨파워그룹코리아', '직무': '외국계 회사 Video System R&D Software Engineer 모집', '경력사항': '신입 · 경력', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['응용프로그램개발', '시스템개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38563093'}
# {'기업명': '(주)코리아휴먼리소시스', '직무': 'ITS 또는 QT등 소프트웨어 개발 C, C++, JAVA', '경력사항': '경력 3년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['전기·전자·제어', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562755'}
# {'기업명': '(주)바인컨설팅', '직무': '대기업그룹사/안드로이드 앱개발자 대리과장급 채용', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38562646'}
# {'기업명': '(주) 허브브레인', '직무': '대기업 IT 사 데이터 엔지니어링 경력 채용', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561511'}
# {'기업명': '(주) 허브브레인', '직무': '대기업 IT 사 빅데이터 플랫폼 구축 경력 채용', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561500'}
# {'기업명': '(주) 허브브레인', '직무': '대기업 IT 사 고객데이터 기반 컨설팅 채용', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561489'}
# {'기업명': '(주) 허브브레인', '직무': '대기업 IT 사 빅데이터 기술 경력 채용', '경력사항': '경력 3년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561461'}
# {'기업명': '(주) 허브브레인', '직무': '대기업 계열 IT 사 AI 알고리즘 개발 신입, 경력 채용', '경력사항': '신입 · 경력', '학력': '석사↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558368'}
# {'기업명': '(주)피플렙', '직무': '의료기기 Sales Manager 과차장급/글로벌 기업', '경력사항': '6 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558343'}
# {'기업명': '(주) 허브브레인', '직무': '대기업 IT 사 고객데이터 분석 관련 오퍼링 발굴 채용', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558047'}
# {'기업명': '헤리티지서치코어', '직무': '빅데이터 수집 분석 시스템 UI /프론트엔드/유명 솔루션 기업', '경력사항': '2 ~ 10년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554760'}
# {'기업명': '헤리티지서치코어', '직무': '인프라솔루션 엔진파트 개발/C++, SQL,Socket /유명 솔루션 기업', '경력사항': '4 ~ 8년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554752'}
# {'기업명': '(주)피플렙', '직무': '의료기기 Sales Manager 과차장급', '경력사항': '6 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38554192'}
# {'기업명': '(주)에이치알그룹', '직무': '로봇 SW 개발자 (5년이상) - 로봇기업', '경력사항': '경력 5년↑', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38548759'}
# {'기업명': '주식회사 코어포인트', '직무': '클라우드 컨설팅/ DevOps, Open API 전문인력 채용(차장,과장급)', '경력사항': '7 ~ 14년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38548744'}
# {'기업명': '비전서치', '직무': '업데이트용 sw 개발', '경력사항': '3 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 성동구', '분류': "['응용프로그램개발', '하드웨어·소프트웨어']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38548178'}
# {'기업명': '(주)에이치알그룹', '직무': '[경력] IT 프로덕트 엔지니어 채용-유망 스타트업', '경력사항': '3 ~ 10년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 서초구', '분류': "['응용프로그램개발', '하드웨어·소프트웨어']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539011'}
# {'기업명': '헤리티지서치코어', '직무': '솔루션영업/경력 5년이상/유명 IT 솔루션기업', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38543031'}
# {'기업명': '하이잡', '직무': '추천 시스템 연구/개발', '경력사항': '경력 2년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 성남시 분당구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38541014'}
# {'기업명': '㈜에이치알맨파워그룹', '직무': '[대기업] AI알고리즘-박사 (서울)', '경력사항': '신입 · 경력', '학력': '박사', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38540948'}
# {'기업명': '(주)피플렙', '직무': 'Medical Device Sales Manager 경력(과차장급)', '경력사항': '7 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38540319'}
# {'기업명': '구루넷', '직무': '[일본취업] 소프트웨어 엔지니어 모집', '경력사항': '2 ~ 15년', '학력': '학력무관', '근무형태': '정규직 · 해외취업', '근무지': '아시아·중동 일본', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539305'}
# {'기업명': '구루넷', '직무': '인공지능 연구원 모집', '경력사항': '2 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['웹개발', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539294'}
# {'기업명': '구루넷', '직무': '영상처리 솔루션 개발자 모집', '경력사항': '2 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 금천구', '분류': "['응용프로그램개발', '시스템개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539278'}
# {'기업명': '구루넷', '직무': '[코스닥 상장사] 시스템 소프트웨어 개발자 모집', '경력사항': '3 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 마포구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539273'}
# {'기업명': '(주)에이치알인재그룹', '직무': '(RPA) 자동화시스템 개발 경력채용', '경력사항': '1 ~ 12년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '경기 오산시', '분류': "['서버·네트워크·보안', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38537627'}
# {'기업명': '(주)피플렙', '직무': 'Medical Device Sales Manager 경력', '경력사항': '7 ~ 15년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발', '인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38535004'}
# {'기업명': '(주)커리어멘토', '직무': '(1.VISION제어/ 2 PC제어/ 3.VISION SW개발/4.VISION FAE)', '경력사항': '4 ~ 12년', '학력': '대학(2,3년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['반도체·디스플레이·LCD', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38534541'}
# {'기업명': 'ES Group', '직무': '[구인구직 Platform] PL/Backend 개발 팀장님 채용', '경력사항': '경력 9년↑', '학력': '대학교(4년)↑', '근무형태': '정규직 · 계약직', '근무지': '서울 강남구', '분류': "['서버·네트워크·보안', '웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38534411'}
# {'기업명': '그레이프 파트너즈', '직무': '모빌리티 기업 Business Information Analyst 데이터 분석가', '경력사항': '2 ~ 12년', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['인공지능(AI)·빅데이터']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533546'}
# {'기업명': '굿커리어', '직무': '유명 대기업 바이오회사 헬스케어 플랫폼 서비스 기획 대리,과장', '경력사항': '경력 4년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['기획·전략·경영', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38531221'}
# {'기업명': '굿커리어', '직무': '유명 대기업 바이오회사 빅데이터 플랫폼 개발 대리,과장', '경력사항': '경력 4년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['기획·전략·경영', '응용프로그램개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38531206'}
# {'기업명': '(주)코어잡', '직무': '패션 중견 기업 자사몰 개발 Product Manager 정규직 과장-부장', '경력사항': '경력 5년↑', '학력': '대학교(4년)↑', '근무형태': '정규직', '근무지': '서울 강남구', '분류': "['웹개발']", '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38530623'}

# %%
# Out:
# array(['스윙로드', '더조은컴퓨터아트학원', '(주)쎄미시스코', '(주)와이비시스템', '국제컴퓨터아카데미',
#        '(주)트랜스코스모스코리아', '행복쇼핑(주)', '(주)세원아토스', '(주)시지온', '에스케이플래닛(주)',
#        '(주)헥사콘', '켈리서비스 유한회사', '사단법인 한국산업기술협회', '(주)데브구루', '(주)상록아이엔씨',
#        '(주)유노믹', '(주)아이스크림에듀', '(주)옷딜', '디아이티(주)', '(주)슈프리마',
#        '(주)제머나이소프트', '네모커머스(주)', '(주)유비온', '(주)어니언스', '에이치투오시스템테크놀로지(주)',
#        '(주)NE능률', '대화제약(주)', '글로벌인', '(주)후이즈', '(주)아이하트',
#        '(사)스마트미디어인재개발원', '(주)아이엔지스토리', '한국직업전문학교', '(주)큐픽스', '주식회사 엔디소프트',
#        '(재)충남정보문화산업진흥원', '뉴로핏 주식회사', '켐아이넷(주)', '(주)씨앤테크', '(주)매드업',
#        '㈜타이호인스트', '모닝인컨설팅', '신한양직업전문학교', '무브(주)', '주식회사 와이즈인컴퍼니',
#        '(주)투윈스컴', '(주)이노와이어리스', '쿠팡(주)', '(주)강림직업전문학교', '(주)프렌츠',
#        '(주)메디벨바이오', '(주)엔씨아이티에스', '스토리앤브라더스(주)', '(주)엔티엘헬스케어',
#        '(주)디케이비엠시', '패스트캠퍼스(주)', '(주)모비노마', '(주)선진', '한국정보기술단', '(주)세차왕',
#        '신한카드(주)', '(주)알리아스', '녹십자지놈', '(주)크레스콤', '지스펙(주)', '트리니티엔지니어링(주)',
#        '콴텍(주)', '한국기술교육직업전문학교', '지엔소프트(주)', '휴먼교육센터학원', '(주)지에스아이티엠',
#        '(주)비바리퍼블리카', '주식회사 성진에이치디에스', '(주)엔키아', '(주)케이몰글로벌',
#        '펜타시큐리티시스템(주)', '(주)맨파워그룹코리아', '(주)트레이지', '(주)소프트케잌', '휴도',
#        '(유)딜리버리히어로 코리아', '현대오트론(주)', '(주)파이버프로', '(주)안랩', '(주)씨제이이엔엠',
#        '(주)휴넷', '주식회사 로원홀딩스', '(주)헬스메디', '펍지(주)', '(주)이상투자그룹',
#        '(주)하나금융티아이', '㈜해커스교육그룹', '한국직업능력교육원 안산', '(주)LG유플러스', '엔사이크(주)',
#        '메디픽셀', '스펙트럼', '네이버파이낸셜(주)', '트래블라이(주)', '몬드리안에이아이(주)', '(주)유니콤넷',
#        '주식회사 에이치이엠', '(주)페이타랩', '(주)모비젠', '굿모니터링(주)', '(주)케이씨넷',
#        '테크빌교육(주)', '메이븐코리아(주)', '(주)하미글로벌', '(주)쓰리웨이소프트', '(주)큐빅테크',
#        '(주)팀플백', '주식회사 노벨알엔디', '주식회사 블루에이치알', '한국IT교육원', '(주)두플',
#        '(주)케이씨피드', '(주)스트라티오코리아', '(주)애드픽네트워크', '(주)커넥트히어로', '분당서울대학교병원',
#        '효성컴퓨터학원', '주식회사 인공지능연구원', '한국에이치알엠', '비젠트로(주)', '워크픽(주)',
#        '(주)알체라', '(주)지비소프트', '(주)올엠', '(주)아이엠비디엑스', '로크웰오토메이션코리아(주)',
#        '(주)티제이팜', '신플렛(주)', '(주)코인원트랜스퍼', '(주)디비엔텍', '베스핀글로벌(주)',
#        '(주)아이콘루프', '(주)엘젠아이씨티', '소프트젠', '포디리플레이코리아(주)', '(주)록스',
#        '알테어엔지니어링(주)', '(주)골든플래닛', '(주)세원이디에스', '(주)에이직스', '(주)인라이플',
#        '㈜이지메디컴', '(주)이젠아카데미인재개발원', '전북대병원 의생명연구원', '㈜알앤비소프트', '(주)헬로네이처',
#        '(주)누리콘', '(주)알큐브', '앰진시큐러스', '(주)에이프릴세븐', '이파로스', '(주)에프앤가이드',
#        '(주)컴트루테크놀로지', '더모임컴퍼니(주)', '(주)포아시스', '(주)비트나인', '(주)아모레퍼시픽',
#        '(주)윈디플랜', '(주)이노그리드', '(주)코이웨어', '주식회사 새집다오', '시큐레터(주)',
#        '(주)열심히커뮤니케이션즈', '(주)티몬', '(주)일화', '(주)에이치에너지', '(주)텐핑거스',
#        '대림비앤코(주)', '(주)제노레이', '(주)제이엘케이', '모든에프엔씨(주)', '(주)바질컴퍼니',
#        '(주)딤커뮤니케이션', '원투씨엠(주)', '(주)스캐터랩', '디랩', '(주)아이소바코리아', '(주)스트리미',
#        '유카로오토모빌(주)', '(주)피처링', '주식회사 샵플링', '(주)트윅스정보통신', '(주)스마트콘',
#        '(주)와이브레인', '이노뎁(주)', '(주)드림아이디어소프트', '(주)파워큐브코리아', '디딤365 주식회사',
#        '(주)비츠로테크', '(주)카카오페이', '가온플랫폼(주)', '(주)코믹스브이', '주식회사 엠케이',
#        '(주)스프링클라우드', '타이아(주)', '도프텍(주)', '(주)아프리카티비', '(주)씰커뮤니케이션',
#        '오토그라운드 주식회사', '(주)에이아이앤잡', '(주)에스엠시스템', '(주)뷰노', '㈜엠앤디',
#        '(주)한국소프트웨어아이엔씨', '㈜지어소프트', '유한회사 미소', '(주)호두랩스', '(주)소프트위즈',
#        '(주)디엠랩', '공간정보기술㈜', '디비디랩(주)', '더화이트커뮤니케이션(주)', '아콘소프트(주)',
#        '(주)루나소프트', '비바엔에스', '코리아크레딧뷰로(주)', '(주)아이티엘', '(주)플라잉캣', '메가존(주)',
#        '(주)뉴지스탁', '(주)에스비시스템즈', '(주)에니트', '(주)서울소프트', '원광대학교산학협력단',
#        '쿠팡 주식회사', '(주)라인월드', '(주)와이디생명과학', '건아정보기술(주)', '(주)서커스컴퍼니',
#        '대한상공회의소 충남인력개발원', '(주)캐럿글로벌', '(주)비플', '(주)엑심베이', '(주)푸드테크',
#        '(주)팬토믹스', '4S Mapper', '(주)글로핸즈', '매드업', '씨엔비소프트(주)', '(주)시큐레이어',
#        '(주)지네트웍스', '주식회사 포티투마루', '(주)판도라티비', '주식회사 메먼트', '(주)한백전자',
#        '엠아이큐브솔루션(주)', '주식회사 디케이테크인', '(주)씨즈데이터', '(주)알엠에이', '(주)엔제로',
#        '(주)여니', '(주)코인원', '조이시티', '네이버시스템(주)', '(주)카이팜', '경기인력개발원',
#        '피플메이드', '와이폴라리스', 'HS Lab(에이치에스 연구소)', '트리노드 주식회사',
#        '이원다이애그노믹스(주)', '(주)인터웹', '주식회사 스포카', '이마고웍스(주)', '(주)미디움',
#        '제이엠피코리아(주)', '(주)유즈브레인넷', '㈜솔트룩스', '플랫비 주식회사', '(주)프로젝트엔',
#        '(주)인클루드시스', '이이넥서스', '주식회사로보그램인공지능로봇연구소', '(주)엔미디어플랫폼',
#        '아토리서치(주)', '(주)펄핏', '(주)애니로직', '(주)브릭', '미래아이티(주)', '아이트로스(주)',
#        '(주)조이시티', '스마트선박벤처기술', '(주)에이스테크놀로지', '(주)티페이', '셀바스에이아이',
#        '(주)주피터코퍼레이션', '(주)유라코퍼레이션', '(주)비전정보통신', '(주)온코크로스',
#        '(주)글로벌트러스트네트웍스코리아', '디노플러스(주)', '(주)로지올', '(주)비트버스', '(주)그라비티',
#        '(주)광개토연구소', '(주)트윔', '(주)비카누스', '라인비즈플러스(주)', '(주)비투윈파트너스',
#        '주식회사 트릿지', '(주)오픈베이스', '㈜로드와이즈', '(주)다비오', '(주)데이터스트림즈',
#        '(주)에스아이알소프트', '㈜엑스큐어넷', '(주)애드펄스', '(주)엠코프', '주식회사 해줌', '(주)딥엑스',
#        '(주)엔코아', '에스피테크놀러지', '(주)핀업', '(주)스누아이랩', '(주)에스와이소프트',
#        '굿어스데이터(주)', '(주)망고', '콘센트릭스서비스코리아(유)', '서울아산병원', '오상자이엘(주)',
#        '에쓰오씨소프트(주)', '(주)인플루엔셜', '에스이테크놀로지(주)', '이투스교육(주)',
#        '(주)데이터마케팅코리아', '밀라노상인', '(주)뉴트리션코트', '알토란이알피(주)', '(주)엔엑스테크놀로지',
#        '한밭대학교산학협력단', '오케스트로(주)', '(주)애니펜', '(주)시스콘', '(주)이팝콘',
#        '(주)솔브리드플러스', '스냅스', '(주)플랫커머스', '(주)에이아이스페라', '엔에이치엔(주)',
#        '(주)카카오게임즈', '(주)티큐에스코리아', '(주)글로우데이즈', '네모파트너즈비에이(주)', '베링랩',
#        '(주)소리자바', '에듀베이션(주)', '오버노드', '투아이시스(주)', '(주)클라리파이', '(주)헤렌',
#        '(주)데브툴즈', '㈜다음소프트', '시크제네시스', '(주)허브넷컴퍼니', '스마트쿱(주)', '(주)메이팜소프트',
#        '(주)두타위즈', '(주)노르마', '스포트라이트101', '나무기술(주)', '에스지에이솔루션즈(주)',
#        '(주)아와소프트', '주식회사 데일리펀딩', '(주)동글', '(주)라이앤캐처스', '태그바이컴퍼니(주)',
#        '렌카(주)', '누리꿈소프트(주)', '(주)소베텍', '(주)데이터빈', '(주)아키핀', '클라우드그램(주)',
#        '휴먼교육센터', '(주)퍼즐데이터', '(주)스위트케이', '엑스투아이(주)', '노을(주)', '(주)오션소프트',
#        '아일랩', '인플루엔셜', '유한책임회사딜리버리히어로코리아', '주식회사 팜코브', '어니컴㈜', '(주)릴리커버',
#        '(주)넥스트코어테크놀로지', '(주)퀀텀솔루션', '(주)제이엔피글로벌', '라인게임즈 주식회사', '(주)휴민텍',
#        '㈜에스에프테크놀로지', '윤시스템', '주식회사 비긴메이트(Beginmate Co. ,Ltd,)', '(주)베가스',
#        '(주)인텔리빅스', '(주)원익로보틱스', '(주)카이', '(주)플레이미션', '(주)에이젠글로벌', '㈜머큐리',
#        '(주)인사', '휴맥스 아이오티', '골든서퍼(주)', '(주)테너지', '중앙일보(주)', '주식회사 더맘마',
#        '코어닷투데이', '(주)쿼드마이너', '스튜디오레논', '주식회사 오픈소스컨설팅', '주식회사 유저해빗',
#        '(주)프래프', '스테이즈', '(주)레드소프트', '(주)실리콘사피엔스', '렌도코리아', '(주)포티투마루',
#        '여의(주)', '(주)웨이브웨어', '(주)코난테크놀로지', '디알엑스(주)', '(주)매쓰모카', '더넷(주)',
#        '카페24㈜', '시너지에이아이(주)', '주식회사 마켓잇', '데이터플로', '(주)지티씨솔루션',
#        '(주)동연에스엔티', '디지털원(주)', '㈜인텔리코드', '(주)코리아센터', '(주)리퓨터', '(주)아톰소프트',
#        '(주)아이티공간', '(주)아이오티플렉스', '㈜키트넷', '비엔비컴퍼니(주)', '(주)솔릭', '(주)펨트론',
#        '(주)지오블루랩', '소스팜(주)', '(주)에이치포테크', '(주)피플커넥트', '(주)여우전자', '트리컴퍼니',
#        '(주)좋은정보기술', '(주)키즈노트', '㈜더아이엠씨', '(주)딥인스펙션', '(주)씨티아이랩',
#        '(주)이피엠솔루션즈', '(주)폰템', '(주)사이버테크프랜드', '(주)앱도', '(주)제오시스', '시어스랩',
#        '(주)파이낸셜데이타시스템', '(주)오픈이노베이션랩', '주식회사 먹깨비', '(주)클래스소프트', '(주)지팡이',
#        '(주)나이츠넷', '(주)미래새한감정평가법인', '(주)엠넥스', '(주)도서출판길벗', '(주)지아이컴퍼니',
#        '이노데이터', '주식회사 오늘앤파트너스', '(주)카비', '주식회사 큐버', '(주)에스지아이코리아', '트윈스돌',
#        '컴즈(주)', '(주)파이디지털헬스케어', '(주)굿스굿', '웹프라임(주)', '시너지파트너즈(주)',
#        '(주)더블다운인터액티브', '호스트웨이아이디씨(주)', '(주)폭스소프트', '(주)나인티나인', '(주)비주얼',
#        '(주)씨이랩', '지디에프랩', '(주)이젠아카데미컴퓨터학원', '(주)듀얼헬스케어', '(주)오큐브이엔지',
#        '(주)유비씨', '테크핀코리아', '(주)앨리스헬스케어', '(주)에이치앤티솔루션', '(주)아그레아블',
#        '카이스컴퍼니', '(주)웰데이타시스템', '(주)솔리드이엔지', '(주)리스트', '(주)디젠트아이디',
#        '(주)라온버드', '(주)지음지식서비스', '주식회사 사운드리퍼블리카',
#        '로컬플랫폼랩(Local Platform Lab)', '창의융합과학(주)', '제이딘', '(주)퍼니플럭스',
#        '(주)소만사', '(주)소이넷', '(주)넷아이디', '(주)모션투에이아이코리아', '(주)오렌지아이', '하이테크',
#        '(주)아시안보스', '온다(주)', '엔아이티서비스 주식회사', '(주)디케이아이테크놀로지', 'ds소프트',
#        '주식회사 핀텔', '(주)파인디지털', '(주)마인즈앤컴퍼니', '(주)아크릴', '(주)더블미', '(주)나누고',
#        '라온피플(주)', '안전성평가솔루션(주)', '(주)엔에이치엔다이퀘스트', '(주)엑시포씨앤에스',
#        '엔에이치엔한국사이버결제주식회사', '(주)IR큐더스', '(주)크리에이트코리아', '(주)스카이오브레드',
#        '(주)맥스피아', '(주)에스티에이테스팅컨설팅', '(유)로우파트너스', '(주)다솔', '(주)레이다앤스페이스',
#        '(주)이노블록', '(주)삼진엘앤디', '주식회사 미로', '위티', '(주)레인보우8', '(주)페르소나',
#        '주식회사 푸름넷', '(주)사랑넷', '엘맨소프트', '(주)스튜디오엑스코', '(주)코리아웹데이터센터',
#        '(주)레메디', '㈜시도우', '지식시스템㈜ KSTEC Inc.', '주식회사 지씨바이오', '(주)디구루',
#        '(주)에스에스티랩', '주식회사 투그램시스템즈', '주식회사 에스알유니버스', '모아플래닛', '주식회사 에이테크',
#        '(주)집쇼코리아', '미래해양', '(주)엠투아이티', '중앙제어(주)', '(주)에이아이더', '(주)미스터픽',
#        '주식회사 유비넷', '(주)넥스리얼', '비디아이티(주)', '세종경영자문(주)', '(주)앱테스트에이아이',
#        '(주)전략인재개발원', '(주)플렉싱크', '㈜에스엔정보시스템', '(주)에어로비전', '(주)온품',
#        '주식회사레몬헬스케어', '(주)누리아이디티', '서울아산병원 의료영상지능실현연구실', '(주)에이치디아이지',
#        '(주)디아이섹', '(주)시정', '피이지코리아', '(주)바인테크', '(주)아리안', '(주)지오아이티',
#        '(주)로봇앤드디자인', '요트(주)', '(주)알티솔루션', '(주)오로스테크놀로지', '주식회사 디벨록',
#        '(주)인피니그루', '바이오에이아이', '마블러스', '(주)대연씨앤아이', '국립암센터', '(주)엣데이터',
#        '빅테크플러스(주)', '(주)파킹고', '(주)에이치브레인', '케빈랩(주)', '(주)나모',
#        '(주)원모어시큐리티', '(주)대호이엔지', '에너지엑스(주)', '아이넷캅', '(주)인튜웍스',
#        '(재)서울호서직업전문학교', '모비어스앤밸류체인(주)', '라미랩(주)', '젠틀몬스터', '(주)삼인에이치엔티',
#        '(주)비긴어스', '(주)소비코프로페셔널', '(주)트라움인포테크', '㈜프론티스', '(주)웨이티즈', '크래카',
#        '(주)원더피플', '인플랩(주)', '순식군', '(주)사이버네틱스이미징시스템즈', '(주)디아이티',
#        '(주)비네아', '중앙직업전문학교', '컨텍스트디', '(주)레이언스', '(주)메쉬코리아', '(주)여기어때컴퍼니',
#        '(주)피노', '(주)매드맨포스트', '서오 주식회사', '위즈메이드(주)', '(주)마인즈랩', '지니언스(주)',
#        '(주)타디스테크놀로지', '(주)아이비즈소프트웨어', '포미트', '(주)헤르스', '주식회사 솔박스',
#        '(주)맨텍', 'SEAGILE주식회사', '이엔에스알', '(주)플라밍고', '(주)YH데이타베이스',
#        '(주)NSHC', '(주)한국해양기상기술', '(주)오픈마인즈', '나무아이씨티', '한국스코어링(주)',
#        '(주)맥사이언스', '㈜코닉글로리', '(주)세마그룹', '디휴브', '빌리버', '(주)시안솔루션',
#        '(주)피식스컨설팅', '퍼닝', '(주)에이아이인사이트', '주식회사 리본소프트', '레이비스(주)',
#        '주식회사 지에스아이에프엔', '(주)오픈메이트', '(주)드림에이스', '주식회사 조이스', '(주)글로벌링커스',
#        '㈜쎄미시스코', '(주)공팔리터', '(재)한국직업능력교육원', '전남대학교산학협력단', '(주)코이노',
#        '㈜코리아서버호스팅', '(주)동녘', '키네마스터 주식회사', '(주)케이아이', '(주)가치소프트',
#        '구미상공회의소', '피엔씨서치', '에버브레인 컨설팅(주)', '(주)아츠코리아', '(주)글로벌터치코리아',
#        '에이치알브로스', '보보스링크(주)', '(주)스카우트플랜', '에이피써치', '파워에이치알',
#        '(주) 잡뉴스솔로몬서치', '굿커리어', '탑커리어인사이트', '휴머레인컨설팅', '라온서치', '(주)스카우트',
#        '터닝포인트HR', '㈜벤처피플', '주식회사 라온서치', '(주)코리아휴먼리소시스', '(주)피플렙',
#        '(사)대덕이노폴리스벤처협회', '(주)투비파트너즈', 'search square', '(주)스카우트파트너스',
#        '(주)맨토스파워', '(주)키스템프', '(주)에이치알맨파워그룹', '오픈포지션', '제이케이서치 주식회사',
#        '(주)베스트에치알 (Best HR)', 'FORTISPTS Partners', '(주)피플케어코리아',
#        '제이떠블유커리어(JW career)', '로버트월터스코리아(주)', '(주)에이치알비즈코리아',
#        '(주)프로매치코리아', '(주)핀커스코리아', '커리어케어', '(주)헤리티지에이치알코리아', '(주)케이맨파워',
#        '(주) 허브브레인', '㈜에이치알맨파워그룹', 'HR컨설팅(주)', '(주)더라이징스타헤딩', '커리어커넥트(주)',
#        '굿에이치알', '헤리티지서치코어', '코리아써치', '잡스테이션코리아', '비전서치', '주식회사 이노서치',
#        '(주)헬로서치', '(주)휴먼디지탈', '제이앤피에이치알컨설팅', '엔터웨이파트너스', '(주)에이치앤티어세스',
#        '(주)스마트미디어인텐시브', '헌터파트너스(주)', '맨쉬 컨설팅 주식회사', '(주)탑앤스카우트',
#        '그린컴퓨터아카데미', '주식회사 엘리튜드', '(주)연세교육아카데미ㅣ연세직업전문학교', '(주)커리어앤스카우트',
#        '헬로우파트너스', '피플워크(주)', '위키에이드', '(주)바른인사컨설팅', '(주)수커리어컨설팅',
#        '그린컴퓨터아트학원 아카데미 성남/분당 ..', '커리어셀파', '인비즈써치', '(주)잡뉴스솔로몬서치',
#        '(주)바인컨설팅', '(주)에이치알그룹', '주식회사 코어포인트', '하이잡', '구루넷', '(주)에이치알인재그룹',
#        '(주)커리어멘토', 'ES Group', '그레이프 파트너즈', '(주)코어잡'], dtype=object)

# %%
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqldb://minji:"+"minji"+"@192.168.0.25:3306/poor_db",encoding="utf-8")
conn = engine.connect()
cloud_df.to_sql(name='jobs_cloud', con=engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     189                                          self.max_stmt_length,
# --> 190                                          self._get_db().encoding)
#     191
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     226             sql += v
# --> 227         rows += self.execute(sql + postfix)
#     228         self.rowcount = rows
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     723             result = MySQLResult(self)
# --> 724             result.read()
#     725         self._result = result
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1068         try:
# -> 1069             first_packet = self.connection._read_packet()
#    1070
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     675                 self._result.unbuffered_active = False
# --> 676             packet.raise_for_error()
#     677         return packet
#
# C:\Anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     222         if DEBUG: print("errno =", errno)
# --> 223         err.raise_mysql_exception(self._data)
#     224
#
# C:\Anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     106         errorclass = InternalError if errno < 1000 else OperationalError
# --> 107     raise errorclass(errno, errval)
#
# OperationalError: (1241, 'Operand should contain 1 column(s)')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-50-6a6fc3171460> in <module>()
#       5 engine = create_engine("mysql+mysqldb://minji:"+"minji"+"@192.168.0.25:3306/poor_db",encoding="utf-8")
#       6 conn = engine.connect()
# ----> 7 cloud_df.to_sql(name='jobs_cloud', con=engine, if_exists='replace', index=False)
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2128         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2129                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2130                    dtype=dtype)
#    2131
#    2132     def to_pickle(self, path, compression='infer',
#
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1125                          schema=schema, dtype=dtype)
#    1126         table.create()
# -> 1127         table.insert(chunksize)
#    1128         if (not name.isdigit() and not name.islower()):
#    1129             # check for potentially case sensitivity issues (GH7815)
#
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize)
#     639
#     640                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 641                 self._execute_insert(conn, keys, chunk_iter)
#     642
#     643     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     614     def _execute_insert(self, conn, keys, data_iter):
#     615         data = [{k: v for k, v in zip(keys, row)} for row in data_iter]
# --> 616         conn.execute(self.insert_statement(), data)
#     617
#     618     def insert(self, chunksize=None):
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1168                         statement,
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#    1172                 if self.dialect._has_events:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     103
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#     107             context._rowcount = rowcount
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     188             return self._do_execute_many(q_prefix, q_values, q_postfix, args,
#     189                                          self.max_stmt_length,
# --> 190                                          self._get_db().encoding)
#     191
#     192         self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     225                 sql += b','
#     226             sql += v
# --> 227         rows += self.execute(sql + postfix)
#     228         self.rowcount = rows
#     229         return rows
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     161         query = self.mogrify(query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#     165         return result
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     319         self._last_executed = q
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     503                 sql = sql.encode(self.encoding, 'surrogateescape')
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#     507
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     722         else:
#     723             result = MySQLResult(self)
# --> 724             result.read()
#     725         self._result = result
#     726         if result.server_status is not None:
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1067     def read(self):
#    1068         try:
# -> 1069             first_packet = self.connection._read_packet()
#    1070
#    1071             if first_packet.is_ok_packet():
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     674             if self._result is not None and self._result.unbuffered_active is True:
#     675                 self._result.unbuffered_active = False
# --> 676             packet.raise_for_error()
#     677         return packet
#     678
#
# C:\Anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     221         errno = self.read_uint16()
#     222         if DEBUG: print("errno =", errno)
# --> 223         err.raise_mysql_exception(self._data)
#     224
#     225     def dump(self):
#
# C:\Anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     105     if errorclass is None:
#     106         errorclass = InternalError if errno < 1000 else OperationalError
# --> 107     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1241, 'Operand should contain 1 column(s)') [SQL: 'INSERT INTO jobs_cloud (`기업명`, `직무`, `경력사항`, `학력`, `근무형태`, `근무지`, `분류`, `상세링크`) VALUES (%(기업명)s, %(직무)s, %(경력사항)s, %(학력)s, %(근무형태)s, %(근무지)s, %(분류)s, %(상세링크)s)'] [parameters: ({'\uae30\uc5c5\uba85': '(주)레뷰코퍼레이션', '\uc9c1\ubb34': '플랫폼그룹 부문별 신입/경력직 채용', '\uacbd\ub825\uc0ac\ud56d': '신입 · 경력', '\ud559\ub825': '학력무관', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 강남구', '\ubd84\ub958': ['캐릭터·만화·애니', '서버·네트워크·보안'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38541335&adsCategoryItem=effect_bold&'}, {'\uae30\uc5c5\uba85': '(주)시지온', '\uc9c1\ubb34': '라이브리 서비스 광고 플랫폼 개발자 모집', '\uacbd\ub825\uc0ac\ud56d': '3 ~ 15년', '\ud559\ub825': '학력무관', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 마포구', '\ubd84\ub958': ['서버·네트워크·보안', '웹개발'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38593999'}, {'\uae30\uc5c5\uba85': '주식회사 코드베르그', '\uc9c1\ubb34': '코드베르그 Back-end 개발부문 모집 (PHP or Node.js)', '\uacbd\ub825\uc0ac\ud56d': '3 ~ 6년', '\ud559\ub825': '학력무관', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 서초구', '\ubd84\ub958': ['서버·네트워크·보안'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38434985'}, {'\uae30\uc5c5\uba85': '파우게임즈', '\uc9c1\ubb34': '[파우게임즈] 기술지원(DB/웹개발) 담당자 채용', '\uacbd\ub825\uc0ac\ud56d': '3 ~ 5년', '\ud559\ub825': '학력무관', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '경기 성남시 분당구', '\ubd84\ub958': ['서버·네트워크·보안', '웹개발'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38406328'}, {'\uae30\uc5c5\uba85': '(주)상록아이엔씨', '\uc9c1\ubb34': '[경험자 우대] Python/Linux AI 시스템 개발자 채용', '\uacbd\ub825\uc0ac\ud56d': '신입 · 경력', '\ud559\ub825': '대학교(4년)↑', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '경기 부천시', '\ubd84\ub958': ['서버·네트워크·보안', '응용프로그램개발'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38601843&adsCategoryItem=effect_bold&'}, {'\uae30\uc5c5\uba85': '(주)옷딜', '\uc9c1\ubb34': 'Ai솔루션 옷딜 각부분 경력모집', '\uacbd\ub825\uc0ac\ud56d': '경력', '\ud559\ub825': '학력무관', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 마포구', '\ubd84\ub958': ['기획·전략·경영', '출판·편집디자인'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580264&adsCategoryItem=effect_bold&'}, {'\uae30\uc5c5\uba85': '(주)중고나라', '\uc9c1\ubb34': '[중고나라] 개발 부문 전문가 채용', '\uacbd\ub825\uc0ac\ud56d': '경력 3년↑', '\ud559\ub825': '학력무관', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 서초구', '\ubd84\ub958': ['웹마스터·QA·테스터', '서버·네트워크·보안'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38573880&adsCategoryItem=effect_bold&'}, {'\uae30\uc5c5\uba85': '(주)자비스', '\uc9c1\ubb34': '[코스닥 상장사 ㈜자비스] 2020년 하반기 공개채용', '\uacbd\ub825\uc0ac\ud56d': '경력', '\ud559\ub825': '학력무관', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '경기 성남시 중원구', '\ubd84\ub958': ['해외영업·무역영업', '사무보조·문서작성'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38578169&adsCategoryItem=effect_bold&'}  ... displaying 10 of 444 total bound parameter sets ...  {'\uae30\uc5c5\uba85': '구루넷', '\uc9c1\ubb34': '웹 개발자 모집', '\uacbd\ub825\uc0ac\ud56d': '3 ~ 15년', '\ud559\ub825': '대학교(4년)↑', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 마포구', '\ubd84\ub958': ['서버·네트워크·보안', '웹개발'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539245'}, {'\uae30\uc5c5\uba85': '(주)맨파워그룹코리아', '\uc9c1\ubb34': '[삼성물산/잠실] 모바일 앱 및 웹 운영 경력 개발자 채용', '\uacbd\ub825\uc0ac\ud56d': '3 ~ 20년', '\ud559\ub825': '학력무관', '\uadfc\ubb34\ud615\ud0dc': '계약직 · 파견직', '\uadfc\ubb34\uc9c0': '서울 송파구', '\ubd84\ub958': ['서버·네트워크·보안', '웹개발 ...

# %%
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     189                                          self.max_stmt_length,
# --> 190                                          self._get_db().encoding)
#     191
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     226             sql += v
# --> 227         rows += self.execute(sql + postfix)
#     228         self.rowcount = rows
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     723             result = MySQLResult(self)
# --> 724             result.read()
#     725         self._result = result
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1068         try:
# -> 1069             first_packet = self.connection._read_packet()
#    1070
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     675                 self._result.unbuffered_active = False
# --> 676             packet.raise_for_error()
#     677         return packet
#
# C:\Anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     222         if DEBUG: print("errno =", errno)
# --> 223         err.raise_mysql_exception(self._data)
#     224
#
# C:\Anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     106         errorclass = InternalError if errno < 1000 else OperationalError
# --> 107     raise errorclass(errno, errval)
#
# OperationalError: (1241, 'Operand should contain 1 column(s)')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-47-4cff80685313> in <module>()
# ----> 1 python_df.to_sql(name='jobs_python', con=engine, if_exists='replace', index=False)
#       2 db_Df.to_sql(name='jobs_db', con=engine, if_exists='replace', index=False)
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2128         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2129                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2130                    dtype=dtype)
#    2131
#    2132     def to_pickle(self, path, compression='infer',
#
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1125                          schema=schema, dtype=dtype)
#    1126         table.create()
# -> 1127         table.insert(chunksize)
#    1128         if (not name.isdigit() and not name.islower()):
#    1129             # check for potentially case sensitivity issues (GH7815)
#
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize)
#     639
#     640                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 641                 self._execute_insert(conn, keys, chunk_iter)
#     642
#     643     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     614     def _execute_insert(self, conn, keys, data_iter):
#     615         data = [{k: v for k, v in zip(keys, row)} for row in data_iter]
# --> 616         conn.execute(self.insert_statement(), data)
#     617
#     618     def insert(self, chunksize=None):
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1168                         statement,
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#    1172                 if self.dialect._has_events:
#
# C:\Anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     103
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#     107             context._rowcount = rowcount
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     188             return self._do_execute_many(q_prefix, q_values, q_postfix, args,
#     189                                          self.max_stmt_length,
# --> 190                                          self._get_db().encoding)
#     191
#     192         self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     225                 sql += b','
#     226             sql += v
# --> 227         rows += self.execute(sql + postfix)
#     228         self.rowcount = rows
#     229         return rows
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     161         query = self.mogrify(query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#     165         return result
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     319         self._last_executed = q
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     503                 sql = sql.encode(self.encoding, 'surrogateescape')
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#     507
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     722         else:
#     723             result = MySQLResult(self)
# --> 724             result.read()
#     725         self._result = result
#     726         if result.server_status is not None:
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1067     def read(self):
#    1068         try:
# -> 1069             first_packet = self.connection._read_packet()
#    1070
#    1071             if first_packet.is_ok_packet():
#
# C:\Anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     674             if self._result is not None and self._result.unbuffered_active is True:
#     675                 self._result.unbuffered_active = False
# --> 676             packet.raise_for_error()
#     677         return packet
#     678
#
# C:\Anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     221         errno = self.read_uint16()
#     222         if DEBUG: print("errno =", errno)
# --> 223         err.raise_mysql_exception(self._data)
#     224
#     225     def dump(self):
#
# C:\Anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     105     if errorclass is None:
#     106         errorclass = InternalError if errno < 1000 else OperationalError
# --> 107     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1241, 'Operand should contain 1 column(s)') [SQL: 'INSERT INTO jobs_python (`기업명`, `직무`, `경력사항`, `학력`, `근무형태`, `근무지`, `분류`, `상세링크`) VALUES (%(기업명)s, %(직무)s, %(경력사항)s, %(학력)s, %(근무형태)s, %(근무지)s, %(분류)s, %(상세링크)s)'] [parameters: ({'\uae30\uc5c5\uba85': '스윙로드', '\uc9c1\ubb34': '스윙로드 (백엔드 부문) 정규직 채용', '\uacbd\ub825\uc0ac\ud56d': '경력 3년↑', '\ud559\ub825': '대학(2,3년)↑', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 강남구', '\ubd84\ub958': ['웹개발'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38423092'}, {'\uae30\uc5c5\uba85': '더조은컴퓨터아트학원', '\uc9c1\ubb34': '[100%무료 취업준비생모집]웹디/건축/게임/프로그래밍/3D프린터', '\uacbd\ub825\uc0ac\ud56d': '신입 · 경력', '\ud559\ub825': '학력무관', '\uadfc\ubb34\ud615\ud0dc': '교육생', '\uadfc\ubb34\uc9c0': '서울전체', '\ubd84\ub958': ['그래픽디자인·CG', '제품·산업디자인'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=34529977&adsCategoryItem=effect_bold&'}, {'\uae30\uc5c5\uba85': '(주)쎄미시스코', '\uc9c1\ubb34': '㈜쎄미시스코 소프트웨어 개발자 경력직 모집', '\uacbd\ub825\uc0ac\ud56d': '경력 1년↑', '\ud559\ub825': '대학(2,3년)↑', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '경기 수원시', '\ubd84\ub958': ['반도체·디스플레이·LCD', '서버·네트워크·보안'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38597487&adsCategoryItem=effect_bold&'}, {'\uae30\uc5c5\uba85': '(주)와이비시스템', '\uc9c1\ubb34': '개발자 담당 경력 정규직 채용', '\uacbd\ub825\uc0ac\ud56d': '경력', '\ud559\ub825': '학력무관', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 서초구', '\ubd84\ub958': ['웹기획·PM', '웹개발'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579699&adsCategoryItem=effect_bold&'}, {'\uae30\uc5c5\uba85': '국제컴퓨터아카데미', '\uc9c1\ubb34': '[100%무료 취업준비생모집]웹디/건축/게임/프로그래밍/3D프린터', '\uacbd\ub825\uc0ac\ud56d': '신입 · 경력', '\ud559\ub825': '학력무관', '\uadfc\ubb34\ud615\ud0dc': '교육생', '\uadfc\ubb34\uc9c0': '서울 관악구', '\ubd84\ub958': ['그래픽디자인·CG', '제품·산업디자인'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=34393991'}, {'\uae30\uc5c5\uba85': '(주)트랜스코스모스코리아', '\uc9c1\ubb34': '당사 프로젝트 개발 및 유지보수 담당자(신입/경력)Mj5E', '\uacbd\ub825\uc0ac\ud56d': '신입 · 경력', '\ud559\ub825': '학력무관', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 용산구', '\ubd84\ub958': ['웹개발', '응용프로그램개발'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38512364'}, {'\uae30\uc5c5\uba85': '행복쇼핑(주)', '\uc9c1\ubb34': 'PHP/REACT/PYTHON/퍼블리셔 경력자 채용', '\uacbd\ub825\uc0ac\ud56d': '경력 3년↑', '\ud559\ub825': '대학(2,3년)↑', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 영등포구', '\ubd84\ub958': ['웹개발', '응용프로그램개발'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38550645&adsCategoryItem=effect_bold&'}, {'\uae30\uc5c5\uba85': '(주)세원아토스', '\uc9c1\ubb34': 'ERP 신입, 경력 개발자를 모십니다.', '\uacbd\ub825\uc0ac\ud56d': '신입 · 경력', '\ud559\ub825': '대학(2,3년)↑', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 구로구', '\ubd84\ub958': ['웹개발', '응용프로그램개발'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38602619'}  ... displaying 10 of 1038 total bound parameter sets ...  {'\uae30\uc5c5\uba85': '굿커리어', '\uc9c1\ubb34': '유명 대기업 바이오회사 빅데이터 플랫폼 개발 대리,과장', '\uacbd\ub825\uc0ac\ud56d': '경력 4년↑', '\ud559\ub825': '대학교(4년)↑', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 강남구', '\ubd84\ub958': ['기획·전략·경영', '응용프로그램개발'], '\uc0c1\uc138\ub9c1\ud06c': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38531206'}, {'\uae30\uc5c5\uba85': '(주)코어잡', '\uc9c1\ubb34': '패션 중견 기업 자사몰 개발 Product Manager 정규직 과장-부장', '\uacbd\ub825\uc0ac\ud56d': '경력 5년↑', '\ud559\ub825': '대학교(4년)↑', '\uadfc\ubb34\ud615\ud0dc': '정규직', '\uadfc\ubb34\uc9c0': '서울 강남구', '\ubd84\ub958': ['웹개발'], '\uc0c1\uc ...

# %%
import pymysql
import sqlalchemy
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("mysql+mysqldb://minji:"+"minji"+"@192.168.0.25:3306/poor_db", encoding="utf-8")
conn = engine.connect()

jobs_dict = {"jobs_cloud": company_list_cloud, "jobs_python": company_list_python, "jobs_db": company_list_db}

for table_name, jobs in jobs_dict.items():
    print("\n", table_name, "\n")
    jobs_df = pd.DataFrame(columns=['기업명', '직무', '경력사항', '학력', '근무형태', '근무지', '분류', '상세링크'])
    
    for post in jobs:
        obj = pd.Series(post)
        jobs_df = news_df.append(obj, ignore_index=True)
        print(article)
    
    news_df.to_sql(name=table_name, con=engine, if_exists='replace', index=True, index_label='id')
