# %%
#library import 하기

import requests
from bs4 import BeautifulSoup
import re
from urllib.parse import urljoin

# %%
# 클라우드 직업 스크래핑

job_list_cloud = []
page_num = 1
main_url = 'http://www.saramin.co.kr'

while True:
    url = f'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page={page_num}&cat_key=41704%2C40220&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=1'
    req_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    }
    html = requests.get(url, req_header).text
    soup = BeautifulSoup(html, 'html.parser')
    
    # 만약 더이상 페이지 리스트에 공고가 없을 경우 break
    if soup.select('div.list_body div.list_item') == []:
        break
    for tag in soup.select('div.list_body div.list_item'):
        company_dict = {}
        company_dict["기업명"] = tag.select('div.company_nm a span')[0].text
        company_dict["직무"] = tag.select('div.notification_info a span')[0].text
        company_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
        company_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
        # 근무형태가 빈칸인 직무들도 있음
        try:
            company_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
        except:
            company_dict["근무형태"] = ""
        try:    
            company_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
        except:
            company_dict["근무지"] = ""
        category_list = []
        # 분류는 여러가지가 있기 때문에 리스트 형태로 저장
        for item in tag.select('div.notification_info div.job_meta span span'):
            category_list.append(item.text)
        company_dict["분류"] = str(category_list)
        company_dict["분류필터"] = "cloud"
        
        detail_url = tag.select_one('div.notification_info a').attrs['href']
        full_detail_url = urljoin(main_url, detail_url)
        company_dict["상세링크"] = full_detail_url
        job_list_cloud.append(company_dict)
    page_num += 1
job_list_cloud
# Out:
# 지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38681621'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[헤딩머니 150만원/ 스타일쉐어] DevOps Engineer 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38681615'},
#  {'기업명': '(주)브이비젼',
#   '직무': '[글로벌벤처그룹] React-Native 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38680991'},
#  {'기업명': '(주)맨파워코리아',
#   '직무': '[외국계 SCM 기업] DevOps Engineer (Hong)',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['ERP·시스템분석·설계', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38659856'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '렌탈 시스템 구축 프로젝트 PL업무 수행 Spring framework',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679732'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '그룹 HR 공유 Infra HRIS 시스템 구축',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679718'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '렌탈 시스템 구축 프로젝트 PL업무 수행 시스템 개발',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679716'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '그룹 HR 공유 Infra HRIS 시스템 구축 SaaS  Cloud',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679704'},
#  {'기업명': '제이케이서치 주식회사',
#   '직무': '[유명 화장품 중견기업] 인프라 엔지니어 채용',
#   '경력사항': '5 ~ 8년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38678646'},
#  {'기업명': '유비스 코리아',
#   '직무': 'AR앱개발사 서버 개발자',
#   '경력사항': '3 ~ 13년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38654304'},
#  {'기업명': '주식회사라피플코리아리미티드',
#   '직무': '스포츠 IT 벤처기업 - 풀스택 개발자',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38675775'},
#  {'기업명': '주식회사라피플코리아리미티드',
#   '직무': '스포츠 IT 벤처기업 - 백엔드 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38632485'},
#  {'기업명': '주식회사라피플코리아리미티드',
#   '직무': '스포츠 IT 벤처기업 - 프론트엔드 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38633268'},
#  {'기업명': '(주)브이비젼',
#   '직무': '[글로벌벤처그룹] Back-end 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38674541'},
#  {'기업명': '(주)헤리티지에이치알코리아',
#   '직무': '[환경가전 1위기업] 정보시스템 운영/개발(정보시스템 담당자)',
#   '경력사항': '5 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38673030'},
#  {'기업명': '베스트네트워크㈜',
#   '직무': '16. [자동차기업] IT 인프라 구축 전문가 정규직 채용',
#   '경력사항': '경력 8년↓',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38667479'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 인프라 가상화 기술기반 서비스 개발 경력자',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666456'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 프론트엔드(FrontEnd) 개발 경력자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666453'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 백엔드(BackEnd) 개발 경력자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666442'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 플랫폼 영업(Sales) 경력직 채용',
#   '경력사항': '경력 7년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['IT·솔루션영업', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666438'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 사업기획 경력직 채용',
#   '경력사항': '5 ~ 12년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['기획·전략·경영', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666432'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 플랫폼/응용상품기획 경력자',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666412'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 인프라 상품기획 경력자',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666409'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 보안상품 웹 서비스 개발 경력자',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['IT·디자인·컴퓨터교육', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666404'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 서비스 (개발자도구) 개발자',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666401'},
#  {'기업명': '커리어커넥트(주)',
#   '직무': '대형금융그룹 IT운영팀원 (WAS / Cloud 금융권 경력자) 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38665724'},
#  {'기업명': '(주)연세교육아카데미ㅣ연세직업전문학교',
#   '직무': '정보보안(모의해킹) 및 클라우드 강사 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '전임 · 계약직',
#   '근무지': '경기 수원시 장안구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38659283'},
#  {'기업명': '로버트월터스코리아(주)',
#   '직무': '[글로벌/IT/엔지니어] DevOps/System Engineer',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38658493'},
#  {'기업명': '(주)에이치알비즈코리아',
#   '직무': '데이터 분석 경력 채용 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38655901'},
#  {'기업명': '(주)브레인센터',
#   '직무': '대기업 클라우드 기획자 (계약직 : 과장~차장급)',
#   '경력사항': '6 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 중구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38652788'},
#  {'기업명': '오픈포지션',
#   '직무': '온라인 서비스 Mobile App 개발자/대리과장급/ 환경가전 대기업',
#   '경력사항': '7 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38651671'},
#  {'기업명': '(주)HR컨설팅그룹',
#   '직무': '(코스닥상장사) 클라우드엔지니어',
#   '경력사항': '5 ~ 14년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649223'},
#  {'기업명': '로버트월터스코리아(주)',
#   '직무': '[글로벌/IT/개발자] Full Stack Developer',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38637203'},
#  {'기업명': '피플워크(주)',
#   '직무': '인공지능 딥러닝기반 영상인식 처리 알고리즘 개발',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '통신·모바일']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38626706'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '응용프로그램 서버 개발자 C++ MFC Linux 개발자 CTI, IVR 개발',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38702180'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '응용프로그램 서버 개발자 C++ MFC Linux 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38702166'},
#  {'기업명': '제이피스 주식회사',
#   '직무': 'LG전자 본사 AI/Dig Data 관련 사무보조 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 강서구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38609512'},
#  {'기업명': '(주)탑앤스카우트',
#   '직무': '[AI, IoT] 공공프로젝트 PM 충원',
#   '경력사항': '경력 8년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38687672'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '(가전 및 생활용품 기업) 데이터 엔지니어',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692602'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '(가전 및 생활용품 기업) 모바일 앱(안드로이드) 개발자',
#   '경력사항': '경력 7년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692575'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[모바일 애드테크 전문기업] 백엔드 엔지니어(대리-과장)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38660129'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 최고 대기업 - 온라인 플랫폼 시스템기획 - 최우대',
#   '경력사항': '경력 10년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693355'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 온라인 플랫폼 시스템 기획 - 최고 대기업 - 최우대',
#   '경력사항': '경력 10년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693354'},
#  {'기업명': '(주)유앤파트너즈',
#   '직무': '마이데이터  및 빅데이타 컨설턴트',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38671463'},
#  {'기업명': '피플워크(주)',
#   '직무': 'AI(인공지능) 딥러닝기반 영상인식 처리 알고리즘 개발',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '통신·모바일']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692250'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692204'},
#  {'기업명': '(주)에이치알맨파워그룹',
#   '직무': 'IT분야 QA(품질보증) 경력사원 모집',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38678529'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 Java, Oracle',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38686018'},
#  {'기업명': '(주)헬로서치',
#   '직무': '[대기업 IT사] 빅데이터 엔지니어 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653269'},
#  {'기업명': '(주)맨파워코리아',
#   '직무': '[외국계 SCM 기업] DevOps Engineer (Big data) (Hong)',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['ERP·시스템분석·설계', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38659838'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Digital Healthcare 플랫폼 서비스 기획원 신약개발 상장사',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679727'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Digital Healthcare 플랫폼 서비스 기획원',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679725'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679720'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Digital Healthcare 빅데이터 플랫폼 전문가',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679707'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Battery 생산지원시스템(QMS/SCM/EMS) 구축 및 Global 확산/운영',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 동구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679706'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 java',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679705'},
#  {'기업명': '(주)브이비젼',
#   '직무': '[글로벌벤처그룹] front-end 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38674517'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[분당] Javascript활용 자동화 개발 및 유지보수 지원-신입가능',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38659832'},
#  {'기업명': '피플워크(주)',
#   '직무': 'AI(인공지능) 딥러닝기반 의료영상처리 알고리즘 개발(5-12년)',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '통신·모바일']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38673146'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Battery 생산지원시스템(QMS/SCM/EMS) 구축',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 동구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38673127'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자 SAP',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38673118'},
#  {'기업명': '(주)피플케어코리아',
#   '직무': 'Partner Sales Enablement Manager (SW/Solution)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['IT·솔루션영업', '영업기획·관리·지원']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38672368'},
#  {'기업명': '(주)헬로서치',
#   '직무': '(대기업) 인프라보안 담당자 채용',
#   '경력사항': '8 ~ 14년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653288'},
#  {'기업명': '에이치알클릭',
#   '직무': '스마트폰 서비스 개발 기획 담당자 긴급 채용',
#   '경력사항': '6 ~ 13년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38665703'},
#  {'기업명': '에이치알니즈',
#   '직무': '[대기업 계열사]  QA 채용',
#   '경력사항': '5 ~ 11년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹마스터·QA·테스터', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38663570'},
#  {'기업명': '(주)스카우트',
#   '직무': '글로벌기업 카테고리매니저 대리과장급',
#   '경력사항': '7 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653342'},
#  {'기업명': '(주)유앤파트너즈',
#   '직무': '[대기업계열] 데이터 전략 컨설턴트 / AI사업부  팀장外',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38639110'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '[삼성물산/연봉상위] 모바일 앱 및 웹 운영 경력 개발자 채용',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591901'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '[삼성물산/잠실역] 모바일 앱 및 웹 운영 경력 개발자 채용',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570689'}]

# %%
# 파이썬 직업 스크래핑

job_list_python = []
page_num = 1
main_url = 'http://www.saramin.co.kr'

while True:
    url = f'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page={page_num}&cat_key=41711%2C40721%2C40426&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=1#searchTitle'
    req_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    }
    html = requests.get(url, req_header).text
    soup = BeautifulSoup(html, 'html.parser')
    if soup.select('div.list_body div.list_item') == []:
        break
    for tag in soup.select('div.list_body div.list_item'):
        company_dict = {}
        company_dict["기업명"] = tag.select('div.company_nm a span')[0].text
        company_dict["직무"] = tag.select('div.notification_info a span')[0].text
        company_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
        company_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
        try:
            company_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
        except:
            company_dict["근무형태"] = ""
        try:    
            company_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
        except:
            company_dict["근무지"] = ""
        category_list = []
        for item in tag.select('div.notification_info div.job_meta span span'):
            category_list.append(item.text)
        company_dict["분류"] = str(category_list)
        company_dict["분류필터"] = "python"
        
        detail_url = tag.select_one('div.notification_info a').attrs['href']
        full_detail_url = urljoin(main_url, detail_url)
        company_dict["상세링크"] = full_detail_url
        job_list_python.append(company_dict)
    page_num += 1
job_list_python
# Out:
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38668137'},
#  {'기업명': '보보스링크(주)',
#   '직무': 'AI개발 신입-사원급 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강동구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690277'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[모바일 애드테크 전문기업] Front-end 엔지니어(대리-과장)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38660082'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[모바일 애드테크 전문기업] 백엔드 엔지니어(대리-과장)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38660129'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[모바일 애드테크 전문기업] 프론트엔드 엔지니어(대리-과장)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38660144'},
#  {'기업명': '굿커리어',
#   '직무': '유명 대기업 합작사 모바일앱 개발자 과장,차장',
#   '경력사항': '7 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679780'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 커머스 통합 주문/재고 시스템 기술PM - 업계 최고 대기업',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693376'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 업계 최고 대기업 - 커머스 통합 주문/재고 시스템 기술PM',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693375'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 최고 대기업 - Data Modeler - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693374'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) Data Modeler - 최고 대기업 - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693368'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 최고 대기업 - 통합 OMS 기술PM (물류시스템 통합)-최우대',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693357'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 통합 OMS 기술PM (물류시스템 통합) - 최고 대기업-최우대',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693356'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 최고 대기업 - 온라인 플랫폼 시스템기획 - 최우대',
#   '경력사항': '경력 10년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693355'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 온라인 플랫폼 시스템 기획 - 최고 대기업 - 최우대',
#   '경력사항': '경력 10년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693354'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) e커머스 - 소프트웨어 개발자 (JavaScript, Node.js)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693323'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 회원 플랫폼 기술PM (회원,인증,멤버십,CRM 등) - 대기업',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693298'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) Technical Product Manager (블록체인)  - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693297'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 블록체인 Technical Product Manager  - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693282'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 플랫폼 기술PM - 최고 대기업 - 최우대',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693270'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 최고 대기업 - 플랫폼 기술PM - 최우대',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693268'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) Data Manager - 업계 최고 대기업 - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693267'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 소프트웨어 개발자 (JavaScript, Node.js) - e커머스',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693261'},
#  {'기업명': '커리어셀파',
#   '직무': '[유통대기업] IT개발 경력사원 채용',
#   '경력사항': '4 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38694395'},
#  {'기업명': '(주)커리어멘토',
#   '직무': '(1.VISION제어/ 2 PC제어/ 3.VISION SW개발/4.모션제어',
#   '경력사항': '4 ~ 12년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기계·기계설비', '전기·전자·제어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38694048'},
#  {'기업명': '비전서치',
#   '직무': '업데이트용 sw 개발',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693704'},
#  {'기업명': '에버브레인컨설팅(주)',
#   '직무': '[국내최대 오픈마켓]서비스/플랫폼 QA',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692365'},
#  {'기업명': '에버브레인컨설팅(주)',
#   '직무': '[국내최대 오픈마켓] Payment 서비스 기획',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692364'},
#  {'기업명': '에버브레인컨설팅(주)',
#   '직무': '[국내최대 오픈마켓] Data Architect',
#   '경력사항': '3 ~ 10년',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692360'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'SW연구개발 대리과장급 Restful API',
#   '경력사항': '경력 4년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692244'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '그룹 HR 공유 Infra HRIS 시스템 구축 SaaS 솔루션 클라우드',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692228'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'SW연구개발 대리과장급',
#   '경력사항': '경력 4년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692220'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692204'},
#  {'기업명': '(주)에이치알맨파워그룹',
#   '직무': '금융 시스템 개발 대리~과(차)장급 경력사원 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38676036'},
#  {'기업명': '(주)에이치알맨파워그룹',
#   '직무': '금융시스템 유지보수 대리~과장급 경력사원 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38676154'},
#  {'기업명': '탑커리어인사이트',
#   '직무': '빅데이터 플랫폼 엔지니어 경력사원 채용 (경력 5년 이상)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38680056'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[헤딩머니 100만원/더쿠스아이앤씨 ] Mobile Software Engineer',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38691627'},
#  {'기업명': '한스컨설팅',
#   '직무': '영등포 위치 국내 1위 구매 SCM솔루션기업 AI개발 대리급',
#   '경력사항': '3 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38691276'},
#  {'기업명': '㈜에이치알맨파워그룹',
#   '직무': '[대기업-상장사] AI알고리즘 (박사연구원-서울)',
#   '경력사항': '신입 · 경력',
#   '학력': '박사',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38686171'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 Java, Oracle',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38686018'},
#  {'기업명': '위키에이드',
#   '직무': '영상처리 / 머신비전 검사 SW 개발 경력',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 화성시',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38685798'},
#  {'기업명': '헤리티지서치코어',
#   '직무': '솔루션영업/경력 5년이상/유명 IT 솔루션기업',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38685656'},
#  {'기업명': '인비즈써치',
#   '직무': '대형증권사 시스템트레이딩 및 로보어드바이저 시스템 개발 모집',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38683166'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '렌탈 시스템 구축 프로젝트 PL업무 수행 Spring framework',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679732'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679720'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '그룹 HR 공유 Infra HRIS 시스템 구축',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679718'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '렌탈 시스템 구축 프로젝트 PL업무 수행 시스템 개발',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679716'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Battery 생산지원시스템(QMS/SCM/EMS) 구축 및 Global 확산/운영',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 동구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679706'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 java',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679705'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '그룹 HR 공유 Infra HRIS 시스템 구축 SaaS  Cloud',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679704'},
#  {'기업명': '(주)솔루게이트',
#   '직무': '[파트 및 아르바이트] 사무보조 및 개발자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '파트 · 아르바이트',
#   '근무지': '서울 금천구',
#   '분류': "['총무·법무·사무', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38676395'},
#  {'기업명': '주식회사라피플코리아리미티드',
#   '직무': '스포츠 IT 벤처기업 - 풀스택 개발자',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38675775'},
#  {'기업명': '주식회사라피플코리아리미티드',
#   '직무': '스포츠 IT 벤처기업 - 백엔드 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38632485'},
#  {'기업명': '주식회사라피플코리아리미티드',
#   '직무': '스포츠 IT 벤처기업 - 프론트엔드 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38633268'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Battery 생산지원시스템(QMS/SCM/EMS) 구축',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 동구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38673127'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자 SAP',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38673118'},
#  {'기업명': 'FNR Consulting',
#   '직무': '국내 Community Service회사 CTO (글로벌 투자 회사 투자 유치)',
#   '경력사항': '7 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38672157'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': 'IT/ICT 소프트웨어 엔지니어',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시 영통구',
#   '분류': "['시스템개발', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666551'},
#  {'기업명': '(주)헬로서치',
#   '직무': '[국내우량기업]딥러닝 개발 인재를 모십니다.',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38659897'},
#  {'기업명': '(주)연세교육아카데미ㅣ연세직업전문학교',
#   '직무': '정보보안(모의해킹) 및 클라우드 강사 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '전임 · 계약직',
#   '근무지': '경기 수원시 장안구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38659283'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '외국계 반도체회사 R&D S/W 연구원(경력) 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649126'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '외국계 회사 Video System R&D Software Engineer 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649125'},
#  {'기업명': '(주)에이치알인재그룹',
#   '직무': '사무자동화(RPA) 개발 경력채용',
#   '경력사항': '4 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 김포시',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648271'},
#  {'기업명': '(주)쿠자피에이에스',
#   '직무': '개발자 SW개발 팀장급 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '울산 중구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38647730'},
#  {'기업명': '그린컴퓨터아트학원 아카데미 성남/분당 ..',
#   '직무': '[국기] JAVA기반(웹,앱,빅데이터) 개발자 과정 훈련교.강사 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '전임 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38629645'},
#  {'기업명': '그린컴퓨터아트학원 아카데미 성남/분당 ..',
#   '직무': '[국가기간] 디지털컨버전스(JAVA기반), 빅데이터취업 국비교육',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '위촉직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38632622'},
#  {'기업명': '그린컴퓨터아카데미',
#   '직무': '자바(JAVA) 개발 / 응용SW 직업훈련교사(강사) 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '울산 남구',
#   '분류': "['웹개발', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38643837'},
#  {'기업명': '(주)핀커스코리아',
#   '직무': '유명기업 웹개발 경력채용(3년~7년)',
#   '경력사항': '3 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38640208'},
#  {'기업명': '㈜에이치알맨파워그룹',
#   '직무': '[대기업] AI알고리즘-박사 (서울)',
#   '경력사항': '신입 · 경력',
#   '학력': '박사',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38635195'},
#  {'기업명': '하이잡',
#   '직무': '추천 시스템 연구/개발',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38634020'},
#  {'기업명': '그린컴퓨터아카데미',
#   '직무': '자바(JAVA) 웹프로그래밍개발 직업훈련교사(강사) 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '울산 남구',
#   '분류': "['웹개발', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38600945'}]

# %%
# db 직업 스크래핑

job_list_db = []
page_num = 1
while True:
    url = f'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page={page_num}&cat_cd=416&cat_key=40745&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=2#searchTitle'
    req_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    }
    html = requests.get(url, req_header).text
    soup = BeautifulSoup(html, 'html.parser')
    if soup.select('div.list_body div.list_item') == []:
        break
    for tag in soup.select('div.list_body div.list_item'):
        company_dict = {}
        company_dict["기업명"] = tag.select('div.company_nm a span')[0].text
        company_dict["직무"] = tag.select('div.notification_info a span')[0].text
        company_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
        company_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
        try:
            company_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
        except:
            company_dict["근무형태"] = ""
        try:    
            company_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
        except:
            company_dict["근무지"] = ""
        category_list = []
        for item in tag.select('div.notification_info div.job_meta span span'):
            category_list.append(item.text)
        company_dict["분류"] = str(category_list)
        company_dict["분류필터"] = "db"
        
        detail_url = tag.select_one('div.notification_info a').attrs['href']
        full_detail_url = urljoin(main_url, detail_url)
        company_dict["상세링크"] = full_detail_url
        job_list_db.append(company_dict)
    page_num += 1
job_list_db
# Out:
# 사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693313'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 커머스/플랫폼 백엔드 개발 (Java,Spring,AWS 등) -최우대',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693296'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) Data Architect - 초일류 대기업 - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693291'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 초일류 대기업 - Data Architect - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693290'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 업계 최고 대기업 - 머신러닝 엔지니어 (이커머스 분야)',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693262'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 커머스/플랫폼 웹개발 (Back-End) - 최고 대기업 - 최우대',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693256'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 백오피스 개발 (Java, NoSQL 등) - 최고 대기업 - 최우대',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693255'},
#  {'기업명': '(주)스카우트플랜',
#   '직무': 'DBA (DW 구축)',
#   '경력사항': '3 ~ 6년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38641650'},
#  {'기업명': '(주)휴먼트리월드와이드',
#   '직무': '유명게임사) 데이터엔지니어링 (2년이상)',
#   '경력사항': '2 ~ 5년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38694136'},
#  {'기업명': '비전서치',
#   '직무': '데이터 아키텍트 DA',
#   '경력사항': '5 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693741'},
#  {'기업명': '(주)케이비앤파트너즈',
#   '직무': '[엔지니어/인천] 시티은행 인천데이터센터 상주 Database Admin.',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 남동구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692234'},
#  {'기업명': '탑커리어인사이트',
#   '직무': 'DBA 경력직 채용 (경력 3년 이상)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38680060'},
#  {'기업명': '갤리언컨설팅그룹',
#   '직무': '[스마트팩토리전문기업] Web 개발자',
#   '경력사항': '3 ~ 9년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690721'},
#  {'기업명': '엔터웨이파트너스',
#   '직무': '국내유명생명보험사- DataMart 기획자(대리~과장)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38688978'},
#  {'기업명': '(주)유앤파트너즈',
#   '직무': '[유망 유통/ T-커머스 W사 ] DBA ( Oracle ) 관리자',
#   '경력사항': '3 ~ 6년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38688073'},
#  {'기업명': '에스에프인촌',
#   '직무': '전산실 시스템 개발 및 운영 경력사원 - 자동차부품 우량대기업',
#   '경력사항': '4 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', 'ERP·시스템분석·설계']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38688045'},
#  {'기업명': '에스에프인촌',
#   '직무': 'MES시스템 개발 및 운영 경력사원 - 자동차부품 우량대기업',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', 'ERP·시스템분석·설계']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38688040'},
#  {'기업명': '(주)에이치알그룹',
#   '직무': '[앱 서비스 플랫폼 개발] java - 대기업 계열사',
#   '경력사항': '8 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38670785'},
#  {'기업명': '삼신테크',
#   '직무': '[분당/상암/대구] 한국정보통신기술협회 SW 시험인증분야',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '파견직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38686081'},
#  {'기업명': '맨쉬 컨설팅 주식회사',
#   '직무': '유명 대기업 금융사 API 플랫폼개발 및 운영 담당자',
#   '경력사항': '4 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38680040'},
#  {'기업명': '맨쉬 컨설팅 주식회사',
#   '직무': '유명 대기업 금융사 Application Developer  모집',
#   '경력사항': '8 ~ 14년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38680032'},
#  {'기업명': '(주)페퍼저축은행',
#   '직무': '페퍼저축은행 정보시스템본부 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679431'},
#  {'기업명': '(주)투맨서치',
#   '직무': '전산실 전산개발자 경력직 모집 공고',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38678648'},
#  {'기업명': '(주)브레인뱅크',
#   '직무': '영상기기 소프트웨어 개발 경력 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38671251'},
#  {'기업명': '(주)드림에이치알',
#   '직무': '국내최고 디지털콘텐츠스토어 기업 앱마켓 서비스 플랫폼 개발',
#   '경력사항': '경력 8년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38669560'},
#  {'기업명': '(주)케이원파트너스컴퍼니',
#   '직무': '[유망 IT 기업] DB개발',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['해외영업·무역영업', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38667677'},
#  {'기업명': '(주)트루에이치알',
#   '직무': '(혁신스타트업 매출 8천억이상기업) Data Infra Operation',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38664359'},
#  {'기업명': '(주)트루에이치알',
#   '직무': '(혁신스타트업 매출 8천억이상기업) DBA',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38664258'},
#  {'기업명': '오픈포지션',
#   '직무': '네트워크 보안/엔드포인트 보안운영/환경가전대기업',
#   '경력사항': '8 ~ 14년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38661828'},
#  {'기업명': '(주)피플케어코리아',
#   '직무': 'Cloud DB Migration',
#   '경력사항': '경력 8년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38658053'},
#  {'기업명': '(주)스카우트',
#   '직무': 'IT기획(전사Data관리 및 IT기획) 경력자',
#   '경력사항': '7 ~ 14년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38657943'},
#  {'기업명': '(주)피플렙',
#   '직무': 'ICT개발(전자금융) [저축은행그룹 모기업]',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649154'},
#  {'기업명': '(주)피플렙',
#   '직무': 'ICT개발(뱅킹시스템) [저축은행그룹 모기업]',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649152'},
#  {'기업명': '갤리언컨설팅그룹',
#   '직무': '[시스템운영 대리,과장급 경력자] 유명 IT기업 인재 채용',
#   '경력사항': '3 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 김포시',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648861'},
#  {'기업명': '㈜피플스카우트',
#   '직무': '[중견사]오라클 DB관리자/신입사원-주임급',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38647165'},
#  {'기업명': '(주)유비소시어스',
#   '직무': 'IT 솔루션기업, DBA 경력자 모집',
#   '경력사항': '2 ~ 8년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38646128'},
#  {'기업명': '㈜에이치알맨파워그룹',
#   '직무': '그룹계열사 OTA 서비스 운영개발',
#   '경력사항': '5 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38646049'},
#  {'기업명': '㈜에이치알맨파워그룹',
#   '직무': '그룹계열사 센터통신 서비스 운영',
#   '경력사항': '4 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38646024'},
#  {'기업명': 'HR컨설팅(주)',
#   '직무': '[ICT그룹] 데이터엔지니어 (BI/DW/DM/ETL) (2년-7년)',
#   '경력사항': '2 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['ERP·시스템분석·설계', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38644520'},
#  {'기업명': '㈜피플스카우트',
#   '직무': '[중견사]DW 데이타베이스 구축 DBA 경력자',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38643647'},
#  {'기업명': '(주)사람인에이치에스',
#   '직무': '(하림그룹/정규직)신입기준 월 300만, 대리이상 IT경력직 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강동구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38636880'},
#  {'기업명': '(주)헬로서치',
#   '직무': '유명게임사 DBA 담당자 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38635367'},
#  {'기업명': '하이잡',
#   '직무': '[IT 대기업] MongoDB Engineer',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38634023'},
#  {'기업명': 'SMI',
#   '직무': '[서울 강남] 서버개발 (서버 컴포넌트 개발 및 SW 설계)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38630948'},
#  {'기업명': '(주)잡뉴스솔로몬서치',
#   '직무': 'IT기업 세종근무 DBA 데이터 분석설계 R&D 과차장급 경력자',
#   '경력사항': '7 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['ERP·시스템분석·설계', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38628523'},
#  {'기업명': '(주)제이티에스코퍼레이션',
#   '직무': '외국계 회사 물류 DB 설계& 개발 시스템 (정규직)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['ERP·시스템분석·설계', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38595378'},
#  {'기업명': '(주)엠아이티마스',
#   '직무': '[국내기업] Oracle DBA Admin채용/ 판교',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38420508'},
#  {'기업명': '(주)코리아인에이치알',
#   '직무': '[KT연구소내/프로젝트] JAVA 개발자 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38697395'},
#  {'기업명': '(주)인큐브시스템',
#   '직무': '[대기업계열사]  Technical Architect 경력직 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38663144'},
#  {'기업명': '(주)인큐브시스템',
#   '직무': '[대기업계열사]  Data Scientist 경력직 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38663081'},
#  {'기업명': '한스컨설팅',
#   '직무': '판교 위치 국내 1위 온라인게임회사 시스템엔지니어 대리급',
#   '경력사항': '3 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38701289'},
#  {'기업명': '제이피스 주식회사',
#   '직무': 'LG전자 본사 AI/Dig Data 관련 사무보조 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 강서구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38609512'},
#  {'기업명': '(주)핀커스코리아',
#   '직무': '외국계  -  디지털  분석   채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['마케팅·광고·분석', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38691121'},
#  {'기업명': '(주)탑앤스카우트',
#   '직무': '[보안솔루션] DBA DB운영 경력직 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38687686'},
#  {'기업명': '㈜피플스카우트',
#   '직무': '[강소기업]서버 개발자(C++, MFC, Linux)',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38700109'},
#  {'기업명': '(주)스카우트',
#   '직무': '디지털 헬스케어 개발/운영 CTO or Technical Leader',
#   '경력사항': '경력 10년↑',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38651612'},
#  {'기업명': '(주)스카우트',
#   '직무': 'B2C 헬스케어 서비스 개발 PL',
#   '경력사항': '경력 8년↑',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38651598'},
#  {'기업명': '로버트월터스코리아(주)',
#   '직무': '[글로벌/웹/모바일서비스/개발자] Data Engineer',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38699112'},
#  {'기업명': '유비스 코리아',
#   '직무': '초우량상장사 스마트팩토리 개발 대리차장급 채용',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38698746'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '(가전 및 생활용품 기업) 데이터 엔지니어',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692602'},
#  {'기업명': '(주)핀커스코리아',
#   '직무': '외국계  -  디지털  분석   전문가  채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['마케팅·광고·분석', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38698259'},
#  {'기업명': '(주)에이치알그룹',
#   '직무': '[QA, 테스트 자동화]  - 대기업 계열사',
#   '경력사항': '4 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹마스터·QA·테스터', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38670810'},
#  {'기업명': '㈜피플스카우트',
#   '직무': '[대기업/그룹사]서버 개발자/사원-대리급 .0',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38696524'},
#  {'기업명': '파워에이치알',
#   '직무': '[코스닥-보안솔루션] 모바일개발(Android, iOS)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '통신·모바일']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38667361'},
#  {'기업명': '파워에이치알',
#   '직무': '[중견 IT솔루션] 웹솔루션 및 서비스 개발',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38674249'},
#  {'기업명': '파워에이치알',
#   '직무': '[주요 SI업체] Cloud 분야 아키텍트(4개포지션)',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648641'},
#  {'기업명': '(주)비에이블컨설팅그룹',
#   '직무': '자바(JAVA) 개발자 (Spring Framework, DB)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38695633'},
#  {'기업명': '(주)비에이블컨설팅그룹',
#   '직무': 'C,C++ 개발 (영상관제, 스마트시티 보안 솔루션)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38695612'},
#  {'기업명': '(주)사람과기술',
#   '직무': '코스닥 상장 보안솔루션 기업 DBA 경력 채용',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38695417'},
#  {'기업명': '(주)한국코퍼레이션',
#   '직무': '[본사] 자바솔루션개발 신입/경력 채용공고',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38695263'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '(창원) 제조업체 전산실 부서장 [ERP/MES]',
#   '경력사항': '경력 10년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경남 창원시',
#   '분류': "['응용프로그램개발', 'ERP·시스템분석·설계']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38654870'},
#  ...]

# %%
job_list = job_list_cloud + job_list_python + job_list_db

# %%
# local db에 job_list 저장하기

import pymysql
import sqlalchemy
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("mysql+mysqldb://django:"+"poordjango"+"@poordb.cubqrb9xgtzf.us-east-1.rds.amazonaws.com/poor_db", encoding="utf-8")
conn = engine.connect()

jobs_df = pd.DataFrame(columns=['기업명', '직무', '경력사항', '학력', '근무형태', '근무지', '분류', '분류필터', '상세링크'])

for post in job_list:
    obj = pd.Series(post)
    jobs_df = jobs_df.append(obj, ignore_index=True)
    
jobs_df.to_sql(name="job_list", con=engine, if_exists='replace', index=True, index_label='id')

# %%
# remote db(멀캠 컴퓨터)에 job_list 저장하기
import pymysql
import sqlalchemy
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("mysql+mysqldb://root:"+"root"+"@localhost:3307/poor_db", encoding="utf-8")
conn = engine.connect()

jobs_dict = {"jobs_cloud": company_list_cloud, "jobs_python": company_list_python, "jobs_db": company_list_db}

for table_name, jobs in jobs_dict.items():
    print("\n", table_name, "\n")
    jobs_df = pd.DataFrame(columns=['기업명', '직무', '경력사항', '학력', '근무형태', '근무지', '분류', '상세링크'])
    
    for post in jobs:
        obj = pd.Series(post)
        jobs_df = jobs_df.append(obj, ignore_index=True)
        print(post)
    
    jobs_df.to_sql(name=table_name, con=engine, if_exists='replace', index=True, index_label='id')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-11a2035904be> in <module>
#       9 conn = engine.connect()
#      10
# ---> 11 jobs_dict = {"jobs_cloud": company_list_cloud, "jobs_python": company_list_python, "jobs_db": company_list_db}
#      12
#      13 for table_name, jobs in jobs_dict.items():
#
# NameError: name 'company_list_cloud' is not defined

# %%
# Web Scrapping Function
def scrapping(url_front, url_back, name):
    page_num = 1
    job_list = []
    while True:
        url = urljoin(url_front, str(page_num), url_back)
        req_header = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
        }
        html = requests.get(url, req_header).text
        soup = BeautifulSoup(html, 'html.parser')

        # 만약 더이상 페이지 리스트에 공고가 없을 경우 break
        if soup.select('div.list_body div.list_item') == []:
            break


        for tag in soup.select('div.list_body div.list_item'):

            # 기본정보
            job_dict = {}
            job_dict["기업명"] = tag.select('div.company_nm a span')[0].text
            job_dict["직무"] = tag.select('div.notification_info a span')[0].text
            job_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
            job_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
            job_dict["분류필터"] = name


            # 근무형태 / 근무지 - 빈칸인 경우도 있음
            try:
                job_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
            except:
                job_dict["근무형태"] = ""
            try:    
                job_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
            except:
                job_dict["근무지"] = ""

            # 분류는 여러가지가 있기 때문에 리스트 형태로 저장              
            category_list = []
            for item in tag.select('div.notification_info div.job_meta span span'):
                category_list.append(item.text)
            job_dict["분류"] = str(category_list)

            #상세 url
            detail_url = tag.select_one('div.notification_info a').attrs['href']
            full_detail_url = urljoin(main_url, detail_url)
            job_dict["상세링크"] = full_detail_url
            job_list.append(job_dict)
        page_num += 1
