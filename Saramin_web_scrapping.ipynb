# %%
#library import 하기

import requests
from bs4 import BeautifulSoup
import re
from urllib.parse import urljoin

# %%
# 클라우드 직업 스크래핑

job_list_cloud = []
page_num = 1
main_url = 'http://www.saramin.co.kr'

while True:
    url = f'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page={page_num}&cat_key=41704%2C40220&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=1'
    req_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    }
    html = requests.get(url, req_header).text
    soup = BeautifulSoup(html, 'html.parser')
    
    # 만약 더이상 페이지 리스트에 공고가 없을 경우 break
    if soup.select('div.list_body div.list_item') == []:
        break
    for tag in soup.select('div.list_body div.list_item'):
        company_dict = {}
        company_dict["기업명"] = tag.select('div.company_nm a span')[0].text
        company_dict["직무"] = tag.select('div.notification_info a span')[0].text
        company_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
        company_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
        # 근무형태가 빈칸인 직무들도 있음
        try:
            company_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
        except:
            company_dict["근무형태"] = ""
        try:    
            company_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
        except:
            company_dict["근무지"] = ""
        category_list = []
        # 분류는 여러가지가 있기 때문에 리스트 형태로 저장
        for item in tag.select('div.notification_info div.job_meta span span'):
            category_list.append(item.text)
        company_dict["분류"] = str(category_list)
        company_dict["분류필터"] = "cloud"
        
        detail_url = tag.select_one('div.notification_info a').attrs['href']
        full_detail_url = urljoin(main_url, detail_url)
        company_dict["상세링크"] = full_detail_url
        job_list_cloud.append(company_dict)
    page_num += 1
job_list_cloud
# Out:
# [{'기업명': '주식회사 하우투약',
#   '직무': '[알약물약] 백엔드 서버 개발자 / 프론트엔드 개발자 경력 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38678203&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)이노디',
#   '직무': '3차원 스캐너 UI  및 3D 모델링 개발자 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['설계·CAD·CAM', '하드웨어·소프트웨어']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38678384'},
#  {'기업명': '비비엠씨(주)',
#   '직무': '각 부문 신입 및 경력 모집 (시스템네트워크운영/콜센터/웹개발/영업)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['일반영업', '기술영업']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38638977&adsCategoryItem=effect_bold&'},
#  {'기업명': '에스비아이코스머니(주)',
#   '직무': '2020년 하반기 각 부문별 직원채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38640756&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)케이아이엔엑스',
#   '직무': '네트워크/시스템 모니터링 및 기술지원 엔지니어 채용',
#   '경력사항': '신입',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기술영업', '웹마스터·QA·테스터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38663055&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)에이치엠씨네트웍스',
#   '직무': '[케어네이션] 데이터분석가(Data Analyst) 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38710104'},
#  {'기업명': '(주)테스트웍스',
#   '직무': '[테스트웍스] 각 부문 신입 · 경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['회계·재무·세무·IR', '마케팅·광고·분석']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38700329&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)슈프리마',
#   '직무': '[슈프리마] 풀스택 개발자 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38304984&adsCategoryItem=effect_bold&'},
#  {'기업명': 'appknot',
#   '직무': '앱-웹 기획/디자인/웹개발/iOS앱개발/마케팅',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['홍보·PR·사보', '마케팅·광고·분석']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38645181&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)레뷰코퍼레이션',
#   '직무': '플랫폼그룹 부문별 신입/경력직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['캐릭터·만화·애니', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38696398&adsCategoryItem=effect_bold&'},
#  {'기업명': '한국직업능력교육원 안산',
#   '직무': '경기/시흥・안산/군포 국비무료 취업연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '경기 안산시 단원구',
#   '분류': "['회계·재무·세무·IR', '생산관리·품질관리']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38677061&adsCategoryItem=effect_bold&'},
#  {'기업명': '동양시스템즈(주)',
#   '직무': '2020년 하반기 신입 및 경력사원 공개 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['그래픽디자인·CG', '출판·편집디자인']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690599&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)중고나라',
#   '직무': '[중고나라] 개발부문 전문가 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38683997&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)지이씨엘코리아',
#   '직무': 'GECL KOREA  경력직 채용 (MD, PHP, JAVA, 웹디자인, SEO)',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 금천구',
#   '분류': "['해외영업·무역영업', '상품기획·MD']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38699334&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)미디어그룹사람과숲',
#   '직무': '뉴딜사업(국책사업) 사업관리자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['사무보조·문서작성', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38705278&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)패브릭타임',
#   '직무': '프론트엔드 엔지니어 리드',
#   '경력사항': '3 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38698948'},
#  {'기업명': '잉카엔트웍스',
#   '직무': 'AWS 클라우드 엔지니어 : 글로벌 대용량 SaaS 서비스',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38705923&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)대우능력개발교육원',
#   '직무': '2020년 100% 국비무료 9~10월 개강 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '서울 중랑구',
#   '분류': "['총무·법무·사무', '사무보조·문서작성']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631354&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)경일게임아카데미',
#   '직무': '정부무료 게임회사 취업연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38644455&adsCategoryItem=effect_bold&'},
#  {'기업명': '휴먼교육센터학원',
#   '직무': '[전액무료]자바/파이썬 IT교육받고 취업하자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38510654&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)매드업',
#   '직무': '[매드업] 퍼포먼스마케터/개발자 외 대규모 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['인사·교육·노무', '마케팅·광고·분석']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596083&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)메디블록',
#   '직무': '[메디블록] 분야별 인재영입 (개발/사업/마케팅/디자인)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693054'},
#  {'기업명': '주식회사 스타랩스',
#   '직무': '(주)스타랩스 IT 각 분야별 경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38661996'},
#  {'기업명': '이투스교육(주)',
#   '직무': '이투스교육 9월 개발자 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38686512'},
#  {'기업명': '이투스교육(주)',
#   '직무': '이투스교육 IT기획직군 공개 채용',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38683356'},
#  {'기업명': '(주)솔트룩스',
#   '직무': '인공지능(AI)전문기업 [솔트룩스] 신입/경력 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38699650'},
#  {'기업명': '(주)웨어포인트',
#   '직무': '(잠실/운영)시스템 엔지니어(SE/TA) 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38680884'},
#  {'기업명': '㈜이지컴아이앤씨',
#   '직무': 'Public 클라우드/IT인프라/리눅스엔지니어 모집(영어가능자우대)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 용인시 기흥구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38706563'},
#  {'기업명': '소상공인연합회',
#   '직무': '2020년 위탁사업담당 (경력) 직원 모집',
#   '경력사항': '5 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '서울 동작구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38700153'},
#  {'기업명': '한국요꼬가와전기(주)',
#   '직무': '한국요꼬가와전기(주) 각 부문별 인턴사원 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '인턴직',
#   '근무지': '서울 영등포구',
#   '분류': "['기획·전략·경영', '회계·재무·세무·IR']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38669688'},
#  {'기업명': '오픈플랜(주)',
#   '직무': '[오픈플랜] back-end Developer 우수 인재를 모십니다.',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38505378'},
#  {'기업명': '(사)한국정보기술서비스산업협회',
#   '직무': '한국IT서비스산업협회 하반기 수시채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['기획·전략·경영', '마케팅·광고·분석']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38701158'},
#  {'기업명': '(주)넷케이티아이',
#   '직무': '전분야 정규직원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['기획·전략·경영', 'IT·솔루션영업']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38689909'},
#  {'기업명': '(주)모니터랩',
#   '직무': '기획, 개발, 마케팅, 영업, 기술지원 공개채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['해외영업·무역영업', '마케팅·광고·분석']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38682604'},
#  {'기업명': '펍지(주)',
#   '직무': '펍지㈜ 각 부문별 수시 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['총무·법무·사무', '인사·교육·노무']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38698942'},
#  {'기업명': '(주)티맥스소프트',
#   '직무': 'TmaxGroup 경력/신입 채용 공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['해외영업·무역영업', '기획·전략·경영']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38681609'},
#  {'기업명': '(주)씨제이이엔엠',
#   '직무': 'CJ ENM E&M부문 온라인 플랫폼 서비스기획/개발 경력사원 모집',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['기획·전략·경영', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38691613'},
#  {'기업명': '(주)지피에이코리아',
#   '직무': '[지피에이코리아] 웹 경력 개발자 모십니다.',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38703745'},
#  {'기업명': '비알코리아(주)',
#   '직무': '[비알코리아] 각 부문 경력사원 모집',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['해외영업·무역영업', '무역사무·수출입']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38684979'},
#  {'기업명': '(주)에이블정보',
#   '직무': '어플리케이션 개발자/웹개발자 정규직 경력 채용',
#   '경력사항': '5 ~ 15년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '게임·Game']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38702665'},
#  {'기업명': '㈜해커스교육그룹',
#   '직무': '2020년 해커스 교육그룹 [신입/경력] 각 부문별 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38369849'},
#  {'기업명': '(주)레이풀시스템',
#   '직무': '솔루션운영관리(SE) 및 솔루션영업 직원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['IT·솔루션영업', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38698251'},
#  {'기업명': '(주)디리아',
#   '직무': '금융IT전문기업 ㈜디리아 경력 개발자 공개 채용',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38696313'},
#  {'기업명': '창원문성대학교산학협력단',
#   '직무': '빅데이터 전문기술 교육과정 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '교육생',
#   '근무지': '경남 창원시 의창구',
#   '분류': "['회계·재무·세무·IR', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38611128'},
#  {'기업명': '스포트라이트101',
#   '직무': '플랫폼 서비스 개발자 채용 (서버/IOS /Android)',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690149'},
#  {'기업명': '(주)네비웍스',
#   '직무': '2020년 네비웍스 SW개발자(신입) 모집',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38682072'},
#  {'기업명': '이에이트(주)',
#   '직무': '2020년 하반기 신입 및 경력직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38686561'},
#  {'기업명': '에이치로보틱스(주)',
#   '직무': '2020년 하반기 각 부문 채용',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 연수구',
#   '분류': "['전기·전자·제어', '웹기획·PM']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38705415'},
#  {'기업명': '오케스트로(주)',
#   '직무': '(경력)지능형클라우드연구소플랫폼개발팀',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38705356'},
#  {'기업명': '(주)시지온',
#   '직무': '라이브리 서비스 광고 플랫폼 개발자 모집',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648078'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 2020년 개발 경력자 대규모 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37872627'},
#  {'기업명': '(주)시지온',
#   '직무': '어트랙트 서비스 자바 백엔드 개발자 모집',
#   '경력사항': '5 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38703528'},
#  {'기업명': '매드업',
#   '직무': '[테크사업부] 백엔드 개발자 채용',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38703416'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 개발 경력자 대규모 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 송파구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561876'},
#  {'기업명': '위티',
#   '직무': '[경력/신입] 플랫폼 서비스 프론트/백엔드 개발자 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558783'},
#  {'기업명': '패스트캠퍼스(주)',
#   '직무': '[패스트캠퍼스] 대규모 인재 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '마케팅·광고·분석']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38230007'},
#  {'기업명': '켈리서비스 유한회사',
#   '직무': '[한국화웨이/영어or중국어] IT Engineer (서버유지보수, ICT)',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 중구',
#   '분류': "['기술영업', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38584624'},
#  {'기업명': '엔카닷컴(주)',
#   '직무': '[내 차 팔기 서비스] Back-end 개발자(경력-3년 이상)',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690715'},
#  {'기업명': '콘텐츠웨이브(주)',
#   '직무': '[WAVVE]개발자 채용 [빌링/플랫폼운영/미디어스트리밍]',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38658117'},
#  {'기업명': '사운드파이프코리아(주)',
#   '직무': 'H자동차그룹 글로벌 Car Cloud 운영 신입 채용(인도+한국팀)',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679994'},
#  {'기업명': '사운드파이프코리아(주)',
#   '직무': 'H자동차그룹 카클라우드 리눅스/오픈소스 시스템엔지니어 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679992'},
#  {'기업명': '사운드파이프코리아(주)',
#   '직무': 'H자동차그룹 Car Cloud (오픈스택+쿠버네티스) 시스템엔지니어',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679991'},
#  {'기업명': '(주) 하트게임즈',
#   '직무': '긴급) 웹/게임 서버 개발 팀장급 채용 ( node.js )',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '게임·Game']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574743'},
#  {'기업명': '주식회사 오픈소스컨설팅',
#   '직무': '[오픈소스컨설팅] 각 부문 엔지니어 채용(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '하드웨어·소프트웨어']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38701306'},
#  {'기업명': '주식회사 라이프시맨틱스',
#   '직무': '시스템운영 경력직 채용',
#   '경력사항': '4 ~ 6년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38701209'},
#  {'기업명': '제이피스 주식회사',
#   '직무': 'LG전자 본사 AI/Dig Data 관련 사무보조 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 강서구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38609512'},
#  {'기업명': '(주)텐일레븐',
#   '직무': '[텐일레븐] 2020 전문연구요원 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '석사↑',
#   '근무형태': '병역특례',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666201'},
#  {'기업명': '클라우드그램(주)',
#   '직무': '[클라우드그램] 경영지원',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['사무보조·문서작성', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38364180'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존클라우드] Mass Migration Center 부문별 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['IT·솔루션영업', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38348572'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존클라우드] APM Solution Engineer 채용(3~8년)',
#   '경력사항': '3 ~ 8년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38398430'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존클라우드] Cloud DBA(Mysql, MS SQL DBA 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38413404'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존클라우드] Product Development 부문 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38438571'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존클라우드] VDI Helpdesk / 24x7 Service 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['사무보조·문서작성', '기술영업']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38439227'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 네트워크 운영 및 정보보호 담당 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38333581'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] DMP(데이터 관리 플랫폼) 개발',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38405474'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 구글클라우드 부문 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['일반영업', 'IT·솔루션영업']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38409477'},
#  {'기업명': '(주)여기어때컴퍼니',
#   '직무': '[여기어때] 서비스제품개발실 서버 개발자 채용(경력)',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38700528'},
#  {'기업명': '(주)지피에이코리아',
#   '직무': '[지피에이코리아] 웹 경력 개발자 모십니다.',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38700483'},
#  {'기업명': '(주)팡게임',
#   '직무': 'DevOps 엔지니어 채용 공고',
#   '경력사항': '2 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38641759'},
#  {'기업명': '(주)온빛',
#   '직무': '병원 플랫폼 앱 개발자 모집(안드로이드/iOS/백엔드, 연봉3000~)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대구 북구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38534946'},
#  {'기업명': '스마일샤크',
#   '직무': '[신입] AWS 솔루션 아키텍트(SA)를 스마일샤크팀으로 모십니다.',
#   '경력사항': '신입',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38586155'},
#  {'기업명': '(주)이앤씨지엘에스',
#   '직무': '4차 산업혁명 물류 IT전문기업 이앤씨지엘에스 모집 공고',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['구매·자재·재고', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38660139'},
#  {'기업명': '(주)큐픽스',
#   '직무': '[신입/경력/전문연구요원] AWS/Ruby 백엔드엔지니어',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38696090'},
#  {'기업명': '주식회사 단비',
#   '직무': 'JAVA / ERP / AI / 머신러닝 / Go / Python / MES',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 해운대구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38695965'},
#  {'기업명': '(주)디모아',
#   '직무': '[쌍방울그룹 계열사] 소프트웨어 영업직 경력/신입 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['IT·솔루션영업', '영업기획·관리·지원']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38668555'},
#  {'기업명': '(주)에이프릴세븐',
#   '직무': '[스타트업] 서버개발자 채용 공고',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38695046'},
#  {'기업명': '에스씨엠케이(주)',
#   '직무': '물류시스템/SI개발/클라우드 SaaS개발 운용 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38680676&adsCategoryItem=effect_bold&'},
#  {'기업명': '(재)대구테크노파크',
#   '직무': '(재)대구테크노파크 각 부문 직원 채용 공고',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직',
#   '근무지': '대구 달서구',
#   '분류': "['기획·전략·경영', '의료기사']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38647327'},
#  {'기업명': '(주)인포플라',
#   '직무': 'AWS 프론트엔드/백엔드 개발자  정규직 채용(인재선발)',
#   '경력사항': '신입 · 경력',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679865'},
#  {'기업명': '주식회사오션라이트에이아이',
#   '직무': '(주)오션라이트에이아이 Back-End 개발자 & 경영기획 모집 공고',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '대구 북구',
#   '분류': "['기획·전략·경영', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692861'},
#  {'기업명': '(주)비즈데이터',
#   '직무': '데이터 엔지니어 채용(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38677231'},
#  {'기업명': '(주)티시스',
#   '직무': '태광그룹 ㈜티시스 경력사원 공개채용 (IT, 부동산, 건설, 레저)',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['AS·서비스·수리', '레저·스포츠']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649618'},
#  {'기업명': '이지지아이에스(주)',
#   '직무': '하반기 각 부문 경력사원 채용 (C# WPF 솔루션 개발/빅데이터 컨설팅)',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38676155'},
#  {'기업명': '아토리서치(주)',
#   '직무': 'IT네트워크/보안 플랫폼/ web 개발 채용공고',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38413436'},
#  {'기업명': '(주)두댓',
#   '직무': '모바일 앱 개발팀장',
#   '경력사항': '경력 10년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690785'},
#  {'기업명': '솔트웨어(주)',
#   '직무': 'AWS 영업, 컨설팅, 기술지원 및 영업마케팅지원 경력직',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38689827'},
#  {'기업명': '(주)크리젠솔루션',
#   '직무': '[신입]크리젠솔루션 JAVA 개발자 모집',
#   '경력사항': '신입',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38639519'},
#  {'기업명': '(주)헬스앤메디슨',
#   '직무': '헬스앤메디슨 Back End Developer (경력 2년 이상) 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38685468'},
#  {'기업명': '이원다이애그노믹스(주)',
#   '직무': 'EDGC : 글로벌R&D본부 IT팀 인재 채용 件',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38489038'},
#  {'기업명': '(주)대교',
#   '직무': '[(주)대교] 디지털 서비스 운영조직 IT 전문 인력 모집 (정규직)',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 관악구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38685980'},
#  {'기업명': '원투씨엠(주)',
#   '직무': 'Java 서버 개발, 웹 개발 등 신입/경력 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533730'},
#  {'기업명': '나무기술(주)',
#   '직무': 'Cloud 엔지니어 / 프리세일즈&컨설팅 / 웹 애플리케이션 개발',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38633878'},
#  {'기업명': '주식회사오션라이트에이아이',
#   '직무': '2020년 하반기 Back-End 개발자 & 경영기획 모집 공고',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '대구 북구',
#   '분류': "['기획·전략·경영', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38683025'},
#  {'기업명': '컴즈(주)',
#   '직무': 'S/W Test & QA Engineer 채용의 件',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 구로구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38646245'},
#  {'기업명': '(주)인텔리콘연구소',
#   '직무': '클라우드 시스템 전문인력(유경험자) 모집',
#   '경력사항': '5 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['하드웨어·소프트웨어', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38681248'},
#  {'기업명': '피플메이드',
#   '직무': '[교육플랫폼 피플메이드] 클래스 기획 MD 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['상품기획·MD', '마케팅·광고·분석']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38641511'},
#  {'기업명': '패스트파이브(주)',
#   '직무': '[FASTFIVE] 서버/인프라 개발자 채용',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679489'},
#  {'기업명': '주식회사 짐싸',
#   '직무': '(주)짐싸 개발팀 백엔드 개발자 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679444'},
#  {'기업명': '주식회사 메먼트',
#   '직무': '(연 3000만 이상) 시스템엔지니어 채용',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526643'},
#  {'기업명': '플러스엑스(주)',
#   '직무': '웹 개발자 (Python, Django) 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679374'},
#  {'기업명': '주식회사 디벨록',
#   '직무': '블록체인 네트워크 / 서버구축 / API 개발 경력자 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 서구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679250'},
#  {'기업명': '(주)제이티넷',
#   '직무': '[NICE 그룹] (주)제이티넷 채용 (시스템 운영관리)',
#   '경력사항': '8 ~ 12년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38678791'},
#  {'기업명': '(주)인포젠',
#   '직무': '클라우드 기반의 개발자 및 리더급 채용 (Spring Boot 개발환경)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38676853'},
#  {'기업명': '(주)뉴트리션코트',
#   '직무': '백엔드개발 경력직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38675684'},
#  {'기업명': '(주)지텐션',
#   '직무': '[한화그룹 계열사] 서버 개발자 모집',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38675225'},
#  {'기업명': '(주)머스트잇',
#   '직무': '카탈로그 백엔드 개발자 채용',
#   '경력사항': '3 ~ 12년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38674883'},
#  {'기업명': '(주)머스트잇',
#   '직무': '서비스 백엔드개발자 채용',
#   '경력사항': '3 ~ 8년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38674794'},
#  {'기업명': '대한상공회의소 광주인력개발원',
#   '직무': '2020년도 국비 기술교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '광주 광산구',
#   '분류': "['기계·기계설비', '전기·전자·제어']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38404367'},
#  {'기업명': '(주)푸드테크',
#   '직무': 'AWS/인프라 부문 경력사원 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631228'},
#  {'기업명': '(주)화이트스캔',
#   '직무': 'R&D 신입/경력 연구원 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서대문구',
#   '분류': "['총무·법무·사무', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38647365'},
#  {'기업명': '(주)코레이즈',
#   '직무': '[코레이즈] IT 부문 네트워크/클라우드/납품·영업/인프라 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 성동구',
#   '분류': "['IT·솔루션영업', '하드웨어·소프트웨어']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38620413'},
#  {'기업명': '주식회사 코드베르그',
#   '직무': '코드베르그 Back-end 개발부문 모집 (PHP or Node.js)',
#   '경력사항': '3 ~ 6년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38434985'},
#  {'기업명': '㈜트인시스템즈',
#   '직무': '서울 인프라 프로젝트 PM 경력 지원 모집',
#   '경력사항': '9 ~ 20년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38652559'},
#  {'기업명': '(유)딜리버리히어로 코리아',
#   '직무': '전 개발직군 대규모 채용중',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38476546'},
#  {'기업명': '(주)프레시멘토',
#   '직무': '네이버 동네시장장보기 백엔드 개발자 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38664637'},
#  {'기업명': '(주)케이닥스',
#   '직무': 'AWS 클라우드 서버 보안 담당자',
#   '경력사항': '1 ~ 6년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38664336'},
#  {'기업명': 'KOG',
#   '직무': '[INFRA팀] 게임 서비스 및 사내 업무 인프라 구축(개발) / 운영',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대구 중구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38641643'},
#  {'기업명': '(주)아이케어닥터',
#   '직무': '헬스케어 큐레이션 플랫폼 개발 및 메인터넌스(정규직)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38662865'},
#  {'기업명': '(주)락플레이스',
#   '직무': 'Azure 엔지니어 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631776'},
#  {'기업명': '푸른IT',
#   '직무': '창원 대기업DC 서버관리 장기 SM ( 고급 서버관리자 ) 10월 1일',
#   '경력사항': '9 ~ 15년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '프리랜서',
#   '근무지': '경남 창원시',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38661737'},
#  {'기업명': '주식회사 오파테크',
#   '직무': '서버개발 정규직 모집 공고(경력)',
#   '경력사항': '3 ~ 6년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38483345'},
#  {'기업명': '(주)민병철교육그룹',
#   '직무': '[민병철유폰] AWS 시스템 엔지니어 (총 경력 5년 이상)',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38659418'},
#  {'기업명': '(주)디타임',
#   '직무': '디타임 프론트엔드 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38613023'},
#  {'기업명': '(주)테크데이타',
#   '직무': '[신입] 테크데이타 IT 기술 엔지니어 채용',
#   '경력사항': '신입',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['IT·솔루션영업', '서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38599126'},
#  {'기업명': '(주)전우행복꿈사람사랑디허브',
#   '직무': '주니어/시니어웹 개발자 분을 (NodeJS 필수 React 권장) 모십니',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 종로구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38456117'},
#  {'기업명': '주식회사 하우투약',
#   '직무': '[알약물약] 프론트엔드 및 백엔드 서버(PHP) 개발자 모십니다',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38655564'},
#  {'기업명': '(주)페칭',
#   '직무': 'Node.js 백엔드 개발자를 모십니다',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 관악구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38655386'},
#  {'기업명': '(주)지에스아이엘',
#   '직무': '(주)지에스아아엘 - 시스템개발팀 경력직 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567524'},
#  {'기업명': '주식회사 해줌',
#   '직무': '발전량 예측 API 백엔드 개발자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38526293'},
#  {'기업명': '(주)디타임',
#   '직무': '(주)디타임 백엔드개발자 경력직 채용',
#   '경력사항': '6 ~ 20년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38565481'},
#  {'기업명': '팀윙크(주)',
#   '직무': '[팀윙크] 핀테크 네이티브 개발자 (시니어) 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38651685'},
#  {'기업명': '(주)이젠아카데미인재개발원',
#   '직무': '[취업연수 국비교육]자바/파이썬/빅데이터/웹/영상/건축',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['캐릭터·만화·애니', '광고·시각디자인']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=36825236'},
#  {'기업명': '(주)판도라티비',
#   '직무': '[ 코박(COBAK) ]  Back-end 개발자 채용(Python / django)',
#   '경력사항': '1 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38636485'},
#  {'기업명': '(주)판도라티비',
#   '직무': '[ 코박(COBAK) ]  Back-end 개발자 채용(Java / Spring)',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649299'},
#  {'기업명': '캐시워크',
#   '직무': '캐시워크와 함께 걸어갈 Node.js 서버 개발자님을 찾습니다',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649262'},
#  {'기업명': '(주)텐일레븐',
#   '직무': '[텐일레븐] 2020 경력 개발자 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38545582'},
#  {'기업명': '코코네(주)',
#   '직무': '(COCONE) 인프라 엔지니어 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648353'},
#  {'기업명': '주식회사 미로',
#   '직무': '(주)미로 IoT & 스마트홈 개발자채용 (신입/경력/전문연구요원)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '인천 연수구',
#   '분류': "['전기·전자·제어', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38559164'},
#  {'기업명': '(주)웰데이타시스템',
#   '직무': 'H자동차그룹 Car Cloud(오픈스택+쿠버네티스) 서비스 운영',
#   '경력사항': '3 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579660'},
#  {'기업명': '(주)위메프',
#   '직무': '[보안]클라우드 보안운영 담당자(정규직)',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37608770'},
#  {'기업명': '(주)위메프',
#   '직무': '[개발]위메프오 DevOps Engineer(정규직)',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38644560'},
#  {'기업명': '(주)위메프',
#   '직무': '[개발]위메프 시스템엔지니어(정규직)',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38643798'},
#  {'기업명': '(주)센드버드코리아',
#   '직무': '[실리콘밸리 기업] 클라우드 데이터 아키텍트 (DA / NoSQL)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38642318'},
#  {'기업명': '(주)피플리',
#   '직무': '워라밸이 실현되는 곳에서 즐겁게 일할 iOS 경력 개발지',
#   '경력사항': '3 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38639559'},
#  {'기업명': '(주)인터웹',
#   '직무': '4차산업혁명 기반의 신사업 참여 개발자 모집',
#   '경력사항': '경력 6년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38634157'},
#  {'기업명': '굿어스데이터(주)',
#   '직무': 'Cloud 엔지니어 (경력 3년 이상)',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38629602'},
#  {'기업명': '(주)립페이',
#   '직무': '[정규직] 서비스 플랫폼(백엔드) 개발자 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '통신·모바일']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38560508'},
#  {'기업명': '호스트웨이아이디씨(주)',
#   '직무': '[정규직] 시스템 엔지니어 모집(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38582146'},
#  {'기업명': '㈜게임스프링',
#   '직무': 'Node.js 게임서버 프로그래머 (병역특례 가능 - 보충역, 전직)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38604925'},
#  {'기업명': '(주)넥스클라우드',
#   '직무': 'Cloud Platform Consulting Manager',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터', '경영분석·컨설턴트']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38619252'},
#  {'기업명': '(주)더블다운인터액티브',
#   '직무': '웹/게임서버 개발자(경력), 클라이언트 개발자(신입/경력) 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '게임·Game']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38580038'},
#  {'기업명': '에스지에이(주)',
#   '직무': 'SGA임베디드-Cloud팀] 클라우드(Azure, M365) 기술지원 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38611017'},
#  {'기업명': '(주)해시스냅',
#   '직무': '백엔드(Back-end) 개발자 채용',
#   '경력사항': '3 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38606564'},
#  {'기업명': '(주)샤픈고트',
#   '직무': '[샤픈고트] 프론트 앤드 개발자 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 해운대구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38611187'},
#  {'기업명': '아토리서치(주)',
#   '직무': '[아토리서치]전문연구요원(병역특례) 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38545903'},
#  {'기업명': '디딤365 주식회사',
#   '직무': 'AWS 클라우드 기술영업 신입사원 모집',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['IT·솔루션영업', '기술영업']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38523449'},
#  {'기업명': '디딤365 주식회사',
#   '직무': '클라우드 및 시스템 엔지니어 신입/경력(청년내일채움공제 가능)',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
# ...
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38673030'},
#  {'기업명': '베스트네트워크㈜',
#   '직무': '16. [자동차기업] IT 인프라 구축 전문가 정규직 채용',
#   '경력사항': '경력 8년↓',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38667479'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 인프라 가상화 기술기반 서비스 개발 경력자',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666456'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 프론트엔드(FrontEnd) 개발 경력자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666453'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 백엔드(BackEnd) 개발 경력자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666442'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 플랫폼 영업(Sales) 경력직 채용',
#   '경력사항': '경력 7년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['IT·솔루션영업', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666438'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 사업기획 경력직 채용',
#   '경력사항': '5 ~ 12년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['기획·전략·경영', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666432'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 플랫폼/응용상품기획 경력자',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666412'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 인프라 상품기획 경력자',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666409'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 보안상품 웹 서비스 개발 경력자',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['IT·디자인·컴퓨터교육', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666404'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '[IT 그룹계열사] 클라우드 서비스 (개발자도구) 개발자',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666401'},
#  {'기업명': '커리어커넥트(주)',
#   '직무': '대형금융그룹 IT운영팀원 (WAS / Cloud 금융권 경력자) 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38665724'},
#  {'기업명': '(주)연세교육아카데미ㅣ연세직업전문학교',
#   '직무': '정보보안(모의해킹) 및 클라우드 강사 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '전임 · 계약직',
#   '근무지': '경기 수원시 장안구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38659283'},
#  {'기업명': '로버트월터스코리아(주)',
#   '직무': '[글로벌/IT/엔지니어] DevOps/System Engineer',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38658493'},
#  {'기업명': '(주)에이치알비즈코리아',
#   '직무': '데이터 분석 경력 채용 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38655901'},
#  {'기업명': '(주)브레인센터',
#   '직무': '대기업 클라우드 기획자 (계약직 : 과장~차장급)',
#   '경력사항': '6 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 중구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38652788'},
#  {'기업명': '오픈포지션',
#   '직무': '온라인 서비스 Mobile App 개발자/대리과장급/ 환경가전 대기업',
#   '경력사항': '7 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38651671'},
#  {'기업명': '(주)HR컨설팅그룹',
#   '직무': '(코스닥상장사) 클라우드엔지니어',
#   '경력사항': '5 ~ 14년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649223'},
#  {'기업명': '로버트월터스코리아(주)',
#   '직무': '[글로벌/IT/개발자] Full Stack Developer',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38637203'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[더기프팅컴퍼니] Data Scientist(경력 3년 이상)',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38708232'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '(가전 및 생활용품 기업) 데이터 엔지니어',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692602'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': '(가전 및 생활용품 기업) 모바일 앱(안드로이드) 개발자',
#   '경력사항': '경력 7년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692575'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 최고 대기업 - 온라인 플랫폼 시스템기획 - 최우대',
#   '경력사항': '경력 10년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38704612'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 온라인 플랫폼 시스템 기획 - 최고 대기업 - 최우대',
#   '경력사항': '경력 10년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38704609'},
#  {'기업명': '(주)맨파워코리아',
#   '직무': '[외국계 SCM 기업] DevOps Engineer (Big data) (Hong)',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['ERP·시스템분석·설계', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38659838'},
#  {'기업명': '피플워크(주)',
#   '직무': '인공지능 딥러닝기반 영상인식 처리 알고리즘 개발',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '통신·모바일']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38626706'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '응용프로그램 서버 개발자 C++ MFC Linux 개발자 CTI, IVR 개발',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38702180'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '응용프로그램 서버 개발자 C++ MFC Linux 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38702166'},
#  {'기업명': '(주)탑앤스카우트',
#   '직무': '[AI, IoT] 공공프로젝트 PM 충원',
#   '경력사항': '경력 8년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', 'ERP·시스템분석·설계']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38687672'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[모바일 애드테크 전문기업] 백엔드 엔지니어(대리-과장)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38660129'},
#  {'기업명': '(주)유앤파트너즈',
#   '직무': '마이데이터  및 빅데이타 컨설턴트',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38671463'},
#  {'기업명': '피플워크(주)',
#   '직무': 'AI(인공지능) 딥러닝기반 영상인식 처리 알고리즘 개발',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '통신·모바일']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692250'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692204'},
#  {'기업명': '(주)에이치알맨파워그룹',
#   '직무': 'IT분야 QA(품질보증) 경력사원 모집',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38678529'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 Java, Oracle',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38686018'},
#  {'기업명': '(주)헬로서치',
#   '직무': '[대기업 IT사] 빅데이터 엔지니어 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653269'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Digital Healthcare 플랫폼 서비스 기획원 신약개발 상장사',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679727'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Digital Healthcare 플랫폼 서비스 기획원',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679725'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679720'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Digital Healthcare 빅데이터 플랫폼 전문가',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹기획·PM', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679707'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Battery 생산지원시스템(QMS/SCM/EMS) 구축 및 Global 확산/운영',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 동구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679706'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 java',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679705'},
#  {'기업명': '(주)브이비젼',
#   '직무': '[글로벌벤처그룹] front-end 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38674517'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[분당] Javascript활용 자동화 개발 및 유지보수 지원-신입가능',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38659832'},
#  {'기업명': '피플워크(주)',
#   '직무': 'AI(인공지능) 딥러닝기반 의료영상처리 알고리즘 개발(5-12년)',
#   '경력사항': '4 ~ 16년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '통신·모바일']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38673146'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Battery 생산지원시스템(QMS/SCM/EMS) 구축',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 동구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38673127'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자 SAP',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38673118'},
#  {'기업명': '(주)피플케어코리아',
#   '직무': 'Partner Sales Enablement Manager (SW/Solution)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['IT·솔루션영업', '영업기획·관리·지원']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38672368'},
#  {'기업명': '(주)헬로서치',
#   '직무': '(대기업) 인프라보안 담당자 채용',
#   '경력사항': '8 ~ 14년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653288'},
#  {'기업명': '에이치알클릭',
#   '직무': '스마트폰 서비스 개발 기획 담당자 긴급 채용',
#   '경력사항': '6 ~ 13년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38665703'},
#  {'기업명': '에이치알니즈',
#   '직무': '[대기업 계열사]  QA 채용',
#   '경력사항': '5 ~ 11년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹마스터·QA·테스터', '인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38663570'},
#  {'기업명': '(주)스카우트',
#   '직무': '글로벌기업 카테고리매니저 대리과장급',
#   '경력사항': '7 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '데이터베이스·DBA']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653342'},
#  {'기업명': '(주)유앤파트너즈',
#   '직무': '[대기업계열] 데이터 전략 컨설턴트 / AI사업부  팀장外',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38639110'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '[삼성물산/연봉상위] 모바일 앱 및 웹 운영 경력 개발자 채용',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591901'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '[삼성물산/잠실역] 모바일 앱 및 웹 운영 경력 개발자 채용',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'cloud',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38570689'}]

# %%
# 파이썬 직업 스크래핑

job_list_python = []
page_num = 1
main_url = 'http://www.saramin.co.kr'

while True:
    url = f'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page={page_num}&cat_key=41711%2C40721%2C40426&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=1#searchTitle'
    req_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    }
    html = requests.get(url, req_header).text
    soup = BeautifulSoup(html, 'html.parser')
    if soup.select('div.list_body div.list_item') == []:
        break
    for tag in soup.select('div.list_body div.list_item'):
        company_dict = {}
        company_dict["기업명"] = tag.select('div.company_nm a span')[0].text
        company_dict["직무"] = tag.select('div.notification_info a span')[0].text
        company_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
        company_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
        try:
            company_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
        except:
            company_dict["근무형태"] = ""
        try:    
            company_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
        except:
            company_dict["근무지"] = ""
        category_list = []
        for item in tag.select('div.notification_info div.job_meta span span'):
            category_list.append(item.text)
        company_dict["분류"] = str(category_list)
        company_dict["분류필터"] = "python"
        
        detail_url = tag.select_one('div.notification_info a').attrs['href']
        full_detail_url = urljoin(main_url, detail_url)
        company_dict["상세링크"] = full_detail_url
        job_list_python.append(company_dict)
    page_num += 1
job_list_python
# Out:
# [{'기업명': '디아이티(주)',
#   '직무': '2020 DIT 하반기 공개 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시 영통구',
#   '분류': "['기계·기계설비', '전기·전자·제어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38577337&adsCategoryItem=effect_bold&'},
#  {'기업명': '비비엠씨(주)',
#   '직무': '각 부문 신입 및 경력 모집 (시스템네트워크운영/콜센터/웹개발/영업)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['일반영업', '기술영업']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38638977&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)캐럿글로벌',
#   '직무': '[솔루션개발팀] 웹기획자/웹디자이너/웹개발자 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690299&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)하이브비젼',
#   '직무': '2020년 [기술영업/기술지원/기술개발] 신입 및 경력 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시',
#   '분류': "['IT·솔루션영업', '기술영업']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38661319&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)오아시스',
#   '직무': '[오아시스마켓] 부문별 채용공고',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 중원구',
#   '분류': "['물류·유통·운송', '납품·배송·택배']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38670798&adsCategoryItem=effect_bold&'},
#  {'기업명': '신플렛(주)',
#   '직무': '인공지능(AI)/딥러닝/파이썬(Python) 개발자 신입/경력모집',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 용인시 수지구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38593006'},
#  {'기업명': '(주)테스트웍스',
#   '직무': '[테스트웍스] 각 부문 신입 · 경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['회계·재무·세무·IR', '마케팅·광고·분석']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38700329&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)슈프리마',
#   '직무': '[슈프리마] 소프트웨어(SW) 개발',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38437988&adsCategoryItem=effect_bold&'},
#  {'기업명': '망고클라우드(주)',
#   '직무': '[망고클라우드] 백엔드 시스템 개발 및 유지보수 담당 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38683639'},
#  {'기업명': '국제컴퓨터아카데미',
#   '직무': '[100%무료 취업준비생모집]웹디/건축/게임/프로그래밍/3D프린터',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울 관악구',
#   '분류': "['그래픽디자인·CG', '제품·산업디자인']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=34393991&adsCategoryItem=effect_bold&'},
#  {'기업명': '엘에이치주거복지정보(주)',
#   '직무': '2020년 LH주거복지정보㈜ 직원 채용 공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 교육생',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['운전·기사', '총무·법무·사무']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38699968&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)이노시스컴퍼니',
#   '직무': 'java 신입/경력 개발자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '고졸↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38698984&adsCategoryItem=effect_bold&'},
#  {'기업명': '한국직업능력교육원 안산',
#   '직무': '경기/시흥・안산/군포 국비무료 취업연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '경기 안산시 단원구',
#   '분류': "['회계·재무·세무·IR', '생산관리·품질관리']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38677061&adsCategoryItem=effect_bold&'},
#  {'기업명': '동양시스템즈(주)',
#   '직무': '2020년 하반기 신입 및 경력사원 공개 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['그래픽디자인·CG', '출판·편집디자인']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690599&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)비상교육',
#   '직무': '2020년 9월 각 부문별 신입 및 경력 사원 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 구로구',
#   '분류': "['기획·전략·경영', '회계·재무·세무·IR']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690055&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)디케이비엠시',
#   '직무': 'CRM, BI, SI 컨설팅솔루션 관리/개발자 채용 공고',
#   '경력사항': '2 ~ 17년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['그래픽디자인·CG', '웹기획·PM']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528106&adsCategoryItem=effect_bold&'},
#  {'기업명': '스윙로드',
#   '직무': '스윙로드 정규직 채용 (백엔드, 서비스 기획)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38423092&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)페이타랩',
#   '직무': '현대인의 필수인 패스오더 개발자를 모십니다.[5개 직군]',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 부산진구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38667561'},
#  {'기업명': '신한양직업전문학교',
#   '직무': '[국비] 무역물류/웹디자인/구매자재관리 취업 연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '부산 부산진구',
#   '분류': "['물류·유통·운송', '기계·기계설비']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38541577&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)패브릭타임',
#   '직무': '백엔드 엔지니어',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38697724'},
#  {'기업명': '한국기술교육직업전문학교',
#   '직무': '[전액국비] 4차산업 IT전문인력 취업연계교육',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '부산 동래구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539306&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)인라이플',
#   '직무': '[업계1위/복지최강] JAVA 개발자 대규모 인재채용 진행',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹마스터·QA·테스터', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38691275&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)대우능력개발교육원',
#   '직무': '2020년 100% 국비무료 9~10월 개강 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '서울 중랑구',
#   '분류': "['총무·법무·사무', '사무보조·문서작성']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631354&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)하늘소프트',
#   '직무': '[하늘소프트] 웹/응용 소프트웨어 개발 정규직/인턴직 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '대전 유성구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38684945'},
#  {'기업명': '휴먼교육센터학원',
#   '직무': '[전액무료]자바/파이썬 IT교육받고 취업하자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38510654&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)매드업',
#   '직무': '[매드업] 퍼포먼스마케터/개발자 외 대규모 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['인사·교육·노무', '마케팅·광고·분석']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596083&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)인라이플',
#   '직무': '가치있는 데이터를 같이 만들 JAVA개발자 채용 (백엔드 부문)',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹마스터·QA·테스터', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38709669'},
#  {'기업명': '(주)엔씨아이티에스',
#   '직무': '[NCSOFT자회사] 엔씨아이티에스 각 분야 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38671440&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)필옵틱스',
#   '직무': '[비전검사실] Vision SW 설계/개발 엔지니어 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시 권선구',
#   '분류': "['반도체·디스플레이·LCD', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38689609&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)키스템프',
#   '직무': '[나주/463만/11개월]한국우편사업진흥원 웹/앱 개발자 3명 채용',
#   '경력사항': '경력 10년↑',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '전남 나주시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38709070'},
#  {'기업명': '(주)키스템프',
#   '직무': '[나주/393만/11개월]한국우편사업진흥원 웹/앱 개발자 2명 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '전남 나주시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38708962'},
#  {'기업명': '(주)스트라티오코리아',
#   '직무': '(주)스트라티오코리아 2020 하반기 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직 · 인턴직',
#   '근무지': '서울 서초구',
#   '분류': "['경리·출납·결산', '회계·재무·세무·IR']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38634125'},
#  {'기업명': '업템포마케터즈',
#   '직무': '영어 번역 프로젝트 매니저 / IT 개발 프로젝트 매니저 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 파트',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['홍보·PR·사보', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38708852'},
#  {'기업명': '(주)미리디',
#   '직무': '[미리디] 데이터 분석가 (Data Analyst)를 모집합니다.',
#   '경력사항': '2 ~ 5년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['마케팅·광고·분석', '웹기획·PM']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38708722'},
#  {'기업명': '(주)픽스트리',
#   '직무': '응용프로그램개발 정규직, 병역특례 채용 - 각 부문별',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 구로구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38708642'},
#  {'기업명': '주식회사 스타랩스',
#   '직무': '(주)스타랩스 IT 각 분야별 경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38661996'},
#  {'기업명': '(주)사람인에이치알',
#   '직무': '데이터마케팅 GA관리 및 SEO 담당 채용 (사원/주임급)',
#   '경력사항': '1 ~ 3년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['마케팅·광고·분석', '웹기획·PM']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38654302'},
#  {'기업명': '트리피누',
#   '직무': '웹개발(Python, 프론트엔드) 채용, 웹디자이너 채용 경력무관',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 전임',
#   '근무지': '울산 남구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38708579'},
#  {'기업명': '(주)서커스컴퍼니',
#   '직무': '서커스컴퍼니 9월 채용 각 부문 크루 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['인사·교육·노무', '회계·재무·세무·IR']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38708417'},
#  {'기업명': '(주)에이플러스비',
#   '직무': '[29CM] 각 부문 경력사원 모집',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['상품기획·MD', '그래픽디자인·CG']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38708217'},
#  {'기업명': '(주)휴플',
#   '직무': '여행플랫폼 스타트업에서 함께할 멤버를 모집합니다(채용형인턴)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '인턴직',
#   '근무지': '제주 제주시',
#   '분류': "['응용프로그램개발', '웹디자인']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38621759'},
#  {'기업명': '주식회사 이커머스테크',
#   '직무': 'JAVA 개발 단기 프로젝트-중급이상',
#   '경력사항': '경력 6년↑',
#   '학력': '학력무관',
#   '근무형태': '프리랜서',
#   '근무지': '서울 강서구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38681876'},
#  {'기업명': '(주)메타넷엠플랫폼',
#   '직무': '[메타넷엠플랫폼 ] 서버 운영 관리 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38707978'},
#  {'기업명': '(주)화이트스캔',
#   '직무': 'AI융합연구소 딥러닝 연구원 채용(경력무관)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서대문구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38707836'},
#  {'기업명': '한국정보기술단',
#   '직무': '[한국정보기술단] 빅데이터 분석 기술인력 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 과천시',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38508480'},
#  {'기업명': '(주)헥사콘',
#   '직무': 'WEB 개발자 경력 채용',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38707832'},
#  {'기업명': '(주)에스아이알소프트',
#   '직무': '웹개발자, 앱개발자 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38529282'},
#  {'기업명': '(주)에스엘솔루션',
#   '직무': '2020년 하반기 Python 파이썬 개발자 경력직 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38707816'},
#  {'기업명': '㈜웨슬리퀘스트',
#   '직무': '데이터 분석가 신입 및 경력사원 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 마포구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38665565'},
#  {'기업명': '콴텍(주)',
#   '직무': '[콴텍, 금융] 함께 성장할 금융 데이터 분석 전문가 모십니다.',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['금융·보험영업', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38482773'},
#  {'기업명': '유호전기공업(주)',
#   '직무': '유호전기공업㈜ 2020년 하반기 부문별 경력/신입 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 양주시',
#   '분류': "['전기·전자·제어', '설계·CAD·CAM']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38707250'},
#  {'기업명': '윤시스템',
#   '직무': '데이터사이언티스트, 인공지능(AI)·빅데이터 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38633297'},
#  {'기업명': '(주)에스유지',
#   '직무': '(기술연구소 직원채용) 웹 개발 경력자 우대',
#   '경력사항': '2 ~ 7년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경남 창원시',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38707207'},
#  {'기업명': '메디픽셀',
#   '직무': '[병특/일반] 의료 인공지능 전문연구요원 채용 (메디픽셀)',
#   '경력사항': '경력무관',
#   '학력': '석사↑',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 마포구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38481522'},
#  {'기업명': '(주)트리플렛',
#   '직무': '[(주)트리플렛] 인공지능 학습 모델 개발 인력 채용(계약직)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '서울 마포구',
#   '분류': "['웹마스터·QA·테스터', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38678224'},
#  {'기업명': '에스케이플래닛(주)',
#   '직무': '각 부문 경력사원 채용',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시',
#   '분류': "['기획·전략·경영', '광고영업']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38083118'},
#  {'기업명': '(주)작가의탄생',
#   '직무': '[경력무관] 인공지능(AI)·빅데이터 개발자 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38706461'},
#  {'기업명': '(주)트랜스코스모스코리아',
#   '직무': '당사 CX개발사업본부 개발 및 운영 담당자(신입/경력)Mj5E',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38665658'},
#  {'기업명': '(주)비투윈파트너스',
#   '직무': '데이터 엔지니어 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38706028'},
#  {'기업명': '네비시스',
#   '직무': '응용 프로그래머 및 안드로이드, IOS 앱 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '대전 서구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38705917'},
#  {'기업명': '(주)로지올',
#   '직무': '[생각대로] 전국1위 배달 플랫폼 백엔드/모바일/웹 개발자',
#   '경력사항': '1 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹개발', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38609242'},
#  {'기업명': '(주)핀크',
#   '직무': '(하나금융그룹/SK텔레콤 합작회사) 각 부문 경력직원 모집',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['기획·전략·경영', '마케팅·광고·분석']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38697473'},
#  {'기업명': '(주)에이치비테크놀러지',
#   '직무': 'HB테크놀러지 신입/경력사원 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '충남 아산시',
#   '분류': "['기획·전략·경영', '회계·재무·세무·IR']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38615564'},
#  {'기업명': '(주)이트라이브',
#   '직무': '[정규직/경력] 이트라이브에서 Java/JSP 웹개발자를 모십니다',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38704451'},
#  {'기업명': '펍지(주)',
#   '직무': '펍지㈜ 각 부문별 수시 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['총무·법무·사무', '인사·교육·노무']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38698942'},
#  {'기업명': '(주)티맥스소프트',
#   '직무': 'TmaxGroup 경력/신입 채용 공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['해외영업·무역영업', '기획·전략·경영']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38681609'},
#  {'기업명': '(주)플레로게임즈',
#   '직무': '[플레로게임즈] 데이터엔지니어 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38705586'},
#  {'기업명': '한국모바일인증(주)',
#   '직무': '한국모바일인증㈜ 각 부문별 신입/경력사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['기획·전략·경영', '마케팅·광고·분석']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38699952'},
#  {'기업명': '(주)켐트로닉스',
#   '직무': '㈜켐트로닉스 전자사업본부 공개채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 용인시 처인구',
#   '분류': "['해외영업·무역영업', '기획·전략·경영']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38684813'},
#  {'기업명': '㈜해커스교육그룹',
#   '직무': '2020년 해커스 교육그룹 [신입/경력] 각 부문별 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38369849'},
#  {'기업명': '(주)소프트위즈',
#   '직무': '㈜소프트위즈 서버팀 모집',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38700659'},
#  {'기업명': '(주)데이터스트림즈',
#   '직무': '2020년 IT빅데이터 솔루션 기업 전사 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38642677'},
#  {'기업명': '(주)아이디어빈스',
#   '직무': '각 부문 경력사원 채용 (개발/웹기획/웹퍼블리셔/사업기획)',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['기획·전략·경영', '서버·네트워크·보안']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38688318'},
#  {'기업명': '경기인력개발원',
#   '직무': '2020년도 전액국비 4차산업 취업연계과정 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '경기 파주시',
#   '분류': "['AS·서비스·수리', '회계·재무·세무·IR']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38652453'},
#  {'기업명': '(주)애드락애드버테인먼트',
#   '직무': '애드락애드버테인먼트 개발자 채용 공고',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38609147'},
#  {'기업명': '(주)열심히커뮤니케이션즈',
#   '직무': '열심히커뮤니케이션즈 부문별 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 용산구',
#   '분류': "['상품기획·MD', '기획·전략·경영']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38700979'},
#  {'기업명': '스포트라이트101',
#   '직무': '플랫폼 서비스 개발자 채용 (서버/IOS /Android)',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690149'},
#  {'기업명': '플랫비 주식회사',
#   '직무': '플랫비 주식회사 각 부문 신입/경력 직원 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38686587'},
#  {'기업명': '(주)네비웍스',
#   '직무': '2020년 네비웍스 SW개발자(신입) 모집',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38682072'},
#  {'기업명': '와이폴라리스',
#   '직무': '2020년 하반기 신입/경력 직원채용(머신러닝/딥러닝)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 남구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38686996'},
#  {'기업명': '이에이트(주)',
#   '직무': '2020년 하반기 신입 및 경력직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38686561'},
#  {'기업명': '메이븐코리아(주)',
#   '직무': 'BI 데이터 시각화 개발자 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38705303'},
#  {'기업명': '(주)뷰노',
#   '직무': '[뷰노] 의료영상, 생체신호, 음성인식 ML/DL 연구원을 찾습니다',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['인공지능(AI)·빅데이터', '연구소·R&D']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38532086'},
#  {'기업명': '(주)시대의영웅',
#   '직무': 'IT 웹 / 응용 / 시스템 프로그래머- Python, Java. JSP 채용 공',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강서구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38705063'},
#  {'기업명': '(주)에니트',
#   '직무': '서울지사 - 솔루션 SW (데이터분석,머신러닝,DB,WEB 부문) 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38467127'},
#  {'기업명': '행복쇼핑 주식회사',
#   '직무': 'PHP/REACT/PYTHON/퍼블리셔 경력자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653615'},
#  {'기업명': '펜타시큐리티시스템(주)',
#   '직무': '[펜타시큐리티]보안S/W 개발자 모집(DB,인증,블록체인,클라우드)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38704592'},
#  {'기업명': '(주)시지온',
#   '직무': '라이브리 서비스 광고 플랫폼 개발자 모집',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648078'},
#  {'기업명': '딥러닝 스튜디오',
#   '직무': '스타트업 팀원 모집 (디자이너/영상/프론트개발)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 송파구',
#   '분류': "['광고·시각디자인', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38703753'},
#  {'기업명': '(주)알리아스',
#   '직무': '[ VR / AR ] 콘텐츠 코딩 엔지니어 신입/경력사원 모집(정규직)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경남 김해시',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666637'},
#  {'기업명': '매드업',
#   '직무': '[테크사업부] 데이터 사이언티스트 채용',
#   '경력사항': '5 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38703446'},
#  {'기업명': '매드업',
#   '직무': '[테크사업부] 백엔드 개발자 채용',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38703416'},
#  {'기업명': '굿모니터링(주)',
#   '직무': '웹.앱 시스템 개발자 채용',
#   '경력사항': '1 ~ 3년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서대문구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38703141'},
#  {'기업명': '파이어씨드',
#   '직무': '프론트엔드/HTML/Python/PHP外 정규직 채용(경력)',
#   '경력사항': '2 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대구 북구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38703131'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 기획 경력자 대규모 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '마케팅·광고·분석']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38502374'},
#  {'기업명': '(주)커머스랩',
#   '직무': '2020년 하반기 각 부문별 신입/경력 채용(CS/운영/서비스기획/웹서비스개발/앱서비스개발)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['사무보조·문서작성', 'TM·인바운드']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38702846'},
#  {'기업명': '켈리서비스 유한회사',
#   '직무': '[글로벌 포털 G사 ] Technical Solutions Consultant',
#   '경력사항': '3 ~ 5년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 강남구',
#   '분류': "['AS·서비스·수리', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38569889'},
#  {'기업명': '위티',
#   '직무': '[경력] 데이터 엔지니어 (파이프라인 구축 및 데이터분석) 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38558985'},
#  {'기업명': '패스트캠퍼스(주)',
#   '직무': '[패스트캠퍼스] 대규모 인재 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '마케팅·광고·분석']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38230007'},
#  {'기업명': '베스핀글로벌(주)',
#   '직무': 'Public Cloud System Architect(SA) 채용(경력 3년이상)',
#   '경력사항': '3 ~ 20년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589952'},
#  {'기업명': '(주)하하랜드',
#   '직무': '[㈜하하랜드] 각 부문별 정규직 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['웹마스터·QA·테스터', '웹기획·PM']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38663946'},
#  {'기업명': '포항가속기연구소',
#   '직무': '연구직 / 기술직 직원 채용',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경북 포항시',
#   '분류': "['기계·기계설비', '반도체·디스플레이·LCD']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38660255'},
#  {'기업명': '콘텐츠웨이브(주)',
#   '직무': '[WAVVE]개발자 채용 [빌링/플랫폼운영/미디어스트리밍]',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38658117'},
#  {'기업명': '주식회사 디케이테크인',
#   '직무': '[카카오계열사] 카카오 공동체 서비스 백엔드 개발자 모집',
#   '경력사항': '2 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38694333'},
#  {'기업명': '(주)아크릴',
#   '직무': 'AI, 인공지능 개발자 모집',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38684262'},
#  {'기업명': '리눅스웨어 주식회사',
#   '직무': '[메일플러그]  웹 / 시스템 개발자 정규직 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38645113'},
#  {'기업명': '이노와이어리스',
#   '직무': '이노와이어리스/큐셀네트웍스 각 분야 신입/경력 채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '통신·모바일']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38701524'},
#  {'기업명': '(주)굿링크',
#   '직무': '서버/클라이언트 Application 개발 기술연구소 연구원 모집',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경남 진주시',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38684402'},
#  {'기업명': '주식회사 오픈소스컨설팅',
#   '직무': '[오픈소스컨설팅] 각 부문 엔지니어 채용(신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38701306'},
#  {'기업명': '테크빌교육(주)',
#   '직무': '[테크빌교육] 프로그래머·데이터분석 등 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38701175'},
#  {'기업명': '더조은컴퓨터아트학원',
#   '직무': '[100%무료 취업준비생모집]웹디/건축/게임/프로그래밍/3D프린터',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['그래픽디자인·CG', '제품·산업디자인']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=34529977'},
#  {'기업명': '클라우드그램(주)',
#   '직무': '[클라우드그램] 2020년 하반기 부문별 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['IT·솔루션영업', '금융·보험영업']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38437647'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존클라우드] Mass Migration Center 부문별 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['IT·솔루션영업', '서버·네트워크·보안']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38348572'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존클라우드] APM Solution Engineer 채용(3~8년)',
#   '경력사항': '3 ~ 8년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38398430'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존클라우드] AI System 부문 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38412758'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존클라우드] Product Development 부문 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38438571'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 오라클 클라우드 Architect 채용(7년이상)',
#   '경력사항': '경력 7년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38398442'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 구글클라우드 부문 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['일반영업', 'IT·솔루션영업']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38409477'},
#  {'기업명': '현대오트론(주)',
#   '직무': '현대오트론 시스템반도체/전장SW 전문가 경력 상시채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['구매·자재·재고', '기획·전략·경영']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38544124'},
#  {'기업명': '(주)데이터에듀',
#   '직무': 'AI, ML 파이썬/자바 개발자 공고(청년채움공제 가능)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '부산 해운대구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38699929'},
#  {'기업명': '이마고웍스(주)',
#   '직무': '딥러닝 기반 의료영상 이미지 처리 모듈 및 알고리즘 개발',
#   '경력사항': '2 ~ 10년',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 동대문구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551989'},
#  {'기업명': '이마고웍스(주)',
#   '직무': '딥러닝 기반 폴리곤 메쉬 프로세싱 모듈 및 알고리즘 개발',
#   '경력사항': '2 ~ 10년',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 동대문구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38551978'},
#  {'기업명': '㈜IDS&TRUST',
#   '직무': '[대웅그룹 자회사] RPA 개발 및 유지보수 경력직 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['ERP·시스템분석·설계', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38698571'},
#  {'기업명': '(주)엠케이',
#   '직무': '2020 하반기 플랫폼 개발 신입&경력 채용 (신입마감)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38574766'},
#  {'기업명': '아콘소프트(주)',
#   '직무': '클라우드 네이티브 전문가/개발자 모집 (쿠버네티즈)',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38697716'},
#  {'기업명': '㈜비즈스프링',
#   '직무': 'Front-End  경력 개발자 채용',
#   '경력사항': '경력 8년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38670952'},
#  {'기업명': '(주)포티투마루',
#   '직무': '[포티투마루] 산업기능요원 병역특례 개발자 모집',
#   '경력사항': '신입',
#   '학력': '학력무관',
#   '근무형태': '병역특례',
#   '근무지': '서울 관악구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38697047'},
#  {'기업명': '(주)씨앤테크',
#   '직무': '[신입/경력] WEB 개발자 공고(AWS / JAVA / Python / PostgreDB)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38696843'},
#  {'기업명': '(주)소프트케잌',
#   '직무': '웹개발자 (경력) - PYTHON, Node, PHP, JQUERY, Vue, React',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '부산 연제구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38529377'},
#  {'기업명': '(주)인라이플',
#   '직무': '(업계1위/복지우수) AI 사업부 Python 개발자 경력직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38696443'},
#  {'기업명': '(주)알스피릿',
#   '직무': '(판교근무) 기계학습-딥러닝 데이터분석(부문별-이미지/텍스트)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38696423'},
#  {'기업명': '(주)유노믹',
#   '직무': '[서울] 신입/경력 채용 (기술영업/마케팅, 데이터분석/SW개발)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['기획·전략·경영', '홍보·PR·사보']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38567864'},
#  {'기업명': '(주)유노믹',
#   '직무': '[부산] 신입/경력 채용 (기술영업/마케팅, 데이터분석/SW개발)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '부산 동구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38579931'},
#  {'기업명': '(주)아임솔텍',
#   '직무': 'RPA 개발자 신입/경력자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38696119'},
#  {'기업명': '(주)큐픽스',
#   '직무': '[신입/경력/전문연구요원] 컴퓨터비전/딥러닝/SLAM 알고리즘',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38696115'},
#  {'기업명': '(주)큐픽스',
#   '직무': '[신입/경력/전문연구요원] AWS/Ruby 백엔드엔지니어',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38696090'},
#  {'기업명': '(주)비트나인',
#   '직무': '[비트나인]  빅데이터 및 그래프데이터 분석 전문가',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38670767'},
#  {'기업명': '(주)비트나인',
#   '직무': '[비트나인] 하반기 신입/경력사원 채용공고',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['웹디자인', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38669902'},
#  {'기업명': '에듀베이션(주)',
#   '직무': '[대교계열사] R&D 부문 개발 경력사원 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38695854'},
#  {'기업명': '앰진시큐러스',
#   '직무': '(주)앰진시큐러스 백엔드 개발자 모집(Python / Java / C / C++)',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38659036'},
#  {'기업명': '노을(주)',
#   '직무': '[노을 주식회사] Web Backend 개발자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 용인시 수지구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38695613'},
#  {'기업명': '주식회사 제이카',
#   '직무': '[정규직] 백엔드 / iOS / Android 개발자 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38659263'},
#  {'기업명': '(주)에이프릴세븐',
#   '직무': '[스타트업] 서버개발자 채용 공고',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38695046'},
#  {'기업명': '(주)컴트루테크놀로지',
#   '직무': '[인공지능 보안솔루션] 딥러닝아키텍쳐 / AI 개발자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '서울 마포구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38694734'},
#  {'기업명': '(주)컴트루테크놀로지',
#   '직무': '[병역특례(보충역)] Web개발, iOS개발, AI개발, 응용개발 모집',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38694731'},
#  {'기업명': '(주)비츠로테크',
#   '직무': '비츠로그룹 경력직(정보DB화) 모집',
#   '경력사항': '5 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 광진구',
#   '분류': "['마케팅·광고·분석', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38694585'},
#  {'기업명': '바이브컴퍼니',
#   '직무': '바이브컴퍼니에서 경력직 개발자 모집합니다.',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38694547'},
#  {'기업명': '하이오(주)',
#   '직무': '미래사업부 개발자 경력직 채용 공고',
#   '경력사항': '5 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 화성시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38680982'},
#  {'기업명': '(주)디랩',
#   '직무': '[무료] 경기도 전지역 SW교육 전문가양성 교육생 모집 (100명)',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직 · 프리랜서',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '교육기획·교재']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38659722'},
#  {'기업명': '(주)삼성엠앤에스',
#   '직무': '2020년 삼성MNS/MPS 신입/경력 각부문별 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38671728'},
#  {'기업명': '(주)중헌제약',
#   '직무': '중헌제약 각 부문 신입/경력 채용',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['경리·출납·결산', '회계·재무·세무·IR']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38654402'},
#  {'기업명': '(주)인텔리안시스템즈',
#   '직무': '각 부문별 신입 및 경력채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['사무보조·문서작성', '웹기획·PM']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38637555'},
#  {'기업명': '(주)코믹스브이',
#   '직무': '(신입/경력) VR웹툰/교육플랫폼, 웹개발, UI/UX디자이너 선발',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692158'},
#  {'기업명': '(주)리얼셀러',
#   '직무': 'PHP / Python(파이썬) / 앱(IOS,안드로이드) 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 성북구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38673251'},
#  {'기업명': '(주)엑시포씨앤에스',
#   '직무': 'Microsoft BI / Data Engineer 모집공고',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38660858'},
#  {'기업명': '포인트정보기술',
#   '직무': '[가산] LG전자 US사이트 개발운영 (Python)',
#   '경력사항': '6 ~ 20년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '프리랜서',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692574'},
#  {'기업명': '주식회사 빌리오',
#   '직무': '빌리오(Billyo) 퍼포먼스 마케터 경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38625336'},
#  {'기업명': '(주)화이트스캔',
#   '직무': 'AI융합연구소 Python 개발자 채용(경력무관)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 서대문구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692327'},
#  {'기업명': '(주)씨유박스',
#   '직무': '각 부문 신입 및 경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '고졸↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 금천구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591207'},
#  {'기업명': '(주)대우건설',
#   '직무': '2020년 경력직 채용 공고',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '서울 중구',
#   '분류': "['일반영업', '기술영업']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38668239'},
#  {'기업명': '이지지아이에스(주)',
#   '직무': '하반기 각 부문 경력사원 채용 (C# WPF 솔루션 개발/빅데이터 컨설팅)',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38676155'},
#  {'기업명': '(주)스틸리언',
#   '직무': '모바일 보안 솔루션 개발 [병특 가능]',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 용산구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38653071'},
#  {'기업명': '이노뎁(주)',
#   '직무': '2020 기술연구그룹 공채',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['사무보조·문서작성', '그래픽디자인·CG']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38637717'},
#  {'기업명': '인재사관학교 주식회사',
#   '직무': '[강남/양재] Java php python개발자 신입',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['마케팅·광고·분석', '웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692081'},
#  {'기업명': '(주)마인드포지',
#   '직무': 'Python, 인공지능(AI), 머신러닝 외 인턴직 모집(경력무관)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '인턴직',
#   '근무지': '서울 구로구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38691744'},
#  {'기업명': '(주)킨펙오토',
#   '직무': '서버 개발자 경력 채용 공고/백엔드/Java/Spring-boot/Python',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '부산 연제구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38630613'},
#  {'기업명': '사이언티픽아날로그랩스 주식회사',
# ...
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38702176'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'DBA 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38702169'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '응용프로그램 서버 개발자 C++ MFC Linux 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38702166'},
#  {'기업명': '헬로우파트너스',
#   '직무': '자동차부품 대기업 내비게이션 Software Engineer 채용',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38702154'},
#  {'기업명': '(주)탑앤스카우트',
#   '직무': '[AI, IoT] 공공프로젝트 PM 충원',
#   '경력사항': '경력 8년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', 'ERP·시스템분석·설계']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38687672'},
#  {'기업명': '헤리티지서치코어',
#   '직무': '빅데이터 수집 분석 시스템 UI /프론트엔드/유명 솔루션 기업',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38700333'},
#  {'기업명': '㈜피플스카우트',
#   '직무': '[강소기업]서버 개발자(C++, MFC, Linux)',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38700109'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[모바일 애드테크 전문기업] Front-end 엔지니어(대리-과장)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38660082'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[모바일 애드테크 전문기업] 백엔드 엔지니어(대리-과장)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38660129'},
#  {'기업명': '㈜벤처피플',
#   '직무': '[모바일 애드테크 전문기업] 프론트엔드 엔지니어(대리-과장)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38660144'},
#  {'기업명': '커리어셀파',
#   '직무': '[유통대기업] IT개발 경력사원 채용',
#   '경력사항': '4 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38694395'},
#  {'기업명': '(주)커리어멘토',
#   '직무': '(1.VISION제어/ 2 PC제어/ 3.VISION SW개발/4.모션제어',
#   '경력사항': '4 ~ 12년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기계·기계설비', '전기·전자·제어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38694048'},
#  {'기업명': '비전서치',
#   '직무': '업데이트용 sw 개발',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38693704'},
#  {'기업명': '에버브레인컨설팅(주)',
#   '직무': '[국내최대 오픈마켓]서비스/플랫폼 QA',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692365'},
#  {'기업명': '에버브레인컨설팅(주)',
#   '직무': '[국내최대 오픈마켓] Payment 서비스 기획',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692364'},
#  {'기업명': '에버브레인컨설팅(주)',
#   '직무': '[국내최대 오픈마켓] Data Architect',
#   '경력사항': '3 ~ 10년',
#   '학력': '석사↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692360'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'SW연구개발 대리과장급 Restful API',
#   '경력사항': '경력 4년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692244'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '그룹 HR 공유 Infra HRIS 시스템 구축 SaaS 솔루션 클라우드',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692228'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'SW연구개발 대리과장급',
#   '경력사항': '경력 4년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692220'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38692204'},
#  {'기업명': '(주)에이치알맨파워그룹',
#   '직무': '금융 시스템 개발 대리~과(차)장급 경력사원 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38676036'},
#  {'기업명': '(주)에이치알맨파워그룹',
#   '직무': '금융시스템 유지보수 대리~과장급 경력사원 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38676154'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[헤딩머니 100만원/더쿠스아이앤씨 ] Mobile Software Engineer',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38691627'},
#  {'기업명': '한스컨설팅',
#   '직무': '영등포 위치 국내 1위 구매 SCM솔루션기업 AI개발 대리급',
#   '경력사항': '3 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38691276'},
#  {'기업명': '㈜에이치알맨파워그룹',
#   '직무': '[대기업-상장사] AI알고리즘 (박사연구원-서울)',
#   '경력사항': '신입 · 경력',
#   '학력': '박사',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38686171'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 Java, Oracle',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38686018'},
#  {'기업명': '위키에이드',
#   '직무': '영상처리 / 머신비전 검사 SW 개발 경력',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 화성시',
#   '분류': "['응용프로그램개발', '하드웨어·소프트웨어']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38685798'},
#  {'기업명': '헤리티지서치코어',
#   '직무': '솔루션영업/경력 5년이상/유명 IT 솔루션기업',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38685656'},
#  {'기업명': '인비즈써치',
#   '직무': '대형증권사 시스템트레이딩 및 로보어드바이저 시스템 개발 모집',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 영등포구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38683166'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '렌탈 시스템 구축 프로젝트 PL업무 수행 Spring framework',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679732'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['응용프로그램개발', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679720'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '그룹 HR 공유 Infra HRIS 시스템 구축',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679718'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '렌탈 시스템 구축 프로젝트 PL업무 수행 시스템 개발',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679716'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Battery 생산지원시스템(QMS/SCM/EMS) 구축 및 Global 확산/운영',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 동구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679706'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '유통산업 및 커머스 분야 시스템 설계 개발자 java',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679705'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': '그룹 HR 공유 Infra HRIS 시스템 구축 SaaS  Cloud',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679704'},
#  {'기업명': '(주)솔루게이트',
#   '직무': '[파트 및 아르바이트] 사무보조 및 개발자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '파트 · 아르바이트',
#   '근무지': '서울 금천구',
#   '분류': "['총무·법무·사무', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38676395'},
#  {'기업명': '주식회사라피플코리아리미티드',
#   '직무': '스포츠 IT 벤처기업 - 풀스택 개발자',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38675775'},
#  {'기업명': '주식회사라피플코리아리미티드',
#   '직무': '스포츠 IT 벤처기업 - 백엔드 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38632485'},
#  {'기업명': '주식회사라피플코리아리미티드',
#   '직무': '스포츠 IT 벤처기업 - 프론트엔드 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38633268'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'Battery 생산지원시스템(QMS/SCM/EMS) 구축',
#   '경력사항': '경력 6년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대전 동구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38673127'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'MRO 관련 기업의 SCM 구축 경험 보유자 SAP',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38673118'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': 'IT/ICT 소프트웨어 엔지니어',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시 영통구',
#   '분류': "['시스템개발', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666551'},
#  {'기업명': '(주)헬로서치',
#   '직무': '[국내우량기업]딥러닝 개발 인재를 모십니다.',
#   '경력사항': '2 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38659897'},
#  {'기업명': '(주)연세교육아카데미ㅣ연세직업전문학교',
#   '직무': '정보보안(모의해킹) 및 클라우드 강사 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '전임 · 계약직',
#   '근무지': '경기 수원시 장안구',
#   '분류': "['서버·네트워크·보안', '인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38659283'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '외국계 반도체회사 R&D S/W 연구원(경력) 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649126'},
#  {'기업명': '(주)맨파워그룹코리아',
#   '직무': '외국계 회사 Video System R&D Software Engineer 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '시스템개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649125'},
#  {'기업명': '(주)에이치알인재그룹',
#   '직무': '사무자동화(RPA) 개발 경력채용',
#   '경력사항': '4 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 김포시',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648271'},
#  {'기업명': '(주)쿠자피에이에스',
#   '직무': '개발자 SW개발 팀장급 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '울산 중구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38647730'},
#  {'기업명': '그린컴퓨터아트학원 아카데미 성남/분당 ..',
#   '직무': '[국기] JAVA기반(웹,앱,빅데이터) 개발자 과정 훈련교.강사 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '전임 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38629645'},
#  {'기업명': '그린컴퓨터아트학원 아카데미 성남/분당 ..',
#   '직무': '[국가기간] 디지털컨버전스(JAVA기반), 빅데이터취업 국비교육',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '위촉직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38632622'},
#  {'기업명': '그린컴퓨터아카데미',
#   '직무': '자바(JAVA) 개발 / 응용SW 직업훈련교사(강사) 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '울산 남구',
#   '분류': "['웹개발', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38643837'},
#  {'기업명': '(주)핀커스코리아',
#   '직무': '유명기업 웹개발 경력채용(3년~7년)',
#   '경력사항': '3 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38640208'},
#  {'기업명': '㈜에이치알맨파워그룹',
#   '직무': '[대기업] AI알고리즘-박사 (서울)',
#   '경력사항': '신입 · 경력',
#   '학력': '박사',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38635195'},
#  {'기업명': '하이잡',
#   '직무': '추천 시스템 연구/개발',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['인공지능(AI)·빅데이터']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38634020'},
#  {'기업명': '그린컴퓨터아카데미',
#   '직무': '자바(JAVA) 웹프로그래밍개발 직업훈련교사(강사) 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '울산 남구',
#   '분류': "['웹개발', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'python',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38600945'}]

# %%
# db 직업 스크래핑

job_list_db = []
page_num = 1
while True:
    url = f'http://www.saramin.co.kr/zf_user/jobs/list/job-category?page={page_num}&cat_cd=416&cat_key=40745&search_optional_item=n&search_done=y&panel_count=y&isAjaxRequest=0&page_count=50&sort=RL&type=job-category&is_param=1&isSearchResultEmpty=1&isSectionHome=0&searchParamCount=2#searchTitle'
    req_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    }
    html = requests.get(url, req_header).text
    soup = BeautifulSoup(html, 'html.parser')
    if soup.select('div.list_body div.list_item') == []:
        break
    for tag in soup.select('div.list_body div.list_item'):
        company_dict = {}
        company_dict["기업명"] = tag.select('div.company_nm a span')[0].text
        company_dict["직무"] = tag.select('div.notification_info a span')[0].text
        company_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
        company_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
        try:
            company_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
        except:
            company_dict["근무형태"] = ""
        try:    
            company_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
        except:
            company_dict["근무지"] = ""
        category_list = []
        for item in tag.select('div.notification_info div.job_meta span span'):
            category_list.append(item.text)
        company_dict["분류"] = str(category_list)
        company_dict["분류필터"] = "db"
        
        detail_url = tag.select_one('div.notification_info a').attrs['href']
        full_detail_url = urljoin(main_url, detail_url)
        company_dict["상세링크"] = full_detail_url
        job_list_db.append(company_dict)
    page_num += 1
job_list_db
# Out:
# [{'기업명': '주식회사 하우투약',
#   '직무': '[알약물약] 백엔드 서버 개발자 / 프론트엔드 개발자 경력 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38678203&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)시니스트',
#   '직무': '㈜시니스트 하반기 개발자/기획운영자 채용 공고',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '마케팅·광고·분석']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38663261&adsCategoryItem=effect_bold&'},
#  {'기업명': '한양이엔지(주)',
#   '직무': '한양이엔지㈜ 부문별 수시채용 직원모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 화성시',
#   '분류': "['회계·재무·세무·IR', '전기·전자·제어']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38668958&adsCategoryItem=effect_bold&'},
#  {'기업명': '노아에이티에스(주)',
#   '직무': '2020년 하반기 신입사원 공개채용',
#   '경력사항': '신입',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38630758&adsCategoryItem=effect_bold&'},
#  {'기업명': '샘표(주)',
#   '직무': '각 부문 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 중구',
#   '분류': "['물류·유통·운송', '해외영업·무역영업']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38695029&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)잘론네츄럴',
#   '직무': '2020년 하반기 빌리브네이처 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['상품기획·MD', '기획·전략·경영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38573516&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)베네통코리아',
#   '직무': '[베네통코리아] E-commerce 각 부문 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 서초구',
#   '분류': "['마케팅·광고·분석', '웹기획·PM']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38682642&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)나비엠알오',
#   '직무': '2020년 하반기 각 분야 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['해외영업·무역영업', '구매·자재·재고']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38605703&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)골든플래닛',
#   '직무': '디지털 마케팅 컨설턴트, 마케팅자동화, 온라인마케팅 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['마케팅·광고·분석', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38681678&adsCategoryItem=effect_bold&'},
#  {'기업명': '에스비아이코스머니(주)',
#   '직무': '2020년 하반기 각 부문별 직원채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38640756&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)이퀴닉스',
#   '직무': 'PHP웹개발/웹기획 경력 채용',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38660238&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)케이아이엔엑스',
#   '직무': '네트워크/시스템 모니터링 및 기술지원 엔지니어 채용',
#   '경력사항': '신입',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기술영업', '웹마스터·QA·테스터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38663055&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)캐럿글로벌',
#   '직무': '[솔루션개발팀] 웹기획자/웹디자이너/웹개발자 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690299&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)글로벌머니익스프레스',
#   '직무': '2020년 개발직군 대규모 채용外',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 종로구',
#   '분류': "['해외영업·무역영업', '기획·전략·경영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38632864&adsCategoryItem=effect_bold&'},
#  {'기업명': '이지스엔터프라이즈(주)',
#   '직무': '각 부문별 경력직 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['사무보조·문서작성', '마케팅·광고·분석']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38667826&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)쓰리탑',
#   '직무': '(주)쓰리탑 2020년 경력사원 모집',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['기획·전략·경영', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38677581&adsCategoryItem=effect_bold&'},
#  {'기업명': '엘에이치주거복지정보(주)',
#   '직무': '2020년 LH주거복지정보㈜ 직원 채용 공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 교육생',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['운전·기사', '총무·법무·사무']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38699968&adsCategoryItem=effect_bold&'},
#  {'기업명': '한국직업능력교육원 안산',
#   '직무': '경기/시흥・안산/군포 국비무료 취업연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '경기 안산시 단원구',
#   '분류': "['회계·재무·세무·IR', '생산관리·품질관리']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38677061&adsCategoryItem=effect_bold&'},
#  {'기업명': '동양시스템즈(주)',
#   '직무': '2020년 하반기 신입 및 경력사원 공개 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['그래픽디자인·CG', '출판·편집디자인']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690599&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)아이네크',
#   '직무': '모바일 APP, 웹프로그래머 경력 및 신입사원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['마케팅·광고·분석', 'IT·솔루션영업']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38699356&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)지이씨엘코리아',
#   '직무': 'GECL KOREA  경력직 채용 (MD, PHP, JAVA, 웹디자인, SEO)',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 금천구',
#   '분류': "['해외영업·무역영업', '상품기획·MD']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38699334&adsCategoryItem=effect_bold&'},
#  {'기업명': '에스지에이솔루션즈(주)',
#   '직무': '2020년 하반기 각 부문별 신입/경력 직원채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['경리·출납·결산', '사무보조·문서작성']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38682928&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)인포렉스',
#   '직무': '[최고대우] 서비스기획, 프론트/APP/서버 개발, 디자이너 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['기획·전략·경영', '그래픽디자인·CG']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38700337&adsCategoryItem=effect_bold&'},
#  {'기업명': '조인스중앙(주)',
#   '직무': '20년 조인스중앙 IT부문 채용연계형 인턴 모집',
#   '경력사항': '신입',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '인턴직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38686946&adsCategoryItem=effect_bold&'},
#  {'기업명': '넥센타이어(주)',
#   '직무': '[경력] 2020년 넥센타이어 웹 개발/디자인/퍼블리싱 담당자 채용',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '계약직',
#   '근무지': '서울 강서구',
#   '분류': "['그래픽디자인·CG', '웹마스터·QA·테스터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38691303&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)정상제이엘에스',
#   '직무': '영상 제작자/영상 디자이너/웹개발자 신입 및 경력직원 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울전체',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38689829&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)디케이비엠시',
#   '직무': 'CRM, BI, SI 컨설팅솔루션 관리/개발자 채용 공고',
#   '경력사항': '2 ~ 17년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['그래픽디자인·CG', '웹기획·PM']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38528106&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)위즈더플래닛',
#   '직무': '컨텐츠기획 및 운영/사진보정/어플 개발자/웹개발자/번역 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 아르바이트',
#   '근무지': '서울 강남구',
#   '분류': "['영업기획·관리·지원', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38681860&adsCategoryItem=effect_bold&'},
#  {'기업명': '(사)한국물가협회',
#   '직무': '사)한국물가협회 직원 채용 공고',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38646976&adsCategoryItem=effect_bold&'},
#  {'기업명': '한국기술교육직업전문학교',
#   '직무': '[전액국비] 4차산업 IT전문인력 취업연계교육',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '부산 동래구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38539306&adsCategoryItem=effect_bold&'},
#  {'기업명': '크레텍(주)',
#   '직무': '전산직 SW개발 경력 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '대구 중구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38663932&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)인라이플',
#   '직무': '[업계1위/복지최강] JAVA 개발자 대규모 인재채용 진행',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹마스터·QA·테스터', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38691275&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)디알젬',
#   '직무': '디알젬 경력사원 모집 (해외영업 기획,연구소,기술지원,구매)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 광명시',
#   '분류': "['구매·자재·재고', '기획·전략·경영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38699014&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)키메디',
#   '직무': 'PHP 개발 경력자 정규직 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '컨텐츠·사이트운영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38678341'},
#  {'기업명': '(주)대우능력개발교육원',
#   '직무': '2020년 100% 국비무료 9~10월 개강 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '교육생',
#   '근무지': '서울 중랑구',
#   '분류': "['총무·법무·사무', '사무보조·문서작성']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631354&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)경일게임아카데미',
#   '직무': '정부무료 게임회사 취업연수생 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '웹기획·PM']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38644455&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)피플벤처스',
#   '직무': 'PHP 웹 개발 (프론트엔드, 백엔드, Api 개발) 경력자 모집공고',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38589794'},
#  {'기업명': '휴먼교육센터학원',
#   '직무': '[전액무료]자바/파이썬 IT교육받고 취업하자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '교육생',
#   '근무지': '서울전체',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38510654&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)매드업',
#   '직무': '[매드업] 퍼포먼스마케터/개발자 외 대규모 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['인사·교육·노무', '마케팅·광고·분석']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38596083&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)필옵틱스',
#   '직무': '[비전검사실] Vision SW 설계/개발 엔지니어 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시 권선구',
#   '분류': "['반도체·디스플레이·LCD', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38689609&adsCategoryItem=effect_bold&'},
#  {'기업명': '(주)위비즈넷',
#   '직무': '(경력) JAVA 소프트웨어 연구/개발 인력 모집',
#   '경력사항': '5 ~ 15년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690631'},
#  {'기업명': '(주)펄어비스',
#   '직무': '[펄어비스] 2020 전 부문 수시채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['총무·법무·사무', '인사·교육·노무']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37536372'},
#  {'기업명': '(주)키스템프',
#   '직무': '[나주/463만/11개월]한국우편사업진흥원 웹/앱 개발자 3명 채용',
#   '경력사항': '경력 10년↑',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '전남 나주시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38709070'},
#  {'기업명': '(주)키스템프',
#   '직무': '[나주/393만/11개월]한국우편사업진흥원 웹/앱 개발자 2명 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '전남 나주시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38708962'},
#  {'기업명': '(주)비엠더코리아',
#   '직무': 'DB분야 (DBA 수행) SI/SM 초급/중급 프리랜서 모집',
#   '경력사항': '2 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '프리랜서',
#   '근무지': '서울 송파구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38429069'},
#  {'기업명': '주식회사 칸정보기술',
#   '직무': '자동제어 프로그램 ASP / DB 개발자 정규직 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 부천시',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648199'},
#  {'기업명': '주식회사 이커머스테크',
#   '직무': 'JAVA 개발 단기 프로젝트-중급이상',
#   '경력사항': '경력 6년↑',
#   '학력': '학력무관',
#   '근무형태': '프리랜서',
#   '근무지': '서울 강서구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38681876'},
#  {'기업명': '주식회사 이커머스테크',
#   '직무': '[JAVA] 클라우드 시스템 개발&유지보수',
#   '경력사항': '3 ~ 7년',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38681785'},
#  {'기업명': '(주)메타넷엠플랫폼',
#   '직무': '[메타넷엠플랫폼 ] 서버 운영 관리 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38707978'},
#  {'기업명': '(주)화이트스캔',
#   '직무': 'AI융합연구소 딥러닝 연구원 채용(경력무관)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서대문구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38707836'},
#  {'기업명': '(주)헥사콘',
#   '직무': 'WEB 개발자 경력 채용',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38707832'},
#  {'기업명': '㈜넷앤드',
#   '직무': '솔루션개발본부 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38707827'},
#  {'기업명': '(주)퓨처젠',
#   '직무': 'C# 신입/경력 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38707502'},
#  {'기업명': '(주)퓨처젠',
#   '직무': 'JAVA Web 경력 개발자 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38707438'},
#  {'기업명': '유호전기공업(주)',
#   '직무': '유호전기공업㈜ 2020년 하반기 부문별 경력/신입 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 양주시',
#   '분류': "['전기·전자·제어', '설계·CAD·CAM']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38707250'},
#  {'기업명': '현대오토에버(주)',
#   '직무': '현대오토에버 경력사원 대규모 상시 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38670835'},
#  {'기업명': '현대오토에버(주)',
#   '직무': 'AI/ 음성인식/ 차량보안/ 빅데이터/ IoT 등 R&D 부문 경력채용',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38670807'},
#  {'기업명': '엘앤에스정보기술(주)',
#   '직무': '데이터베이스 마이그레이션 개발자 채용·DBA(Oracle&Tibero)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 프리랜서',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38706944'},
#  {'기업명': '(주)에스티컴',
#   '직무': 'DBA(경력자) 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38706915'},
#  {'기업명': '주식회사 써머스플랫폼',
#   '직무': '[에누리가격비교]써머스플랫폼 개발부문(연구소) 경력직 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38521796'},
#  {'기업명': '(주)큐브리드',
#   '직무': 'DBMS 기술 전문 엔지니어 신입 및 경력 사원 모집 (대전,광주)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38706468'},
#  {'기업명': '(주)미르이즈',
#   '직무': '응용프로그램(Java/Oracle) 개발 및 운영 초~중급 개발자 채용',
#   '경력사항': '1 ~ 6년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38706412'},
#  {'기업명': '(주)컴투스',
#   '직무': '[컴투스/게임빌컴투스플랫폼/게임빌] 각 부문별 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 금천구',
#   '분류': "['기획·전략·경영', '회계·재무·세무·IR']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38706213'},
#  {'기업명': '(주)트랜스코스모스코리아',
#   '직무': '당사 CX개발사업본부 개발 및 운영 담당자(신입/경력)Mj5E',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38665658'},
#  {'기업명': '(주)핀크',
#   '직무': '(하나금융그룹/SK텔레콤 합작회사) 각 부문 경력직원 모집',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['기획·전략·경영', '마케팅·광고·분석']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38697473'},
#  {'기업명': '(주)인터플렉스',
#   '직무': '[영풍그룹] ㈜인터플렉스 각 부문 신입/경력 사원 모집',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 안산시 단원구',
#   '분류': "['기획·전략·경영', '일반영업']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38698975'},
#  {'기업명': '(주)에이치비테크놀러지',
#   '직무': 'HB테크놀러지 신입/경력사원 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '충남 아산시',
#   '분류': "['기획·전략·경영', '회계·재무·세무·IR']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38615564'},
#  {'기업명': '(주)모니터랩',
#   '직무': '기획, 개발, 마케팅, 영업, 기술지원 공개채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['해외영업·무역영업', '마케팅·광고·분석']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38682604'},
#  {'기업명': '펍지(주)',
#   '직무': '펍지㈜ 각 부문별 수시 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['총무·법무·사무', '인사·교육·노무']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38698942'},
#  {'기업명': '(주)티맥스소프트',
#   '직무': 'TmaxGroup 경력/신입 채용 공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['해외영업·무역영업', '기획·전략·경영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38681609'},
#  {'기업명': '(주)씨제이이엔엠',
#   '직무': 'CJ ENM E&M부문 온라인 플랫폼 서비스기획/개발 경력사원 모집',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['기획·전략·경영', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38691613'},
#  {'기업명': '(주)지피에이코리아',
#   '직무': '[지피에이코리아] 웹 경력 개발자 모십니다.',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38703745'},
#  {'기업명': '㈜해커스교육그룹',
#   '직무': '2020년 해커스 교육그룹 [신입/경력] 각 부문별 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 서초구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38369849'},
#  {'기업명': '(주)제이니스',
#   '직무': '각 부문 경력 채용 [PM, JAVA개발, 유지보수개발]',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38684679'},
#  {'기업명': '(주)데이터스트림즈',
#   '직무': '2020년 IT빅데이터 솔루션 기업 전사 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38642677'},
#  {'기업명': '창원문성대학교산학협력단',
#   '직무': '빅데이터 전문기술 교육과정 교육생 모집',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '교육생',
#   '근무지': '경남 창원시 의창구',
#   '분류': "['회계·재무·세무·IR', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38611128'},
#  {'기업명': '(주)아이디어빈스',
#   '직무': '각 부문 경력사원 채용 (개발/웹기획/웹퍼블리셔/사업기획)',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['기획·전략·경영', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38688318'},
#  {'기업명': '(주)애드락애드버테인먼트',
#   '직무': '애드락애드버테인먼트 개발자 채용 공고',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38609147'},
#  {'기업명': '스포트라이트101',
#   '직무': '플랫폼 서비스 개발자 채용 (서버/IOS /Android)',
#   '경력사항': '경력 1년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690149'},
#  {'기업명': '이에이트(주)',
#   '직무': '2020년 하반기 신입 및 경력직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['기획·전략·경영', '총무·법무·사무']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38686561'},
#  {'기업명': '웹케시(주)',
#   '직무': '2020년 하반기 신입 공채',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '서울 영등포구',
#   '분류': "['상품기획·MD', '기획·전략·경영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38636975'},
#  {'기업명': '메이븐코리아(주)',
#   '직무': '데이터 모델링 개발자 채용',
#   '경력사항': '3 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38705307'},
#  {'기업명': '메이븐코리아(주)',
#   '직무': 'BI 데이터 시각화 개발자 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38705303'},
#  {'기업명': '(재)행복아이씨티',
#   '직무': '[서울 수송동] Java 개발',
#   '경력사항': '경력 6년↑',
#   '학력': '학력무관',
#   '근무형태': '프리랜서',
#   '근무지': '서울 종로구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38705180'},
#  {'기업명': '(주)에니트',
#   '직무': '서울지사 - 솔루션 SW (데이터분석,머신러닝,DB,WEB 부문) 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38467127'},
#  {'기업명': '(주)피타소프트',
#   '직무': 'F/W 개발 경력직 모집(주임/선임연구원급 이상)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['시스템개발', '동영상·편집·코덱']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38623380'},
#  {'기업명': '(주)매스코',
#   '직무': 'GIS 네비게이션 전자지도DATA 구축',
#   '경력사항': '1 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['통신·모바일', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38704213'},
#  {'기업명': '(주)시지온',
#   '직무': '라이브리 서비스 광고 플랫폼 개발자 모집',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38648078'},
#  {'기업명': '(주)캐롯아이',
#   '직무': '캐롯아이와 함께 성장 할 Developer 모집합니다.',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 고양시 일산동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38703752'},
#  {'기업명': '(주)신영이에스디',
#   '직무': '(주)신영이에스디 정보화 분야 신입/경력 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 안양시 동안구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38703719'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 2020년 개발 경력자 대규모 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=37872627'},
#  {'기업명': '㈜넷앤드',
#   '직무': 'DB솔루션개발본부 개발자(C++) 신입/경력 채용',
#   '경력사항': '경력무관',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38703503'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 개발 경력자 대규모 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 송파구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38561876'},
#  {'기업명': '(주)커머스랩',
#   '직무': '2020년 하반기 각 부문별 신입/경력 채용(CS/운영/서비스기획/웹서비스개발/앱서비스개발)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['사무보조·문서작성', 'TM·인바운드']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38702846'},
#  {'기업명': '(주)에이텍티앤',
#   '직무': '[서울역/경력직] AFC관련 S/W개발 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 용인시 수지구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38701548'},
#  {'기업명': '엔카닷컴(주)',
#   '직무': '[내 차 팔기 서비스] Back-end 개발자(경력-3년 이상)',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690715'},
#  {'기업명': '(주)하하랜드',
#   '직무': '[㈜하하랜드] 각 부문별 정규직 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['웹마스터·QA·테스터', '웹기획·PM']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38663946'},
#  {'기업명': '포항가속기연구소',
#   '직무': '연구직 / 기술직 직원 채용',
#   '경력사항': '경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경북 포항시',
#   '분류': "['기계·기계설비', '반도체·디스플레이·LCD']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38660255'},
#  {'기업명': '콘텐츠웨이브(주)',
#   '직무': '[WAVVE]개발자 채용 [빌링/플랫폼운영/미디어스트리밍]',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38658117'},
#  {'기업명': '사운드파이프코리아(주)',
#   '직무': 'H자동차그룹 Car 클라우드 시스템 DBA',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 용산구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38679993'},
#  {'기업명': '(주)모비데이즈',
#   '직무': '모비데이즈 백엔드개발자(광고플랫폼) 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38701782'},
#  {'기업명': '제이피스 주식회사',
#   '직무': 'LG전자 본사 AI/Dig Data 관련 사무보조 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '서울 강서구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38609512'},
#  {'기업명': '㈜연우',
#   '직무': '(주)연우 - ERP/MES 개발운영 경력직 모집',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 서구',
#   '분류': "['웹개발', 'ERP·시스템분석·설계']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38701056'},
#  {'기업명': '(주)파고다아카데미',
#   '직무': '3분기 파고다교육그룹 (개발직,법무) 수시채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '',
#   '근무지': '서울 강남구',
#   '분류': "['총무·법무·사무', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690652'},
#  {'기업명': '(주)메디헬프라인',
#   '직무': '[메디헬프라인] 임상시험 자료관리(DM) / DMA모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['의료기타직', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38445122'},
#  {'기업명': '클라우드그램(주)',
#   '직무': '[클라우드그램] 2020년 하반기 부문별 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['IT·솔루션영업', '금융·보험영업']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38437647'},
#  {'기업명': '(주)나임네트웍스',
#   '직무': '[나임네트웍스] 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38530161'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존클라우드] Mass Migration Center 부문별 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['IT·솔루션영업', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38348572'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존클라우드] APM Solution Engineer 채용(3~8년)',
#   '경력사항': '3 ~ 8년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38398430'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존클라우드] Cloud DBA(Mysql, MS SQL DBA 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38413404'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존클라우드] VDI Helpdesk / 24x7 Service 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['사무보조·문서작성', '기술영업']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38439227'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존클라우드] Cloud Infra System Engineer 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 병역특례',
#   '근무지': '서울 강남구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38439282'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 오라클 클라우드 Architect 채용(7년이상)',
#   '경력사항': '경력 7년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38398442'},
#  {'기업명': '메가존(주)',
#   '직무': '[메가존] 구글클라우드 부문 채용',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['일반영업', 'IT·솔루션영업']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38409477'},
#  {'기업명': '(주)여기어때컴퍼니',
#   '직무': '[여기어때] 데이터 엔지니어 (DBA/DW구축) 채용',
#   '경력사항': '3 ~ 10년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38700493'},
#  {'기업명': '(주)한국지에스티',
#   '직무': '응용프로그래머 및 웹디자이너 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 중구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38671239'},
#  {'기업명': '코리아소프트(주)',
#   '직무': 'DBA / ASP 개발자 채용합니다',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '인천 부평구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38699913'},
#  {'기업명': '(주)휴비즈아이씨티',
#   '직무': '[경력] 휴비즈ICT - SI , SM  개발자 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 파견직',
#   '근무지': '경북 포항시 남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38699773'},
#  {'기업명': '(주)피어스넷',
#   '직무': 'Java,JSP(SSO/리포팅툴)/DB암호화 개발/엔지니어 구인공고',
#   '경력사항': '1 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강서구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591032'},
#  {'기업명': '아비코전자(주)',
#   '직무': '전산팀 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 중원구',
#   '분류': "['회계·재무·세무·IR', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38587433'},
#  {'기업명': '현대오토에버(주)',
#   '직무': '웹/ 앱/ 시스템/ 인프라/ 네트웍/ 서버/보안 부문 경력채용',
#   '경력사항': '3 ~ 20년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38670780'},
#  {'기업명': '시앤지원(주)',
#   '직무': 'DB 경력(과장급)이상',
#   '경력사항': '7 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38665296'},
#  {'기업명': '시앤지원(주)',
#   '직무': 'DB 경력(차장급)이상',
#   '경력사항': '10 ~ 14년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38665301'},
#  {'기업명': '㈜네오플',
#   '직무': '[네오플] 기술지원 (게임QA/DBA) 직군 인재 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '제주 제주시',
#   '분류': "['웹마스터·QA·테스터', '게임·Game']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690943'},
#  {'기업명': '(주)알스피릿',
#   '직무': '(판교근무) 기계학습-딥러닝 데이터분석(부문별-이미지/텍스트)',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38696423'},
#  {'기업명': '(주)아이엔에스시스템',
#   '직무': '[분당]대기업 DB운영 및 솔루션 관리 경력자 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38480590'},
#  {'기업명': '(주)에이치와이모터스',
#   '직무': 'IT 전산 (정보시스템 운영, 개발, 관리)',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 군포시',
#   '분류': "['응용프로그램개발', 'ERP·시스템분석·설계']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38696297'},
#  {'기업명': '(주)블루오션',
#   '직무': '2020년 블루오션 Swift 기반 iOS 앱 개발자 채용',
#   '경력사항': '3 ~ 5년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38681544'},
#  {'기업명': '(주)비트나인',
#   '직무': '[비트나인] 하반기 신입/경력사원 채용공고',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강서구',
#   '분류': "['웹디자인', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38669902'},
#  {'기업명': '엔셀 주식회사',
#   '직무': 'Display 전산/DB/SQL운영, shell 프로그래밍 정규직',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '충남 아산시',
#   '분류': "['서버·네트워크·보안', '컨텐츠·사이트운영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38627184'},
#  {'기업명': '오티아이(주)',
#   '직무': '오티아이(주) SW개발 부문 신입 및 경력직 채용(대전)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '대전 유성구',
#   '분류': "['웹개발', '하드웨어·소프트웨어']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38695203'},
#  {'기업명': '(주)핀샷',
#   '직무': '개발자 모집 (신입/경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 인턴직',
#   '근무지': '서울 마포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38694743'},
#  {'기업명': '신한신용정보(주)',
#   '직무': '신한신용정보 2020년 신입 및 경력직원 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 영등포구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38673959'},
#  {'기업명': '광동제약(주)',
#   '직무': 'IT전략팀 경력직 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38670586'},
#  {'기업명': '콩게임즈',
#   '직무': '웹 게임 개발 및 유지,보수 / 웹 디자이너 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 수원시 영통구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38683587'},
#  {'기업명': '(주)씨엠에스에듀',
#   '직무': '[CMS에듀] IT팀 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38694010'},
#  {'기업명': '(주)아름누리메디컴',
#   '직무': '㈜아름누리메디컴 각 부문별 신입/경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 용인시 수지구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38674497'},
#  {'기업명': '(주)디랩',
#   '직무': '[무료] 경기도 전지역 SW교육 전문가양성 교육생 모집 (100명)',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직 · 프리랜서',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발', '교육기획·교재']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38659722'},
#  {'기업명': '(주)나래에스앤씨',
#   '직무': '흥국생명 개발 및 운영-콜센터/일반보험, 재무',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 중구',
#   '분류': "['회계·재무·세무·IR', '금융·보험영업']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690133'},
#  {'기업명': '말랑하니(주)',
#   '직무': '(유아 쇼핑몰 스타트업) 육아 정보 및 쇼핑 정보 데이터 정리',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 아르바이트',
#   '근무지': '부산 해운대구',
#   '분류': "['사무보조·문서작성', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38688177'},
#  {'기업명': '(주)엑시포씨앤에스',
#   '직무': 'Microsoft BI / Data Engineer 모집공고',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38660858'},
#  {'기업명': '(주)씨유박스',
#   '직무': '각 부문 신입 및 경력 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '고졸↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 금천구',
#   '분류': "['기획·전략·경영', '사무보조·문서작성']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38591207'},
#  {'기업명': '(주)티시스',
#   '직무': '태광그룹 ㈜티시스 경력사원 공개채용 (IT, 부동산, 건설, 레저)',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['AS·서비스·수리', '레저·스포츠']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649618'},
#  {'기업명': '(주)대우건설',
#   '직무': '2020년 경력직 채용 공고',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '계약직',
#   '근무지': '서울 중구',
#   '분류': "['일반영업', '기술영업']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38668239'},
#  {'기업명': '이지지아이에스(주)',
#   '직무': '하반기 각 부문 경력사원 채용 (C# WPF 솔루션 개발/빅데이터 컨설팅)',
#   '경력사항': '경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38676155'},
#  {'기업명': '(주)유진홈센터',
#   '직무': '[유진그룹] ACE 하드웨어 전문인재 공개채용',
#   '경력사항': '경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 용산구',
#   '분류': "['상품기획·MD', '기획·전략·경영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38649399'},
#  {'기업명': '이노뎁(주)',
#   '직무': '2020 기술연구그룹 공채',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['사무보조·문서작성', '그래픽디자인·CG']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38637717'},
#  {'기업명': '티엔에이치(주)',
#   '직무': '하반기 각 부문별 신입/경력 채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['그래픽디자인·CG', '웹기획·PM']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38631690'},
#  {'기업명': '(주)버블콘',
#   '직무': '(주)버블콘 하반기 개발 경력/신입 사원 채용(정규직)',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '인천 연수구',
#   '분류': "['웹개발', '컨텐츠·사이트운영']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38652747'},
#  {'기업명': '(주)에어릭스',
#   '직무': '[신입/경력] 웹개발(프론트엔드/백엔드) 정규직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38680329'},
#  {'기업명': '이루온',
#   '직무': '(주)이루온 시스템엔지니어 모집(대전근무)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '시스템개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38691403'},
#  {'기업명': '이루온',
#   '직무': '(주)이루온 시스템엔지니어 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['서버·네트워크·보안', '시스템개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38691399'},
#  {'기업명': '㈜데이타뱅크시스템즈',
#   '직무': 'Oracle Database 엔지니어 모집(서울)',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 금천구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38690363'},
#  {'기업명': '(주)에이스톰테크놀로지',
#   '직무': '[신입/경력] 소프트웨어 엔지니어 정규직 채용',
#   '경력사항': '경력무관',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['하드웨어·소프트웨어', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38609805'},
#  {'기업명': '커스토머인사이트',
#   '직무': 'DB 분석가 채용 (SQL)',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38689445'},
#  {'기업명': '(주)필라넷',
#   '직무': '㈜필라넷 각 부문별 인재 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 성동구',
#   '분류': "['IT·솔루션영업', '웹마스터·QA·테스터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38593486'},
#  {'기업명': '(주)빗썸코리아',
#   '직무': '빗썸 IT 전문인력 경력직 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹마스터·QA·테스터', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38688268'},
#  {'기업명': '(주)아워컴즈',
#   '직무': 'JAVA, 빅데이터(스마트저장소 데이터 변환), Back-end 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 구로구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38682958'},
#  {'기업명': '(주)스파이더랩',
#   '직무': '데이터 분석가',
#   '경력사항': '경력무관',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38685946'},
#  {'기업명': '(주)위메프',
#   '직무': '[플랫폼]NoSQL운영 및 기술지원 담당자',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38686506'},
#  {'기업명': '(주)휴네시온',
#   '직무': '2020년 휴네시온 신입/경력 채용공고',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['IT·솔루션영업', '영업기획·관리·지원']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38678812'},
#  {'기업명': '오티아이(주)',
#   '직무': '오티아이㈜ 각 부문 신입 및 경력직 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['총무·법무·사무', '사무보조·문서작성']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38660965'},
#  {'기업명': '(주)콜텍',
#   '직무': '전산직 인턴 직원 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직 · 인턴직',
#   '근무지': '서울 강서구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38673842'},
#  {'기업명': '디이엑스인포',
#   '직무': 'DB 관제업무 경력직 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 서초구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38685728'},
#  {'기업명': '원투씨엠(주)',
#   '직무': 'Java 서버 개발, 웹 개발 등 신입/경력 개발자 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38533730'},
#  {'기업명': '(주)데이타벅스',
#   '직무': '[경력] Oracle&SW(소프트웨어) 정규직/계약직 채용',
#   '경력사항': '3 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 이천시',
#   '분류': "['하드웨어·소프트웨어', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38685059'},
#  {'기업명': '(주)클래스액트',
#   '직무': '정밀의료시스템 개발을위한 풀스택 개발자 모집',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38684235'},
#  {'기업명': '가온데이터',
#   '직무': 'PPAS(DBA)운영관리자 모집(초, 중급기술자)',
#   '경력사항': '경력 4년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 프리랜서',
#   '근무지': '서울 서초구',
# ...
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38449022'},
#  {'기업명': '(주)유니마이크로테크놀러지',
#   '직무': 'MS-SQL 기술지원 엔지니어(경력)',
#   '경력사항': '신입 · 경력',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38448301'},
#  {'기업명': '슈퍼시스템(주)',
#   '직무': '(주)슈퍼시스템 개발자 채용',
#   '경력사항': '2 ~ 7년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 동작구',
#   '분류': "['응용프로그램개발', '퍼블리싱·UI개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38446763'},
#  {'기업명': '(주)플라밍고',
#   '직무': '백엔드 Java·JSP,JavaScript, API , 클라우드 개발 채용',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 광진구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38444129'},
#  {'기업명': '(주)플라밍고',
#   '직무': '웹개발, 응용프로그램개발 정규직/계약직 채용(인재선발)',
#   '경력사항': '신입 · 경력',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 광진구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38444106'},
#  {'기업명': '재팬리미트파이낸스(주)',
#   '직무': '[재팬리미트파이낸스] 웹개발 경력자',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38441606'},
#  {'기업명': '(주)인플러스',
#   '직무': '앱(Android, iOS) 프론트&백엔드 개발 프리랜서/계약직 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '계약직 · 프리랜서',
#   '근무지': '울산 남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38440228'},
#  {'기업명': '(주)인플러스',
#   '직무': '웹(PHP, JSP)/앱(Android, iOS) 프론트&백엔드 개발자 모집',
#   '경력사항': '3 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '울산 남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38440099'},
#  {'기업명': '씽킹블록체인(주)',
#   '직무': 'PHP 웹 개발자 모집 경력사원 채용 공고(정규직)',
#   '경력사항': '경력 3년↑',
#   '학력': '고졸↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38438745'},
#  {'기업명': '엠포플러스(주)',
#   '직무': '병역특례 보충역 개발자 모집',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 광진구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38438634'},
#  {'기업명': '(주)에이원플랫폼',
#   '직무': '[정규직/탄력근무제] 솔루션 웹 개발 모집',
#   '경력사항': '경력 4년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '퍼블리싱·UI개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38433434'},
#  {'기업명': '(주)네이블커뮤니케이션즈',
#   '직무': 'JAVA 서버개발자 경력직 채용',
#   '경력사항': '5 ~ 7년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38432996'},
#  {'기업명': '(주)포위즈시스템',
#   '직무': '[포위즈시스템] 2020년 하반기 경력자 채용',
#   '경력사항': '경력 1년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '대구 동구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38431194'},
#  {'기업명': '(주)다인리더스',
#   '직무': '(주)다인리더스 기획/컨설팅 직무 채용 공고',
#   '경력사항': '2 ~ 3년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 성동구',
#   '분류': "['기획·전략·경영', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38428797'},
#  {'기업명': '(주)청담홀딩스',
#   '직무': '[대전] [SI개발부] 웹프로그래머 경력직 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '대전 유성구',
#   '분류': "['웹개발', 'IT·디자인·컴퓨터교육']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38426538'},
#  {'기업명': '(주)소프트엔지니어소사이어티',
#   '직무': '(Java, Spring, Mybatis, Ajax 기반) 웹 프로그램 개발자 채용',
#   '경력사항': '경력 2년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38423306'},
#  {'기업명': '굿네트워크',
#   '직무': '[스타트업-방굿] IOS/안드로이드 개발자 채용',
#   '경력사항': '경력 7년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38421467'},
#  {'기업명': '(주)루나소프트',
#   '직무': '[㈜루나소프트] .net(닷넷) 개발 3년 이상 경력자 채용',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38419178'},
#  {'기업명': '(주)구루아이오티',
#   '직무': '[구루IOT] S/W 개발자 모집',
#   '경력사항': '경력 1년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38412563'},
#  {'기업명': '(주)티디아이',
#   '직무': '코로나19 여파에도 성장하는 (주)TDI 채용공고 - 기자',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38416616'},
#  {'기업명': '(주)세마그룹',
#   '직무': 'PHP(Laravel) 웹앱 개발 경력직 채용(급여 최고 대우)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '부산 부산진구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38414638'},
#  {'기업명': '(주)웨어밸리',
#   '직무': '소프트웨어(SW) 테스트(QA)경력자 모집',
#   '경력사항': '경력 2년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 마포구',
#   '분류': "['웹마스터·QA·테스터', '서버·네트워크·보안']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38413042'},
#  {'기업명': '(주)솔라테크',
#   '직무': '홈페이지 디자인 & 개발',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직 · 계약직',
#   '근무지': '경기 광명시',
#   '분류': "['웹개발', '퍼블리싱·UI개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38411916'},
#  {'기업명': '라온서치',
#   '직무': '대기업 경로탐색 분석시스템 개발 및 운영',
#   '경력사항': '4 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38708659'},
#  {'기업명': '(주)사람인에이치에스',
#   '직무': '(하림그룹/정규직)신입기준 월 300만, 대리이상 IT경력직 모집',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강동구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38636880'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[더기프팅컴퍼니] Data Engineer(경력 1~10년)',
#   '경력사항': '1 ~ 10년',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38708280'},
#  {'기업명': '(주)사람인에이치에스',
#   '직무': '[공공기관/월393만이상/나주]시스템개발센터 개발직원채용',
#   '경력사항': '경력무관',
#   '학력': '학력무관',
#   '근무형태': '계약직 · 파견직',
#   '근무지': '전남 나주시',
#   '분류': "['웹기획·PM', '웹개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38618418'},
#  {'기업명': '(주)HR컨설팅그룹',
#   '직무': 'User SW 로봇 어플리케이션 개발(대기업 계열사)',
#   '경력사항': '5 ~ 14년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['하드웨어·소프트웨어', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38707043'},
#  {'기업명': '(주)제이앤씨에이치알',
#   '직무': '(주)제이윈파트너스  채용공고 ( DBA,  JAVA,  Android, ios )',
#   '경력사항': '경력 5년↑',
#   '학력': '대학(2,3년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 송파구',
#   '분류': "['응용프로그램개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38705599'},
#  {'기업명': '(주)스카우트',
#   '직무': '병의원 의료정보 플랫폼 백엔드 개발자',
#   '경력사항': '경력 8년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38651604'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 최고 대기업 - 커머스/플랫폼 웹개발 (Back-End) - 최우대',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38705158'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 업계 최고 대기업 - 머신러닝 엔지니어 (이커머스 분야)',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38705150'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) Data Architect - 초일류 대기업 - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38705145'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 초일류 대기업 - Data Architect - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38705144'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 커머스/플랫폼 웹개발 (Back-End) - 최고 대기업 - 최우대',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38704978'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 백오피스 개발 (Java, NoSQL 등) - 최고 대기업 - 최우대',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38704966'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 커머스/플랫폼 백엔드 개발 (Java,Spring,AWS 등) -최우대',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38704925'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) (Java,Spring,AWS 등) 커머스/플랫폼 백엔드 개발 -최우대',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38704772'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 머신러닝 엔지니어 (이커머스 분야) - 업계 최고 대기업 -',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38704763'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) Data Modeler - 최고 대기업 - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38704739'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 최고 대기업 - 백오피스 개발 (Java, NoSQL 등) - 최우대',
#   '경력사항': '경력 5년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['서버·네트워크·보안', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38704619'},
#  {'기업명': '휴머레인컨설팅',
#   '직무': '긴급) 최고 대기업 - Data Modeler - 최우대',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA', '인공지능(AI)·빅데이터']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38704558'},
#  {'기업명': '(주)에이치알그룹',
#   '직무': '[앱 서비스 플랫폼 개발] java - 대기업 계열사',
#   '경력사항': '8 ~ 15년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['웹개발', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38670785'},
#  {'기업명': '(주)스카우트파트너스',
#   '직무': '클라우드 DB 관리(대리~ 과장급 ) 경력',
#   '경력사항': '5 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38650366'},
#  {'기업명': '(주)글로벌터치코리아',
#   '직무': '[애드테크 스타트업/급성장 기업] 데이터 사이언티스트 채용',
#   '경력사항': '경력 5년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38702672'},
#  {'기업명': '탑커리어인사이트',
#   '직무': 'DBA 경력직 채용 (경력 3년 이상)',
#   '경력사항': '경력 3년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38680060'},
#  {'기업명': '(주)HR컨설팅그룹',
#   '직무': '(IT 상장기업) EAI - SAP PI 운영 (과장급)',
#   '경력사항': '7 ~ 13년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38694784'},
#  {'기업명': '파워에이치알',
#   '직무': '[대기업 계열] 플랫폼 개발 경력자 채용',
#   '경력사항': '경력 7년↑',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '경기 성남시 분당구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38666335'},
#  {'기업명': '커리어커넥트(주)',
#   '직무': '대그룹계열 우량 IT기업 DBA  경력직 모집',
#   '경력사항': '3 ~ 9년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38642404'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'DBA 개발자/ BI / OLAP / ETL 경력',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38702176'},
#  {'기업명': '(주)코리아휴먼리소시스',
#   '직무': 'DBA 개발자',
#   '경력사항': '경력 3년↑',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 금천구',
#   '분류': "['웹개발', '응용프로그램개발']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38702169'},
#  {'기업명': '오픈포지션',
#   '직무': '데이터 엔지니어 / 대리,과장급/ 환경 가전 대기업',
#   '경력사항': '5 ~ 14년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 중구',
#   '분류': "['서버·네트워크·보안', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38697927'},
#  {'기업명': '서울외대스카우트',
#   '직무': 'SW엔지니어 (DB 빅데이터 / 1~3년)',
#   '경력사항': '신입 · 경력',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['전기·전자·제어', '하드웨어·소프트웨어']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38688289'},
#  {'기업명': '(주)더라이징스타헤딩',
#   '직무': '[헤딩머니100만원]글로벌소비재기업 데이터 엔지니어(과장급)',
#   '경력사항': '6 ~ 9년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38697341'},
#  {'기업명': '베스트네트워크㈜',
#   '직무': '16. [금융 생명보험사] 금융생명사 BI/DW 데이터마트 정규직 채',
#   '경력사항': '4 ~ 9년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['회계·재무·세무·IR', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38696204'},
#  {'기업명': '(주)투비파트너즈',
#   '직무': 'CRM 데이터분석',
#   '경력사항': '3 ~ 12년',
#   '학력': '대학교(4년)↑',
#   '근무형태': '정규직',
#   '근무지': '서울 서초구',
#   '분류': "['마케팅·광고·분석', '데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38668499'},
#  {'기업명': '(주)스카우트플랜',
#   '직무': 'DBA (DW 구축)',
#   '경력사항': '3 ~ 6년',
#   '학력': '학력무관',
#   '근무형태': '정규직',
#   '근무지': '서울 강남구',
#   '분류': "['데이터베이스·DBA']",
#   '분류필터': 'db',
#   '상세링크': 'http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38641650'},
#  ...]

# %%
job_list = job_list_cloud + job_list_python + job_list_db

# %%
# local db에 job_list 저장하기

import pymysql
import sqlalchemy
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("mysql+mysqldb://django:"+"poordjango"+"@poordb.cubqrb9xgtzf.us-east-1.rds.amazonaws.com/poor_db", encoding="utf-8")
conn = engine.connect()

jobs_df = pd.DataFrame(columns=['기업명', '직무', '경력사항', '학력', '근무형태', '근무지', '분류', '분류필터', '상세링크'])

for post in job_list:
    obj = pd.Series(post)
    jobs_df = jobs_df.append(obj, ignore_index=True)
    
jobs_df.to_sql(name="job_list", con=engine, if_exists='replace', index=True, index_label='id')

# %%
# # remote db(멀캠 컴퓨터)에 job_list 저장하기
# import pymysql
# import sqlalchemy
# pymysql.install_as_MySQLdb()
# from sqlalchemy import create_engine
# import pandas as pd

# engine = create_engine("mysql+mysqldb://root:"+"root"+"@localhost:3307/poor_db", encoding="utf-8")
# conn = engine.connect()

# jobs_dict = {"jobs_cloud": company_list_cloud, "jobs_python": company_list_python, "jobs_db": company_list_db}

# for table_name, jobs in jobs_dict.items():
#     print("\n", table_name, "\n")
#     jobs_df = pd.DataFrame(columns=['기업명', '직무', '경력사항', '학력', '근무형태', '근무지', '분류', '상세링크'])
    
#     for post in jobs:
#         obj = pd.Series(post)
#         jobs_df = jobs_df.append(obj, ignore_index=True)
#         print(post)
    
#     jobs_df.to_sql(name=table_name, con=engine, if_exists='replace', index=True, index_label='id')

# %%
# # Web Scrapping Function
# def scrapping(url_front, url_back, name):
#     page_num = 1
#     job_list = []
#     while True:
#         url = urljoin(url_front, str(page_num), url_back)
#         req_header = {
#         "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
#         }
#         html = requests.get(url, req_header).text
#         soup = BeautifulSoup(html, 'html.parser')

#         # 만약 더이상 페이지 리스트에 공고가 없을 경우 break
#         if soup.select('div.list_body div.list_item') == []:
#             break


#         for tag in soup.select('div.list_body div.list_item'):

#             # 기본정보
#             job_dict = {}
#             job_dict["기업명"] = tag.select('div.company_nm a span')[0].text
#             job_dict["직무"] = tag.select('div.notification_info a span')[0].text
#             job_dict["경력사항"] = tag.select('div.recruit_condition p.career')[0].text
#             job_dict["학력"] = tag.select('div.recruit_condition p.education')[0].text
#             job_dict["분류필터"] = name


#             # 근무형태 / 근무지 - 빈칸인 경우도 있음
#             try:
#                 job_dict["근무형태"] = tag.select('div.company_info p.employment_type')[0].text
#             except:
#                 job_dict["근무형태"] = ""
#             try:    
#                 job_dict["근무지"] = tag.select('div.company_info p.work_place')[0].text
#             except:
#                 job_dict["근무지"] = ""

#             # 분류는 여러가지가 있기 때문에 리스트 형태로 저장              
#             category_list = []
#             for item in tag.select('div.notification_info div.job_meta span span'):
#                 category_list.append(item.text)
#             job_dict["분류"] = str(category_list)

#             #상세 url
#             detail_url = tag.select_one('div.notification_info a').attrs['href']
#             full_detail_url = urljoin(main_url, detail_url)
#             job_dict["상세링크"] = full_detail_url
#             job_list.append(job_dict)
#         page_num += 1
