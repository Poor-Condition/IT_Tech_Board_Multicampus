# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from datetime import datetime, timedelta

# %%
def it_news_date_count(date):
    current_time = datetime.now()
    if date.endswith("전"):
        temp = date[0]
        published_date = current_time + timedelta(days=-int(temp))
        published_date = published_date.strftime("%Y.%m.%d")

    else:
        published_date = date

    return published_date

# %%
def get_it_news(it_news_main_url, fields):
    it_news_list = []

    for page_id in range(1, 8):
        params = {"page": page_id}

        it_news_res = requests.get(it_news_main_url, params=params)
        it_news_soup = BeautifulSoup(it_news_res.text, "html.parser")

        tags = it_news_soup.select(".row-fluid .contents-body div.list_")

        for tag in tags:
            it_news_dict = {}

            a_tags = tag.select_one("h4 a")
            img_tags = tag.select_one("div.list_image img.fit_image")
            text_tags = tag.select_one(".news_body_summary")

            news_link = urljoin("http://www.ciokorea.com/main/", a_tags["href"])

            if img_tags == None:
                img_link = "이미지 없음"
            else:
                img_link = urljoin("http://www.ciokorea.com/main/", img_tags["src"])

            date = tag.select_one(".list_time")
            news_published_date = it_news_date_count(str(date.text).strip())

            it_news_dict["분류"] = fields
            it_news_dict["제목"] = a_tags.text
            it_news_dict["링크"] = news_link
            it_news_dict["이미지"] = img_link
            it_news_dict["등록날짜"] = news_published_date
            it_news_dict["내용"] = str(text_tags.text).strip()

            it_news_list.append(it_news_dict)

    print(it_news_list, len(it_news_list))    

    return it_news_list

# %%
new_tech_list = get_it_news("http://www.ciokorea.com/t/557/%EC%8B%A0%EA%B8%B0%EC%88%A0%7C%EB%AF%B8%EB%9E%98?page=1", "신기술")
# Out:
# 형 서비스의 미래를 소개하였... ...'}, {'분류': '신기술', '제목': '‘속도와 범위, 혼잡도가 다르다’ 3가지 범위의 5G 주파수 따라잡기', '링크': 'http://www.ciokorea.com/t/557/%EC%8B%A0%EA%B8%B0%EC%88%A0%7C%EB%AF%B8%EB%9E%98/158736', '이미지': 'http://www.ciokorea.com/files/ciokr/2020/07/wave.110x60.jpg', '등록날짜': '2020.07.24', '내용': '5G가 사용하는 주파수 대역은 크게 3가지다. 이에 따라 커버리지와 속도에서 다른 특성을 가지며, 이는 기지국 배치 전략에 영향을 미친다.\xa0\n\n5G 기술은 이전 세대에 비해 크게 개선된 특징을 지닌다. 그리고 이러한 향상의 이면에는 오래된 물... ...'}, {'분류': '신기술', '제목': '내 눈은 늘 너를 향한다··· MS, 화상회의용 AI ‘아이 콘택트’ 기능 테스트 중', '링크': 'http://www.ciokorea.com/t/557/%EC%8B%A0%EA%B8%B0%EC%88%A0%7C%EB%AF%B8%EB%9E%98/158641', '이미지': 'http://www.ciokorea.com/files/ciokr/2020/07/EYE.110x60.jpg', '등록날짜': '2020.07.23', '내용': '마이크로소프트가 최신 윈도우 10 인사이더 빌드에서 색다른 기능을 소개했다. 화상 채팅 시 사용자의 시선이 마치 상대방을 향하는 것처럼 보이도록 하는 기능이다. AI를 이용해 구현되는 이 기능은 그러나 아주 일부의 테스터만 이용해볼 수 있으며, 향후 ... ...'}, {'분류': '신기술', '제목': '"다음 10년을 규정할 포스트 코로나 트렌드 5가지는..." 포레스터 보고서', '링크': 'http://www.ciokorea.com/t/557/%EC%8B%A0%EA%B8%B0%EC%88%A0%7C%EB%AF%B8%EB%9E%9
# ...

# %%
dev_list = get_it_news("http://www.ciokorea.com/t/21999/%EA%B0%9C%EB%B0%9C%EC%9E%90", "개발자")
# Out:
# ': '블로그 | 종착역에 도달한 윈도우 상의 PHP', '링크': 'http://www.ciokorea.com/t/21999/%EA%B0%9C%EB%B0%9C%EC%9E%90/158206', '이미지': 'http://www.ciokorea.com/files/itworld/2020/07_02/end_beginning_start_finish_stages_order_road_signs_direction_navigation_sequence_sequencing_by_gajus_gettyimages-464905528-100787194-large.110x60.jpg', '등록날짜': '2020.07.20', '내용': 'PHP는 나온 지 꽤 오랜 시간이 지났지만, 여전히 중요한 웹 개발 툴이다. 선언적 프로그래밍 모델을 기반으로 하는 PHP는 부가적인 명령과 함수로 익숙한 HTML 구문을 더 확장해서 웹 콘텐츠에 인라인 프로그래밍과 확장 기능을 추가한다. 이 모델은 ... ...'}, {'분류': '개발자', '제목': 'C++ 프로그래밍의 감초··· ‘인기 라이브러리 8선’', '링크': 'http://www.ciokorea.com/t/21999/%EA%B0%9C%EB%B0%9C%EC%9E%90/158051', '이미지': 'http://www.ciokorea.com/files/ciokr/2020/07/thumbup.110x60.jpg', '등록날짜': '2020.07.16', '내용': 'C++ 개발자들은 윈도우 앱, 모바일 앱, 머신러닝(ML) 및 과학 앱 등을 개발할 때 아래와 같은 라이브러리를 애용한다.\n\n범용 시스템 프로그래밍 언어인 C++은 1979년에 설계됐다. 이제 40살도 넘었다. 그래도 열기가 식기는커녕 여전히 여러 프... ...'}, {'분류': '개발자', '제목': '디에스랩글로벌, 인공지능 자동개발 솔루션 ‘클릭 AI’ 오픈 서비스 시작', '링크': 'http://www.ciokorea.com/t/21999/%EA%B0%9C%EB%
# ...

# %%
cloud_list = get_it_news("http://www.ciokorea.com/t/32/%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C", "클라우드")
# Out:
# 축해 주는 클라우드 기반 IDE 플랫폼이다.\xa0\n&nbs... ...'}, {'분류': '클라우드', '제목': '구글 자바 컨테이너 기술(Jib), 확장 프레임워크 공개 \xa0', '링크': 'http://www.ciokorea.com/t/32/%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C/161960', '이미지': 'http://www.ciokorea.com/files/ciokr/2020/08/GettyImages-1138820011.110x60.jpg', '등록날짜': '2020.08.25', '내용': '구글의 ‘지브(Jib)’를 사용하면 개발자가 자바 애플리케이션용 도커 컨테이너 생성을 최적화하고, 메이븐(Maven) 및 그래들(Gradle)용 플러그인을 사용자 정의해 프로세스를 조정할 수 있다.\xa0\n\n구글이 자바 애플리케이션용 지브 컨테이너... ...'}, {'분류': '클라우드', '제목': '시스코, CN-WAN 오픈소스 프로젝트 소개··· "SD-WAN과 쿠버네티스 연결"', '링크': 'http://www.ciokorea.com/t/32/%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C/161900', '이미지': 'http://www.ciokorea.com/files/ciokr/2020/08/GettyImages-1222690711.110x60.jpg', '등록날짜': '2020.08.24', '내용': '시스코가 클라우드 네이티브 SD-WAN 프로젝트를 통해 SD-WAN과 쿠버네티스 애플리케이션을 연결한다. 레이턴시를 최적화하고 데이터 패킷 손실을 줄이는 데 필요한 수작업을 절감하는 게 목적이다.\n\n시스코는 이번에 소개한 오픈소스 프로젝트가 SD-WA... ...'}, {'분류': '클라우드', '제목': '칼럼ㅣ2021년은 기업의 단절(disconnect) 원년이다', '링크': 'http://www.ciokorea.com/t/32/%ED%81%B4%EB%9D%BC%EC%9A%
# ...

# %%
iot_list = get_it_news("http://www.ciokorea.com/t/13931/IoT", "IoT")
# Out:
#  '내용': '삼성전자가 가장 높은 수준의 데이터 보안 등급을 획득한 스마트기기용 차세대 핵심 보안칩 ‘S3FV9RR’을 공개했다.\n\n삼성전자가 자체 개발한 보안 소프트웨어를 탑재한 이 제품은 ‘보안 국제 공통 평가 기준(Common Criteria, 이하 CC)’... ...'}, {'분류': 'IoT', '제목': '코비드-19 여파로 의료 IoT 공격 증가 ', '링크': 'http://www.ciokorea.com/t/13931/IoT/153612', '이미지': 'http://www.ciokorea.com/files/ciokr/2020/05/GettyImages-1199298380.110x60.jpg', '등록날짜': '2020.05.26', '내용': '코로나바이러스만으로 수용 능력의 한계에 도달한 미국 의료 시스템에 또 다른 위협이 등장했다. 바로 사이버공격이다. 특히 의료 IoT 장비와 네트워크를 노린 랜섬웨어 기반 사이버공격은 감염증 확산과 더불어 더욱 흔해지고 있다.\n\xa0\n\n\n포레스터 ... ...'}, {'분류': 'IoT', '제목': '펜타시큐리티, IoT 전용 암호모듈 ‘펜타 IOT-CC’ 출시', '링크': 'http://www.ciokorea.com/t/13931/IoT/153596', '이미지': '이미지 없음', '등록날짜': '2020.05.26', '내용': '펜타시큐리티시스템이 사물인터넷(IoT) 환경에 적합한 펌웨어 형태 암호모듈 ‘펜타 IoT-CC’를 출시했다고 밝혔다.\n\nIoT 보급으로 에너지 관리 효율화를 위해 각종 계량기에 IoT 기술을 융합한 스마트 미터링 사업이 활발하다. 현재 정부는 지능형 ... ...'}, {'분류': 'IoT', '제목': '엡손, 내장메모리와 디스플레이 SW 결합한 MCU 개발', '링크': 'http://www.ciokorea.com/t/13931/IoT/153545', '이미지': '이미지 없음', '등록날짜': '2020.05.26', '내용': '세이코엡손(
# ...

# %%
ai_list = get_it_news("http://www.ciokorea.com/t/22000/AI", "AI")
# Out:
# 31', '이미지': 'http://www.ciokorea.com/files/itworld/2020/08_01/0803_ai.110x60.png', '등록날짜': '2020.08.03', '내용': '셀바스 AI에 따르면 올해부터 경찰청 산하 모든 경찰서에 인공지능(AI) 기반 음성인식 기술을 활용한 ‘음성인식 기반 경찰청 성폭력 피해 조사 및 조서 작성 지원 시스템’이 구축된다.\n\n\n\n셀바스 AI는 경찰청이 자사 인공지능 음성기술을 활용해 수사관... ...'}, {'분류': 'AI', '제목': "엔비디아, 'MLperf AI' 벤치마크 테스트서 16개 부문 AI 성능 기록 경신", '링크': 'http://www.ciokorea.com/t/22000/AI/159260', '이미지': 'http://www.ciokorea.com/files/itworld/2020/07_02/0730_nvidia.110x60.jpg', '등록날짜': '2020.07.30', '내용': '최근 발표된 MLPerf AI 벤치마크 테스트 결과에 따르면\xa0엔비디아가 전 세계 상용 제품 중 가장 빠른 AI 훈련 성능을 기록했다.\n\xa0\n\n\n엔비디아는 A100 텐서 코어(Tensor Core) GPU가 8개의 모든 MLPerf 벤치... ...'}, {'분류': 'AI', '제목': '크라우드웍스, 전국 랜드마크 이미지 AI 학습용 데이터 구축 사업에 참여', '링크': 'http://www.ciokorea.com/t/22000/AI/159231', '이미지': '이미지 없음', '등록날짜': '2020.07.30', '내용': '크라우드웍스가 과학기술정보통신부 주관의 ‘딥페이크 방지영상’과 ‘랜드마크 이미지’의 AI 학습용 데이터 구축 사업을 진행한다고 밝혔다.\xa0\n\n이번 크라우드웍스가 추진하는 사업은 과기정통부가 AI 통합지원 플랫폼인 ‘AI허브(www.aihub.o... ...'}, {'분류': 'AI', '제목': "주니퍼 네트웍스, '4세대 AI 
# ...

# %%
security_list = get_it_news("http://www.ciokorea.com/t/37/%EB%B3%B4%EC%95%88", "보안")
# Out:
# 목': "코로나 고비는 넘겼지만... 6개월 안에 해야 할 '재택근무 보안 지침' 10가지", '링크': 'http://www.ciokorea.com/t/37/%EB%B3%B4%EC%95%88/162370', '이미지': 'http://www.ciokorea.com/files/ciokr/2020/08/GettyImages-1133544370.110x60.jpg', '등록날짜': '2020.08.27', '내용': '올해 초의 최우선 순위는 무엇보다 집에서도 필요한 애플리케이션에 안전하게 접근하는 것이었다. 그로부터 3~4개월이 지났다. 이제 재택근무가 새로운 현실로 자리 잡는 분위기다. 그렇다면 CIO 혹은 CSO가 앞으로 해야 할 일은 무엇일까?\xa0\n&... ...'}, {'분류': '보안', '제목': '표준 없는 하드웨어 기반 암호화···IBM, 인텔, AMD의 서로 다른 접근법', '링크': 'http://www.ciokorea.com/t/37/%EB%B3%B4%EC%95%88/162250', '이미지': 'http://www.ciokorea.com/files/itworld/2020/08_02/secured_conceptual_chain_of_hardware_circuitry_and_cpu_chips_within_a_network_of_connections_hardware_security_encryption_secure_processing_by_bet_noire_gettyimages-1191489807_cso_nw_2400x1600-100855186-large.110x60.jpg', '등록날짜': '2020.08.27', '내용': '전송되는 데이터를 암호화할 수 있다. 저장해 보관하는 데이터도 암호화할 수 있다. 그러나 암호화가 어려운 데이터가 있는데, 바로 사용하는 데이터이다. 문서에서 맞춤법을 검사하는 등 애플리케이션이 데이터를 처리하기 위해서는 데이터를 볼 수 있어야 한다.... ...'}, {'분류': '보안', '제목': '쿤텍, 해
# ...

# %%
devops_list = get_it_news("http://www.ciokorea.com/t/27240/%EB%8D%B0%EB%B8%8C%EC%98%B5%EC%8A%A4", "DevOps")
# Out:
# 0\n\n\n1996년 처음 발표된 COBIT(Control Objectives for I... ...'}, {'분류': 'DevOps', '제목': "'개발자부터 CIO까지' 2019년 英 IT급여 전망", '링크': 'http://www.ciokorea.com/t/27240/%EB%8D%B0%EB%B8%8C%EC%98%B5%EC%8A%A4/114498', '이미지': 'http://www.ciokorea.com/files/ciokr/2019/01/dreamstime_m_62152848_1.110x60.jpg', '등록날짜': '2019.01.09', '내용': '로버트 하프 테크놀로지(Robert Half Technology)의 IT급여 전망은 IT일자리에 대한 임금이 인상되고 있음을 보여준다.\n\n2019년 영국 내 IT종사자는 얼마를 벌게 될까? CIO, 네트워크 엔지니어, 모바일 개발자 등 어떤 직종이든 ... ...'}, {'분류': 'DevOps', '제목': "'데브옵스부터 데이터 과학까지' 2019년 고액 연봉 기대되는 IT직종은? ", '링크': 'http://www.ciokorea.com/t/27240/%EB%8D%B0%EB%B8%8C%EC%98%B5%EC%8A%A4/113727', '이미지': 'http://www.ciokorea.com/files/ciokr/2018/12/GettyImages-968859958.110x60.jpg', '등록날짜': '2018.12.24', '내용': '새해에 급여 인상을 원하나? 경력을 쌓으며 성장하는 데 돈만을 근거로 삼아서는 안 되지만, 돈은 분명 중요하다. 페이스케일(PayScale) 연봉 통계로 본 2019년 고액 연봉이 기대되는 IT직종을 소개한다.\xa0\n\xa0\n\n\n1. 데이터 ... ...'}, {'분류': 'DevOps', '제목': "아틀라시안, 지라옵스에 '장애 후 검토' 기능 추가", '링크': 'http://www.ciokorea.com/t/27240/%EB%8D%B0%
# ...

# %%
big_data_list = get_it_news("http://www.ciokorea.com/t/2996/%EB%B9%85%20%EB%8D%B0%EC%9D%B4%ED%84%B0", "빅데이터")
# Out:
# %EC%9D%B4%ED%84%B0/155745', '이미지': '이미지 없음', '등록날짜': '2020.06.18', '내용': '티맥스데이터와 지능형 인슈테크 플랫폼 기업 인슈로보가 함께 금융·보험 시장을 공략한다.\n\n티맥스데이터는 인슈로보와 인슈어테크(IT 기술을 활용한 혁신적인 보험 서비스) 융합플랫폼 서비스를 위한 업무 협약을 체결하고, 인슈로보의 핀테크 서비스와 티맥스의... ...'}, {'분류': '빅데이터', '제목': '칼럼ㅣ소프트웨어가 ‘밥상’을 먹어 치우고 있다', '링크': 'http://www.ciokorea.com/t/2996/%EB%B9%85%20%EB%8D%B0%EC%9D%B4%ED%84%B0/155664', '이미지': 'http://www.ciokorea.com/files/ciokr/2020/06/GettyImages-1130934413.110x60.jpg', '등록날짜': '2020.06.17', '내용': '‘소프트웨어가 세상을 먹어 치우고 있다(Software is eating the world).’ 이는 넷스케이프 창업자이자 실리콘밸리 벤처투자자인 마크 앤드리슨이 9년 전 월스트리트 저널 기고문을 통해 남긴 유명한 말이다.\xa0\n\n앤드리슨은 기고... ...'}, {'분류': '빅데이터', '제목': "'데이터 과학자' 영입보다 양성··· 한 제조서비스 회사의 업스킬링 사례", '링크': 'http://www.ciokorea.com/t/2996/%EB%B9%85%20%EB%8D%B0%EC%9D%B4%ED%84%B0/155352', '이미지': 'http://www.ciokorea.com/files/ciokr/2020/06/GettyImages-507072286.110x60.jpg', '등록날짜': '2020.06.15', '내용': '데이터 과학자 영입으로 고군분투했던 글로벌 제조 서비스 업체가 ‘시민 데이터 과학 프로그램(Citizen Data Science program)’이라는 카드를 꺼내들었다. 내부
# ...

# %%
news_link = dev_list+ cloud_list+ big_data_list+ ai_list+ iot_list+ devops_list+ security_list+ new_tech_list
news_link
# Out:
#  콘택트’ 기능 테스트 중',
#   '링크': 'http://www.ciokorea.com/t/557/%EC%8B%A0%EA%B8%B0%EC%88%A0%7C%EB%AF%B8%EB%9E%98/158641',
#   '이미지': 'http://www.ciokorea.com/files/ciokr/2020/07/EYE.110x60.jpg',
#   '등록날짜': '2020.07.23',
#   '내용': '마이크로소프트가 최신 윈도우 10 인사이더 빌드에서 색다른 기능을 소개했다. 화상 채팅 시 사용자의 시선이 마치 상대방을 향하는 것처럼 보이도록 하는 기능이다. AI를 이용해 구현되는 이 기능은 그러나 아주 일부의 테스터만 이용해볼 수 있으며, 향후 ... ...'},
#  {'분류': '신기술',
#   '제목': '"다음 10년을 규정할 포스트 코로나 트렌드 5가지는..." 포레스터 보고서',
#   '링크': 'http://www.ciokorea.com/t/557/%EC%8B%A0%EA%B8%B0%EC%88%A0%7C%EB%AF%B8%EB%9E%98/158591',
#   '이미지': 'http://www.ciokorea.com/files/ciokr/2020/07/covid-19_dreamstime_1_3.110x60.jpg',
#   '등록날짜': '2020.07.23',
#   '내용': '코로나19의 영향으로 나타난 5가지 트렌드가 기업과 기술을 영구히 바꿀 것이라고 포레스터가 진단했다. 이 리서치 기업이 발간한 ‘새롭고 불안정한 노멀’(New, Unstable Normal)이라는 제목의 보고서는 코로나19가 향후 10년 동안 초래할 ... ...'},
#  {'분류': '신기술',
#   '제목': '애플, 2030년까지 탄소 순배출량 ‘0’ 달성 계획 밝혀… 무탄소 알루미늄 맥북 제조도 포함',
# ...

# %%
import pymysql
import sqlalchemy
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("mysql+mysqldb://root:"+"root"+"@localhost:3307/it_wave_db", encoding="utf-8")
conn = engine.connect()

news_df = pd.DataFrame(columns=["제목", "링크", "이미지", "등록날짜", "분류", "내용"])


for article in news_link:
    obj = pd.Series(article)
    news_df = news_df.append(obj, ignore_index=True)
    print(article)
    news_df["article_like_count"]=0
    
news_df.to_sql(name="articles", con=engine, if_exists='append', index=False, index_label='id')
# Out:
# 스와 기술의 미래로서, 사이버 물리 시스템(CPS)으로 발전해가는 미래 정보통신 기술과 지능형 서비스의 미래를 소개하였... ...'}
# {'분류': '신기술', '제목': '‘속도와 범위, 혼잡도가 다르다’ 3가지 범위의 5G 주파수 따라잡기', '링크': 'http://www.ciokorea.com/t/557/%EC%8B%A0%EA%B8%B0%EC%88%A0%7C%EB%AF%B8%EB%9E%98/158736', '이미지': 'http://www.ciokorea.com/files/ciokr/2020/07/wave.110x60.jpg', '등록날짜': '2020.07.24', '내용': '5G가 사용하는 주파수 대역은 크게 3가지다. 이에 따라 커버리지와 속도에서 다른 특성을 가지며, 이는 기지국 배치 전략에 영향을 미친다.\xa0\n\n5G 기술은 이전 세대에 비해 크게 개선된 특징을 지닌다. 그리고 이러한 향상의 이면에는 오래된 물... ...'}
# {'분류': '신기술', '제목': '내 눈은 늘 너를 향한다··· MS, 화상회의용 AI ‘아이 콘택트’ 기능 테스트 중', '링크': 'http://www.ciokorea.com/t/557/%EC%8B%A0%EA%B8%B0%EC%88%A0%7C%EB%AF%B8%EB%9E%98/158641', '이미지': 'http://www.ciokorea.com/files/ciokr/2020/07/EYE.110x60.jpg', '등록날짜': '2020.07.23', '내용': '마이크로소프트가 최신 윈도우 10 인사이더 빌드에서 색다른 기능을 소개했다. 화상 채팅 시 사용자의 시선이 마치 상대방을 향하는 것처럼 보이도록 하는 기능이다. AI를 이용해 구현되는 이 기능은 그러나 아주 일부의 테스터만 이용해볼 수 있으며, 향후 ... ...'}
# ...
